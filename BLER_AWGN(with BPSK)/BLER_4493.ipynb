# %%
import numpy as np
from numpy.random import rand, randn, randint
import random
import matplotlib.pyplot as plt
from numpy import sqrt

# %% [markdown]
# ## Single AWE ANcode Decoder(A=53)

# %%
def AN_decoder53(residue,quotient):
    s_re=str(residue)
    msg={
        "1": lambda quotient: quotient,
        "2": lambda quotient: quotient,
        "4": lambda quotient: quotient,
        "8": lambda quotient: quotient,
        "16": lambda quotient: quotient,
        "32": lambda quotient: quotient,
        "11": lambda quotient: quotient-1,
        "22": lambda quotient: quotient-2,
        "44": lambda quotient: quotient-4,
        "35": lambda quotient: quotient-9,
        "17": lambda quotient: quotient-19,
        "34": lambda quotient: quotient-38,
        "15": lambda quotient: quotient-77,
        "30": lambda quotient: quotient-154,
        "7": lambda quotient: quotient-309,
        "14": lambda quotient: quotient-618,
        "28": lambda quotient: quotient-1236,
        "3": lambda quotient: quotient-2473,
        "6": lambda quotient: quotient-4946,
        "12": lambda quotient: quotient-9892,
        "24": lambda quotient: quotient-19784,
        "48": lambda quotient: quotient-39568,
        "43": lambda quotient: quotient-79137,
        "33": lambda quotient: quotient-158275,
        "13": lambda quotient: quotient-316551,
        "26": lambda quotient: quotient-633102,
        "52": lambda quotient: quotient+1,
        "51": lambda quotient: quotient+1,
        "49": lambda quotient: quotient+1,
        "45": lambda quotient: quotient+1,
        "37": lambda quotient: quotient+1,
        "21": lambda quotient: quotient+1,
        "42": lambda quotient: quotient+2,
        "31": lambda quotient: quotient+3,
        "9": lambda quotient: quotient+5,
        "18": lambda quotient: quotient+10,
        "36": lambda quotient: quotient+20,
        "19": lambda quotient: quotient+39,
        "38": lambda quotient: quotient+78,
        "23": lambda quotient: quotient+155,
        "46": lambda quotient: quotient+310,
        "39": lambda quotient: quotient+619,
        "25": lambda quotient: quotient+1237,
        "50": lambda quotient: quotient+2474,
        "47": lambda quotient: quotient+4947,
        "41": lambda quotient: quotient+9893,
        "29": lambda quotient: quotient+19785,
        "5": lambda quotient: quotient+39569,
        "10": lambda quotient: quotient+79138,
        "20": lambda quotient: quotient+158276,
        "40": lambda quotient: quotient+316552,
        "27": lambda quotient: quotient+633103,
        "0" :lambda quotient: quotient,
    }[s_re](quotient)
    msg
    return int(msg)

def Barret_q_53(x):
    x = np.int64(x)
    q = (x * 39568) >> 21
    r = x - q * 53
    if r < 53:
        return (r,q)
    else:
        return (r-53,q+1)

# %%
# 傳遞資料為0~32767(15-bits)的無號數整數
message=[]
message_count=1000000
for i in range(message_count):
    message.append(random.randint(0,32767))

## A=53乘積編碼
codeword53=[]
for element in message:
    codeword53.append(element*53)
    
#turn *53 into binary
codeword53_bin=[]
for ele in codeword53:
    s='{0:021b}'.format(ele)
    codeword53_bin.append(s)
#codeword53_bin


#can be replaced by np.reshape
bit53_part=[]
for c_bin in codeword53_bin:
    for single_bit in c_bin:
            bit53_part.append(int(single_bit))
#transmition bit
tran53=[]
for b in bit53_part:
    if b==1:
        tran53.append(sqrt(1))
    else:
        tran53.append(-sqrt(1))

# %%
N = message_count*21
EbNodB_range = range(0,19)
itr = len(EbNodB_range)
print(itr)
ber = [None]*itr
uncode_ber=[None]*itr
bler=[None]*itr

two_d_array_bler53=[None]*itr
q_ber53=[None]*itr
# Out:
# 19

# %%
#transmission part 
for n in range (0, itr): 
    EbNodB = EbNodB_range[n]   
    EbNo=10.0**(EbNodB/10.0)
    #input
    uncode_bit = 2 * (rand(N) >= 0.5) - 1
    x53=tran53  
    
    #AWGN
    noise_std = 1/sqrt(2*EbNo)
    ## 雜訊強度增加2倍
    noise_std *= 2
    uncode_bit_noise=uncode_bit + noise_std * randn(N)

    y53 = x53 + noise_std * randn(N)
    #BPSK decode
    ###### AN code receive decode for A=13 ##########
    y53_d = 2 * (y53 >= 0) - 1    
    receive53=[]
    for receive_bit in y53_d:
        if(receive_bit==1):
            receive53.append(1)
        else:
            receive53.append(0)
    ################################################
    

    ########### uncode_receive decode##############
    uncode_bit_receive = 2 * (uncode_bit_noise >= 0) - 1
    uncode_receive_decode=[]
    for receive_bit in uncode_bit_receive:
        if(receive_bit==1):
            uncode_receive_decode.append(1)
        else:
            uncode_receive_decode.append(-1)
    ############################################
    

    #reshape
    temp53 = np.reshape(receive53, (message_count,21))
    #bit to decimal
    receive53_decimal = []
    

    for ele in temp53:
        int_out=0
        for ind,val in enumerate (ele):        
            int_out=2**(20-ind)*val+int_out
        receive53_decimal.append(int_out)

    # 2d array 
    decode53_num_msg=[]
    decode53_num_codeword=[]
    q53_check_list=[]
    #10x10x2 array
    for i in range(10000):
        receive53_decimal_100=[]
        receive53_decimal_100=receive53_decimal[0+100*i:100+100*i]

        rq_table=np.zeros((10,10,2),int)
        
        r53_list=[]
        q53_list=[]

        for ele in receive53_decimal_100:
            r,q=Barret_q_53(ele)
            r53_list.append(r)
            q53_list.append(q)

            q53_check_list.append(q)
            
        #put r,q into 3d rq array table
        for i in range(100):
            rq_table[i//10,i%10]=[r53_list[i],q53_list[i]]  

        error53_row=[]
        error53_col=[]
        for i in range(10):
            s_r53=sum(rq_table[i,:,0]) #sum of residue at i row
            s_c53=sum(rq_table[:,i,0]) #sum of residue at i colunm
            error53_row.append(s_r53)
            error53_col.append(s_c53)
        #turn into true false
        for ind,val in enumerate(error53_row):
            if(val!=0):
                error53_row[ind]=True
            else:
                error53_row[ind]=False

        for ind,val in enumerate(error53_col):
            if(val!=0):
                error53_col[ind]=True
            else:
                error53_col[ind]=False
        #find error location and return the first value to ANdecoder
        true_false_table53_for_row_col=np.zeros((10,10),bool)
        # row and colunm to find error location
        for i in range(10):
            for j in range(10):
                true_false_table53_for_row_col[i,j]=error53_row[i] and error53_col[j]

        true_false_table53_for_row_col=true_false_table53_for_row_col.reshape(100,1)
        error_index_from_TF53_table=-1
        #find the fisrt error location and return index value to ANdecoder
        for ind,ele in enumerate(true_false_table53_for_row_col):
            if(ele):
                error_index_from_TF53_table=ind
                break

        if(error_index_from_TF53_table==-1):
            decode53_msg100=q53_list
            decode53_num_msg.extend(decode53_msg100)
            #print(len(decode53_num_msg),"no error")
        else:
            #correct the error value and return msg
            error_codeword=receive53_decimal_100[error_index_from_TF53_table]
            r,q=Barret_q_53(error_codeword)
            corrected_value=AN_decoder53(r,q)
            q53_list[ind]=corrected_value
            decode53_msg100=q53_list
            decode53_num_msg.extend(decode53_msg100)
            #print(len(decode13_num_msg),"error")
    

   
    ## 2d BLER #########################
    BLER53_ERROR=0
    for c in range(len(decode53_num_msg)):
        if(decode53_num_msg[c] !=message[c]):
            BLER53_ERROR=BLER53_ERROR+1  
    two_d_array_bler53[n] =1.0 * BLER53_ERROR / message_count
    ########################################
    #uncode BER
    uncode_error =(uncode_bit !=uncode_receive_decode).sum()
    uncode_ber[n]=1.*uncode_error/N
    
    q53_num=0
    for i in range(len(decode53_num_msg)):
        if(message[i]!=q53_check_list[i]):
            q53_num=q53_num+1

    q_ber53[n]=1.*q53_num/len(decode53_num_msg)
    



    
    print ("EbNodB:", EbNodB)
    print("Uncoded Error probability", uncode_ber[n])
    print ("Error probability without decoder:", q_ber53[n] )
    print ("Error probability with decoder A=53:", two_d_array_bler53[n] )
# Out:
# EbNodB: 0
# Uncoded Error probability 0.23977814285714286
# Error probability without decoder: 0.989835
# Error probability with decoder A=53: 0.989663
# EbNodB: 1
# Uncoded Error probability 0.21382809523809523
# Error probability without decoder: 0.982503
# Error probability with decoder A=53: 0.982172
# EbNodB: 2
# Uncoded Error probability 0.18670085714285714
# Error probability without decoder: 0.970106
# Error probability with decoder A=53: 0.969519
# EbNodB: 3
# Uncoded Error probability 0.15877742857142857
# Error probability without decoder: 0.948359
# Error probability with decoder A=53: 0.947426
# EbNodB: 4
# Uncoded Error probability 0.13110723809523808
# Error probability without decoder: 0.912231
# Error probability with decoder A=53: 0.91081
# EbNodB: 5
# Uncoded Error probability 0.10431804761904762
# Error probability without decoder: 0.853193
# Error probability with decoder A=53: 0.851086
# EbNodB: 6
# Uncoded Error probability 0.07899547619047619
# Error probability without decoder: 0.765215
# Error probability with decoder A=53: 0.762409
# EbNodB: 7
# Uncoded Error probability 0.056662619047619045
# Error probability without decoder: 0.644548
# Error probability with decoder A=53: 0.641291
# EbNodB: 8
# Uncoded Error probability 0.03784357142857143
# Error probability without decoder: 0.496735
# Error probability with decoder A=53: 0.493611
# EbNodB: 9
# Uncoded Error probability 0.023101619047619048
# Error probability without decoder: 0.342282
# Error probability with decoder A=53: 0.339667
# EbNodB: 10
# Uncoded Error probability 0.012632666666666667
# Error probability without decoder: 0.204529
# Error probability with decoder A=53: 0.202455
# EbNodB: 11
# Uncoded Error probability 0.006047
# Error probability without decoder: 0.10359
# Error probability with decoder A=53: 0.101658
# EbNodB: 12
# Uncoded Error probability 0.002445285714285714
# Error probability without decoder: 0.043722
# Error probability with decoder A=53: 0.040766
# EbNodB: 13
# Uncoded Error probability 0.000784
# Error probability without decoder: 0.01423
# Error probability with decoder A=53: 0.009427
# EbNodB: 14
# Uncoded Error probability 0.00019504761904761905
# Error probability without decoder: 0.003471
# Error probability with decoder A=53: 0.000869
# EbNodB: 15
# Uncoded Error probability 3.604761904761905e-05
# Error probability without decoder: 0.000673
# Error probability with decoder A=53: 3.6e-05
# EbNodB: 16
# Uncoded Error probability 4.666666666666666e-06
# Error probability without decoder: 8.3e-05
# Error probability with decoder A=53: 0.0
# EbNodB: 17
# Uncoded Error probability 2.380952380952381e-07
# Error probability without decoder: 6e-06
# Error probability with decoder A=53: 0.0
# EbNodB: 18
# Uncoded Error probability 0.0
# Error probability without decoder: 0.0
# Error probability with decoder A=53: 0.0

# %%
print(two_d_array_bler53)
# Out:
# [0.989663, 0.982172, 0.969519, 0.947426, 0.91081, 0.851086, 0.762409, 0.641291, 0.493611, 0.339667, 0.202455, 0.101658, 0.040766, 0.009427, 0.000869, 3.6e-05, 0.0, 0.0, 0.0]

# %%
#two_d_BLER13=plt.plot( EbNodB_range, two_d_array_bler13, 'r',label="2_d_BLER(A=13) ")
two_d_BLER53=plt.plot( EbNodB_range, two_d_array_bler53, 'b',label="2_d_BLER(A=53) ")
only_q53=plt.plot( EbNodB_range, q_ber53, 'y',label="only q ber bler")
uncode_ber_line=plt.plot(EbNodB_range,uncode_ber,'g',label="uncode")

#hamming_ber_line=plt.plot(EbNodB_range, hamming_ber, 'y',label="(7,4)hamming_ber")
plt.legend()
#plt.plot(EbNodB_range, an_decode_ber, 'b')
plt.axis([0, itr, 1e-6, 1])
plt.xscale('linear')
plt.yscale('log')
plt.xlabel('EbNo(dB)')
plt.ylabel('BER')
plt.grid(True)
plt.title('BPSK Modulation for 15-bits data')
plt.savefig("BPSK with A=53(15bits)")
plt.show()

# %% [markdown]
# ### 使用查找表更正
# * Function Definition

# %%
import math
import numpy as np

def decimal_to_binary(decimal_number):
    if decimal_number == 0:
        return "0"
    # 處理正數：直接轉換
    if decimal_number > 0:
        return bin(decimal_number)[2:]  # 移除 "0b" 前綴
       # 處理負數：自動計算所需位元數（2's complement）
    abs_value = abs(decimal_number)
    bits = abs_value.bit_length() + 1  # 負數多一個符號位元
    two_complement_value = (1 << bits) + decimal_number
    
    return bin(two_complement_value)[2:]  # 移除 "0b" 前綴

def bits_needed(number):
    if number < 0:
        raise ValueError("2's complement is not available")  # 如果輸入負數，拋出錯誤
    if number == 0:
        return 1  # 0 需要 1 個位元
    
    # 計算位元數
    bits = math.floor(math.log2(number)) + 1
    return bits

def bits_range(bits, signed=False):     ## 可選擇設定 有號數 或 無號數
    if bits <= 0:
        return "位元數必須為正整數！"
    
    if signed:
        # 二補數範圍: -2^(bits-1) 到 2^(bits-1)-1
        min_value = -(2**(bits - 1))
        max_value = 2**(bits - 1) - 1
    else:
        # 無符號範圍: 0 到 2^bits - 1
        min_value = 0
        max_value = 2**bits - 1

    return min_value, max_value

## 把重複的 AWE 去除
def remove_duplicates(input_list):
    unique_list = []
    for number in input_list:
        if number not in unique_list:
            unique_list.append(number)
    return sorted(unique_list)

def custom_mod(a, b):
    if b == 0:
        return "錯誤：除數不能為零！"
    # 計算商和餘數，修正餘數計算邏輯
    quotient = a // b
    remainder = a - b * quotient
    # 修正負餘數的情況
    if remainder > 0 and a < 0:
        remainder -= abs(b)
        quotient += 1
    return remainder

def remainder_unique(input_list):
    # 使用集合判斷元素是否有重複
    return len(input_list) == len(set(input_list))


def create_mapping(source_list, address_map):
    """
    建立值到位址和位址到值的雙向映射。
    若 address_map 中某位址沒有對應值，則該位址的值為 0。
    
    參數:
    source_list (list): 原始資料列表。
    address_map (list): 位址映射列表。
    
    回傳:
    tuple: (值到位址的映射, 位址到值的映射)
    """
    # 初始化值到位址的映射
    value_to_address = {value: addr for value, addr in zip(source_list, address_map)}
    
    # 初始化位址到值的映射，未指定的位址預設為 0
    max_address = max(address_map)  # 確保涵蓋所有位址
    address_to_value = {addr: 0 for addr in range(max_address + 1)}  # 預設為 0
    for value, addr in zip(source_list, address_map):
        address_to_value[addr] = value  # 更新有指定值的位址

    return value_to_address, address_to_value
def decimal_to_binary(decimal_number):
    if decimal_number == 0:
        return "0"
    # 處理正數：直接轉換
    if decimal_number > 0:
        return bin(decimal_number)[2:]  # 移除 "0b" 前綴
       # 處理負數：自動計算所需位元數（2's complement）
    abs_value = abs(decimal_number)
    bits = abs_value.bit_length() + 1  # 負數多一個符號位元
    two_complement_value = (1 << bits) + decimal_number
    
    return bin(two_complement_value)[2:]  # 移除 "0b" 前綴

def bits_needed(number):
    if number < 0:
        raise ValueError("2's complement is not available")  # 如果輸入負數，拋出錯誤
    if number == 0:
        return 1  # 0 需要 1 個位元
    
    # 計算位元數
    bits = math.floor(math.log2(number)) + 1
    return bits

def bits_range(bits, signed=False):     ## 可選擇設定 有號數 或 無號數
    if bits <= 0:
        return "位元數必須為正整數！"
    
    if signed:
        # 二補數範圍: -2^(bits-1) 到 2^(bits-1)-1
        min_value = -(2**(bits - 1))
        max_value = 2**(bits - 1) - 1
    else:
        # 無符號範圍: 0 到 2^bits - 1
        min_value = 0
        max_value = 2**bits - 1

    return min_value, max_value

## 把重複的 AWE 去除
def remove_duplicates(input_list):
    unique_list = []
    for number in input_list:
        if number not in unique_list:
            unique_list.append(number)
    return sorted(unique_list)

def custom_mod(a, b):
    if b == 0:
        return "錯誤：除數不能為零！"
    # 計算商和餘數，修正餘數計算邏輯
    quotient = a // b
    remainder = a - b * quotient
    # 修正負餘數的情況
    if remainder > 0 and a < 0:
        remainder -= abs(b)
        quotient += 1
    return remainder

def remainder_unique(input_list):
    # 使用集合判斷元素是否有重複
    return len(input_list) == len(set(input_list))

# %%
### 輸入數值為data, ANcode的A為AN
### 乘完A後的數值為 input
data = 32767
AN = 4493     ## AN:4493 只適用輸入為0~32767
input = data*AN
bits = bits_needed(input)

### 1-bit AWE:
AWE_1=[]
e1=0     ## 錯誤數量
e1_data=[]
for i in range(0, bits):
    AWE_1.insert(e1 , input + 2**i)
    e1_data.insert(e1, 2**i)
    e1 = e1 + 1
    AWE_1.insert(e1 , input - 2**i)
    e1_data.insert(e1, -2**i)
    e1 = e1 + 1
    
### 2-bit AWE:
AWE_2=[]
e2=0     ## 錯誤數量
p=0      ## 錯誤位置
e2_data=[]
for i in range(0, bits):
    for j in range(i+1, bits):
        AWE_2.insert(e2 , (input + 2**i + 2**j))
        e2_data.insert(e2 , (2**i + 2**j))        
        print(f"第 {e2} 筆錯誤資料: {AWE_2[e2]}")
        print(f"第 {e2} 筆算術錯誤: {e2_data[e2]}")
        e2 = e2 + 1
        AWE_2.insert(e2 , (input + 2**i - 2**j))
        e2_data.insert(e2 , (2**i - 2**j))        
        print(f"第 {e2} 筆錯誤資料: {AWE_2[e2]}")
        print(f"第 {e2} 筆算術錯誤: {e2_data[e2]}")
        e2 = e2 + 1
        AWE_2.insert(e2 , (input - 2**i + 2**j))
        e2_data.insert(e2 , (-2**i + 2**j))                
        print(f"第 {e2} 筆錯誤資料: {AWE_2[e2]}")
        print(f"第 {e2} 筆算術錯誤: {e2_data[e2]}")
        e2 = e2 + 1
        AWE_2.insert(e2 , (input - 2**i -2**j))
        e2_data.insert(e2 , (-2**i - 2**j))
        print(f"第 {e2} 筆錯誤資料: {AWE_2[e2]}")
        print(f"第 {e2} 筆算術錯誤: {e2_data[e2]}")
        e2 = e2 + 1
        p = p + 1
        
## 把list:AWE_1 和 list:AWE_2合併
AWE = AWE_1 + AWE_2
e_total = e1_data + e2_data
## 把重複的 AWE 去除
new_AWE = remove_duplicates(AWE)
new_e_total = remove_duplicates(e_total)
AWE_count = np.size(new_AWE)
e_count = np.size(new_e_total)

### 模AN, 使用一般mod函數和 Barret reduction 比較
remainder = []
for m in range(0,AWE_count):
    mod = custom_mod(new_AWE[m], AN)
    remainder.append(mod)

print("錯誤資料對AN取完模數:\n",remainder)

##############################################################
### Barret reduction ###
def Barret_q_4493(x):
    x = np.int64(x)      
    q = (x * 59745 ) >> 28        ## (2^28)//4493後, 右移28次 
    r = x - q * 4493
    if r < 4493:
        return (r,q)
    else:
        return (r - 4493,q+1)
    
Barret_remainder = []
for m in range(0,AWE_count):
    Barret_r,Barret_q = Barret_q_4493(new_AWE[m])
    Barret_remainder.append(Barret_r)
    
print("Barret reduction對錯誤資料取完模數:\n",Barret_remainder)
print("Barret reduction是否可以使用:", Barret_remainder == remainder)
#################################################################
print("所有餘數(一般mod函數)是否完全相異:", remainder_unique(remainder))
print("所有餘數(Barret reduction)是否完全相異:", remainder_unique(Barret_remainder))
print("所有的AWE:\n", new_e_total)
print(np.size(remainder))

### 建立錯誤映射表(LUT)
## Decoder
AWE_to_remainder, remainder_to_AWE = create_mapping(new_e_total, Barret_remainder)

## example
example_r1 = Barret_remainder[0]
example_r2 = Barret_remainder[1]
print(f"輸入餘數 {example_r1}, 對應算術錯誤: {remainder_to_AWE[example_r1]}")
print(f"輸入餘數 {example_r2}, 對應算術錯誤: {remainder_to_AWE[example_r2]}")

Raw_data1 = new_AWE[0]-remainder_to_AWE[example_r1]
Raw_data2 = new_AWE[1]-remainder_to_AWE[example_r2]
print(Raw_data1)
print(Raw_data2)
print("更正是否正確:", input == Raw_data1)
# Out:
# 第 0 筆錯誤資料: 147222134
# 第 0 筆算術錯誤: 3
# 第 1 筆錯誤資料: 147222130
# 第 1 筆算術錯誤: -1
# 第 2 筆錯誤資料: 147222132
# 第 2 筆算術錯誤: 1
# 第 3 筆錯誤資料: 147222128
# 第 3 筆算術錯誤: -3
2097156, -2097154, -2097153, -2097152, -2097151, -2097150, -2097148, -2097144, -2097136, -2097120, -2097088, -2097024, -2096896, -2096640, -2096128, -2095104, -2093056, -2088960, -2080768, -2064384, -2031616, -1966080, -1835008, -1572864, -1310720, -1179648, -1114112, -1081344, -1064960, -1056768, -1052672, -1050624, -1049600, -1049088, -1048832, -1048704, -1048640, -1048608, -1048592, -1048584, -1048580, -1048578, -1048577, -1048576, -1048575, -1048574, -1048572, -1048568, -1048560, -1048544, -1048512, -1048448, -1048320, -1048064, -1047552, -1046528, -1044480, -1040384, -1032192, -1015808, -983040, -917504, -786432, -655360, -589824, -557056, -540672, -532480, -528384, - ...
# 1462
# 輸入餘數 245, 對應算術錯誤: -201326592
# 輸入餘數 953, 對應算術錯誤: -167772160
# 147222131
# 147222131
# 更正是否正確: True

# %% [markdown]
# ## 使用查找表更正2-bits Error 的BLER

# %%
# 傳遞資料為0~32767(15-bits)的無號數整數
message=[]
message_count=1000000
for i in range(message_count):
    message.append(random.randint(0,32767))

## DEC_AN=4493乘積編碼
codeword4493=[]
for element in message:
    codeword4493.append(element*4493)
    
#turn *4493 into binary
codeword4493_bin=[]
for ele in codeword4493:
    s='{0:028b}'.format(ele)
    codeword4493_bin.append(s)
#codeword1939_bin


#can be replaced by np.reshape
bit4493_part=[]
for c_bin in codeword4493_bin:
    for single_bit in c_bin:
            bit4493_part.append(int(single_bit))
#transmition bit
tran4493=[]
for b in bit4493_part:
    if b==1:
        tran4493.append(sqrt(1))
    else:
        tran4493.append(-sqrt(1))

# %%
N = message_count*28
EbNodB_range = range(0,19)
itr = len(EbNodB_range)
print(itr)
ber = [None]*itr
uncode_ber=[None]*itr
bler=[None]*itr

two_d_array_bler4493=[None]*itr
q_ber4493=[None]*itr
# Out:
# 19

# %%
#transmission part 
for n in range (0, itr): 
    EbNodB = EbNodB_range[n]   
    EbNo=10.0**(EbNodB/10.0)
    #input
    uncode_bit = 2 * (rand(N) >= 0.5) - 1
    x4493 = tran4493  
    
    #AWGN
    noise_std = 1/sqrt(2*EbNo)
    ## 雜訊強度增加2倍
    noise_std *= 2
    uncode_bit_noise=uncode_bit + noise_std * randn(N)

    y4493 = x4493 + noise_std * randn(N)
    #BPSK decode
    ###### AN code receive decode for A=4493 ##########
    y4493_d = 2 * (y4493 >= 0) - 1    
    receive4493=[]
    for receive_bit in y4493_d:
        if(receive_bit==1):
            receive4493.append(1)
        else:
            receive4493.append(0)
    ################################################
    

    ########### uncode_receive decode##############
    uncode_bit_receive = 2 * (uncode_bit_noise >= 0) - 1
    uncode_receive_decode=[]
    for receive_bit in uncode_bit_receive:
        if(receive_bit==1):
            uncode_receive_decode.append(1)
        else:
            uncode_receive_decode.append(-1)
    ############################################
    

    #reshape
    temp4493 = np.reshape(receive4493, (message_count, 28))
    
    #bit to decimal
    receive4493_decimal = []
    for ele in temp4493:
        int_out=0
        for ind,val in enumerate (ele):        
            int_out=2**(27-ind)*val+int_out
        receive4493_decimal.append(int_out)

    # 2d array 
    decode4493_num_msg=[]
    decode4493_num_codeword=[]
    q4493_check_list=[]
    #100x100x2 array
    for i in range(10000):
        receive4493_decimal_100=[]
        receive4493_decimal_100=receive4493_decimal[0+100*i:100+100*i]

        rq_table=np.zeros((10,10,2),int)
        
        r4493_list=[]
        q4493_list=[]

        for ele in receive4493_decimal_100:
            r,q=Barret_q_4493(ele)
            r4493_list.append(r)
            q4493_list.append(q)

            q4493_check_list.append(q)
            
        #put r,q into 3d rq array table
        for i in range(100):
            rq_table[i//10,i%10]=[r4493_list[i],q4493_list[i]]  

        error4493_row=[]
        error4493_col=[]
        for i in range(10):
            s_r4493=sum(rq_table[i,:,0]) #sum of residue at i row
            s_c4493=sum(rq_table[:,i,0]) #sum of residue at i colunm
            error4493_row.append(s_r4493)
            error4493_col.append(s_c4493)
        #turn into true false
        for ind,val in enumerate(error4493_row):
            if(val!=0):
                error4493_row[ind]=True
            else:
                error4493_row[ind]=False

        for ind,val in enumerate(error4493_col):
            if(val!=0):
                error4493_col[ind]=True
            else:
                error4493_col[ind]=False
        #find error location and return the first value to ANdecoder
        true_false_table4493_for_row_col=np.zeros((10,10),bool)
        # row and colunm to find error location
        for i in range(10):
            for j in range(10):
                true_false_table4493_for_row_col[i,j]=error4493_row[i] and error4493_col[j]

        true_false_table4493_for_row_col=true_false_table4493_for_row_col.reshape(100,1)
        error_index_from_TF4493_table=-1
        #find the fisrt error location and return index value to ANdecoder
        for ind,ele in enumerate(true_false_table4493_for_row_col):
            if(ele):
                error_index_from_TF4493_table=ind
                break

        if(error_index_from_TF4493_table==-1):
            decode4493_msg100=q4493_list
            decode4493_num_msg.extend(decode4493_msg100)
            #print(len(decode1939_num_msg),"no error")
        else:
            #correct the error value and return msg
            error_codeword=receive4493_decimal_100[error_index_from_TF4493_table]
            r,q=Barret_q_4493(error_codeword)
            ### using LUT to recovery it 
            RAW_DATA = error_codeword - remainder_to_AWE[r]
            ### mod 4493 to get correct data
            corrected_r,corrected_q = Barret_q_4493(RAW_DATA)
            q4493_list[ind]=corrected_q
            decode4493_msg100=q4493_list
            decode4493_num_msg.extend(decode4493_msg100)
            #print(len(decode13_num_msg),"error")
    

   
    ## 2d BLER #########################
    BLER4493_ERROR=0
    for c in range(len(decode4493_num_msg)):
        if(decode4493_num_msg[c] !=message[c]):
            BLER4493_ERROR=BLER4493_ERROR+1  
    two_d_array_bler4493[n] =1.0 * BLER4493_ERROR / message_count
    ########################################
    ### uncode BER
    uncode_error =(uncode_bit !=uncode_receive_decode).sum()
    uncode_ber[n]=1.*uncode_error/N
    ########################################
    ### no decoder for AN
    q4493_num=0
    for i in range(len(decode4493_num_msg)):
        if(message[i]!=q4493_check_list[i]):
            q4493_num=q4493_num+1

    q_ber4493[n]=1.*q4493_num/len(decode4493_num_msg)
    



    
    print ("EbNodB:", EbNodB)
    print("Uncoded Error probability", uncode_ber[n])
    print ("Error probability without decoder:", q_ber4493[n] )
    print ("Error probability with decoder A=4493:", two_d_array_bler4493[n] )
# Out:
# EbNodB: 0
# Uncoded Error probability 0.2397505357142857
# Error probability without decoder: 0.991638
# Error probability with decoder A=4493: 0.991393
# EbNodB: 1
# Uncoded Error probability 0.21382875
# Error probability without decoder: 0.986369
# Error probability with decoder A=4493: 0.985887
# EbNodB: 2
# Uncoded Error probability 0.18664564285714286
# Error probability without decoder: 0.976221
# Error probability with decoder A=4493: 0.975369
# EbNodB: 3
# Uncoded Error probability 0.15911
# Error probability without decoder: 0.959645
# Error probability with decoder A=4493: 0.958254
# EbNodB: 4
# Uncoded Error probability 0.13126292857142857
# Error probability without decoder: 0.930748
# Error probability with decoder A=4493: 0.928461
# EbNodB: 5
# Uncoded Error probability 0.10425789285714286
# Error probability without decoder: 0.882749
# Error probability with decoder A=4493: 0.879259
# EbNodB: 6
# Uncoded Error probability 0.07909335714285715
# Error probability without decoder: 0.805555
# Error probability with decoder A=4493: 0.801048
# EbNodB: 7
# Uncoded Error probability 0.056700071428571426
# Error probability without decoder: 0.694215
# Error probability with decoder A=4493: 0.68917
# EbNodB: 8
# Uncoded Error probability 0.03784942857142857
# Error probability without decoder: 0.550395
# Error probability with decoder A=4493: 0.545719
# EbNodB: 9
# Uncoded Error probability 0.023123928571428573
# Error probability without decoder: 0.388784
# Error probability with decoder A=4493: 0.385044
# EbNodB: 10
# Uncoded Error probability 0.012685392857142857
# Error probability without decoder: 0.236771
# Error probability with decoder A=4493: 0.234346
# EbNodB: 11
# Uncoded Error probability 0.0060508571428571425
# Error probability without decoder: 0.121396
# Error probability with decoder A=4493: 0.119618
# EbNodB: 12
# Uncoded Error probability 0.0024345
# Error probability without decoder: 0.051181
# Error probability with decoder A=4493: 0.048901
# EbNodB: 13
# Uncoded Error probability 0.0007879642857142857
# Error probability without decoder: 0.017114
# Error probability with decoder A=4493: 0.012873
# EbNodB: 14
# Uncoded Error probability 0.00019942857142857143
# Error probability without decoder: 0.004356
# Error probability with decoder A=4493: 0.001413
# EbNodB: 15
# Uncoded Error probability 3.492857142857143e-05
# Error probability without decoder: 0.000781
# Error probability with decoder A=4493: 4.9e-05
# EbNodB: 16
# Uncoded Error probability 3.964285714285714e-06
# Error probability without decoder: 9.4e-05
# Error probability with decoder A=4493: 0.0
# EbNodB: 17
# Uncoded Error probability 2.857142857142857e-07
# Error probability without decoder: 8e-06
# Error probability with decoder A=4493: 0.0
# EbNodB: 18
# Uncoded Error probability 3.571428571428571e-08
# Error probability without decoder: 0.0
# Error probability with decoder A=4493: 0.0

# %%
two_d_BLER53=plt.plot( EbNodB_range, two_d_array_bler53, 'r',label="SingleAWE_2d(A=53) ")
two_d_BLER4493=plt.plot( EbNodB_range, two_d_array_bler4493, 'b',label="DoubleAWE_2d(A=4493) ")
only_q4493=plt.plot( EbNodB_range, q_ber4493, 'y',label="Without Decoder")
uncode_ber_line=plt.plot(EbNodB_range,uncode_ber,'g',label="uncode")

plt.legend()
plt.axis([0, itr, 1e-7, 1])
plt.xscale('linear')
plt.yscale('log')
plt.xlabel('EbNo(dB)')
plt.ylabel('BER')
plt.grid(True)
plt.title('BPSK Modulation')
plt.savefig("BPSK with 4493(15bits)")
plt.show()
