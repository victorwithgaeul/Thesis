# %% [markdown]
# ## 分析加法,乘法運算時底層硬體電路受到白雜訊 (SNR) 干擾發生的錯誤

# %% [markdown]
# * AER (Arithmetic Error Rate): 1bit 發生加錯或減錯的機率 (like BER)
# * CER (Carry Error Rate): Carry(進位) 受到影響而發生錯誤的機率
# * RER (Register Error Rate): 整個資料的發生錯誤的機率 (like BLER)

# %% [markdown]
# #### 加法: 以全加器 --> Ripple-Carry-Adder 模擬

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import rand, randn, randint
import random
import scipy
from scipy.stats import truncnorm
import math
from numpy import sqrt

a, b = 0, 1  # 範圍限制在 0 ~ 1
mean = 0.2   # 平均值
std = 0.1    # 標准差
data = truncnorm.rvs((a - mean) / std, (b - mean) / std, loc=mean, scale=std, size=10000)

### 輸出直方圖
plt.hist(data, bins=50, density=True, alpha=0.6)
plt.title(f"Truncated Normal Distribution (mean={mean}, std={std})")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

### 計算實際標準差
print("實際標準差:", np.std(data))   
print(np.random.normal(0, 0.2))
# Out:
# 實際標準差: 0.09267001960457757
# 0.12341515452324235

# %%
def fast_truncated_normal(mean, std, low, high, size):
    result = []
    while len(result) < size:
        samples = np.random.normal(loc=mean, scale=std, size=size)
        accepted = samples[(samples >= low) & (samples <= high)]
        result.extend(accepted)
    return np.array(result[:size])  # 裁切到精確大小

a, b = 0, 1     # 截斷範圍
mean = 0.2
std = 0.1
size = 10000

data = fast_truncated_normal(mean, std, a, b, size)

# 繪圖
plt.hist(data, bins=50, density=True, alpha=0.6)
plt.title(f"Fast Truncated Normal (mean={mean}, std={std})")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# 標準差
print("實際標準差:", np.std(data))
# Out:
# 實際標準差: 0.09496561934676995

# %%
def truncated_normal_sample(mean, std, low, high):
    while True:
        x = np.random.normal(mean, std)
        if low <= x <= high:
            return x
        
sample = truncated_normal_sample(mean=0.2, std=0.1, low=0, high=1)
print("Sample:", sample)
# Out:
# Sample: 0.3208553916450554

# %% [markdown]
# #### Uncode example:

# %%
### 50bits + 50bits
Range_Max_number = 1125899906842623
bits = math.floor(math.log2(Range_Max_number)) + 1

def simulate_adder_noise(A, B, sigma, threshold=0.42):
    """
    模擬 Ripple-Carry-Adder,計算 A + B
    - A, B: bits位數值
    - sigma: 高斯白雜訊的標準差
    - threshold: 當雜訊超過此值，翻轉該位元
    回傳值: 最終結果 (包含可能的溢位)
    """
    carry_in = 0
    
    result_bits = []
    
    for i in range(bits):
        a_bit = (A >> i) & 1
        b_bit = (B >> i) & 1
        
        #### 所有1-bit加法器邏輯閘, 以及模擬雜訊 ####
        XOR_AB = a_bit ^ b_bit
        ### 引入高斯白雜訊
        noise_XOR_AB = truncated_normal_sample(mean=0.2, std=sigma, low=0, high=1)
        # 如果雜訊絕對值超過 threshold，翻轉該位
        if abs(noise_XOR_AB) > threshold:
            XOR_AB = XOR_AB ^ 1            #翻轉 XOR_AB
        
        sum_out = XOR_AB ^ carry_in
        noise_sum = truncated_normal_sample(mean=0.2, std=sigma, low=0, high=1)
        if abs(noise_sum) > threshold:
            sum_out = sum_out ^ 1           #翻轉 sum_out
            
        AND_AB = a_bit & b_bit
        noise_AND_AB = truncated_normal_sample(mean=0.2, std=sigma, low=0, high=1)
        if abs(noise_AND_AB) > threshold:
            AND_AB = AND_AB ^ 1             #翻轉 AND_AB
        
        AND_Cin = XOR_AB & carry_in
        noise_AND_Cin = truncated_normal_sample(mean=0.2, std=sigma, low=0, high=1)
        if abs(noise_AND_Cin) > threshold:
            AND_Cin = AND_Cin ^ 1           #翻轉 AND_Cin
            
        carry_out = AND_AB | AND_Cin
        noise_carry = truncated_normal_sample(mean=0.2, std=sigma, low=0, high=1)
        if abs(noise_carry) > threshold:
            carry_out = carry_out ^ 1       #翻轉 carry_out
        
        result_bits.append(sum_out)
        carry_in = carry_out                #傳遞到下一個位元
    
    # 第5位 (溢位)
    result_bits.append(carry_in)
        
    # 將 result_bits (list) 組合成整數
    final_result = 0
    for i, bit_val in enumerate(result_bits):
        final_result |= (bit_val << i)
    
    return final_result

def noise_simulation(trials=100000, sigma=0.2, threshold=0.42):
    
    error_count = 0
    for _ in range(trials):
        A = random.randint(0, Range_Max_number)     # 隨機整數 A
        B = random.randint(0, Range_Max_number)     # 隨機整數 B
        correct_result = A + B                      # 正確答案
        result = simulate_adder_noise(A, B, sigma, threshold)
        if result != correct_result:
            error_count += 1
    
    uncode_error_rate = error_count / trials
    return uncode_error_rate

if __name__ == "__main__":
    # 參數設定
    uncode_list = []
    trials = 200000                             # 模擬次數
    EbNodB_range = range(12,23)
    itr = len(EbNodB_range)
    threshold = 0.42                             # 當雜訊超過此值時翻轉
    
    for n in range (0, itr): 
        EbNodB = EbNodB_range[n]   
        EbNo=10.0**(EbNodB/10.0)
        noise_std = 1/sqrt(2*EbNo)
        uncode_error_rate = noise_simulation(trials=trials, sigma=noise_std, threshold=threshold)
        uncode_list.append(uncode_error_rate)
        print(f"SNR={EbNodB}, Noise_std={noise_std}, Error Rate={uncode_error_rate:.5f}")
# Out:
# SNR=12, Noise_std=0.17761719292909026, Error Rate=1.00000
# SNR=13, Noise_std=0.15830148982673414, Error Rate=1.00000
# SNR=14, Noise_std=0.1410863513160464, Error Rate=1.00000
# SNR=15, Noise_std=0.12574334296829354, Error Rate=0.99995
# SNR=16, Noise_std=0.11206887238456492, Error Rate=0.99667
# SNR=17, Noise_std=0.09988148764833452, Error Rate=0.95976
# SNR=18, Noise_std=0.08901946956877224, Error Rate=0.78943
# SNR=19, Noise_std=0.07933868576533668, Error Rate=0.47300
# SNR=20, Noise_std=0.07071067811865475, Error Rate=0.19340
# SNR=21, Noise_std=0.06302095820932435, Error Rate=0.05507
# SNR=22, Noise_std=0.05616748812614789, Error Rate=0.01041

# %%
print(uncode_list)
# Out:
# [1.0, 1.0, 1.0, 0.99995, 0.996665, 0.959765, 0.789425, 0.473, 0.193405, 0.055075, 0.01041]

# %% [markdown]
# #### Single AWE ANcode Decoder(A=131)

# %%
def A131_AN_decoder(residue):
    msg = {  
        1: +2**0,
        2: +2**1,
        4: +2**2,
        8: +2**3,
        16: +2**4,
        32: +2**5,
        64: +2**6,
        128: +2**7,
        125: +2**8,
        119: +2**9,
        107: +2**10,
        83: +2**11,
        35: +2**12,
        70: +2**13,
        9: +2**14,
        18: +2**15,
        36: +2**16,
        72: +2**17,
        13: +2**18,
        26: +2**19,
        52: +2**20,
        104: +2**21,
        77: +2**22,
        23: +2**23,
        46: +2**24,
        92: +2**25,
        53: +2**26,
        106: +2**27,
        81: +2**28,
        31: +2**29,
        62: +2**30,
        124: +2**31,
        117: +2**32,
        103: +2**33,
        75: +2**34,
        19: +2**35,
        38: +2**36,
        76: +2**37,
        21: +2**38,
        42: +2**39,
        84: +2**40,
        37: +2**41,
        74: +2**42,
        17: +2**43,
        34: +2**44,
        68: +2**45,
        5: +2**46,
        10: +2**47,
        20: +2**48,
        40: +2**49,
        80: +2**50,
        29: +2**51,
        58: +2**52,
        116: +2**53,
        101: +2**54,
        71: +2**55,
        11: +2**56,
        22: +2**57,
        44: +2**58,
        88: +2**59,
        45: +2**60,
        90: +2**61,
        49: +2**62,
        98: +2**63,
        65: +2**64,
        130: -2**0,
        129: -2**1,
        127: -2**2,
        123: -2**3,
        115: -2**4,
        99: -2**5,
        67: -2**6,
        3: -2**7,
        6: -2**8,
        12: -2**9,
        24: -2**10,
        48: -2**11,
        96: -2**12,
        61: -2**13,
        122: -2**14,
        113: -2**15,
        95: -2**16,
        59: -2**17,
        118: -2**18,
        105: -2**19,
        79: -2**20,
        27: -2**21,
        54: -2**22,
        108: -2**23,
        85: -2**24,
        39: -2**25,
        78: -2**26,
        25: -2**27,
        50: -2**28,
        100: -2**29,
        69: -2**30,
        7: -2**31,
        14: -2**32,
        28: -2**33,
        56: -2**34,
        112: -2**35,
        93: -2**36,
        55: -2**37,
        110: -2**38,
        89: -2**39,
        47: -2**40,
        94: -2**41,
        57: -2**42,
        114: -2**43,
        97: -2**44,
        63: -2**45,
        126: -2**46,
        121: -2**47,
        111: -2**48,
        91: -2**49,
        51: -2**50,
        102: -2**51,
        73: -2**52,
        15: -2**53,
        30: -2**54,
        60: -2**55,
        120: -2**56,
        109: -2**57,
        87: -2**58,
        43: -2**59,
        86: -2**60,
        41: -2**61,
        82: -2**62,
        33: -2**63,
        66: -2**64,
        0: 0,
    }
    return msg.get(residue, 0)  # 預設為 0，避免 None



def Barret_q_131(x):
    q = (int(x) * 4400463758041400) >> 59       ## (2^59)//131後, 右移59次         
    r = x - q * 131
    if r < 131:
        return (r,q)
    else:
        return (r - 131, q + 1)

# %% [markdown]
# #### Conventional SEC_ANcode:

# %%
SEC_A = 131
Range_Max_number = 1125899906842623
SEC_Range_Max_number = 1125899906842623 * SEC_A
SEC_A_bits = math.floor(math.log2(SEC_Range_Max_number)) + 1
print(SEC_A_bits)
# Out:
# 58

# %%
def simulate_adder_noise(A, B, sigma, threshold=0.42):
    """
    模擬 Ripple-Carry-Adder,計算 A + B
    - A, B: bits位數值
    - sigma: 高斯白雜訊的標準差
    - threshold: 當雜訊超過此值，翻轉該位元
    回傳值: 最終結果 (包含可能的溢位)
    """
    carry_in = 0
    
    result_bits = []
    
    for i in range(SEC_A_bits):
        a_bit = (A >> i) & 1
        b_bit = (B >> i) & 1
        
        #### 所有1-bit加法器邏輯閘, 以及模擬雜訊 ####
        XOR_AB = a_bit ^ b_bit
        ### 引入高斯白雜訊
        noise_XOR_AB = truncated_normal_sample(mean=0.2, std=sigma, low=0, high=1)
        # 如果雜訊絕對值超過 threshold，翻轉該位
        if abs(noise_XOR_AB) > threshold:
            XOR_AB = XOR_AB ^ 1            #翻轉 XOR_AB
        
        sum_out = XOR_AB ^ carry_in
        noise_sum = truncated_normal_sample(mean=0.2, std=sigma, low=0, high=1)
        if abs(noise_sum) > threshold:
            sum_out = sum_out ^ 1           #翻轉 sum_out
            
        AND_AB = a_bit & b_bit
        noise_AND_AB = truncated_normal_sample(mean=0.2, std=sigma, low=0, high=1)
        if abs(noise_AND_AB) > threshold:
            AND_AB = AND_AB ^ 1             #翻轉 AND_AB
        
        AND_Cin = XOR_AB & carry_in
        noise_AND_Cin = truncated_normal_sample(mean=0.2, std=sigma, low=0, high=1)
        if abs(noise_AND_Cin) > threshold:
            AND_Cin = AND_Cin ^ 1           #翻轉 AND_Cin
            
        carry_out = AND_AB | AND_Cin
        noise_carry = truncated_normal_sample(mean=0.2, std=sigma, low=0, high=1)
        if abs(noise_carry) > threshold:
            carry_out = carry_out ^ 1       #翻轉 carry_out
        
        result_bits.append(sum_out)
        carry_in = carry_out                #傳遞到下一個位元
    
    # 第5位 (溢位)
    result_bits.append(carry_in)
        
    # 將 result_bits (list) 組合成整數
    final_result = 0
    for i, bit_val in enumerate(result_bits):
        final_result |= (bit_val << i)
    
    return final_result

def noise_simulation(trials=100000, sigma=0.2, threshold=0.42):
        
    error_count = 0
    for _ in range(trials):
        A = random.randint(0, Range_Max_number)  # 隨機整數 A
        B = random.randint(0, Range_Max_number)  # 隨機整數 B
        correct_result = A + B                   
        SEC_AN_A = A * SEC_A
        SEC_AN_B = B * SEC_A
        result_withA = simulate_adder_noise(SEC_AN_A, SEC_AN_B, sigma, threshold)
        result_dividebyA = result_withA // SEC_A
        if result_dividebyA != correct_result:
            r,q = Barret_q_131(result_withA)
            RAW_DATA = int(result_withA) - int(A131_AN_decoder(r))
            corrected_r,corrected_value = Barret_q_131(RAW_DATA)
            if corrected_value != correct_result:
                error_count += 1
    
    SEC_error_rate = error_count / trials
    return SEC_error_rate

if __name__ == "__main__":
    # 參數設定
    SEC_AN_list = []
    trials = 200000                             # 模擬次數
    EbNodB_range = range(12,23)
    itr = len(EbNodB_range)
    threshold = 0.42                             # 當雜訊超過此值時翻轉
    
    for n in range (0, itr): 
        EbNodB = EbNodB_range[n]   
        EbNo=10.0**(EbNodB/10.0)
        noise_std = 1/sqrt(2*EbNo)
        SEC_error_rate = noise_simulation(trials=trials, sigma=noise_std, threshold=threshold)
        SEC_AN_list.append(SEC_error_rate)
        print(f"SNR={EbNodB}, Noise_std={noise_std}, Error Rate={SEC_error_rate:.6f}")
# Out:
# SNR=12, Noise_std=0.17761719292909026, Error Rate=1.000000
# SNR=13, Noise_std=0.15830148982673414, Error Rate=1.000000
# SNR=14, Noise_std=0.1410863513160464, Error Rate=0.999995
# SNR=15, Noise_std=0.12574334296829354, Error Rate=0.999585
# SNR=16, Noise_std=0.11206887238456492, Error Rate=0.988215
# SNR=17, Noise_std=0.09988148764833452, Error Rate=0.870725
# SNR=18, Noise_std=0.08901946956877224, Error Rate=0.518185
# SNR=19, Noise_std=0.07933868576533668, Error Rate=0.161180
# SNR=20, Noise_std=0.07071067811865475, Error Rate=0.024635
# SNR=21, Noise_std=0.06302095820932435, Error Rate=0.001845
# SNR=22, Noise_std=0.05616748812614789, Error Rate=0.000065

# %%
print(SEC_AN_list)
# Out:
# [1.0, 1.0, 0.999995, 0.999585, 0.988215, 0.870725, 0.518185, 0.16118, 0.024635, 0.001845, 6.5e-05]

# %% [markdown]
# ### 使用查找表更正: DEC_ANcode, A = 50861
# * Function Definition

# %%
import math
import numpy as np

def decimal_to_binary(decimal_number):
    if decimal_number == 0:
        return "0"
    # 處理正數：直接轉換
    if decimal_number > 0:
        return bin(decimal_number)[2:]  # 移除 "0b" 前綴
       # 處理負數：自動計算所需位元數（2's complement）
    abs_value = abs(decimal_number)
    bits = abs_value.bit_length() + 1  # 負數多一個符號位元
    two_complement_value = (1 << bits) + decimal_number
    
    return bin(two_complement_value)[2:]  # 移除 "0b" 前綴

def bits_needed(number):
    if number < 0:
        raise ValueError("2's complement is not available")  # 如果輸入負數，拋出錯誤
    if number == 0:
        return 1  # 0 需要 1 個位元
    
    # 計算位元數
    bits = math.floor(math.log2(number)) + 1
    return bits

def bits_range(bits, signed=False):     ## 可選擇設定 有號數 或 無號數
    if bits <= 0:
        return "位元數必須為正整數！"
    
    if signed:
        # 二補數範圍: -2^(bits-1) 到 2^(bits-1)-1
        min_value = -(2**(bits - 1))
        max_value = 2**(bits - 1) - 1
    else:
        # 無符號範圍: 0 到 2^bits - 1
        min_value = 0
        max_value = 2**bits - 1

    return min_value, max_value

## 把重複的 AWE 去除
def remove_duplicates(input_list):
    unique_list = []
    for number in input_list:
        if number not in unique_list:
            unique_list.append(number)
    return sorted(unique_list)

def custom_mod(a, b):
    if b == 0:
        return "錯誤：除數不能為零！"
    # 計算商和餘數，修正餘數計算邏輯
    quotient = a // b
    remainder = a - b * quotient
    # 修正負餘數的情況
    if remainder > 0 and a < 0:
        remainder -= abs(b)
        quotient += 1
    return remainder

def remainder_unique(input_list):
    # 使用集合判斷元素是否有重複
    return len(input_list) == len(set(input_list))


def create_mapping(source_list, address_map):
    """
    建立值到位址和位址到值的雙向映射。
    若 address_map 中某位址沒有對應值，則該位址的值為 0。
    
    參數:
    source_list (list): 原始資料列表。
    address_map (list): 位址映射列表。
    
    回傳:
    tuple: (值到位址的映射, 位址到值的映射)
    """
    # 初始化值到位址的映射
    value_to_address = {value: addr for value, addr in zip(source_list, address_map)}
    
    # 初始化位址到值的映射，未指定的位址預設為 0
    max_address = max(address_map)  # 確保涵蓋所有位址
    address_to_value = {addr: 0 for addr in range(max_address + 1)}  # 預設為 0
    for value, addr in zip(source_list, address_map):
        address_to_value[addr] = value  # 更新有指定值的位址

    return value_to_address, address_to_value
def decimal_to_binary(decimal_number):
    if decimal_number == 0:
        return "0"
    # 處理正數：直接轉換
    if decimal_number > 0:
        return bin(decimal_number)[2:]  # 移除 "0b" 前綴
       # 處理負數：自動計算所需位元數（2's complement）
    abs_value = abs(decimal_number)
    bits = abs_value.bit_length() + 1  # 負數多一個符號位元
    two_complement_value = (1 << bits) + decimal_number
    
    return bin(two_complement_value)[2:]  # 移除 "0b" 前綴

def bits_needed(number):
    if number < 0:
        raise ValueError("2's complement is not available")  # 如果輸入負數，拋出錯誤
    if number == 0:
        return 1  # 0 需要 1 個位元
    
    # 計算位元數
    bits = math.floor(math.log2(number)) + 1
    return bits

def bits_range(bits, signed=False):     ## 可選擇設定 有號數 或 無號數
    if bits <= 0:
        return "位元數必須為正整數！"
    
    if signed:
        # 二補數範圍: -2^(bits-1) 到 2^(bits-1)-1
        min_value = -(2**(bits - 1))
        max_value = 2**(bits - 1) - 1
    else:
        # 無符號範圍: 0 到 2^bits - 1
        min_value = 0
        max_value = 2**bits - 1

    return min_value, max_value

## 把重複的 AWE 去除
def remove_duplicates(input_list):
    unique_list = []
    for number in input_list:
        if number not in unique_list:
            unique_list.append(number)
    return sorted(unique_list)

def custom_mod(a, b):
    if b == 0:
        return "錯誤：除數不能為零！"
    # 計算商和餘數，修正餘數計算邏輯
    quotient = a // b
    remainder = a - b * quotient
    # 修正負餘數的情況
    if remainder > 0 and a < 0:
        remainder -= abs(b)
        quotient += 1
    return remainder

def remainder_unique(input_list):
    # 使用集合判斷元素是否有重複
    return len(input_list) == len(set(input_list))

# %%
### 輸入數值為data, ANcode的A為AN
### 乘完A後的數值為 input
data = 1125899906842623
AN =  50861    ## AN:50861, 只適用輸入為0 ~ 1125899906842623
input = data*AN
bits = bits_needed(input)

### 1-bit AWE:
AWE_1=[]
e1=0     ## 錯誤數量
e1_data=[]
for i in range(0, bits):
    AWE_1.insert(e1 , input + 2**i)
    e1_data.insert(e1, 2**i)
    e1 = e1 + 1
    AWE_1.insert(e1 , input - 2**i)
    e1_data.insert(e1, -2**i)
    e1 = e1 + 1
    
### 2-bit AWE:
AWE_2=[]
e2=0     ## 錯誤數量
p=0      ## 錯誤位置
e2_data=[]
for i in range(0, bits):
    for j in range(i+1, bits):
        AWE_2.insert(e2 , (input + 2**i + 2**j))
        e2_data.insert(e2 , (2**i + 2**j))        
        print(f"第 {e2} 筆錯誤資料: {AWE_2[e2]}")
        print(f"第 {e2} 筆算術錯誤: {e2_data[e2]}")
        e2 = e2 + 1
        AWE_2.insert(e2 , (input + 2**i - 2**j))
        e2_data.insert(e2 , (2**i - 2**j))        
        print(f"第 {e2} 筆錯誤資料: {AWE_2[e2]}")
        print(f"第 {e2} 筆算術錯誤: {e2_data[e2]}")
        e2 = e2 + 1
        AWE_2.insert(e2 , (input - 2**i + 2**j))
        e2_data.insert(e2 , (-2**i + 2**j))                
        print(f"第 {e2} 筆錯誤資料: {AWE_2[e2]}")
        print(f"第 {e2} 筆算術錯誤: {e2_data[e2]}")
        e2 = e2 + 1
        AWE_2.insert(e2 , (input - 2**i -2**j))
        e2_data.insert(e2 , (-2**i - 2**j))
        print(f"第 {e2} 筆錯誤資料: {AWE_2[e2]}")
        print(f"第 {e2} 筆算術錯誤: {e2_data[e2]}")
        e2 = e2 + 1
        p = p + 1
        
## 把list:AWE_1 和 list:AWE_2合併
AWE = AWE_1 + AWE_2
e_total = e1_data + e2_data
## 把重複的 AWE 去除
new_AWE = remove_duplicates(AWE)
new_e_total = remove_duplicates(e_total)
AWE_count = np.size(new_AWE)
e_count = np.size(new_e_total)

### 模AN, 使用一般mod函數和 Barret reduction 比較
remainder = []
for m in range(0,AWE_count):
    mod = new_AWE[m] % AN
    remainder.append(mod)

print("錯誤資料對AN取完模數:\n",remainder)

##############################################################
### Barret reduction ###
def Barret_q_50861(x):      
    q = (int(x) * 2901514964111527) >> 67        ## (2^67)//50861, 右移67次 
    r = x - q * 50861
    if r < 50861:
        return (r,q)
    else:
        return (r - 50861, q + 1)
    
Barret_remainder = []
for m in range(0,AWE_count):
    Barret_r,Barret_q = Barret_q_50861(new_AWE[m])
    Barret_remainder.append(Barret_r)
    
print("Barret reduction對錯誤資料取完模數:\n",Barret_remainder)
print("Barret reduction是否可以使用:", Barret_remainder == remainder)
#################################################################
print("所有餘數(一般mod函數)是否完全相異:", remainder_unique(remainder))
print("所有餘數(Barret reduction)是否完全相異:", remainder_unique(Barret_remainder))
print("所有的AWE:\n", new_e_total)
print(np.size(remainder))

### 建立錯誤映射表(LUT)
## Decoder
AWE_to_remainder, remainder_to_AWE = create_mapping(new_e_total, Barret_remainder)

## example
example_r1 = Barret_remainder[0]
example_r2 = Barret_remainder[1]
print(f"輸入餘數 {example_r1}, 對應算術錯誤: {remainder_to_AWE[example_r1]}")
print(f"輸入餘數 {example_r2}, 對應算術錯誤: {remainder_to_AWE[example_r2]}")

Raw_data1 = new_AWE[0]-remainder_to_AWE[example_r1]
Raw_data2 = new_AWE[1]-remainder_to_AWE[example_r2]
print(Raw_data1)
print(Raw_data2)
print("更正是否正確:", input == Raw_data1)
# Out:
# 第 0 筆錯誤資料: 57264395161922648406
# 第 0 筆算術錯誤: 3
# 第 1 筆錯誤資料: 57264395161922648402
# 第 1 筆算術錯誤: -1
# 第 2 筆錯誤資料: 57264395161922648404
# 第 2 筆算術錯誤: 1
# 第 3 筆錯誤資料: 57264395161922648400
# 第 3 筆算術錯誤: -3
# 第 4 筆錯誤資料: 57264395161922648408
# 第 4 筆算術錯誤: 5
# 第 5 筆錯誤資料: 57264395161922648400
# 第 5 筆算術錯誤: -3
# 第 6 筆錯誤資料: 57264395161922648406
# 第 6 筆算術錯誤: 3
# 第 7 筆錯誤資料: 57264395161922648398
# 第 7 筆算術錯誤: -5
# 第 8 筆錯誤資料: 57264395161922648412
# 第 8 筆算術錯誤: 9
# 第 9 筆錯誤資料: 57264395161922648396
# 第 9 筆算術錯誤: -7
# 第 10 筆錯誤資料: 57264395161922648410
# 第 10 筆算術錯誤: 7
# 第 11 筆錯誤資料: 57264395161922648394
# 第 11 筆算術錯誤: -9
# 第 12 筆錯誤資料: 57264395161922648420
# 第 12 筆算術錯誤: 17
# 第 13 筆錯誤資料: 57264395161922648388
# 第 13 筆算術錯誤: -15
# 第 14 筆錯誤資料: 57264395161922648418
# 第 14 筆算術錯誤: 15
# 第 15 筆錯誤資料: 57264395161922648386
# 第 15 筆算術錯誤: -17
# 第 16 筆錯誤資料: 57264395161922648436
# 第 16 筆算術錯誤: 33
# 第 17 筆錯誤資料: 57264395161922648372
# 第 17 筆算術錯誤: -31
# 第 18 筆錯誤資料: 57264395161922648434
# 第 18 筆算術錯誤: 31
# 第 19 筆錯誤資料: 57264395161922648370
# 第 19 筆算術錯誤: -33
# 第 20 筆錯誤資料: 57264395161922648468
# 第 20 筆算術錯誤: 65
# 第 21 筆錯誤資料: 57264395161922648340
# 第 21 筆算術錯誤: -63
# 第 22 筆錯誤資料: 57264395161922648466
# 第 22 筆算術錯誤: 63
# 第 23 筆錯誤資料: 57264395161922648338
# 第 23 筆算術錯誤: -65
# 第 24 筆錯誤資料: 57264395161922648532
# 第 24 筆算術錯誤: 129
# 第 25 筆錯誤資料: 57264395161922648276
# 第 25 筆算術錯誤: -127
# 第 26 筆錯誤資料: 57264395161922648530
# 第 26 筆算術錯誤: 127
# 第 27 筆錯誤資料: 57264395161922648274
# 第 27 筆算術錯誤: -129
# 第 28 筆錯誤資料: 57264395161922648660
# 第 28 筆算術錯誤: 257
# 第 29 筆錯誤資料: 57264395161922648148
# 第 29 筆算術錯誤: -255
# 第 30 筆錯誤資料: 57264395161922648658
# 第 30 筆算術錯誤: 255
# 第 31 筆錯誤資料: 57264395161922648146
# 第 31 筆算術錯誤: -257
# 第 32 筆錯誤資料: 57264395161922648916
# 第 32 筆算術錯誤: 513
# 第 33 筆錯誤資料: 57264395161922647892
# 第 33 筆算術錯誤: -511
# 第 34 筆錯誤資料: 57264395161922648914
# 第 34 筆算術錯誤: 511
# 第 35 筆錯誤資料: 57264395161922647890
# 第 35 筆算術錯誤: -513
# 第 36 筆錯誤資料: 57264395161922649428
# 第 36 筆算術錯誤: 1025
# 第 37 筆錯誤資料: 57264395161922647380
# 第 37 筆算術錯誤: -1023
# 第 38 筆錯誤資料: 57264395161922649426
# 第 38 筆算術錯誤: 1023
# 第 39 筆錯誤資料: 57264395161922647378
# 第 39 筆算術錯誤: -1025
# 第 40 筆錯誤資料: 57264395161922650452
# 第 40 筆算術錯誤: 2049
# 第 41 筆錯誤資料: 57264395161922646356
# 第 41 筆算術錯誤: -2047
# 第 42 筆錯誤資料: 57264395161922650450
# 第 42 筆算術錯誤: 2047
# 第 43 筆錯誤資料: 57264395161922646354
# 第 43 筆算術錯誤: -2049
# 第 44 筆錯誤資料: 57264395161922652500
# 第 44 筆算術錯誤: 4097
# 第 45 筆錯誤資料: 57264395161922644308
# 第 45 筆算術錯誤: -4095
# 第 46 筆錯誤資料: 57264395161922652498
# 第 46 筆算術錯誤: 4095
# 第 47 筆錯誤資料: 57264395161922644306
# 第 47 筆算術錯誤: -4097
# 第 48 筆錯誤資料: 57264395161922656596
# 第 48 筆算術錯誤: 8193
# 第 49 筆錯誤資料: 57264395161922640212
# 第 49 筆算術錯誤: -8191
# 第 50 筆錯誤資料: 57264395161922656594
# 第 50 筆算術錯誤: 8191
# 第 51 筆錯誤資料: 57264395161922640210
# 第 51 筆算術錯誤: -8193
# 第 52 筆錯誤資料: 57264395161922664788
# 第 52 筆算術錯誤: 16385
# 第 53 筆錯誤資料: 57264395161922632020
# 第 53 筆算術錯誤: -16383
# 第 54 筆錯誤資料: 57264395161922664786
# 第 54 筆算術錯誤: 16383
# 第 55 筆錯誤資料: 57264395161922632018
# 第 55 筆算術錯誤: -16385
# 第 56 筆錯誤資料: 57264395161922681172
# 第 56 筆算術錯誤: 32769
# 第 57 筆錯誤資料: 57264395161922615636
# 第 57 筆算術錯誤: -32767
# 第 58 筆錯誤資料: 57264395161922681170
# 第 58 筆算術錯誤: 32767
# 第 59 筆錯誤資料: 57264395161922615634
# 第 59 筆算術錯誤: -32769
# 第 60 筆錯誤資料: 57264395161922713940
# 第 60 筆算術錯誤: 65537
# 第 61 筆錯誤資料: 57264395161922582868
# 第 61 筆算術錯誤: -65535
# 第 62 筆錯誤資料: 57264395161922713938
# 第 62 筆算術錯誤: 65535
# 第 63 筆錯誤資料: 57264395161922582866
# 第 63 筆算術錯誤: -65537
# 第 64 筆錯誤資料: 57264395161922779476
# 第 64 筆算術錯誤: 131073
# 第 65 筆錯誤資料: 57264395161922517332
# 第 65 筆算術錯誤: -131071
# 第 66 筆錯誤資料: 57264395161922779474
# 第 66 筆算術錯誤: 131071
# 第 67 筆錯誤資料: 57264395161922517330
# 第 67 筆算術錯誤: -131073
# 第 68 筆錯誤資料: 57264395161922910548
# 第 68 筆算術錯誤: 262145
# 第 69 筆錯誤資料: 57264395161922386260
# 第 69 筆算術錯誤: -262143
# 第 70 筆錯誤資料: 57264395161922910546
# 第 70 筆算術錯誤: 262143
# 第 71 筆錯誤資料: 57264395161922386258
# 第 71 筆算術錯誤: -262145
# 第 72 筆錯誤資料: 57264395161923172692
# 第 72 筆算術錯誤: 524289
# 第 73 筆錯誤資料: 57264395161922124116
# 第 73 筆算術錯誤: -524287
# 第 74 筆錯誤資料: 57264395161923172690
# 第 74 筆算術錯誤: 524287
# 第 75 筆錯誤資料: 57264395161922124114
# 第 75 筆算術錯誤: -524289
# 第 76 筆錯誤資料: 57264395161923696980
# 第 76 筆算術錯誤: 1048577
# 第 77 筆錯誤資料: 57264395161921599828
# 第 77 筆算術錯誤: -1048575
# 第 78 筆錯誤資料: 57264395161923696978
# 第 78 筆算術錯誤: 1048575
# 第 79 筆錯誤資料: 57264395161921599826
# 第 79 筆算術錯誤: -1048577
# 第 80 筆錯誤資料: 57264395161924745556
# 第 80 筆算術錯誤: 2097153
# 第 81 筆錯誤資料: 57264395161920551252
# 第 81 筆算術錯誤: -2097151
# 第 82 筆錯誤資料: 57264395161924745554
# 第 82 筆算術錯誤: 2097151
# 第 83 筆錯誤資料: 57264395161920551250
# 第 83 筆算術錯誤: -2097153
# 第 84 筆錯誤資料: 57264395161926842708
# 第 84 筆算術錯誤: 4194305
# 第 85 筆錯誤資料: 57264395161918454100
# 第 85 筆算術錯誤: -4194303
# 第 86 筆錯誤資料: 57264395161926842706
# 第 86 筆算術錯誤: 4194303
# 第 87 筆錯誤資料: 57264395161918454098
# 第 87 筆算術錯誤: -4194305
# 第 88 筆錯誤資料: 57264395161931037012
# 第 88 筆算術錯誤: 8388609
# 第 89 筆錯誤資料: 57264395161914259796
# 第 89 筆算術錯誤: -8388607
# 第 90 筆錯誤資料: 57264395161931037010
# 第 90 筆算術錯誤: 8388607
# 第 91 筆錯誤資料: 57264395161914259794
# 第 91 筆算術錯誤: -8388609
# 第 92 筆錯誤資料: 57264395161939425620
# 第 92 筆算術錯誤: 16777217
# 第 93 筆錯誤資料: 57264395161905871188
# 第 93 筆算術錯誤: -16777215
# 第 94 筆錯誤資料: 57264395161939425618
# 第 94 筆算術錯誤: 16777215
# 第 95 筆錯誤資料: 57264395161905871186
# 第 95 筆算術錯誤: -16777217
# 第 96 筆錯誤資料: 57264395161956202836
# 第 96 筆算術錯誤: 33554433
# 第 97 筆錯誤資料: 57264395161889093972
# 第 97 筆算術錯誤: -33554431
# 第 98 筆錯誤資料: 57264395161956202834
# 第 98 筆算術錯誤: 33554431
# 第 99 筆錯誤資料: 57264395161889093970
# 第 99 筆算術錯誤: -33554433
# 第 100 筆錯誤資料: 57264395161989757268
# 第 100 筆算術錯誤: 67108865
# 第 101 筆錯誤資料: 57264395161855539540
# 第 101 筆算術錯誤: -67108863
# 第 102 筆錯誤資料: 57264395161989757266
# 第 102 筆算術錯誤: 67108863
# 第 103 筆錯誤資料: 57264395161855539538
# 第 103 筆算術錯誤: -67108865
# 第 104 筆錯誤資料: 57264395162056866132
# 第 104 筆算術錯誤: 134217729
# 第 105 筆錯誤資料: 57264395161788430676
# 第 105 筆算術錯誤: -134217727
# 第 106 筆錯誤資料: 57264395162056866130
# 第 106 筆算術錯誤: 134217727
# 第 107 筆錯誤資料: 57264395161788430674
# 第 107 筆算術錯誤: -134217729
# 第 108 筆錯誤資料: 57264395162191083860
# 第 108 筆算術錯誤: 268435457
# 第 109 筆錯誤資料: 57264395161654212948
# 第 109 筆算術錯誤: -268435455
# 第 110 筆錯誤資料: 57264395162191083858
# 第 110 筆算術錯誤: 268435455
# 第 111 筆錯誤資料: 57264395161654212946
# 第 111 筆算術錯誤: -268435457
# 第 112 筆錯誤資料: 57264395162459519316
# 第 112 筆算術錯誤: 536870913
# 第 113 筆錯誤資料: 57264395161385777492
# 第 113 筆算術錯誤: -536870911
# 第 114 筆錯誤資料: 57264395162459519314
# 第 114 筆算術錯誤: 536870911
# 第 115 筆錯誤資料: 57264395161385777490
# 第 115 筆算術錯誤: -536870913
# 第 116 筆錯誤資料: 57264395162996390228
# 第 116 筆算術錯誤: 1073741825
# 第 117 筆錯誤資料: 57264395160848906580
# 第 117 筆算術錯誤: -1073741823
# 第 118 筆錯誤資料: 57264395162996390226
# 第 118 筆算術錯誤: 1073741823
# 第 119 筆錯誤資料: 57264395160848906578
# 第 119 筆算術錯誤: -1073741825
# 第 120 筆錯誤資料: 57264395164070132052
# 第 120 筆算術錯誤: 2147483649
# 第 121 筆錯誤資料: 57264395159775164756
# 第 121 筆算術錯誤: -2147483647
# 第 122 筆錯誤資料: 57264395164070132050
# 第 122 筆算術錯誤: 2147483647
# 第 123 筆錯誤資料: 57264395159775164754
# 第 123 筆算術錯誤: -2147483649
# 第 124 筆錯誤資料: 57264395166217615700
# 第 124 筆算術錯誤: 4294967297
# 第 125 筆錯誤資料: 57264395157627681108
# 第 125 筆算術錯誤: -4294967295
# 第 126 筆錯誤資料: 57264395166217615698
# 第 126 筆算術錯誤: 4294967295
# 第 127 筆錯誤資料: 57264395157627681106
# 第 127 筆算術錯誤: -4294967297
# 第 128 筆錯誤資料: 57264395170512582996
# 第 128 筆算術錯誤: 8589934593
# 第 129 筆錯誤資料: 57264395153332713812
# 第 129 筆算術錯誤: -8589934591
# 第 130 筆錯誤資料: 57264395170512582994
# 第 130 筆算術錯誤: 8589934591
# 第 131 筆錯誤資料: 57264395153332713810
# 第 131 筆算術錯誤: -8589934593
# 第 132 筆錯誤資料: 57264395179102517588
# 第 132 筆算術錯誤: 17179869185
# 第 133 筆錯誤資料: 57264395144742779220
# 第 133 筆算術錯誤: -17179869183
# 第 134 筆錯誤資料: 57264395179102517586
# 第 134 筆算術錯誤: 17179869183
# 第 135 筆錯誤資料: 57264395144742779218
# 第 135 筆算術錯誤: -17179869185
# 第 136 筆錯誤資料: 57264395196282386772
# 第 136 筆算術錯誤: 34359738369
# 第 137 筆錯誤資料: 57264395127562910036
# 第 137 筆算術錯誤: -34359738367
# 第 138 筆錯誤資料: 57264395196282386770
# 第 138 筆算術錯誤: 34359738367
# 第 139 筆錯誤資料: 57264395127562910034
# 第 139 筆算術錯誤: -34359738369
# 第 140 筆錯誤資料: 57264395230642125140
# 第 140 筆算術錯誤: 68719476737
# 第 141 筆錯誤資料: 57264395093203171668
# 第 141 筆算術錯誤: -68719476735
# 第 142 筆錯誤資料: 57264395230642125138
# 第 142 筆算術錯誤: 68719476735
# 第 143 筆錯誤資料: 57264395093203171666
# 第 143 筆算術錯誤: -68719476737
# 第 144 筆錯誤資料: 57264395299361601876
# 第 144 筆算術錯誤: 137438953473
# 第 145 筆錯誤資料: 57264395024483694932
# 第 145 筆算術錯誤: -137438953471
# 第 146 筆錯誤資料: 57264395299361601874
# 第 146 筆算術錯誤: 137438953471
# 第 147 筆錯誤資料: 57264395024483694930
# 第 147 筆算術錯誤: -137438953473
# 第 148 筆錯誤資料: 57264395436800555348
# 第 148 筆算術錯誤: 274877906945
# 第 149 筆錯誤資料: 57264394887044741460
# 第 149 筆算術錯誤: -274877906943
# 第 150 筆錯誤資料: 57264395436800555346
# 第 150 筆算術錯誤: 274877906943
# 第 151 筆錯誤資料: 57264394887044741458
# 第 151 筆算術錯誤: -274877906945
# 第 152 筆錯誤資料: 57264395711678462292
# 第 152 筆算術錯誤: 549755813889
# 第 153 筆錯誤資料: 57264394612166834516
# 第 153 筆算術錯誤: -549755813887
# 第 154 筆錯誤資料: 57264395711678462290
# 第 154 筆算術錯誤: 549755813887
# 第 155 筆錯誤資料: 57264394612166834514
# 第 155 筆算術錯誤: -549755813889
# 第 156 筆錯誤資料: 57264396261434276180
# 第 156 筆算術錯誤: 1099511627777
# 第 157 筆錯誤資料: 57264394062411020628
# 第 157 筆算術錯誤: -1099511627775
# 第 158 筆錯誤資料: 57264396261434276178
# 第 158 筆算術錯誤: 1099511627775
# 第 159 筆錯誤資料: 57264394062411020626
# 第 159 筆算術錯誤: -1099511627777
# 第 160 筆錯誤資料: 57264397360945903956
# 第 160 筆算術錯誤: 2199023255553
# 第 161 筆錯誤資料: 57264392962899392852
# 第 161 筆算術錯誤: -2199023255551
# 第 162 筆錯誤資料: 57264397360945903954
# 第 162 筆算術錯誤: 2199023255551
# 第 163 筆錯誤資料: 57264392962899392850
# 第 163 筆算術錯誤: -2199023255553
# 第 164 筆錯誤資料: 57264399559969159508
# 第 164 筆算術錯誤: 4398046511105
# 第 165 筆錯誤資料: 57264390763876137300
# 第 165 筆算術錯誤: -4398046511103
# 第 166 筆錯誤資料: 57264399559969159506
# 第 166 筆算術錯誤: 4398046511103
# 第 167 筆錯誤資料: 57264390763876137298
# 第 167 筆算術錯誤: -4398046511105
# 第 168 筆錯誤資料: 57264403958015670612
# 第 168 筆算術錯誤: 8796093022209
# 第 169 筆錯誤資料: 57264386365829626196
# 第 169 筆算術錯誤: -8796093022207
# 第 170 筆錯誤資料: 57264403958015670610
# 第 170 筆算術錯誤: 8796093022207
# 第 171 筆錯誤資料: 57264386365829626194
# 第 171 筆算術錯誤: -8796093022209
# 第 172 筆錯誤資料: 57264412754108692820
# 第 172 筆算術錯誤: 17592186044417
# 第 173 筆錯誤資料: 57264377569736603988
# 第 173 筆算術錯誤: -17592186044415
# 第 174 筆錯誤資料: 57264412754108692818
# 第 174 筆算術錯誤: 17592186044415
# 第 175 筆錯誤資料: 57264377569736603986
# 第 175 筆算術錯誤: -17592186044417
# 第 176 筆錯誤資料: 57264430346294737236
# 第 176 筆算術錯誤: 35184372088833
# 第 177 筆錯誤資料: 57264359977550559572
# 第 177 筆算術錯誤: -35184372088831
# 第 178 筆錯誤資料: 57264430346294737234
# 第 178 筆算術錯誤: 35184372088831
# 第 179 筆錯誤資料: 57264359977550559570
# 第 179 筆算術錯誤: -35184372088833
# 第 180 筆錯誤資料: 57264465530666826068
# 第 180 筆算術錯誤: 70368744177665
# 第 181 筆錯誤資料: 57264324793178470740
# 第 181 筆算術錯誤: -70368744177663
# 第 182 筆錯誤資料: 57264465530666826066
# 第 182 筆算術錯誤: 70368744177663
# 第 183 筆錯誤資料: 57264324793178470738
# 第 183 筆算術錯誤: -70368744177665
# 第 184 筆錯誤資料: 57264535899411003732
# 第 184 筆算術錯誤: 140737488355329
# 第 185 筆錯誤資料: 57264254424434293076
# 第 185 筆算術錯誤: -140737488355327
# 第 186 筆錯誤資料: 57264535899411003730
# 第 186 筆算術錯誤: 140737488355327
# 第 187 筆錯誤資料: 57264254424434293074
# 第 187 筆算術錯誤: -140737488355329
# 第 188 筆錯誤資料: 57264676636899359060
# 第 188 筆算術錯誤: 281474976710657
# 第 189 筆錯誤資料: 57264113686945937748
# 第 189 筆算術錯誤: -281474976710655
# 第 190 筆錯誤資料: 57264676636899359058
# 第 190 筆算術錯誤: 281474976710655
# 第 191 筆錯誤資料: 57264113686945937746
# 第 191 筆算術錯誤: -281474976710657
# 第 192 筆錯誤資料: 57264958111876069716
# 第 192 筆算術錯誤: 562949953421313
# 第 193 筆錯誤資料: 57263832211969227092
# 第 193 筆算術錯誤: -562949953421311
# 第 194 筆錯誤資料: 57264958111876069714
# 第 194 筆算術錯誤: 562949953421311
# 第 195 筆錯誤資料: 57263832211969227090
# 第 195 筆算術錯誤: -562949953421313
# 第 196 筆錯誤資料: 57265521061829491028
# 第 196 筆算術錯誤: 1125899906842625
# 第 197 筆錯誤資料: 57263269262015805780
# 第 197 筆算術錯誤: -1125899906842623
# 第 198 筆錯誤資料: 57265521061829491026
# 第 198 筆算術錯誤: 1125899906842623
# 第 199 筆錯誤資料: 57263269262015805778
# 第 199 筆算術錯誤: -1125899906842625
# 第 200 筆錯誤資料: 57266646961736333652
# 第 200 筆算術錯誤: 2251799813685249
# 第 201 筆錯誤資料: 57262143362108963156
# 第 201 筆算術錯誤: -2251799813685247
# 第 202 筆錯誤資料: 57266646961736333650
# 第 202 筆算術錯誤: 2251799813685247
# 第 203 筆錯誤資料: 57262143362108963154
# 第 203 筆算術錯誤: -2251799813685249
# 第 204 筆錯誤資料: 57268898761550018900
# 第 204 筆算術錯誤: 4503599627370497
# 第 205 筆錯誤資料: 57259891562295277908
# 第 205 筆算術錯誤: -4503599627370495
# 第 206 筆錯誤資料: 57268898761550018898
# 第 206 筆算術錯誤: 4503599627370495
# 第 207 筆錯誤資料: 57259891562295277906
# 第 207 筆算術錯誤: -4503599627370497
# 第 208 筆錯誤資料: 57273402361177389396
# 第 208 筆算術錯誤: 9007199254740993
# 第 209 筆錯誤資料: 57255387962667907412
# 第 209 筆算術錯誤: -9007199254740991
# 第 210 筆錯誤資料: 57273402361177389394
# 第 210 筆算術錯誤: 9007199254740991
# 第 211 筆錯誤資料: 57255387962667907410
# 第 211 筆算術錯誤: -9007199254740993
# 第 212 筆錯誤資料: 57282409560432130388
# 第 212 筆算術錯誤: 18014398509481985
# 第 213 筆錯誤資料: 57246380763413166420
# 第 213 筆算術錯誤: -18014398509481983
# 第 214 筆錯誤資料: 57282409560432130386
# 第 214 筆算術錯誤: 18014398509481983
# 第 215 筆錯誤資料: 57246380763413166418
# 第 215 筆算術錯誤: -18014398509481985
# 第 216 筆錯誤資料: 57300423958941612372
# 第 216 筆算術錯誤: 36028797018963969
# 第 217 筆錯誤資料: 57228366364903684436
# 第 217 筆算術錯誤: -36028797018963967
# 第 218 筆錯誤資料: 57300423958941612370
# 第 218 筆算術錯誤: 36028797018963967
# 第 219 筆錯誤資料: 57228366364903684434
# 第 219 筆算術錯誤: -36028797018963969
# 第 220 筆錯誤資料: 57336452755960576340
# 第 220 筆算術錯誤: 72057594037927937
# 第 221 筆錯誤資料: 57192337567884720468
# 第 221 筆算術錯誤: -72057594037927935
# 第 222 筆錯誤資料: 57336452755960576338
# 第 222 筆算術錯誤: 72057594037927935
# 第 223 筆錯誤資料: 57192337567884720466
# 第 223 筆算術錯誤: -72057594037927937
# 第 224 筆錯誤資料: 57408510349998504276
# 第 224 筆算術錯誤: 144115188075855873
# 第 225 筆錯誤資料: 57120279973846792532
# 第 225 筆算術錯誤: -144115188075855871
# 第 226 筆錯誤資料: 57408510349998504274
# 第 226 筆算術錯誤: 144115188075855871
# 第 227 筆錯誤資料: 57120279973846792530
# 第 227 筆算術錯誤: -144115188075855873
# 第 228 筆錯誤資料: 57552625538074360148
# 第 228 筆算術錯誤: 288230376151711745
# 第 229 筆錯誤資料: 56976164785770936660
# 第 229 筆算術錯誤: -288230376151711743
# 第 230 筆錯誤資料: 57552625538074360146
# 第 230 筆算術錯誤: 288230376151711743
# 第 231 筆錯誤資料: 56976164785770936658
# 第 231 筆算術錯誤: -288230376151711745
# 第 232 筆錯誤資料: 57840855914226071892
# 第 232 筆算術錯誤: 576460752303423489
# 第 233 筆錯誤資料: 56687934409619224916
# 第 233 筆算術錯誤: -576460752303423487
# 第 234 筆錯誤資料: 57840855914226071890
# 第 234 筆算術錯誤: 576460752303423487
# 第 235 筆錯誤資料: 56687934409619224914
# 第 235 筆算術錯誤: -576460752303423489
# 第 236 筆錯誤資料: 58417316666529495380
# 第 236 筆算術錯誤: 1152921504606846977
# 第 237 筆錯誤資料: 56111473657315801428
# 第 237 筆算術錯誤: -1152921504606846975
# 第 238 筆錯誤資料: 58417316666529495378
# 第 238 筆算術錯誤: 1152921504606846975
# 第 239 筆錯誤資料: 56111473657315801426
# 第 239 筆算術錯誤: -1152921504606846977
# 第 240 筆錯誤資料: 59570238171136342356
# 第 240 筆算術錯誤: 2305843009213693953
# 第 241 筆錯誤資料: 54958552152708954452
# 第 241 筆算術錯誤: -2305843009213693951
# 第 242 筆錯誤資料: 59570238171136342354
# 第 242 筆算術錯誤: 2305843009213693951
# 第 243 筆錯誤資料: 54958552152708954450
# 第 243 筆算術錯誤: -2305843009213693953
# 第 244 筆錯誤資料: 61876081180350036308
# 第 244 筆算術錯誤: 4611686018427387905
# 第 245 筆錯誤資料: 52652709143495260500
# 第 245 筆算術錯誤: -4611686018427387903
# 第 246 筆錯誤資料: 61876081180350036306
# 第 246 筆算術錯誤: 4611686018427387903
# 第 247 筆錯誤資料: 52652709143495260498
# 第 247 筆算術錯誤: -4611686018427387905
# 第 248 筆錯誤資料: 66487767198777424212
# 第 248 筆算術錯誤: 9223372036854775809
# 第 249 筆錯誤資料: 48041023125067872596
# 第 249 筆算術錯誤: -9223372036854775807
# 第 250 筆錯誤資料: 66487767198777424210
# 第 250 筆算術錯誤: 9223372036854775807
# 第 251 筆錯誤資料: 48041023125067872594
# 第 251 筆算術錯誤: -9223372036854775809
# 第 252 筆錯誤資料: 75711139235632200020
# 第 252 筆算術錯誤: 18446744073709551617
# 第 253 筆錯誤資料: 38817651088213096788
# 第 253 筆算術錯誤: -18446744073709551615
# 第 254 筆錯誤資料: 75711139235632200018
# 第 254 筆算術錯誤: 18446744073709551615
# 第 255 筆錯誤資料: 38817651088213096786
# 第 255 筆算術錯誤: -18446744073709551617
# 第 256 筆錯誤資料: 94157883309341751636
# 第 256 筆算術錯誤: 36893488147419103233
# 第 257 筆錯誤資料: 20370907014503545172
# 第 257 筆算術錯誤: -36893488147419103231
# 第 258 筆錯誤資料: 94157883309341751634
# 第 258 筆算術錯誤: 36893488147419103231
# 第 259 筆錯誤資料: 20370907014503545170
# 第 259 筆算術錯誤: -36893488147419103233
# 第 260 筆錯誤資料: 57264395161922648409
# 第 260 筆算術錯誤: 6
# 第 261 筆錯誤資料: 57264395161922648401
# 第 261 筆算術錯誤: -2
# 第 262 筆錯誤資料: 57264395161922648405
# 第 262 筆算術錯誤: 2
# 第 263 筆錯誤資料: 57264395161922648397
# 第 263 筆算術錯誤: -6
# 第 264 筆錯誤資料: 57264395161922648413
# 第 264 筆算術錯誤: 10
# 第 265 筆錯誤資料: 57264395161922648397
# 第 265 筆算術錯誤: -6
# 第 266 筆錯誤資料: 57264395161922648409
# 第 266 筆算術錯誤: 6
# 第 267 筆錯誤資料: 57264395161922648393
# 第 267 筆算術錯誤: -10
# 第 268 筆錯誤資料: 57264395161922648421
# 第 268 筆算術錯誤: 18
# 第 269 筆錯誤資料: 57264395161922648389
# 第 269 筆算術錯誤: -14
# 第 270 筆錯誤資料: 57264395161922648417
# 第 270 筆算術錯誤: 14
# 第 271 筆錯誤資料: 57264395161922648385
# 第 271 筆算術錯誤: -18
# 第 272 筆錯誤資料: 57264395161922648437
# 第 272 筆算術錯誤: 34
# 第 273 筆錯誤資料: 57264395161922648373
# 第 273 筆算術錯誤: -30
# 第 274 筆錯誤資料: 57264395161922648433
# 第 274 筆算術錯誤: 30
# 第 275 筆錯誤資料: 57264395161922648369
# 第 275 筆算術錯誤: -34
# 第 276 筆錯誤資料: 57264395161922648469
# 第 276 筆算術錯誤: 66
# 第 277 筆錯誤資料: 57264395161922648341
# 第 277 筆算術錯誤: -62
# 第 278 筆錯誤資料: 57264395161922648465
# 第 278 筆算術錯誤: 62
# 第 279 筆錯誤資料: 57264395161922648337
# 第 279 筆算術錯誤: -66
# 第 280 筆錯誤資料: 57264395161922648533
# 第 280 筆算術錯誤: 130
# 第 281 筆錯誤資料: 57264395161922648277
# 第 281 筆算術錯誤: -126
# 第 282 筆錯誤資料: 57264395161922648529
# 第 282 筆算術錯誤: 126
# 第 283 筆錯誤資料: 57264395161922648273
# 第 283 筆算術錯誤: -130
# 第 284 筆錯誤資料: 57264395161922648661
# 第 284 筆算術錯誤: 258
# 第 285 筆錯誤資料: 57264395161922648149
# 第 285 筆算術錯誤: -254
# 第 286 筆錯誤資料: 57264395161922648657
# 第 286 筆算術錯誤: 254
# 第 287 筆錯誤資料: 57264395161922648145
# 第 287 筆算術錯誤: -258
# 第 288 筆錯誤資料: 57264395161922648917
# 第 288 筆算術錯誤: 514
# 第 289 筆錯誤資料: 57264395161922647893
# 第 289 筆算術錯誤: -510
# 第 290 筆錯誤資料: 57264395161922648913
# 第 290 筆算術錯誤: 510
# 第 291 筆錯誤資料: 57264395161922647889
# 第 291 筆算術錯誤: -514
# 第 292 筆錯誤資料: 57264395161922649429
# 第 292 筆算術錯誤: 1026
# 第 293 筆錯誤資料: 57264395161922647381
# 第 293 筆算術錯誤: -1022
# 第 294 筆錯誤資料: 57264395161922649425
# 第 294 筆算術錯誤: 1022
# 第 295 筆錯誤資料: 57264395161922647377
# 第 295 筆算術錯誤: -1026
# 第 296 筆錯誤資料: 57264395161922650453
# 第 296 筆算術錯誤: 2050
# 第 297 筆錯誤資料: 57264395161922646357
# 第 297 筆算術錯誤: -2046
# 第 298 筆錯誤資料: 57264395161922650449
# 第 298 筆算術錯誤: 2046
# 第 299 筆錯誤資料: 57264395161922646353
# 第 299 筆算術錯誤: -2050
# 第 300 筆錯誤資料: 57264395161922652501
# 第 300 筆算術錯誤: 4098
# 第 301 筆錯誤資料: 57264395161922644309
# 第 301 筆算術錯誤: -4094
# 第 302 筆錯誤資料: 57264395161922652497
# 第 302 筆算術錯誤: 4094
# 第 303 筆錯誤資料: 57264395161922644305
# 第 303 筆算術錯誤: -4098
# 第 304 筆錯誤資料: 57264395161922656597
# 第 304 筆算術錯誤: 8194
# 第 305 筆錯誤資料: 57264395161922640213
# 第 305 筆算術錯誤: -8190
# 第 306 筆錯誤資料: 57264395161922656593
# 第 306 筆算術錯誤: 8190
# 第 307 筆錯誤資料: 57264395161922640209
# 第 307 筆算術錯誤: -8194
# 第 308 筆錯誤資料: 57264395161922664789
# 第 308 筆算術錯誤: 16386
# 第 309 筆錯誤資料: 57264395161922632021
# 第 309 筆算術錯誤: -16382
# 第 310 筆錯誤資料: 57264395161922664785
# 第 310 筆算術錯誤: 16382
# 第 311 筆錯誤資料: 57264395161922632017
# 第 311 筆算術錯誤: -16386
# 第 312 筆錯誤資料: 57264395161922681173
# 第 312 筆算術錯誤: 32770
# 第 313 筆錯誤資料: 57264395161922615637
# 第 313 筆算術錯誤: -32766
# 第 314 筆錯誤資料: 57264395161922681169
# 第 314 筆算術錯誤: 32766
# 第 315 筆錯誤資料: 57264395161922615633
# 第 315 筆算術錯誤: -32770
# 第 316 筆錯誤資料: 57264395161922713941
# 第 316 筆算術錯誤: 65538
# 第 317 筆錯誤資料: 57264395161922582869
# 第 317 筆算術錯誤: -65534
# 第 318 筆錯誤資料: 57264395161922713937
# 第 318 筆算術錯誤: 65534
# 第 319 筆錯誤資料: 57264395161922582865
# 第 319 筆算術錯誤: -65538
# 第 320 筆錯誤資料: 57264395161922779477
# 第 320 筆算術錯誤: 131074
# 第 321 筆錯誤資料: 57264395161922517333
# 第 321 筆算術錯誤: -131070
# 第 322 筆錯誤資料: 57264395161922779473
# 第 322 筆算術錯誤: 131070
# 第 323 筆錯誤資料: 57264395161922517329
# 第 323 筆算術錯誤: -131074
# 第 324 筆錯誤資料: 57264395161922910549
# 第 324 筆算術錯誤: 262146
# 第 325 筆錯誤資料: 57264395161922386261
# 第 325 筆算術錯誤: -262142
# 第 326 筆錯誤資料: 57264395161922910545
# 第 326 筆算術錯誤: 262142
# 第 327 筆錯誤資料: 57264395161922386257
# 第 327 筆算術錯誤: -262146
# 第 328 筆錯誤資料: 57264395161923172693
# 第 328 筆算術錯誤: 524290
# 第 329 筆錯誤資料: 57264395161922124117
# 第 329 筆算術錯誤: -524286
# 第 330 筆錯誤資料: 57264395161923172689
# 第 330 筆算術錯誤: 524286
# 第 331 筆錯誤資料: 57264395161922124113
# 第 331 筆算術錯誤: -524290
# 第 332 筆錯誤資料: 57264395161923696981
# 第 332 筆算術錯誤: 1048578
# 第 333 筆錯誤資料: 57264395161921599829
# 第 333 筆算術錯誤: -1048574
# 第 334 筆錯誤資料: 57264395161923696977
# 第 334 筆算術錯誤: 1048574
# 第 335 筆錯誤資料: 57264395161921599825
# 第 335 筆算術錯誤: -1048578
# 第 336 筆錯誤資料: 57264395161924745557
# 第 336 筆算術錯誤: 2097154
# 第 337 筆錯誤資料: 57264395161920551253
# 第 337 筆算術錯誤: -2097150
# 第 338 筆錯誤資料: 57264395161924745553
# 第 338 筆算術錯誤: 2097150
# 第 339 筆錯誤資料: 57264395161920551249
# 第 339 筆算術錯誤: -2097154
# 第 340 筆錯誤資料: 57264395161926842709
# 第 340 筆算術錯誤: 4194306
# 第 341 筆錯誤資料: 57264395161918454101
# 第 341 筆算術錯誤: -4194302
# 第 342 筆錯誤資料: 57264395161926842705
# 第 342 筆算術錯誤: 4194302
# 第 343 筆錯誤資料: 57264395161918454097
# 第 343 筆算術錯誤: -4194306
# 第 344 筆錯誤資料: 57264395161931037013
# 第 344 筆算術錯誤: 8388610
# 第 345 筆錯誤資料: 57264395161914259797
# 第 345 筆算術錯誤: -8388606
# 第 346 筆錯誤資料: 57264395161931037009
# 第 346 筆算術錯誤: 8388606
# 第 347 筆錯誤資料: 57264395161914259793
# 第 347 筆算術錯誤: -8388610
# 第 348 筆錯誤資料: 57264395161939425621
# 第 348 筆算術錯誤: 16777218
# 第 349 筆錯誤資料: 57264395161905871189
# 第 349 筆算術錯誤: -16777214
# 第 350 筆錯誤資料: 57264395161939425617
# 第 350 筆算術錯誤: 16777214
# 第 351 筆錯誤資料: 57264395161905871185
# 第 351 筆算術錯誤: -16777218
# 第 352 筆錯誤資料: 57264395161956202837
# 第 352 筆算術錯誤: 33554434
# 第 353 筆錯誤資料: 57264395161889093973
# 第 353 筆算術錯誤: -33554430
# 第 354 筆錯誤資料: 57264395161956202833
# 第 354 筆算術錯誤: 33554430
# 第 355 筆錯誤資料: 57264395161889093969
# 第 355 筆算術錯誤: -33554434
# 第 356 筆錯誤資料: 57264395161989757269
# 第 356 筆算術錯誤: 67108866
# 第 357 筆錯誤資料: 57264395161855539541
# 第 357 筆算術錯誤: -67108862
# 第 358 筆錯誤資料: 57264395161989757265
# 第 358 筆算術錯誤: 67108862
# 第 359 筆錯誤資料: 57264395161855539537
# 第 359 筆算術錯誤: -67108866
# 第 360 筆錯誤資料: 57264395162056866133
# 第 360 筆算術錯誤: 134217730
# 第 361 筆錯誤資料: 57264395161788430677
# 第 361 筆算術錯誤: -134217726
# 第 362 筆錯誤資料: 57264395162056866129
# 第 362 筆算術錯誤: 134217726
# 第 363 筆錯誤資料: 57264395161788430673
# 第 363 筆算術錯誤: -134217730
# 第 364 筆錯誤資料: 57264395162191083861
# 第 364 筆算術錯誤: 268435458
# 第 365 筆錯誤資料: 57264395161654212949
# 第 365 筆算術錯誤: -268435454
# 第 366 筆錯誤資料: 57264395162191083857
# 第 366 筆算術錯誤: 268435454
# 第 367 筆錯誤資料: 57264395161654212945
# 第 367 筆算術錯誤: -268435458
# 第 368 筆錯誤資料: 57264395162459519317
# 第 368 筆算術錯誤: 536870914
# 第 369 筆錯誤資料: 57264395161385777493
# 第 369 筆算術錯誤: -536870910
# 第 370 筆錯誤資料: 57264395162459519313
# 第 370 筆算術錯誤: 536870910
# 第 371 筆錯誤資料: 57264395161385777489
# 第 371 筆算術錯誤: -536870914
# 第 372 筆錯誤資料: 57264395162996390229
# 第 372 筆算術錯誤: 1073741826
# 第 373 筆錯誤資料: 57264395160848906581
# 第 373 筆算術錯誤: -1073741822
# 第 374 筆錯誤資料: 57264395162996390225
# 第 374 筆算術錯誤: 1073741822
# 第 375 筆錯誤資料: 57264395160848906577
# 第 375 筆算術錯誤: -1073741826
# 第 376 筆錯誤資料: 57264395164070132053
# 第 376 筆算術錯誤: 2147483650
# 第 377 筆錯誤資料: 57264395159775164757
# 第 377 筆算術錯誤: -2147483646
# 第 378 筆錯誤資料: 57264395164070132049
# 第 378 筆算術錯誤: 2147483646
# 第 379 筆錯誤資料: 57264395159775164753
# 第 379 筆算術錯誤: -2147483650
# 第 380 筆錯誤資料: 57264395166217615701
# 第 380 筆算術錯誤: 4294967298
# 第 381 筆錯誤資料: 57264395157627681109
# 第 381 筆算術錯誤: -4294967294
# 第 382 筆錯誤資料: 57264395166217615697
# 第 382 筆算術錯誤: 4294967294
# 第 383 筆錯誤資料: 57264395157627681105
# 第 383 筆算術錯誤: -4294967298
# 第 384 筆錯誤資料: 57264395170512582997
# 第 384 筆算術錯誤: 8589934594
# 第 385 筆錯誤資料: 57264395153332713813
# 第 385 筆算術錯誤: -8589934590
# 第 386 筆錯誤資料: 57264395170512582993
# 第 386 筆算術錯誤: 8589934590
# 第 387 筆錯誤資料: 57264395153332713809
# 第 387 筆算術錯誤: -8589934594
# 第 388 筆錯誤資料: 57264395179102517589
# 第 388 筆算術錯誤: 17179869186
# 第 389 筆錯誤資料: 57264395144742779221
# 第 389 筆算術錯誤: -17179869182
# 第 390 筆錯誤資料: 57264395179102517585
# 第 390 筆算術錯誤: 17179869182
# 第 391 筆錯誤資料: 57264395144742779217
# 第 391 筆算術錯誤: -17179869186
# 第 392 筆錯誤資料: 57264395196282386773
# 第 392 筆算術錯誤: 34359738370
# 第 393 筆錯誤資料: 57264395127562910037
# 第 393 筆算術錯誤: -34359738366
# 第 394 筆錯誤資料: 57264395196282386769
# 第 394 筆算術錯誤: 34359738366
# 第 395 筆錯誤資料: 57264395127562910033
# 第 395 筆算術錯誤: -34359738370
# 第 396 筆錯誤資料: 57264395230642125141
# 第 396 筆算術錯誤: 68719476738
# 第 397 筆錯誤資料: 57264395093203171669
# 第 397 筆算術錯誤: -68719476734
# 第 398 筆錯誤資料: 57264395230642125137
# 第 398 筆算術錯誤: 68719476734
# 第 399 筆錯誤資料: 57264395093203171665
# 第 399 筆算術錯誤: -68719476738
# 第 400 筆錯誤資料: 57264395299361601877
# 第 400 筆算術錯誤: 137438953474
# 第 401 筆錯誤資料: 57264395024483694933
# 第 401 筆算術錯誤: -137438953470
# 第 402 筆錯誤資料: 57264395299361601873
# 第 402 筆算術錯誤: 137438953470
# 第 403 筆錯誤資料: 57264395024483694929
# 第 403 筆算術錯誤: -137438953474
# 第 404 筆錯誤資料: 57264395436800555349
# 第 404 筆算術錯誤: 274877906946
# 第 405 筆錯誤資料: 57264394887044741461
# 第 405 筆算術錯誤: -274877906942
# 第 406 筆錯誤資料: 57264395436800555345
# 第 406 筆算術錯誤: 274877906942
# 第 407 筆錯誤資料: 57264394887044741457
# 第 407 筆算術錯誤: -274877906946
# 第 408 筆錯誤資料: 57264395711678462293
# 第 408 筆算術錯誤: 549755813890
# 第 409 筆錯誤資料: 57264394612166834517
# 第 409 筆算術錯誤: -549755813886
# 第 410 筆錯誤資料: 57264395711678462289
# 第 410 筆算術錯誤: 549755813886
# 第 411 筆錯誤資料: 57264394612166834513
# 第 411 筆算術錯誤: -549755813890
# 第 412 筆錯誤資料: 57264396261434276181
# 第 412 筆算術錯誤: 1099511627778
# 第 413 筆錯誤資料: 57264394062411020629
# 第 413 筆算術錯誤: -1099511627774
# 第 414 筆錯誤資料: 57264396261434276177
# 第 414 筆算術錯誤: 1099511627774
# 第 415 筆錯誤資料: 57264394062411020625
# 第 415 筆算術錯誤: -1099511627778
# 第 416 筆錯誤資料: 57264397360945903957
# 第 416 筆算術錯誤: 2199023255554
# 第 417 筆錯誤資料: 57264392962899392853
# 第 417 筆算術錯誤: -2199023255550
# 第 418 筆錯誤資料: 57264397360945903953
# 第 418 筆算術錯誤: 2199023255550
# 第 419 筆錯誤資料: 57264392962899392849
# 第 419 筆算術錯誤: -2199023255554
# 第 420 筆錯誤資料: 57264399559969159509
# 第 420 筆算術錯誤: 4398046511106
# 第 421 筆錯誤資料: 57264390763876137301
# 第 421 筆算術錯誤: -4398046511102
# 第 422 筆錯誤資料: 57264399559969159505
# 第 422 筆算術錯誤: 4398046511102
# 第 423 筆錯誤資料: 57264390763876137297
# 第 423 筆算術錯誤: -4398046511106
# 第 424 筆錯誤資料: 57264403958015670613
# 第 424 筆算術錯誤: 8796093022210
# 第 425 筆錯誤資料: 57264386365829626197
# 第 425 筆算術錯誤: -8796093022206
# 第 426 筆錯誤資料: 57264403958015670609
# 第 426 筆算術錯誤: 8796093022206
# 第 427 筆錯誤資料: 57264386365829626193
# 第 427 筆算術錯誤: -8796093022210
# 第 428 筆錯誤資料: 57264412754108692821
# 第 428 筆算術錯誤: 17592186044418
# 第 429 筆錯誤資料: 57264377569736603989
# 第 429 筆算術錯誤: -17592186044414
# 第 430 筆錯誤資料: 57264412754108692817
# 第 430 筆算術錯誤: 17592186044414
# 第 431 筆錯誤資料: 57264377569736603985
# 第 431 筆算術錯誤: -17592186044418
# 第 432 筆錯誤資料: 57264430346294737237
# 第 432 筆算術錯誤: 35184372088834
# 第 433 筆錯誤資料: 57264359977550559573
# 第 433 筆算術錯誤: -35184372088830
# 第 434 筆錯誤資料: 57264430346294737233
# 第 434 筆算術錯誤: 35184372088830
# 第 435 筆錯誤資料: 57264359977550559569
# 第 435 筆算術錯誤: -35184372088834
# 第 436 筆錯誤資料: 57264465530666826069
# 第 436 筆算術錯誤: 70368744177666
# 第 437 筆錯誤資料: 57264324793178470741
# 第 437 筆算術錯誤: -70368744177662
# 第 438 筆錯誤資料: 57264465530666826065
# 第 438 筆算術錯誤: 70368744177662
# 第 439 筆錯誤資料: 57264324793178470737
# 第 439 筆算術錯誤: -70368744177666
# 第 440 筆錯誤資料: 57264535899411003733
# 第 440 筆算術錯誤: 140737488355330
# 第 441 筆錯誤資料: 57264254424434293077
# 第 441 筆算術錯誤: -140737488355326
# 第 442 筆錯誤資料: 57264535899411003729
# 第 442 筆算術錯誤: 140737488355326
# 第 443 筆錯誤資料: 57264254424434293073
# 第 443 筆算術錯誤: -140737488355330
# 第 444 筆錯誤資料: 57264676636899359061
# 第 444 筆算術錯誤: 281474976710658
# 第 445 筆錯誤資料: 57264113686945937749
# 第 445 筆算術錯誤: -281474976710654
# 第 446 筆錯誤資料: 57264676636899359057
# 第 446 筆算術錯誤: 281474976710654
# 第 447 筆錯誤資料: 57264113686945937745
# 第 447 筆算術錯誤: -281474976710658
# 第 448 筆錯誤資料: 57264958111876069717
# 第 448 筆算術錯誤: 562949953421314
# 第 449 筆錯誤資料: 57263832211969227093
# 第 449 筆算術錯誤: -562949953421310
# 第 450 筆錯誤資料: 57264958111876069713
# 第 450 筆算術錯誤: 562949953421310
# 第 451 筆錯誤資料: 57263832211969227089
# 第 451 筆算術錯誤: -562949953421314
# 第 452 筆錯誤資料: 57265521061829491029
# 第 452 筆算術錯誤: 1125899906842626
# 第 453 筆錯誤資料: 57263269262015805781
# 第 453 筆算術錯誤: -1125899906842622
# 第 454 筆錯誤資料: 57265521061829491025
# 第 454 筆算術錯誤: 1125899906842622
# 第 455 筆錯誤資料: 57263269262015805777
# 第 455 筆算術錯誤: -1125899906842626
# 第 456 筆錯誤資料: 57266646961736333653
# 第 456 筆算術錯誤: 2251799813685250
# 第 457 筆錯誤資料: 57262143362108963157
# 第 457 筆算術錯誤: -2251799813685246
# 第 458 筆錯誤資料: 57266646961736333649
# 第 458 筆算術錯誤: 2251799813685246
# 第 459 筆錯誤資料: 57262143362108963153
# 第 459 筆算術錯誤: -2251799813685250
# 第 460 筆錯誤資料: 57268898761550018901
# 第 460 筆算術錯誤: 4503599627370498
# 第 461 筆錯誤資料: 57259891562295277909
# 第 461 筆算術錯誤: -4503599627370494
# 第 462 筆錯誤資料: 57268898761550018897
# 第 462 筆算術錯誤: 4503599627370494
# 第 463 筆錯誤資料: 57259891562295277905
# 第 463 筆算術錯誤: -4503599627370498
# 第 464 筆錯誤資料: 57273402361177389397
# 第 464 筆算術錯誤: 9007199254740994
# 第 465 筆錯誤資料: 57255387962667907413
# 第 465 筆算術錯誤: -9007199254740990
# 第 466 筆錯誤資料: 57273402361177389393
# 第 466 筆算術錯誤: 9007199254740990
# 第 467 筆錯誤資料: 57255387962667907409
# 第 467 筆算術錯誤: -9007199254740994
# 第 468 筆錯誤資料: 57282409560432130389
# 第 468 筆算術錯誤: 18014398509481986
# 第 469 筆錯誤資料: 57246380763413166421
# 第 469 筆算術錯誤: -18014398509481982
# 第 470 筆錯誤資料: 57282409560432130385
# 第 470 筆算術錯誤: 18014398509481982
# 第 471 筆錯誤資料: 57246380763413166417
# 第 471 筆算術錯誤: -18014398509481986
# 第 472 筆錯誤資料: 57300423958941612373
# 第 472 筆算術錯誤: 36028797018963970
# 第 473 筆錯誤資料: 57228366364903684437
# 第 473 筆算術錯誤: -36028797018963966
# 第 474 筆錯誤資料: 57300423958941612369
# 第 474 筆算術錯誤: 36028797018963966
# 第 475 筆錯誤資料: 57228366364903684433
# 第 475 筆算術錯誤: -36028797018963970
# 第 476 筆錯誤資料: 57336452755960576341
# 第 476 筆算術錯誤: 72057594037927938
# 第 477 筆錯誤資料: 57192337567884720469
# 第 477 筆算術錯誤: -72057594037927934
# 第 478 筆錯誤資料: 57336452755960576337
# 第 478 筆算術錯誤: 72057594037927934
# 第 479 筆錯誤資料: 57192337567884720465
# 第 479 筆算術錯誤: -72057594037927938
# 第 480 筆錯誤資料: 57408510349998504277
# 第 480 筆算術錯誤: 144115188075855874
# 第 481 筆錯誤資料: 57120279973846792533
# 第 481 筆算術錯誤: -144115188075855870
# 第 482 筆錯誤資料: 57408510349998504273
# 第 482 筆算術錯誤: 144115188075855870
# 第 483 筆錯誤資料: 57120279973846792529
# 第 483 筆算術錯誤: -144115188075855874
# 第 484 筆錯誤資料: 57552625538074360149
# 第 484 筆算術錯誤: 288230376151711746
# 第 485 筆錯誤資料: 56976164785770936661
# 第 485 筆算術錯誤: -288230376151711742
# 第 486 筆錯誤資料: 57552625538074360145
# 第 486 筆算術錯誤: 288230376151711742
# 第 487 筆錯誤資料: 56976164785770936657
# 第 487 筆算術錯誤: -288230376151711746
# 第 488 筆錯誤資料: 57840855914226071893
# 第 488 筆算術錯誤: 576460752303423490
# 第 489 筆錯誤資料: 56687934409619224917
# 第 489 筆算術錯誤: -576460752303423486
# 第 490 筆錯誤資料: 57840855914226071889
# 第 490 筆算術錯誤: 576460752303423486
# 第 491 筆錯誤資料: 56687934409619224913
# 第 491 筆算術錯誤: -576460752303423490
# 第 492 筆錯誤資料: 58417316666529495381
# 第 492 筆算術錯誤: 1152921504606846978
# 第 493 筆錯誤資料: 56111473657315801429
# 第 493 筆算術錯誤: -1152921504606846974
# 第 494 筆錯誤資料: 58417316666529495377
# 第 494 筆算術錯誤: 1152921504606846974
# 第 495 筆錯誤資料: 56111473657315801425
# 第 495 筆算術錯誤: -1152921504606846978
# 第 496 筆錯誤資料: 59570238171136342357
# 第 496 筆算術錯誤: 2305843009213693954
# 第 497 筆錯誤資料: 54958552152708954453
# 第 497 筆算術錯誤: -2305843009213693950
# 第 498 筆錯誤資料: 59570238171136342353
# 第 498 筆算術錯誤: 2305843009213693950
# 第 499 筆錯誤資料: 54958552152708954449
# 第 499 筆算術錯誤: -2305843009213693954
# 第 500 筆錯誤資料: 61876081180350036309
# 第 500 筆算術錯誤: 4611686018427387906
# 第 501 筆錯誤資料: 52652709143495260501
# 第 501 筆算術錯誤: -4611686018427387902
# 第 502 筆錯誤資料: 61876081180350036305
# 第 502 筆算術錯誤: 4611686018427387902
# 第 503 筆錯誤資料: 52652709143495260497
# 第 503 筆算術錯誤: -4611686018427387906
# 第 504 筆錯誤資料: 66487767198777424213
# 第 504 筆算術錯誤: 9223372036854775810
# 第 505 筆錯誤資料: 48041023125067872597
# 第 505 筆算術錯誤: -9223372036854775806
# 第 506 筆錯誤資料: 66487767198777424209
# 第 506 筆算術錯誤: 9223372036854775806
# 第 507 筆錯誤資料: 48041023125067872593
# 第 507 筆算術錯誤: -9223372036854775810
# 第 508 筆錯誤資料: 75711139235632200021
# 第 508 筆算術錯誤: 18446744073709551618
# 第 509 筆錯誤資料: 38817651088213096789
# 第 509 筆算術錯誤: -18446744073709551614
# 第 510 筆錯誤資料: 75711139235632200017
# 第 510 筆算術錯誤: 18446744073709551614
# 第 511 筆錯誤資料: 38817651088213096785
# 第 511 筆算術錯誤: -18446744073709551618
# 第 512 筆錯誤資料: 94157883309341751637
# 第 512 筆算術錯誤: 36893488147419103234
# 第 513 筆錯誤資料: 20370907014503545173
# 第 513 筆算術錯誤: -36893488147419103230
# 第 514 筆錯誤資料: 94157883309341751633
# 第 514 筆算術錯誤: 36893488147419103230
# 第 515 筆錯誤資料: 20370907014503545169
# 第 515 筆算術錯誤: -36893488147419103234
# 第 516 筆錯誤資料: 57264395161922648415
# 第 516 筆算術錯誤: 12
# 第 517 筆錯誤資料: 57264395161922648399
# 第 517 筆算術錯誤: -4
# 第 518 筆錯誤資料: 57264395161922648407
# 第 518 筆算術錯誤: 4
# 第 519 筆錯誤資料: 57264395161922648391
# 第 519 筆算術錯誤: -12
# 第 520 筆錯誤資料: 57264395161922648423
# 第 520 筆算術錯誤: 20
# 第 521 筆錯誤資料: 57264395161922648391
# 第 521 筆算術錯誤: -12
# 第 522 筆錯誤資料: 57264395161922648415
# 第 522 筆算術錯誤: 12
# 第 523 筆錯誤資料: 57264395161922648383
# 第 523 筆算術錯誤: -20
# 第 524 筆錯誤資料: 57264395161922648439
# 第 524 筆算術錯誤: 36
# 第 525 筆錯誤資料: 57264395161922648375
# 第 525 筆算術錯誤: -28
# 第 526 筆錯誤資料: 57264395161922648431
# 第 526 筆算術錯誤: 28
# 第 527 筆錯誤資料: 57264395161922648367
# 第 527 筆算術錯誤: -36
# 第 528 筆錯誤資料: 57264395161922648471
# 第 528 筆算術錯誤: 68
# 第 529 筆錯誤資料: 57264395161922648343
# 第 529 筆算術錯誤: -60
# 第 530 筆錯誤資料: 57264395161922648463
# 第 530 筆算術錯誤: 60
# 第 531 筆錯誤資料: 57264395161922648335
# 第 531 筆算術錯誤: -68
# 第 532 筆錯誤資料: 57264395161922648535
# 第 532 筆算術錯誤: 132
# 第 533 筆錯誤資料: 57264395161922648279
# 第 533 筆算術錯誤: -124
# 第 534 筆錯誤資料: 57264395161922648527
# 第 534 筆算術錯誤: 124
# 第 535 筆錯誤資料: 57264395161922648271
# 第 535 筆算術錯誤: -132
# 第 536 筆錯誤資料: 57264395161922648663
# 第 536 筆算術錯誤: 260
# 第 537 筆錯誤資料: 57264395161922648151
# 第 537 筆算術錯誤: -252
# 第 538 筆錯誤資料: 57264395161922648655
# 第 538 筆算術錯誤: 252
# 第 539 筆錯誤資料: 57264395161922648143
# 第 539 筆算術錯誤: -260
# 第 540 筆錯誤資料: 57264395161922648919
# 第 540 筆算術錯誤: 516
# 第 541 筆錯誤資料: 57264395161922647895
# 第 541 筆算術錯誤: -508
# 第 542 筆錯誤資料: 57264395161922648911
# 第 542 筆算術錯誤: 508
# 第 543 筆錯誤資料: 57264395161922647887
# 第 543 筆算術錯誤: -516
# 第 544 筆錯誤資料: 57264395161922649431
# 第 544 筆算術錯誤: 1028
# 第 545 筆錯誤資料: 57264395161922647383
# 第 545 筆算術錯誤: -1020
# 第 546 筆錯誤資料: 57264395161922649423
# 第 546 筆算術錯誤: 1020
# 第 547 筆錯誤資料: 57264395161922647375
# 第 547 筆算術錯誤: -1028
# 第 548 筆錯誤資料: 57264395161922650455
# 第 548 筆算術錯誤: 2052
# 第 549 筆錯誤資料: 57264395161922646359
# 第 549 筆算術錯誤: -2044
# 第 550 筆錯誤資料: 57264395161922650447
# 第 550 筆算術錯誤: 2044
# 第 551 筆錯誤資料: 57264395161922646351
# 第 551 筆算術錯誤: -2052
# 第 552 筆錯誤資料: 57264395161922652503
# 第 552 筆算術錯誤: 4100
# 第 553 筆錯誤資料: 57264395161922644311
# 第 553 筆算術錯誤: -4092
# 第 554 筆錯誤資料: 57264395161922652495
# 第 554 筆算術錯誤: 4092
# 第 555 筆錯誤資料: 57264395161922644303
# 第 555 筆算術錯誤: -4100
# 第 556 筆錯誤資料: 57264395161922656599
# 第 556 筆算術錯誤: 8196
# 第 557 筆錯誤資料: 57264395161922640215
# 第 557 筆算術錯誤: -8188
# 第 558 筆錯誤資料: 57264395161922656591
# 第 558 筆算術錯誤: 8188
# 第 559 筆錯誤資料: 57264395161922640207
# 第 559 筆算術錯誤: -8196
# 第 560 筆錯誤資料: 57264395161922664791
# 第 560 筆算術錯誤: 16388
# 第 561 筆錯誤資料: 57264395161922632023
# 第 561 筆算術錯誤: -16380
# 第 562 筆錯誤資料: 57264395161922664783
# 第 562 筆算術錯誤: 16380
# 第 563 筆錯誤資料: 57264395161922632015
# 第 563 筆算術錯誤: -16388
# 第 564 筆錯誤資料: 57264395161922681175
# 第 564 筆算術錯誤: 32772
# 第 565 筆錯誤資料: 57264395161922615639
# 第 565 筆算術錯誤: -32764
# 第 566 筆錯誤資料: 57264395161922681167
# 第 566 筆算術錯誤: 32764
# 第 567 筆錯誤資料: 57264395161922615631
# 第 567 筆算術錯誤: -32772
# 第 568 筆錯誤資料: 57264395161922713943
# 第 568 筆算術錯誤: 65540
# 第 569 筆錯誤資料: 57264395161922582871
# 第 569 筆算術錯誤: -65532
# 第 570 筆錯誤資料: 57264395161922713935
# 第 570 筆算術錯誤: 65532
# 第 571 筆錯誤資料: 57264395161922582863
# 第 571 筆算術錯誤: -65540
# 第 572 筆錯誤資料: 57264395161922779479
# 第 572 筆算術錯誤: 131076
# 第 573 筆錯誤資料: 57264395161922517335
# 第 573 筆算術錯誤: -131068
# 第 574 筆錯誤資料: 57264395161922779471
# 第 574 筆算術錯誤: 131068
# 第 575 筆錯誤資料: 57264395161922517327
# 第 575 筆算術錯誤: -131076
# 第 576 筆錯誤資料: 57264395161922910551
# 第 576 筆算術錯誤: 262148
# 第 577 筆錯誤資料: 57264395161922386263
# 第 577 筆算術錯誤: -262140
# 第 578 筆錯誤資料: 57264395161922910543
# 第 578 筆算術錯誤: 262140
# 第 579 筆錯誤資料: 57264395161922386255
# 第 579 筆算術錯誤: -262148
# 第 580 筆錯誤資料: 57264395161923172695
# 第 580 筆算術錯誤: 524292
# 第 581 筆錯誤資料: 57264395161922124119
# 第 581 筆算術錯誤: -524284
# 第 582 筆錯誤資料: 57264395161923172687
# 第 582 筆算術錯誤: 524284
# 第 583 筆錯誤資料: 57264395161922124111
# 第 583 筆算術錯誤: -524292
# 第 584 筆錯誤資料: 57264395161923696983
# 第 584 筆算術錯誤: 1048580
# 第 585 筆錯誤資料: 57264395161921599831
# 第 585 筆算術錯誤: -1048572
# 第 586 筆錯誤資料: 57264395161923696975
# 第 586 筆算術錯誤: 1048572
# 第 587 筆錯誤資料: 57264395161921599823
# 第 587 筆算術錯誤: -1048580
# 第 588 筆錯誤資料: 57264395161924745559
# 第 588 筆算術錯誤: 2097156
# 第 589 筆錯誤資料: 57264395161920551255
# 第 589 筆算術錯誤: -2097148
# 第 590 筆錯誤資料: 57264395161924745551
# 第 590 筆算術錯誤: 2097148
# 第 591 筆錯誤資料: 57264395161920551247
# 第 591 筆算術錯誤: -2097156
# 第 592 筆錯誤資料: 57264395161926842711
# 第 592 筆算術錯誤: 4194308
# 第 593 筆錯誤資料: 57264395161918454103
# 第 593 筆算術錯誤: -4194300
# 第 594 筆錯誤資料: 57264395161926842703
# 第 594 筆算術錯誤: 4194300
# 第 595 筆錯誤資料: 57264395161918454095
# 第 595 筆算術錯誤: -4194308
# 第 596 筆錯誤資料: 57264395161931037015
# 第 596 筆算術錯誤: 8388612
# 第 597 筆錯誤資料: 57264395161914259799
# 第 597 筆算術錯誤: -8388604
# 第 598 筆錯誤資料: 57264395161931037007
# 第 598 筆算術錯誤: 8388604
# 第 599 筆錯誤資料: 57264395161914259791
# 第 599 筆算術錯誤: -8388612
# 第 600 筆錯誤資料: 57264395161939425623
# 第 600 筆算術錯誤: 16777220
# 第 601 筆錯誤資料: 57264395161905871191
# 第 601 筆算術錯誤: -16777212
# 第 602 筆錯誤資料: 57264395161939425615
# 第 602 筆算術錯誤: 16777212
# 第 603 筆錯誤資料: 57264395161905871183
# 第 603 筆算術錯誤: -16777220
# 第 604 筆錯誤資料: 57264395161956202839
# 第 604 筆算術錯誤: 33554436
# 第 605 筆錯誤資料: 57264395161889093975
# 第 605 筆算術錯誤: -33554428
# 第 606 筆錯誤資料: 57264395161956202831
# 第 606 筆算術錯誤: 33554428
# 第 607 筆錯誤資料: 57264395161889093967
# 第 607 筆算術錯誤: -33554436
# 第 608 筆錯誤資料: 57264395161989757271
# 第 608 筆算術錯誤: 67108868
# 第 609 筆錯誤資料: 57264395161855539543
# 第 609 筆算術錯誤: -67108860
# 第 610 筆錯誤資料: 57264395161989757263
# 第 610 筆算術錯誤: 67108860
# 第 611 筆錯誤資料: 57264395161855539535
# 第 611 筆算術錯誤: -67108868
# 第 612 筆錯誤資料: 57264395162056866135
# 第 612 筆算術錯誤: 134217732
# 第 613 筆錯誤資料: 57264395161788430679
# 第 613 筆算術錯誤: -134217724
# 第 614 筆錯誤資料: 57264395162056866127
# 第 614 筆算術錯誤: 134217724
# 第 615 筆錯誤資料: 57264395161788430671
# 第 615 筆算術錯誤: -134217732
# 第 616 筆錯誤資料: 57264395162191083863
# 第 616 筆算術錯誤: 268435460
# 第 617 筆錯誤資料: 57264395161654212951
# 第 617 筆算術錯誤: -268435452
# 第 618 筆錯誤資料: 57264395162191083855
# 第 618 筆算術錯誤: 268435452
# 第 619 筆錯誤資料: 57264395161654212943
# 第 619 筆算術錯誤: -268435460
# 第 620 筆錯誤資料: 57264395162459519319
# 第 620 筆算術錯誤: 536870916
# 第 621 筆錯誤資料: 57264395161385777495
# 第 621 筆算術錯誤: -536870908
# 第 622 筆錯誤資料: 57264395162459519311
# 第 622 筆算術錯誤: 536870908
# 第 623 筆錯誤資料: 57264395161385777487
# 第 623 筆算術錯誤: -536870916
# 第 624 筆錯誤資料: 57264395162996390231
# 第 624 筆算術錯誤: 1073741828
# 第 625 筆錯誤資料: 57264395160848906583
# 第 625 筆算術錯誤: -1073741820
# 第 626 筆錯誤資料: 57264395162996390223
# 第 626 筆算術錯誤: 1073741820
# 第 627 筆錯誤資料: 57264395160848906575
# 第 627 筆算術錯誤: -1073741828
# 第 628 筆錯誤資料: 57264395164070132055
# 第 628 筆算術錯誤: 2147483652
# 第 629 筆錯誤資料: 57264395159775164759
# 第 629 筆算術錯誤: -2147483644
# 第 630 筆錯誤資料: 57264395164070132047
# 第 630 筆算術錯誤: 2147483644
# 第 631 筆錯誤資料: 57264395159775164751
# 第 631 筆算術錯誤: -2147483652
# 第 632 筆錯誤資料: 57264395166217615703
# 第 632 筆算術錯誤: 4294967300
# 第 633 筆錯誤資料: 57264395157627681111
# 第 633 筆算術錯誤: -4294967292
# 第 634 筆錯誤資料: 57264395166217615695
# 第 634 筆算術錯誤: 4294967292
# 第 635 筆錯誤資料: 57264395157627681103
# 第 635 筆算術錯誤: -4294967300
# 第 636 筆錯誤資料: 57264395170512582999
# 第 636 筆算術錯誤: 8589934596
# 第 637 筆錯誤資料: 57264395153332713815
# 第 637 筆算術錯誤: -8589934588
# 第 638 筆錯誤資料: 57264395170512582991
# 第 638 筆算術錯誤: 8589934588
# 第 639 筆錯誤資料: 57264395153332713807
# 第 639 筆算術錯誤: -8589934596
# 第 640 筆錯誤資料: 57264395179102517591
# 第 640 筆算術錯誤: 17179869188
# 第 641 筆錯誤資料: 57264395144742779223
# 第 641 筆算術錯誤: -17179869180
# 第 642 筆錯誤資料: 57264395179102517583
# 第 642 筆算術錯誤: 17179869180
# 第 643 筆錯誤資料: 57264395144742779215
# 第 643 筆算術錯誤: -17179869188
# 第 644 筆錯誤資料: 57264395196282386775
# 第 644 筆算術錯誤: 34359738372
# 第 645 筆錯誤資料: 57264395127562910039
# 第 645 筆算術錯誤: -34359738364
# 第 646 筆錯誤資料: 57264395196282386767
# 第 646 筆算術錯誤: 34359738364
# 第 647 筆錯誤資料: 57264395127562910031
# 第 647 筆算術錯誤: -34359738372
# 第 648 筆錯誤資料: 57264395230642125143
# 第 648 筆算術錯誤: 68719476740
# 第 649 筆錯誤資料: 57264395093203171671
# 第 649 筆算術錯誤: -68719476732
# 第 650 筆錯誤資料: 57264395230642125135
# 第 650 筆算術錯誤: 68719476732
# 第 651 筆錯誤資料: 57264395093203171663
# 第 651 筆算術錯誤: -68719476740
# 第 652 筆錯誤資料: 57264395299361601879
# 第 652 筆算術錯誤: 137438953476
# 第 653 筆錯誤資料: 57264395024483694935
# 第 653 筆算術錯誤: -137438953468
# 第 654 筆錯誤資料: 57264395299361601871
# 第 654 筆算術錯誤: 137438953468
# 第 655 筆錯誤資料: 57264395024483694927
# 第 655 筆算術錯誤: -137438953476
# 第 656 筆錯誤資料: 57264395436800555351
# 第 656 筆算術錯誤: 274877906948
# 第 657 筆錯誤資料: 57264394887044741463
# 第 657 筆算術錯誤: -274877906940
# 第 658 筆錯誤資料: 57264395436800555343
# 第 658 筆算術錯誤: 274877906940
# 第 659 筆錯誤資料: 57264394887044741455
# 第 659 筆算術錯誤: -274877906948
# 第 660 筆錯誤資料: 57264395711678462295
# 第 660 筆算術錯誤: 549755813892
# 第 661 筆錯誤資料: 57264394612166834519
# 第 661 筆算術錯誤: -549755813884
# 第 662 筆錯誤資料: 57264395711678462287
# 第 662 筆算術錯誤: 549755813884
# 第 663 筆錯誤資料: 57264394612166834511
# 第 663 筆算術錯誤: -549755813892
# 第 664 筆錯誤資料: 57264396261434276183
# 第 664 筆算術錯誤: 1099511627780
# 第 665 筆錯誤資料: 57264394062411020631
# 第 665 筆算術錯誤: -1099511627772
# 第 666 筆錯誤資料: 57264396261434276175
# 第 666 筆算術錯誤: 1099511627772
# 第 667 筆錯誤資料: 57264394062411020623
# 第 667 筆算術錯誤: -1099511627780
# 第 668 筆錯誤資料: 57264397360945903959
# 第 668 筆算術錯誤: 2199023255556
# 第 669 筆錯誤資料: 57264392962899392855
# 第 669 筆算術錯誤: -2199023255548
# 第 670 筆錯誤資料: 57264397360945903951
# 第 670 筆算術錯誤: 2199023255548
# 第 671 筆錯誤資料: 57264392962899392847
# 第 671 筆算術錯誤: -2199023255556
# 第 672 筆錯誤資料: 57264399559969159511
# 第 672 筆算術錯誤: 4398046511108
# 第 673 筆錯誤資料: 57264390763876137303
# 第 673 筆算術錯誤: -4398046511100
# 第 674 筆錯誤資料: 57264399559969159503
# 第 674 筆算術錯誤: 4398046511100
# 第 675 筆錯誤資料: 57264390763876137295
# 第 675 筆算術錯誤: -4398046511108
# 第 676 筆錯誤資料: 57264403958015670615
# 第 676 筆算術錯誤: 8796093022212
# 第 677 筆錯誤資料: 57264386365829626199
# 第 677 筆算術錯誤: -8796093022204
# 第 678 筆錯誤資料: 57264403958015670607
# 第 678 筆算術錯誤: 8796093022204
# 第 679 筆錯誤資料: 57264386365829626191
# 第 679 筆算術錯誤: -8796093022212
# 第 680 筆錯誤資料: 57264412754108692823
# 第 680 筆算術錯誤: 17592186044420
# 第 681 筆錯誤資料: 57264377569736603991
# 第 681 筆算術錯誤: -17592186044412
# 第 682 筆錯誤資料: 57264412754108692815
# 第 682 筆算術錯誤: 17592186044412
# 第 683 筆錯誤資料: 57264377569736603983
# 第 683 筆算術錯誤: -17592186044420
# 第 684 筆錯誤資料: 57264430346294737239
# 第 684 筆算術錯誤: 35184372088836
# 第 685 筆錯誤資料: 57264359977550559575
# 第 685 筆算術錯誤: -35184372088828
# 第 686 筆錯誤資料: 57264430346294737231
# 第 686 筆算術錯誤: 35184372088828
# 第 687 筆錯誤資料: 57264359977550559567
# 第 687 筆算術錯誤: -35184372088836
# 第 688 筆錯誤資料: 57264465530666826071
# 第 688 筆算術錯誤: 70368744177668
# 第 689 筆錯誤資料: 57264324793178470743
# 第 689 筆算術錯誤: -70368744177660
# 第 690 筆錯誤資料: 57264465530666826063
# 第 690 筆算術錯誤: 70368744177660
# 第 691 筆錯誤資料: 57264324793178470735
# 第 691 筆算術錯誤: -70368744177668
# 第 692 筆錯誤資料: 57264535899411003735
# 第 692 筆算術錯誤: 140737488355332
# 第 693 筆錯誤資料: 57264254424434293079
# 第 693 筆算術錯誤: -140737488355324
# 第 694 筆錯誤資料: 57264535899411003727
# 第 694 筆算術錯誤: 140737488355324
# 第 695 筆錯誤資料: 57264254424434293071
# 第 695 筆算術錯誤: -140737488355332
# 第 696 筆錯誤資料: 57264676636899359063
# 第 696 筆算術錯誤: 281474976710660
# 第 697 筆錯誤資料: 57264113686945937751
# 第 697 筆算術錯誤: -281474976710652
# 第 698 筆錯誤資料: 57264676636899359055
# 第 698 筆算術錯誤: 281474976710652
# 第 699 筆錯誤資料: 57264113686945937743
# 第 699 筆算術錯誤: -281474976710660
# 第 700 筆錯誤資料: 57264958111876069719
# 第 700 筆算術錯誤: 562949953421316
# 第 701 筆錯誤資料: 57263832211969227095
# 第 701 筆算術錯誤: -562949953421308
# 第 702 筆錯誤資料: 57264958111876069711
# 第 702 筆算術錯誤: 562949953421308
# 第 703 筆錯誤資料: 57263832211969227087
# 第 703 筆算術錯誤: -562949953421316
# 第 704 筆錯誤資料: 57265521061829491031
# 第 704 筆算術錯誤: 1125899906842628
# 第 705 筆錯誤資料: 57263269262015805783
# 第 705 筆算術錯誤: -1125899906842620
# 第 706 筆錯誤資料: 57265521061829491023
# 第 706 筆算術錯誤: 1125899906842620
# 第 707 筆錯誤資料: 57263269262015805775
# 第 707 筆算術錯誤: -1125899906842628
# 第 708 筆錯誤資料: 57266646961736333655
# 第 708 筆算術錯誤: 2251799813685252
# 第 709 筆錯誤資料: 57262143362108963159
# 第 709 筆算術錯誤: -2251799813685244
# 第 710 筆錯誤資料: 57266646961736333647
# 第 710 筆算術錯誤: 2251799813685244
# 第 711 筆錯誤資料: 57262143362108963151
# 第 711 筆算術錯誤: -2251799813685252
# 第 712 筆錯誤資料: 57268898761550018903
# 第 712 筆算術錯誤: 4503599627370500
# 第 713 筆錯誤資料: 57259891562295277911
# 第 713 筆算術錯誤: -4503599627370492
# 第 714 筆錯誤資料: 57268898761550018895
# 第 714 筆算術錯誤: 4503599627370492
# 第 715 筆錯誤資料: 57259891562295277903
# 第 715 筆算術錯誤: -4503599627370500
# 第 716 筆錯誤資料: 57273402361177389399
# 第 716 筆算術錯誤: 9007199254740996
# 第 717 筆錯誤資料: 57255387962667907415
# 第 717 筆算術錯誤: -9007199254740988
# 第 718 筆錯誤資料: 57273402361177389391
# 第 718 筆算術錯誤: 9007199254740988
# 第 719 筆錯誤資料: 57255387962667907407
# 第 719 筆算術錯誤: -9007199254740996
# 第 720 筆錯誤資料: 57282409560432130391
# 第 720 筆算術錯誤: 18014398509481988
# 第 721 筆錯誤資料: 57246380763413166423
# 第 721 筆算術錯誤: -18014398509481980
# 第 722 筆錯誤資料: 57282409560432130383
# 第 722 筆算術錯誤: 18014398509481980
# 第 723 筆錯誤資料: 57246380763413166415
# 第 723 筆算術錯誤: -18014398509481988
# 第 724 筆錯誤資料: 57300423958941612375
# 第 724 筆算術錯誤: 36028797018963972
# 第 725 筆錯誤資料: 57228366364903684439
# 第 725 筆算術錯誤: -36028797018963964
# 第 726 筆錯誤資料: 57300423958941612367
# 第 726 筆算術錯誤: 36028797018963964
# 第 727 筆錯誤資料: 57228366364903684431
# 第 727 筆算術錯誤: -36028797018963972
# 第 728 筆錯誤資料: 57336452755960576343
# 第 728 筆算術錯誤: 72057594037927940
# 第 729 筆錯誤資料: 57192337567884720471
# 第 729 筆算術錯誤: -72057594037927932
# 第 730 筆錯誤資料: 57336452755960576335
# 第 730 筆算術錯誤: 72057594037927932
# 第 731 筆錯誤資料: 57192337567884720463
# 第 731 筆算術錯誤: -72057594037927940
# 第 732 筆錯誤資料: 57408510349998504279
# 第 732 筆算術錯誤: 144115188075855876
# 第 733 筆錯誤資料: 57120279973846792535
# 第 733 筆算術錯誤: -144115188075855868
# 第 734 筆錯誤資料: 57408510349998504271
# 第 734 筆算術錯誤: 144115188075855868
# 第 735 筆錯誤資料: 57120279973846792527
# 第 735 筆算術錯誤: -144115188075855876
# 第 736 筆錯誤資料: 57552625538074360151
# 第 736 筆算術錯誤: 288230376151711748
# 第 737 筆錯誤資料: 56976164785770936663
# 第 737 筆算術錯誤: -288230376151711740
# 第 738 筆錯誤資料: 57552625538074360143
# 第 738 筆算術錯誤: 288230376151711740
# 第 739 筆錯誤資料: 56976164785770936655
# 第 739 筆算術錯誤: -288230376151711748
# 第 740 筆錯誤資料: 57840855914226071895
# 第 740 筆算術錯誤: 576460752303423492
# 第 741 筆錯誤資料: 56687934409619224919
# 第 741 筆算術錯誤: -576460752303423484
# 第 742 筆錯誤資料: 57840855914226071887
# 第 742 筆算術錯誤: 576460752303423484
# 第 743 筆錯誤資料: 56687934409619224911
# 第 743 筆算術錯誤: -576460752303423492
# 第 744 筆錯誤資料: 58417316666529495383
# 第 744 筆算術錯誤: 1152921504606846980
# 第 745 筆錯誤資料: 56111473657315801431
# 第 745 筆算術錯誤: -1152921504606846972
# 第 746 筆錯誤資料: 58417316666529495375
# 第 746 筆算術錯誤: 1152921504606846972
# 第 747 筆錯誤資料: 56111473657315801423
# 第 747 筆算術錯誤: -1152921504606846980
# 第 748 筆錯誤資料: 59570238171136342359
# 第 748 筆算術錯誤: 2305843009213693956
# 第 749 筆錯誤資料: 54958552152708954455
# 第 749 筆算術錯誤: -2305843009213693948
# 第 750 筆錯誤資料: 59570238171136342351
# 第 750 筆算術錯誤: 2305843009213693948
# 第 751 筆錯誤資料: 54958552152708954447
# 第 751 筆算術錯誤: -2305843009213693956
# 第 752 筆錯誤資料: 61876081180350036311
# 第 752 筆算術錯誤: 4611686018427387908
# 第 753 筆錯誤資料: 52652709143495260503
# 第 753 筆算術錯誤: -4611686018427387900
# 第 754 筆錯誤資料: 61876081180350036303
# 第 754 筆算術錯誤: 4611686018427387900
# 第 755 筆錯誤資料: 52652709143495260495
# 第 755 筆算術錯誤: -4611686018427387908
# 第 756 筆錯誤資料: 66487767198777424215
# 第 756 筆算術錯誤: 9223372036854775812
# 第 757 筆錯誤資料: 48041023125067872599
# 第 757 筆算術錯誤: -9223372036854775804
# 第 758 筆錯誤資料: 66487767198777424207
# 第 758 筆算術錯誤: 9223372036854775804
# 第 759 筆錯誤資料: 48041023125067872591
# 第 759 筆算術錯誤: -9223372036854775812
# 第 760 筆錯誤資料: 75711139235632200023
# 第 760 筆算術錯誤: 18446744073709551620
# 第 761 筆錯誤資料: 38817651088213096791
# 第 761 筆算術錯誤: -18446744073709551612
# 第 762 筆錯誤資料: 75711139235632200015
# 第 762 筆算術錯誤: 18446744073709551612
# 第 763 筆錯誤資料: 38817651088213096783
# 第 763 筆算術錯誤: -18446744073709551620
# 第 764 筆錯誤資料: 94157883309341751639
# 第 764 筆算術錯誤: 36893488147419103236
# 第 765 筆錯誤資料: 20370907014503545175
# 第 765 筆算術錯誤: -36893488147419103228
# 第 766 筆錯誤資料: 94157883309341751631
# 第 766 筆算術錯誤: 36893488147419103228
# 第 767 筆錯誤資料: 20370907014503545167
# 第 767 筆算術錯誤: -36893488147419103236
# 第 768 筆錯誤資料: 57264395161922648427
# 第 768 筆算術錯誤: 24
# 第 769 筆錯誤資料: 57264395161922648395
# 第 769 筆算術錯誤: -8
# 第 770 筆錯誤資料: 57264395161922648411
# 第 770 筆算術錯誤: 8
# 第 771 筆錯誤資料: 57264395161922648379
# 第 771 筆算術錯誤: -24
# 第 772 筆錯誤資料: 57264395161922648443
# 第 772 筆算術錯誤: 40
# 第 773 筆錯誤資料: 57264395161922648379
# 第 773 筆算術錯誤: -24
# 第 774 筆錯誤資料: 57264395161922648427
# 第 774 筆算術錯誤: 24
# 第 775 筆錯誤資料: 57264395161922648363
# 第 775 筆算術錯誤: -40
# 第 776 筆錯誤資料: 57264395161922648475
# 第 776 筆算術錯誤: 72
# 第 777 筆錯誤資料: 57264395161922648347
# 第 777 筆算術錯誤: -56
# 第 778 筆錯誤資料: 57264395161922648459
# 第 778 筆算術錯誤: 56
# 第 779 筆錯誤資料: 57264395161922648331
# 第 779 筆算術錯誤: -72
# 第 780 筆錯誤資料: 57264395161922648539
# 第 780 筆算術錯誤: 136
# 第 781 筆錯誤資料: 57264395161922648283
# 第 781 筆算術錯誤: -120
# 第 782 筆錯誤資料: 57264395161922648523
# 第 782 筆算術錯誤: 120
# 第 783 筆錯誤資料: 57264395161922648267
# 第 783 筆算術錯誤: -136
# 第 784 筆錯誤資料: 57264395161922648667
# 第 784 筆算術錯誤: 264
# 第 785 筆錯誤資料: 57264395161922648155
# 第 785 筆算術錯誤: -248
# 第 786 筆錯誤資料: 57264395161922648651
# 第 786 筆算術錯誤: 248
# 第 787 筆錯誤資料: 57264395161922648139
# 第 787 筆算術錯誤: -264
# 第 788 筆錯誤資料: 57264395161922648923
# 第 788 筆算術錯誤: 520
# 第 789 筆錯誤資料: 57264395161922647899
# 第 789 筆算術錯誤: -504
# 第 790 筆錯誤資料: 57264395161922648907
# 第 790 筆算術錯誤: 504
# 第 791 筆錯誤資料: 57264395161922647883
# 第 791 筆算術錯誤: -520
# 第 792 筆錯誤資料: 57264395161922649435
# 第 792 筆算術錯誤: 1032
# 第 793 筆錯誤資料: 57264395161922647387
# 第 793 筆算術錯誤: -1016
# 第 794 筆錯誤資料: 57264395161922649419
# 第 794 筆算術錯誤: 1016
# 第 795 筆錯誤資料: 57264395161922647371
# 第 795 筆算術錯誤: -1032
# 第 796 筆錯誤資料: 57264395161922650459
# 第 796 筆算術錯誤: 2056
# 第 797 筆錯誤資料: 57264395161922646363
# 第 797 筆算術錯誤: -2040
# 第 798 筆錯誤資料: 57264395161922650443
# 第 798 筆算術錯誤: 2040
# 第 799 筆錯誤資料: 57264395161922646347
# 第 799 筆算術錯誤: -2056
# 第 800 筆錯誤資料: 57264395161922652507
# 第 800 筆算術錯誤: 4104
# 第 801 筆錯誤資料: 57264395161922644315
# 第 801 筆算術錯誤: -4088
# 第 802 筆錯誤資料: 57264395161922652491
# 第 802 筆算術錯誤: 4088
# 第 803 筆錯誤資料: 57264395161922644299
# 第 803 筆算術錯誤: -4104
# 第 804 筆錯誤資料: 57264395161922656603
# 第 804 筆算術錯誤: 8200
# 第 805 筆錯誤資料: 57264395161922640219
# 第 805 筆算術錯誤: -8184
# 第 806 筆錯誤資料: 57264395161922656587
# 第 806 筆算術錯誤: 8184
# 第 807 筆錯誤資料: 57264395161922640203
# 第 807 筆算術錯誤: -8200
# 第 808 筆錯誤資料: 57264395161922664795
# 第 808 筆算術錯誤: 16392
# 第 809 筆錯誤資料: 57264395161922632027
# 第 809 筆算術錯誤: -16376
# 第 810 筆錯誤資料: 57264395161922664779
# 第 810 筆算術錯誤: 16376
# 第 811 筆錯誤資料: 57264395161922632011
# 第 811 筆算術錯誤: -16392
# 第 812 筆錯誤資料: 57264395161922681179
# 第 812 筆算術錯誤: 32776
# 第 813 筆錯誤資料: 57264395161922615643
# 第 813 筆算術錯誤: -32760
# 第 814 筆錯誤資料: 57264395161922681163
# 第 814 筆算術錯誤: 32760
# 第 815 筆錯誤資料: 57264395161922615627
# 第 815 筆算術錯誤: -32776
# 第 816 筆錯誤資料: 57264395161922713947
# 第 816 筆算術錯誤: 65544
# 第 817 筆錯誤資料: 57264395161922582875
# 第 817 筆算術錯誤: -65528
# 第 818 筆錯誤資料: 57264395161922713931
# 第 818 筆算術錯誤: 65528
# 第 819 筆錯誤資料: 57264395161922582859
# 第 819 筆算術錯誤: -65544
# 第 820 筆錯誤資料: 57264395161922779483
# 第 820 筆算術錯誤: 131080
# 第 821 筆錯誤資料: 57264395161922517339
# 第 821 筆算術錯誤: -131064
# ...
# 第 8527 筆算術錯誤: -5764607523034234880
# 第 8528 筆錯誤資料: 67640688703384271187
# 第 8528 筆算術錯誤: 10376293541461622784
# 第 8529 筆錯誤資料: 49193944629674719571
# 第 8529 筆算術錯誤: -8070450532247928832
# 第 8530 筆錯誤資料: 65334845694170577235
# 第 8530 筆算術錯誤: 8070450532247928832
# 第 8531 筆錯誤資料: 46888101620461025619
# 第 8531 筆算術錯誤: -10376293541461622784
# 第 8532 筆錯誤資料: 76864060740239046995
# 第 8532 筆算術錯誤: 19599665578316398592
# 第 8533 筆錯誤資料: 39970572592819943763
# 第 8533 筆算術錯誤: -17293822569102704640
# 第 8534 筆錯誤資料: 74558217731025353043
# 第 8534 筆算術錯誤: 17293822569102704640
# 第 8535 筆錯誤資料: 37664729583606249811
# 第 8535 筆算術錯誤: -19599665578316398592
# 第 8536 筆錯誤資料: 95310804813948598611
# 第 8536 筆算術錯誤: 38046409652025950208
# 第 8537 筆錯誤資料: 21523828519110392147
# 第 8537 筆算術錯誤: -35740566642812256256
# 第 8538 筆錯誤資料: 93004961804734904659
# 第 8538 筆算術錯誤: 35740566642812256256
# 第 8539 筆錯誤資料: 19217985509896698195
# 第 8539 筆算術錯誤: -38046409652025950208
# 第 8540 筆錯誤資料: 64181924189563730259
# 第 8540 筆算術錯誤: 6917529027641081856
# 第 8541 筆錯誤資料: 54958552152708954451
# 第 8541 筆算術錯誤: -2305843009213693952
# 第 8542 筆錯誤資料: 59570238171136342355
# 第 8542 筆算術錯誤: 2305843009213693952
# 第 8543 筆錯誤資料: 50346866134281566547
# 第 8543 筆算術錯誤: -6917529027641081856
# 第 8544 筆錯誤資料: 68793610207991118163
# 第 8544 筆算術錯誤: 11529215046068469760
# 第 8545 筆錯誤資料: 50346866134281566547
# 第 8545 筆算術錯誤: -6917529027641081856
# 第 8546 筆錯誤資料: 64181924189563730259
# 第 8546 筆算術錯誤: 6917529027641081856
# 第 8547 筆錯誤資料: 45735180115854178643
# 第 8547 筆算術錯誤: -11529215046068469760
# 第 8548 筆錯誤資料: 78016982244845893971
# 第 8548 筆算術錯誤: 20752587082923245568
# 第 8549 筆錯誤資料: 41123494097426790739
# 第 8549 筆算術錯誤: -16140901064495857664
# 第 8550 筆錯誤資料: 73405296226418506067
# 第 8550 筆算術錯誤: 16140901064495857664
# 第 8551 筆錯誤資料: 36511808078999402835
# 第 8551 筆算術錯誤: -20752587082923245568
# 第 8552 筆錯誤資料: 96463726318555445587
# 第 8552 筆算術錯誤: 39199331156632797184
# 第 8553 筆錯誤資料: 22676750023717239123
# 第 8553 筆算術錯誤: -34587645138205409280
# 第 8554 筆錯誤資料: 91852040300128057683
# 第 8554 筆算術錯誤: 34587645138205409280
# 第 8555 筆錯誤資料: 18065064005289851219
# 第 8555 筆算術錯誤: -39199331156632797184
# 第 8556 筆錯誤資料: 71099453217204812115
# 第 8556 筆算術錯誤: 13835058055282163712
# 第 8557 筆錯誤資料: 52652709143495260499
# 第 8557 筆算術錯誤: -4611686018427387904
# 第 8558 筆錯誤資料: 61876081180350036307
# 第 8558 筆算術錯誤: 4611686018427387904
# 第 8559 筆錯誤資料: 43429337106640484691
# 第 8559 筆算術錯誤: -13835058055282163712
# 第 8560 筆錯誤資料: 80322825254059587923
# 第 8560 筆算術錯誤: 23058430092136939520
# 第 8561 筆錯誤資料: 43429337106640484691
# 第 8561 筆算術錯誤: -13835058055282163712
# 第 8562 筆錯誤資料: 71099453217204812115
# 第 8562 筆算術錯誤: 13835058055282163712
# 第 8563 筆錯誤資料: 34205965069785708883
# 第 8563 筆算術錯誤: -23058430092136939520
# 第 8564 筆錯誤資料: 98769569327769139539
# 第 8564 筆算術錯誤: 41505174165846491136
# 第 8565 筆錯誤資料: 24982593032930933075
# 第 8565 筆算術錯誤: -32281802128991715328
# 第 8566 筆錯誤資料: 89546197290914363731
# 第 8566 筆算術錯誤: 32281802128991715328
# 第 8567 筆錯誤資料: 15759220996076157267
# 第 8567 筆算術錯誤: -41505174165846491136
# 第 8568 筆錯誤資料: 84934511272486975827
# 第 8568 筆算術錯誤: 27670116110564327424
# 第 8569 筆錯誤資料: 48041023125067872595
# 第 8569 筆算術錯誤: -9223372036854775808
# 第 8570 筆錯誤資料: 66487767198777424211
# 第 8570 筆算術錯誤: 9223372036854775808
# 第 8571 筆錯誤資料: 29594279051358320979
# 第 8571 筆算術錯誤: -27670116110564327424
# 第 8572 筆錯誤資料: 103381255346196527443
# 第 8572 筆算術錯誤: 46116860184273879040
# 第 8573 筆錯誤資料: 29594279051358320979
# 第 8573 筆算術錯誤: -27670116110564327424
# 第 8574 筆錯誤資料: 84934511272486975827
# 第 8574 筆算術錯誤: 27670116110564327424
# 第 8575 筆錯誤資料: 11147534977648769363
# 第 8575 筆算術錯誤: -46116860184273879040
# 第 8576 筆錯誤資料: 112604627383051303251
# 第 8576 筆算術錯誤: 55340232221128654848
# 第 8577 筆錯誤資料: 38817651088213096787
# 第 8577 筆算術錯誤: -18446744073709551616
# 第 8578 筆錯誤資料: 75711139235632200019
# 第 8578 筆算術錯誤: 18446744073709551616
# 第 8579 筆錯誤資料: 1924162940793993555
# 第 8579 筆算術錯誤: -55340232221128654848
# 錯誤資料對AN取完模數:
#  [4755, 29393, 41712, 22441, 38236, 20703, 37367, 45699, 49865, 1087, 27559, 40795, 47413, 50722, 26946, 15058, 9114, 6142, 4656, 3913, 28972, 16071, 35051, 44541, 49286, 26228, 14699, 34365, 44198, 23684, 13427, 33729, 43880, 23525, 38778, 20974, 12072, 7621, 30826, 16998, 10084, 6627, 30329, 42180, 22675, 38353, 46192, 24681, 39356, 21263, 37647, 45839, 49935, 1122, 2146, 2658, 2914, 3042, 3106, 3138, 3154, 3162, 3166, 3168, 3169, 3170, 3171, 3172, 3174, 3178, 3186, 3202, 3234, 3298, 3426, 3682, 4194, 5218, 7266, 11362, 19554, 35938, 17845, 32520, 11009, 18848, 34526, 15021, 26872, 50574, 47117, 40203, 26375, 49580, 45129, 36227, 18423, 33676, 13321, 23472, 43774, 33517, 13003, 22836, 42502, 30973, 7915, 12660, 22150, 41130, 28229, 2427, 1684, 198, 48087, 42143, 30255, 6479, 9788, 16406, 29642, 5253, 7336, 11502, 19834, 36498, 18965, 34760, 15489, 27808, 40127, 20856, 36651, 19118, 35782, 44114, 48280, 50363, 25974, 39210, 45828, 49137, 25361, 13473, 7529, 4557, 3071, 2328, 27387, 14486, 33466, 42956, 47701, 24643, 13114, 32780, 42613, 22099, 11842, 32144, 42295, 21940, 37193, 19389, 10487, 6036, 29241, 15413, 8499, 5042, 28744, 40595, 21090, 36768, 44607, 23096, 37771, 19678, 36062, 44254, 48350, 50398, 561, 1073, 1329, 1457, 1521, 1553, 1569, 1577, 1581, 1583, 1584, 1585, 1586, 1587, 1589, 1593, 1601, 1617, 1649, 1713, 1841, 2097, 2609, 3633, 5681, 9777, 17969, 34353, 16260, 30935, 9424, 17263, 32941, 13436, 25287, 48989, 45532, 38618, 24790, 47995, 43544, 34642, 16838, 32091, 11736, 21887, 42189, 31932, 11418, 21251, 40917, 29388, 6330, 11075, 20565, 39545, 26644, 842, 99, 49474, 46502, 40558, 28670, 4894, 8203, 14821, 28057, 3668, 5751, 9917, 18249, 34913, 17380, 33175, 13904, 45494, 10428, 43756, 9559, 17891, 22057, 24140, 50612, 12987, 19605, 22914, 49999, 38111, 32167, 29195, 27709, 26966, 1164, 39124, 7243, 16733, 21478, 49281, 37752, 6557, 16390, 46737, 36480, 5921, 16072, 46578, 10970, 44027, 35125, 30674, 3018, 40051, 33137, 29680, 2521, 14372, 45728, 10545, 18384, 47734, 11548, 44316, 9839, 18031, 22127, 24175, 25199, 25711, 25967, 26095, 26159, 26191, 26207, 26215, 26219, 26221, 26222, 26223, 26224, 26225, 26227, 26231, 26239, 26255, 26287, 26351, 26479, 26735, 27247, 28271, 30319, 34415, 42607, 8130, 40898, 4712, 34062, 41901, 6718, 38074, 49925, 22766, 19309, 12395, 49428, 21772, 17321, 8419, 41476, 5868, 36374, 46525, 15966, 5709, 36056, 45889, 14694, 3165, 30968, 35713, 45203, 13322, 421, 25480, 24737, 23251, 20279, 14335, 2447, 29532, 32841, 39459, 1834, 28306, 30389, 34555, 42887, 8690, 42018, 6952, 22747, 5214, 21878, 30210, 34376, 36459, 12070, 25306, 31924, 35233, 11457, 50430, 44486, 41514, 40028, 39285, 13483, 582, 19562, 29052, 33797, 10739, 50071, 18876, 28709, 8195, 48799, 18240, 28391, 8036, 23289, 5485, 47444, 42993, 15337, 1509, 45456, 41999, 14840, 26691, 7186, 22864, 30703, 9192, 23867, 5774, 22158, 30350, 34446, 36494, 37518, 38030, 38286, 38414, 38478, 38510, 38526, 38534, 38538, 38540, 38541, 38542, 38543, 38544, 38546, 38550, 38558, 38574, 38606, 38670, 38798, 39054, 39566, 40590, 42638, 46734, 4065, 20449, 2356, 17031, 46381, 3359, 19037, 50393, 11383, 35085, 31628, 24714, 10886, 34091, 29640, 20738, 2934, 18187, 48693, 7983, 28285, 18028, 48375, 7347, 27013, 15484, 43287, 48032, 6661, 25641, 12740, 37799, 37056, 35570, 32598, 26654, 14766, 41851, 45160, 917, 14153, 40625, 42708, 46874, 4345, 21009, 3476, 36804, 2607, 10939, 15105, 17188, 43660, 6035, 12653, 15962, 43047, 31159, 25215, 22243, 20757, 20014, 45073, 32172, 291, 9781, 14526, 42329, 30800, 50466, 9438, 39785, 29528, 49830, 9120, 39626, 4018, 37075, 28173, 23722, 46927, 33099, 26185, 22728, 46430, 7420, 38776, 3593, 11432, 40782, 4596, 37364, 2887, 11079, 15175, 17223, 18247, 18759, 19015, 19143, 19207, 19239, 19255, 19263, 19267, 19269, 19270, 19271, 19272, 19273, 19275, 19279, 19287, 19303, 19335, 19399, 19527, 19783, 20295, 21319, 23367, 27463, 35655, 1178, 33946, 48621, 27110, 34949, 50627, 31122, 42973, 15814, 12357, 5443, ...
# Barret reduction對錯誤資料取完模數:
#  [4755, 29393, 41712, 22441, 38236, 20703, 37367, 45699, 49865, 1087, 27559, 40795, 47413, 50722, 26946, 15058, 9114, 6142, 4656, 3913, 28972, 16071, 35051, 44541, 49286, 26228, 14699, 34365, 44198, 23684, 13427, 33729, 43880, 23525, 38778, 20974, 12072, 7621, 30826, 16998, 10084, 6627, 30329, 42180, 22675, 38353, 46192, 24681, 39356, 21263, 37647, 45839, 49935, 1122, 2146, 2658, 2914, 3042, 3106, 3138, 3154, 3162, 3166, 3168, 3169, 3170, 3171, 3172, 3174, 3178, 3186, 3202, 3234, 3298, 3426, 3682, 4194, 5218, 7266, 11362, 19554, 35938, 17845, 32520, 11009, 18848, 34526, 15021, 26872, 50574, 47117, 40203, 26375, 49580, 45129, 36227, 18423, 33676, 13321, 23472, 43774, 33517, 13003, 22836, 42502, 30973, 7915, 12660, 22150, 41130, 28229, 2427, 1684, 198, 48087, 42143, 30255, 6479, 9788, 16406, 29642, 5253, 7336, 11502, 19834, 36498, 18965, 34760, 15489, 27808, 40127, 20856, 36651, 19118, 35782, 44114, 48280, 50363, 25974, 39210, 45828, 49137, 25361, 13473, 7529, 4557, 3071, 2328, 27387, 14486, 33466, 42956, 47701, 24643, 13114, 32780, 42613, 22099, 11842, 32144, 42295, 21940, 37193, 19389, 10487, 6036, 29241, 15413, 8499, 5042, 28744, 40595, 21090, 36768, 44607, 23096, 37771, 19678, 36062, 44254, 48350, 50398, 561, 1073, 1329, 1457, 1521, 1553, 1569, 1577, 1581, 1583, 1584, 1585, 1586, 1587, 1589, 1593, 1601, 1617, 1649, 1713, 1841, 2097, 2609, 3633, 5681, 9777, 17969, 34353, 16260, 30935, 9424, 17263, 32941, 13436, 25287, 48989, 45532, 38618, 24790, 47995, 43544, 34642, 16838, 32091, 11736, 21887, 42189, 31932, 11418, 21251, 40917, 29388, 6330, 11075, 20565, 39545, 26644, 842, 99, 49474, 46502, 40558, 28670, 4894, 8203, 14821, 28057, 3668, 5751, 9917, 18249, 34913, 17380, 33175, 13904, 45494, 10428, 43756, 9559, 17891, 22057, 24140, 50612, 12987, 19605, 22914, 49999, 38111, 32167, 29195, 27709, 26966, 1164, 39124, 7243, 16733, 21478, 49281, 37752, 6557, 16390, 46737, 36480, 5921, 16072, 46578, 10970, 44027, 35125, 30674, 3018, 40051, 33137, 29680, 2521, 14372, 45728, 10545, 18384, 47734, 11548, 44316, 9839, 18031, 22127, 24175, 25199, 25711, 25967, 26095, 26159, 26191, 26207, 26215, 26219, 26221, 26222, 26223, 26224, 26225, 26227, 26231, 26239, 26255, 26287, 26351, 26479, 26735, 27247, 28271, 30319, 34415, 42607, 8130, 40898, 4712, 34062, 41901, 6718, 38074, 49925, 22766, 19309, 12395, 49428, 21772, 17321, 8419, 41476, 5868, 36374, 46525, 15966, 5709, 36056, 45889, 14694, 3165, 30968, 35713, 45203, 13322, 421, 25480, 24737, 23251, 20279, 14335, 2447, 29532, 32841, 39459, 1834, 28306, 30389, 34555, 42887, 8690, 42018, 6952, 22747, 5214, 21878, 30210, 34376, 36459, 12070, 25306, 31924, 35233, 11457, 50430, 44486, 41514, 40028, 39285, 13483, 582, 19562, 29052, 33797, 10739, 50071, 18876, 28709, 8195, 48799, 18240, 28391, 8036, 23289, 5485, 47444, 42993, 15337, 1509, 45456, 41999, 14840, 26691, 7186, 22864, 30703, 9192, 23867, 5774, 22158, 30350, 34446, 36494, 37518, 38030, 38286, 38414, 38478, 38510, 38526, 38534, 38538, 38540, 38541, 38542, 38543, 38544, 38546, 38550, 38558, 38574, 38606, 38670, 38798, 39054, 39566, 40590, 42638, 46734, 4065, 20449, 2356, 17031, 46381, 3359, 19037, 50393, 11383, 35085, 31628, 24714, 10886, 34091, 29640, 20738, 2934, 18187, 48693, 7983, 28285, 18028, 48375, 7347, 27013, 15484, 43287, 48032, 6661, 25641, 12740, 37799, 37056, 35570, 32598, 26654, 14766, 41851, 45160, 917, 14153, 40625, 42708, 46874, 4345, 21009, 3476, 36804, 2607, 10939, 15105, 17188, 43660, 6035, 12653, 15962, 43047, 31159, 25215, 22243, 20757, 20014, 45073, 32172, 291, 9781, 14526, 42329, 30800, 50466, 9438, 39785, 29528, 49830, 9120, 39626, 4018, 37075, 28173, 23722, 46927, 33099, 26185, 22728, 46430, 7420, 38776, 3593, 11432, 40782, 4596, 37364, 2887, 11079, 15175, 17223, 18247, 18759, 19015, 19143, 19207, 19239, 19255, 19263, 19267, 19269, 19270, 19271, 19272, 19273, 19275, 19279, 19287, 19303, 19335, 19399, 19527, 19783, 20295, 21319, 23367, 27463, 35655, 1178, 33946, 48621, 27110, 34949, 50627, 31122, 42973, 15814, 12357, 5443, ...
# Barret reduction是否可以使用: True
# 所有餘數(一般mod函數)是否完全相異: True
# 所有餘數(Barret reduction)是否完全相異: True
# 所有的AWE:
#  [-55340232221128654848, -46116860184273879040, -41505174165846491136, -39199331156632797184, -38046409652025950208, -37469948899722526720, -37181718523570814976, -37037603335494959104, -36965545741457031168, -36929516944438067200, -36911502545928585216, -36902495346673844224, -36897991747046473728, -36895739947232788480, -36894614047325945856, -36894051097372524544, -36893769622395813888, -36893628884907458560, -36893558516163280896, -36893523331791192064, -36893505739605147648, -36893496943512125440, -36893492545465614336, -36893490346442358784, -36893489246930731008, -36893488697174917120, -36893488422297010176, -36893488284858056704, -36893488216138579968, -36893488181778841600, -36893488164598972416, -36893488156009037824, -36893488151714070528, -36893488149566586880, -36893488148492845056, -36893488147955974144, -36893488147687538688, -36893488147553320960, -36893488147486212096, -36893488147452657664, -36893488147435880448, -36893488147427491840, -36893488147423297536, -36893488147421200384, -36893488147420151808, -36893488147419627520, -36893488147419365376, -36893488147419234304, -36893488147419168768, -36893488147419136000, -36893488147419119616, -36893488147419111424, -36893488147419107328, -36893488147419105280, -36893488147419104256, -36893488147419103744, -36893488147419103488, -36893488147419103360, -36893488147419103296, -36893488147419103264, -36893488147419103248, -36893488147419103240, -36893488147419103236, -36893488147419103234, -36893488147419103233, -36893488147419103232, -36893488147419103231, -36893488147419103230, -36893488147419103228, -36893488147419103224, -36893488147419103216, -36893488147419103200, -36893488147419103168, -36893488147419103104, -36893488147419102976, -36893488147419102720, -36893488147419102208, -36893488147419101184, -36893488147419099136, -36893488147419095040, -36893488147419086848, -36893488147419070464, -36893488147419037696, -36893488147418972160, -36893488147418841088, -36893488147418578944, -36893488147418054656, -36893488147417006080, -36893488147414908928, -36893488147410714624, -36893488147402326016, -36893488147385548800, -36893488147351994368, -36893488147284885504, -36893488147150667776, -36893488146882232320, -36893488146345361408, -36893488145271619584, -36893488143124135936, -36893488138829168640, -36893488130239234048, -36893488113059364864, -36893488078699626496, -36893488009980149760, -36893487872541196288, -36893487597663289344, -36893487047907475456, -36893485948395847680, -36893483749372592128, -36893479351326081024, -36893470555233058816, -36893452963047014400, -36893417778674925568, -36893347409930747904, -36893206672442392576, -36892925197465681920, -36892362247512260608, -36891236347605417984, -36888984547791732736, -36884480948164362240, -36875473748909621248, -36857459350400139264, -36821430553381175296, -36749372959343247360, -36605257771267391488, -36317027395115679744, -35740566642812256256, -34587645138205409280, -32281802128991715328, -27670116110564327424, -23058430092136939520, -20752587082923245568, -19599665578316398592, -19023204826012975104, -18734974449861263360, -18590859261785407488, -18518801667747479552, -18482772870728515584, -18464758472219033600, -18455751272964292608, -18451247673336922112, -18448995873523236864, -18447869973616394240, -18447307023662972928, -18447025548686262272, -18446884811197906944, -18446814442453729280, -18446779258081640448, -18446761665895596032, -18446752869802573824, -18446748471756062720, -18446746272732807168, -18446745173221179392, -18446744623465365504, -18446744348587458560, -18446744211148505088, -18446744142429028352, -18446744108069289984, -18446744090889420800, -18446744082299486208, -18446744078004518912, -18446744075857035264, -18446744074783293440, -18446744074246422528, -18446744073977987072, -18446744073843769344, -18446744073776660480, -18446744073743106048, -18446744073726328832, -18446744073717940224, -18446744073713745920, -18446744073711648768, -18446744073710600192, -184467440737100759 ...
# 8454
# 輸入餘數 4755, 對應算術錯誤: -55340232221128654848
# 輸入餘數 29393, 對應算術錯誤: -46116860184273879040
# 57264395161922648403
# 57264395161922648403
# 更正是否正確: True

# %% [markdown]
# #### DEC_ANcode (LUT):

# %%
DEC_A = 50861
Range_Max_number = 1125899906842623
DEC_Range_Max_number = 1125899906842623 * DEC_A
DEC_A_bits = math.floor(math.log2(DEC_Range_Max_number)) + 1
print(DEC_A_bits)
# Out:
# 66

# %%
def simulate_adder_noise(A, B, sigma, threshold=0.42):
    """
    模擬 Ripple-Carry-Adder,計算 A + B
    - A, B: bits位數值
    - sigma: 高斯白雜訊的標準差
    - threshold: 當雜訊超過此值，翻轉該位元
    回傳值: 最終結果 (包含可能的溢位)
    """
    carry_in = 0
    
    result_bits = []
    
    for i in range(DEC_A_bits):
        a_bit = (A >> i) & 1
        b_bit = (B >> i) & 1
        
        #### 所有1-bit加法器邏輯閘, 以及模擬雜訊 ####
        XOR_AB = a_bit ^ b_bit
        ### 引入高斯白雜訊
        noise_XOR_AB = truncated_normal_sample(mean=0.2, std=sigma, low=0, high=1)
        # 如果雜訊絕對值超過 threshold，翻轉該位
        if abs(noise_XOR_AB) > threshold:
            XOR_AB = XOR_AB ^ 1            #翻轉 XOR_AB
        
        sum_out = XOR_AB ^ carry_in
        noise_sum = truncated_normal_sample(mean=0.2, std=sigma, low=0, high=1)
        if abs(noise_sum) > threshold:
            sum_out = sum_out ^ 1           #翻轉 sum_out
            
        AND_AB = a_bit & b_bit
        noise_AND_AB = truncated_normal_sample(mean=0.2, std=sigma, low=0, high=1)
        if abs(noise_AND_AB) > threshold:
            AND_AB = AND_AB ^ 1             #翻轉 AND_AB
        
        AND_Cin = XOR_AB & carry_in
        noise_AND_Cin = truncated_normal_sample(mean=0.2, std=sigma, low=0, high=1)
        if abs(noise_AND_Cin) > threshold:
            AND_Cin = AND_Cin ^ 1           #翻轉 AND_Cin
            
        carry_out = AND_AB | AND_Cin
        noise_carry = truncated_normal_sample(mean=0.2, std=sigma, low=0, high=1)
        if abs(noise_carry) > threshold:
            carry_out = carry_out ^ 1       #翻轉 carry_out
        
        result_bits.append(sum_out)
        carry_in = carry_out                #傳遞到下一個位元
    
    # 第5位 (溢位)
    result_bits.append(carry_in)
        
    # 將 result_bits (list) 組合成整數
    final_result = 0
    for i, bit_val in enumerate(result_bits):
        final_result |= (bit_val << i)
    
    return final_result

def noise_simulation(trials=100000, sigma=0.2, threshold=0.42):
        
    error_count = 0
    for _ in range(trials):
        A = random.randint(0, Range_Max_number)  # 隨機整數 A
        B = random.randint(0, Range_Max_number)  # 隨機整數 B
        correct_result = A + B                   # 正確答案
        DEC_AN_A = A * DEC_A
        DEC_AN_B = B * DEC_A
        result_withA = simulate_adder_noise(DEC_AN_A, DEC_AN_B, sigma, threshold)
        result_dividebyA = result_withA // DEC_A
        if result_dividebyA != correct_result:
            r,q = Barret_q_50861(result_withA)
            ### using LUT to recover it 
            RAW_DATA = int(result_withA) - int(remainder_to_AWE[r])
            corrected_r, corrected_value = Barret_q_50861(RAW_DATA)
            if corrected_value != correct_result:
                error_count += 1
    
    DEC_error_rate = error_count / trials
    return DEC_error_rate

if __name__ == "__main__":
    # 參數設定
    DEC_AN_list = []
    trials = 250000                            # 模擬次數
    EbNodB_range = range(12,23)
    itr = len(EbNodB_range)
    threshold = 0.42                             # 當雜訊超過此值時翻轉
    
    for n in range (0, itr): 
        EbNodB = EbNodB_range[n]   
        EbNo=10.0**(EbNodB/10.0)
        noise_std = 1/sqrt(2*EbNo)
        DEC_error_rate = noise_simulation(trials=trials, sigma=noise_std, threshold=threshold)
        DEC_AN_list.append(DEC_error_rate)
        print(f"SNR={EbNodB}, Noise_std={noise_std}, Error Rate={DEC_error_rate:.6f}")
# Out:
# SNR=12, Noise_std=0.17761719292909026, Error Rate=1.000000
# SNR=13, Noise_std=0.15830148982673414, Error Rate=1.000000
# SNR=14, Noise_std=0.1410863513160464, Error Rate=1.000000
# SNR=15, Noise_std=0.12574334296829354, Error Rate=0.999320
# SNR=16, Noise_std=0.11206887238456492, Error Rate=0.975396
# SNR=17, Noise_std=0.09988148764833452, Error Rate=0.764520
# SNR=18, Noise_std=0.08901946956877224, Error Rate=0.316496
# SNR=19, Noise_std=0.07933868576533668, Error Rate=0.053624
# SNR=20, Noise_std=0.07071067811865475, Error Rate=0.005140
# SNR=21, Noise_std=0.06302095820932435, Error Rate=0.000664
# SNR=22, Noise_std=0.05616748812614789, Error Rate=0.000104

# %%
print(DEC_AN_list)
# Out:
# [1.0, 1.0, 1.0, 0.99932, 0.975396, 0.76452, 0.316496, 0.053624, 0.00514, 0.000664, 0.000104]

# %%
import matplotlib.pyplot as plt

SEC_RER = plt.plot(EbNodB_range, SEC_AN_list,marker='o',linestyle='-.',color='#DC143C',markersize=4,label="SEC_RER(A=131)")
DEC_RER = plt.plot(EbNodB_range, DEC_AN_list,marker='D', linestyle='--',color='#0000FF',markersize=4,label="DEC_RER(A=50861)")
Uncode_RER=plt.plot(EbNodB_range, uncode_list,color='#008000',marker='v', linestyle='-',markersize=6,label="Uncode RER")


plt.legend()
plt.axis([12, 23, 1e-6, 1])
plt.xscale('linear')
plt.yscale('log')
plt.xlabel('EbNo(dB)')
plt.ylabel('RER')
plt.grid(True)
plt.title('Adder in 50-bits: SEC v.s. DEC v.s Uncode')
plt.savefig("Adder in 50bits SEC vs DEC vs Uncode(21dB)")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 生成常態分佈數據
data = np.random.normal(0, 0.1, 10000)  # 生成10000個point

# 繪製直方圖
plt.hist(data, bins=50, density=True, alpha=0.8, color='blue', edgecolor='black')


plt.title('Histogram of np.random.normal')
plt.xlabel('Value')
plt.ylabel('Density')


plt.show()
