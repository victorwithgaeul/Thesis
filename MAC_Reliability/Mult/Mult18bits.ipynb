# %% [markdown]
# ## 分析加法,乘法運算時底層硬體電路受到白雜訊 (SNR) 干擾發生的錯誤

# %% [markdown]
# * AER (Arithmetic Error Rate): 1bit 發生加錯或減錯的機率 (like BER)
# * CER (Carry Error Rate): Carry(進位) 受到影響而發生錯誤的機率
# * RER (Register Error Rate): 整個資料的發生錯誤的機率 (like BLER)

# %% [markdown]
# #### 乘法: 以 --> Array Multipiler 模擬

# %%
import numpy as np
from numpy.random import rand, randn, randint
import random
import scipy
from scipy.stats import truncnorm
import math
from numpy import sqrt

a, b = 0, 1  # 範圍限制在 0 ~ 1
mean = 0.5   # 平均值
std = 0.1    # 標准差
data = truncnorm.rvs((a - mean) / std, (b - mean) / std, loc=mean, scale=std, size=1).item()
print(data) 
print(np.random.normal(0, 0.2))
# Out:
# 0.5190485801725558
# 0.3217715407143777

# %%
Range_Max_number = (1 << 18) - 1                         # n-bit最大值
bits = math.floor(math.log2(Range_Max_number)) + 1      # bits = 

def simulate_adder_noise(A, B, width, sigma, threshold=0.22):
    carry_in = 0
    result_bits = []

    for i in range(width):
        a_bit = (A >> i) & 1
        b_bit = (B >> i) & 1

        # XOR(a, b)
        XOR_AB = a_bit ^ b_bit
        if abs(np.random.normal(0, sigma)) > threshold:
            XOR_AB ^= 1

        # sum = XOR_AB ^ carry_in
        sum_out = XOR_AB ^ carry_in
        if abs(np.random.normal(0, sigma)) > threshold:
            sum_out ^= 1

        # AND(a, b)
        AND_AB = a_bit & b_bit
        if abs(np.random.normal(0, sigma)) > threshold:
            AND_AB ^= 1

        # AND(XOR_AB, carry_in)
        AND_Cin = XOR_AB & carry_in
        if abs(np.random.normal(0, sigma)) > threshold:
            AND_Cin ^= 1

        # OR(AND_AB, AND_Cin)
        carry_out = AND_AB | AND_Cin
        if abs(np.random.normal(0, sigma)) > threshold:
            carry_out ^= 1

        result_bits.append(sum_out)
        carry_in = carry_out

    result_bits.append(carry_in)

    final_result = 0
    for i, bit in enumerate(result_bits):
        final_result |= (bit << i)

    return final_result

def simulate_array_multiplier_noise(A, B, sigma, threshold=0.22):
    """
    模擬具雜訊的 Array Multiplier（Shift-Add 實作 + 加上 AND 雜訊）
    - A, B: 18-bit 整數
    - sigma: 高斯白雜訊標準差
    - threshold: 閘門輸出被翻轉的雜訊門檻
    回傳值: 加上雜訊後的乘積
    """
    product = 0
    
    for i in range(bits):               # 對 B 的每一個位元 i
        partial = 0                     # 初始化此層的 partial product
        b_bit = (B >> i) & 1            # 搬到外層，B[i] 固定，只算一次
        
        for j in range(bits):  # 對 A 的每個位元 j
            a_bit = (A >> j) & 1
            
            # AND gate 模擬部分積：pp[i][j] = A[j] & B[i]
            AND_result = a_bit & b_bit
            
            # 加入雜訊 (noise)
            noise_AND = np.random.normal(0, sigma)
            if abs(noise_AND) > threshold:
                AND_result ^= 1  # 翻轉此位元
            
            # 將 and_result 放到對應的位移上（i + j）
            partial |= (AND_result << (i + j))
        
        # 將此層 partial product 累加進總乘積
        product = simulate_adder_noise(product, partial, width=2*bits, sigma=sigma, threshold=threshold)
    
    return product

def noise_simulation(trials=1000, sigma=0.22, threshold=0.22):
    error_count = 0
    for _ in range(trials):
        A = random.randint(0, Range_Max_number)
        B = random.randint(0, Range_Max_number)
        correct_result = A * B
        result = simulate_array_multiplier_noise(A, B, sigma, threshold)
        if result != correct_result:
            error_count += 1
    return error_count / trials

if __name__ == "__main__":
    trials = 20000                              
    EbNodB_range = range(17, 24)
    threshold = 0.22
    uncode_list = []

    for EbNodB in EbNodB_range:
        EbNo = 10.0**(EbNodB / 10.0)
        noise_std = 1 / sqrt(2 * EbNo)
        err_rate = noise_simulation(trials=trials, sigma=noise_std, threshold=threshold)
        uncode_list.append(err_rate)
        print(f"SNR={EbNodB} dB, Noise Std={noise_std:.5f}, Error Rate={err_rate:.5f}")
# Out:
# SNR=17 dB, Noise Std=0.09988, Error Rate=1.00000
# SNR=18 dB, Noise Std=0.08902, Error Rate=1.00000
# SNR=19 dB, Noise Std=0.07934, Error Rate=1.00000
# SNR=20 dB, Noise Std=0.07071, Error Rate=0.99790
# SNR=21 dB, Noise Std=0.06302, Error Rate=0.80845
# SNR=22 dB, Noise Std=0.05617, Error Rate=0.26470
# SNR=23 dB, Noise Std=0.05006, Error Rate=0.03535

# %%
print(uncode_list)
# Out:
# [1.0, 1.0, 1.0, 0.9979, 0.80845, 0.2647, 0.03535]

# %% [markdown]
# #### Single AWE ANcode Decoder(A=101)

# %%
def A101_AN_decoder(residue):
    msg = {  
        1: +2**0,
        2: +2**1,
        4: +2**2,
        8: +2**3,
        16: +2**4,
        32: +2**5,
        64: +2**6,
        27: +2**7,
        54: +2**8,
        7: +2**9,
        14: +2**10,
        28: +2**11,
        56: +2**12,
        11: +2**13,
        22: +2**14,
        44: +2**15,
        88: +2**16,
        75: +2**17,
        49: +2**18,
        98: +2**19,
        95: +2**20,
        89: +2**21,
        77: +2**22,
        53: +2**23,
        5: +2**24,
        10: +2**25,
        20: +2**26,
        40: +2**27,
        80: +2**28,
        59: +2**29,
        17: +2**30,
        34: +2**31,
        68: +2**32,
        35: +2**33,
        70: +2**34,
        39: +2**35,
        78: +2**36,
        55: +2**37,
        9: +2**38,
        18: +2**39,
        36: +2**40,
        72: +2**41,
        43: +2**42,
        86: +2**43,
        71: +2**44,
        41: +2**45,
        82: +2**46,
        63: +2**47,
        25: +2**48,
        50: +2**49,
        100: -2**0,
        99: -2**1,
        97: -2**2,
        93: -2**3,
        85: -2**4,
        69: -2**5,
        37: -2**6,
        74: -2**7,
        47: -2**8,
        94: -2**9,
        87: -2**10,
        73: -2**11,
        45: -2**12,
        90: -2**13,
        79: -2**14,
        57: -2**15,
        13: -2**16,
        26: -2**17,
        52: -2**18,
        3: -2**19,
        6: -2**20,
        12: -2**21,
        24: -2**22,
        48: -2**23,
        96: -2**24,
        91: -2**25,
        81: -2**26,
        61: -2**27,
        21: -2**28,
        42: -2**29,
        84: -2**30,
        67: -2**31,
        33: -2**32,
        66: -2**33,
        31: -2**34,
        62: -2**35,
        23: -2**36,
        46: -2**37,
        92: -2**38,
        83: -2**39,
        65: -2**40,
        29: -2**41,
        58: -2**42,
        15: -2**43,
        30: -2**44,
        60: -2**45,
        19: -2**46,
        38: -2**47,
        76: -2**48,
        51: -2**49,
        0: 0,
    }
    return msg.get(residue, 0)  # 預設為 0，避免 None



def Barret_q_101(x):
    q = (int(x) * 87090029922) >> 43      ## (2^43)//101後, 右移43次         
    r = x - q * 101
    if r < 101:
        return (r,q)
    else:
        return (r - 101, q + 1)

# %% [markdown]
# #### Conventional SEC_ANcode:

# %%
SEC_A = 101
Range_Max_number = 262143
SEC_Range_Max_number = 262143 * SEC_A
SEC_A_bits = math.floor(math.log2(SEC_Range_Max_number)) + 1
bits = math.floor(math.log2(Range_Max_number)) + 1      
print(bits)
print(SEC_A_bits)
# Out:
# 18
# 25

# %%
def simulate_adder_noise(A, B, width, sigma, threshold=0.22):
    carry_in = 0
    result_bits = []

    for i in range(width):
        a_bit = (A >> i) & 1
        b_bit = (B >> i) & 1

        # XOR(a, b)
        XOR_AB = a_bit ^ b_bit
        if abs(np.random.normal(0, sigma)) > threshold:
            XOR_AB ^= 1

        # sum = XOR_AB ^ carry_in
        sum_out = XOR_AB ^ carry_in
        if abs(np.random.normal(0, sigma)) > threshold:
            sum_out ^= 1

        # AND(a, b)
        AND_AB = a_bit & b_bit
        if abs(np.random.normal(0, sigma)) > threshold:
            AND_AB ^= 1

        # AND(XOR_AB, carry_in)
        AND_Cin = XOR_AB & carry_in
        if abs(np.random.normal(0, sigma)) > threshold:
            AND_Cin ^= 1

        # OR(AND_AB, AND_Cin)
        carry_out = AND_AB | AND_Cin
        if abs(np.random.normal(0, sigma)) > threshold:
            carry_out ^= 1

        result_bits.append(sum_out)
        carry_in = carry_out

    result_bits.append(carry_in)

    final_result = 0
    for i, bit in enumerate(result_bits):
        final_result |= (bit << i)

    return final_result

def simulate_array_multiplier_noise(A, B, sigma, threshold=0.22):
    """
    模擬具雜訊的 Array Multiplier（Shift-Add 實作 + 加上 AND 雜訊）
    - A, B: 18-bit 整數
    - sigma: 高斯白雜訊標準差
    - threshold: 閘門輸出被翻轉的雜訊門檻
    回傳值: 加上雜訊後的乘積
    """
    product = 0
    
    for i in range(bits):               # 對 B 的每一個位元 i
        partial = 0                     # 初始化此層的 partial product
        b_bit = (B >> i) & 1            # 搬到外層，B[i] 固定，只算一次
        
        for j in range(SEC_A_bits):           # 對 A 的每個位元 j
            a_bit = (A >> j) & 1
            
            # AND gate 模擬部分積：pp[i][j] = A[j] & B[i]
            AND_result = a_bit & b_bit
            
            # 加入雜訊 (noise)
            noise_AND = np.random.normal(0, sigma)
            if abs(noise_AND) > threshold:
                AND_result ^= 1  # 翻轉此位元
            
            # 將 AND_result 放到對應的位移上（i + j）
            partial |= (AND_result << (i + j))
        
        # 將此層 partial product 累加進總乘積
        product = simulate_adder_noise(product, partial, width=(bits + SEC_A_bits), sigma=sigma, threshold=threshold)
    
    return product

def noise_simulation(trials=1000, sigma=0.22, threshold=0.22):                   
        
    SEC_error_count = 0
    for _ in range(trials):
        A = random.randint(0, Range_Max_number)
        B = random.randint(0, Range_Max_number)
        correct_result = A * B
        SEC_AN_A = A * SEC_A
        SEC_AN_B = B
        result_withA = simulate_array_multiplier_noise(SEC_AN_A, SEC_AN_B, sigma, threshold)
        result_dividebyA = result_withA // SEC_A
        if result_dividebyA != correct_result:
            ### r = result_withA % SEC_A
            ### q = result_withA // SEC_A
            r,q = Barret_q_101(result_withA)
            RAW_DATA = int(result_withA) - int(A101_AN_decoder(r))
            corrected_r,corrected_value = Barret_q_101(RAW_DATA)
            ### corrected_value =  RAW_DATA % SEC_A
            if corrected_value != correct_result:
                SEC_error_count += 1
                
    return SEC_error_count / trials

if __name__ == "__main__":
    trials = 20000                              
    EbNodB_range = range(17, 24)
    threshold = 0.22
    SEC_AN_list = []

    for EbNodB in EbNodB_range:
        EbNo = 10.0**(EbNodB / 10.0)
        noise_std = 1 / sqrt(2 * EbNo)
        SEC_err_rate = noise_simulation(trials=trials, sigma=noise_std, threshold=threshold)
        SEC_AN_list.append(SEC_err_rate)
        print(f"SNR={EbNodB} dB, Noise Std={noise_std:.5f}, Error Rate={SEC_err_rate:.5f}")
# Out:
# SNR=17 dB, Noise Std=0.09988, Error Rate=1.00000
# SNR=18 dB, Noise Std=0.08902, Error Rate=1.00000
# SNR=19 dB, Noise Std=0.07934, Error Rate=1.00000
# SNR=20 dB, Noise Std=0.07071, Error Rate=0.99385
# SNR=21 dB, Noise Std=0.06302, Error Rate=0.57850
# SNR=22 dB, Noise Std=0.05617, Error Rate=0.05200
# SNR=23 dB, Noise Std=0.05006, Error Rate=0.00110

# %% [markdown]
# ### 使用查找表更正: DEC_ANcode, A = 23359
# * 18-bits*18bits = 36-bits
# * Function Definition

# %%
import math
import numpy as np

def decimal_to_binary(decimal_number):
    if decimal_number == 0:
        return "0"
    # 處理正數：直接轉換
    if decimal_number > 0:
        return bin(decimal_number)[2:]  # 移除 "0b" 前綴
       # 處理負數：自動計算所需位元數（2's complement）
    abs_value = abs(decimal_number)
    bits = abs_value.bit_length() + 1  # 負數多一個符號位元
    two_complement_value = (1 << bits) + decimal_number
    
    return bin(two_complement_value)[2:]  # 移除 "0b" 前綴

def bits_needed(number):
    if number < 0:
        raise ValueError("2's complement is not available")  # 如果輸入負數，拋出錯誤
    if number == 0:
        return 1  # 0 需要 1 個位元
    
    # 計算位元數
    bits = math.floor(math.log2(number)) + 1
    return bits

def bits_range(bits, signed=False):     ## 可選擇設定 有號數 或 無號數
    if bits <= 0:
        return "位元數必須為正整數！"
    
    if signed:
        # 二補數範圍: -2^(bits-1) 到 2^(bits-1)-1
        min_value = -(2**(bits - 1))
        max_value = 2**(bits - 1) - 1
    else:
        # 無符號範圍: 0 到 2^bits - 1
        min_value = 0
        max_value = 2**bits - 1

    return min_value, max_value

## 把重複的 AWE 去除
def remove_duplicates(input_list):
    unique_list = []
    for number in input_list:
        if number not in unique_list:
            unique_list.append(number)
    return sorted(unique_list)

def custom_mod(a, b):
    if b == 0:
        return "錯誤：除數不能為零！"
    # 計算商和餘數，修正餘數計算邏輯
    quotient = a // b
    remainder = a - b * quotient
    # 修正負餘數的情況
    if remainder > 0 and a < 0:
        remainder -= abs(b)
        quotient += 1
    return remainder

def remainder_unique(input_list):
    # 使用集合判斷元素是否有重複
    return len(input_list) == len(set(input_list))


def create_mapping(source_list, address_map):
    """
    建立值到位址和位址到值的雙向映射。
    若 address_map 中某位址沒有對應值，則該位址的值為 0。
    
    參數:
    source_list (list): 原始資料列表。
    address_map (list): 位址映射列表。
    
    回傳:
    tuple: (值到位址的映射, 位址到值的映射)
    """
    # 初始化值到位址的映射
    value_to_address = {value: addr for value, addr in zip(source_list, address_map)}
    
    # 初始化位址到值的映射，未指定的位址預設為 0
    max_address = max(address_map)  # 確保涵蓋所有位址
    address_to_value = {addr: 0 for addr in range(max_address + 1)}  # 預設為 0
    for value, addr in zip(source_list, address_map):
        address_to_value[addr] = value  # 更新有指定值的位址

    return value_to_address, address_to_value
def decimal_to_binary(decimal_number):
    if decimal_number == 0:
        return "0"
    # 處理正數：直接轉換
    if decimal_number > 0:
        return bin(decimal_number)[2:]  # 移除 "0b" 前綴
       # 處理負數：自動計算所需位元數（2's complement）
    abs_value = abs(decimal_number)
    bits = abs_value.bit_length() + 1  # 負數多一個符號位元
    two_complement_value = (1 << bits) + decimal_number
    
    return bin(two_complement_value)[2:]  # 移除 "0b" 前綴

def bits_needed(number):
    if number < 0:
        raise ValueError("2's complement is not available")  # 如果輸入負數，拋出錯誤
    if number == 0:
        return 1  # 0 需要 1 個位元
    
    # 計算位元數
    bits = math.floor(math.log2(number)) + 1
    return bits

def bits_range(bits, signed=False):     ## 可選擇設定 有號數 或 無號數
    if bits <= 0:
        return "位元數必須為正整數！"
    
    if signed:
        # 二補數範圍: -2^(bits-1) 到 2^(bits-1)-1
        min_value = -(2**(bits - 1))
        max_value = 2**(bits - 1) - 1
    else:
        # 無符號範圍: 0 到 2^bits - 1
        min_value = 0
        max_value = 2**bits - 1

    return min_value, max_value

## 把重複的 AWE 去除
def remove_duplicates(input_list):
    unique_list = []
    for number in input_list:
        if number not in unique_list:
            unique_list.append(number)
    return sorted(unique_list)

def custom_mod(a, b):
    if b == 0:
        return "錯誤：除數不能為零！"
    # 計算商和餘數，修正餘數計算邏輯
    quotient = a // b
    remainder = a - b * quotient
    # 修正負餘數的情況
    if remainder > 0 and a < 0:
        remainder -= abs(b)
        quotient += 1
    return remainder

def remainder_unique(input_list):
    # 使用集合判斷元素是否有重複
    return len(input_list) == len(set(input_list))

# %%
data = (1 << 36) - 1
print(data)
# Out:
# 68719476735

# %%
### 輸入數值為data, ANcode的A為AN
### 乘完A後的數值為 input
data = (1 << 36) - 1
AN = 23359     ## AN:23359, 只適用輸入為0 ~ 68719476735
input = data*AN
bits = bits_needed(input)

### 1-bit AWE:
AWE_1=[]
e1=0     ## 錯誤數量
e1_data=[]
for i in range(0, bits):
    AWE_1.insert(e1 , input + 2**i)
    e1_data.insert(e1, 2**i)
    e1 = e1 + 1
    AWE_1.insert(e1 , input - 2**i)
    e1_data.insert(e1, -2**i)
    e1 = e1 + 1
    
### 2-bit AWE:
AWE_2=[]
e2=0     ## 錯誤數量
p=0      ## 錯誤位置
e2_data=[]
for i in range(0, bits):
    for j in range(i+1, bits):
        AWE_2.insert(e2 , (input + 2**i + 2**j))
        e2_data.insert(e2 , (2**i + 2**j))        
        print(f"第 {e2} 筆錯誤資料: {AWE_2[e2]}")
        print(f"第 {e2} 筆算術錯誤: {e2_data[e2]}")
        e2 = e2 + 1
        AWE_2.insert(e2 , (input + 2**i - 2**j))
        e2_data.insert(e2 , (2**i - 2**j))        
        print(f"第 {e2} 筆錯誤資料: {AWE_2[e2]}")
        print(f"第 {e2} 筆算術錯誤: {e2_data[e2]}")
        e2 = e2 + 1
        AWE_2.insert(e2 , (input - 2**i + 2**j))
        e2_data.insert(e2 , (-2**i + 2**j))                
        print(f"第 {e2} 筆錯誤資料: {AWE_2[e2]}")
        print(f"第 {e2} 筆算術錯誤: {e2_data[e2]}")
        e2 = e2 + 1
        AWE_2.insert(e2 , (input - 2**i -2**j))
        e2_data.insert(e2 , (-2**i - 2**j))
        print(f"第 {e2} 筆錯誤資料: {AWE_2[e2]}")
        print(f"第 {e2} 筆算術錯誤: {e2_data[e2]}")
        e2 = e2 + 1
        p = p + 1
        
## 把list:AWE_1 和 list:AWE_2合併
AWE = AWE_1 + AWE_2
e_total = e1_data + e2_data
## 把重複的 AWE 去除
new_AWE = remove_duplicates(AWE)
new_e_total = remove_duplicates(e_total)
AWE_count = np.size(new_AWE)
e_count = np.size(new_e_total)

### 模AN, 使用一般mod函數和 Barret reduction 比較
remainder = []
for m in range(0,AWE_count):
    mod = new_AWE[m] % AN
    remainder.append(mod)

print("錯誤資料對AN取完模數:\n",remainder)

##############################################################
### Barret reduction ###
def Barret_q_23359(x):      
    q = (int(x) * 96399666667 ) >> 51       ## (2^51)//23359後, 右移51次 
    r = x - q * 23359
    if r < 23359:
        return (r,q)
    else:
        return (r - 23359, q + 1)
    
Barret_remainder = []
for m in range(0,AWE_count):
    Barret_r,Barret_q = Barret_q_23359(new_AWE[m])
    Barret_remainder.append(Barret_r)
    
print("Barret reduction對錯誤資料取完模數:\n",Barret_remainder)
print("Barret reduction是否可以使用:", Barret_remainder == remainder)
#################################################################
print("所有餘數(一般mod函數)是否完全相異:", remainder_unique(remainder))
print("所有餘數(Barret reduction)是否完全相異:", remainder_unique(Barret_remainder))
print("所有的AWE:\n", new_e_total)
print(np.size(remainder))

### 建立錯誤映射表(LUT)
## Decoder
AWE_to_remainder, remainder_to_AWE = create_mapping(new_e_total, Barret_remainder)

## example
example_r1 = Barret_remainder[0]
example_r2 = Barret_remainder[1]
print(f"輸入餘數 {example_r1}, 對應算術錯誤: {remainder_to_AWE[example_r1]}")
print(f"輸入餘數 {example_r2}, 對應算術錯誤: {remainder_to_AWE[example_r2]}")

Raw_data1 = new_AWE[0]-remainder_to_AWE[example_r1]
Raw_data2 = new_AWE[1]-remainder_to_AWE[example_r2]
print(Raw_data1)
print(Raw_data2)
print("更正是否正確:", input == Raw_data1)
# Out:
# 第 0 筆錯誤資料: 1605218257052868
# 第 0 筆算術錯誤: 3
# 第 1 筆錯誤資料: 1605218257052864
# 第 1 筆算術錯誤: -1
# 第 2 筆錯誤資料: 1605218257052866
# 第 2 筆算術錯誤: 1
# 第 3 筆錯誤資料: 1605218257052862
# 第 3 筆算術錯誤: -3
# 第 4 筆錯誤資料: 1605218257052870
# 第 4 筆算術錯誤: 5
# 第 5 筆錯誤資料: 1605218257052862
# 第 5 筆算術錯誤: -3
# 第 6 筆錯誤資料: 1605218257052868
# 第 6 筆算術錯誤: 3
# 第 7 筆錯誤資料: 1605218257052860
# 第 7 筆算術錯誤: -5
# 第 8 筆錯誤資料: 1605218257052874
# 第 8 筆算術錯誤: 9
# 第 9 筆錯誤資料: 1605218257052858
# 第 9 筆算術錯誤: -7
# 第 10 筆錯誤資料: 1605218257052872
# 第 10 筆算術錯誤: 7
# 第 11 筆錯誤資料: 1605218257052856
# 第 11 筆算術錯誤: -9
# 第 12 筆錯誤資料: 1605218257052882
# 第 12 筆算術錯誤: 17
# 第 13 筆錯誤資料: 1605218257052850
# 第 13 筆算術錯誤: -15
# 第 14 筆錯誤資料: 1605218257052880
# 第 14 筆算術錯誤: 15
# 第 15 筆錯誤資料: 1605218257052848
# 第 15 筆算術錯誤: -17
# 第 16 筆錯誤資料: 1605218257052898
# 第 16 筆算術錯誤: 33
# 第 17 筆錯誤資料: 1605218257052834
# 第 17 筆算術錯誤: -31
# 第 18 筆錯誤資料: 1605218257052896
# 第 18 筆算術錯誤: 31
# 第 19 筆錯誤資料: 1605218257052832
# 第 19 筆算術錯誤: -33
# 第 20 筆錯誤資料: 1605218257052930
# 第 20 筆算術錯誤: 65
# 第 21 筆錯誤資料: 1605218257052802
# 第 21 筆算術錯誤: -63
# 第 22 筆錯誤資料: 1605218257052928
# 第 22 筆算術錯誤: 63
# 第 23 筆錯誤資料: 1605218257052800
# 第 23 筆算術錯誤: -65
# 第 24 筆錯誤資料: 1605218257052994
# 第 24 筆算術錯誤: 129
# 第 25 筆錯誤資料: 1605218257052738
# 第 25 筆算術錯誤: -127
# 第 26 筆錯誤資料: 1605218257052992
# 第 26 筆算術錯誤: 127
# 第 27 筆錯誤資料: 1605218257052736
# 第 27 筆算術錯誤: -129
# 第 28 筆錯誤資料: 1605218257053122
# 第 28 筆算術錯誤: 257
# 第 29 筆錯誤資料: 1605218257052610
# 第 29 筆算術錯誤: -255
# 第 30 筆錯誤資料: 1605218257053120
# 第 30 筆算術錯誤: 255
# 第 31 筆錯誤資料: 1605218257052608
# 第 31 筆算術錯誤: -257
# 第 32 筆錯誤資料: 1605218257053378
# 第 32 筆算術錯誤: 513
# 第 33 筆錯誤資料: 1605218257052354
# 第 33 筆算術錯誤: -511
# 第 34 筆錯誤資料: 1605218257053376
# 第 34 筆算術錯誤: 511
# 第 35 筆錯誤資料: 1605218257052352
# 第 35 筆算術錯誤: -513
# 第 36 筆錯誤資料: 1605218257053890
# 第 36 筆算術錯誤: 1025
# 第 37 筆錯誤資料: 1605218257051842
# 第 37 筆算術錯誤: -1023
# 第 38 筆錯誤資料: 1605218257053888
# 第 38 筆算術錯誤: 1023
# 第 39 筆錯誤資料: 1605218257051840
# 第 39 筆算術錯誤: -1025
# 第 40 筆錯誤資料: 1605218257054914
# 第 40 筆算術錯誤: 2049
# 第 41 筆錯誤資料: 1605218257050818
# 第 41 筆算術錯誤: -2047
# 第 42 筆錯誤資料: 1605218257054912
# 第 42 筆算術錯誤: 2047
# 第 43 筆錯誤資料: 1605218257050816
# 第 43 筆算術錯誤: -2049
# 第 44 筆錯誤資料: 1605218257056962
# 第 44 筆算術錯誤: 4097
# 第 45 筆錯誤資料: 1605218257048770
# 第 45 筆算術錯誤: -4095
# 第 46 筆錯誤資料: 1605218257056960
# 第 46 筆算術錯誤: 4095
# 第 47 筆錯誤資料: 1605218257048768
# 第 47 筆算術錯誤: -4097
# 第 48 筆錯誤資料: 1605218257061058
# 第 48 筆算術錯誤: 8193
# 第 49 筆錯誤資料: 1605218257044674
# 第 49 筆算術錯誤: -8191
# 第 50 筆錯誤資料: 1605218257061056
# 第 50 筆算術錯誤: 8191
# 第 51 筆錯誤資料: 1605218257044672
# 第 51 筆算術錯誤: -8193
# 第 52 筆錯誤資料: 1605218257069250
# 第 52 筆算術錯誤: 16385
# 第 53 筆錯誤資料: 1605218257036482
# 第 53 筆算術錯誤: -16383
# 第 54 筆錯誤資料: 1605218257069248
# 第 54 筆算術錯誤: 16383
# 第 55 筆錯誤資料: 1605218257036480
# 第 55 筆算術錯誤: -16385
# 第 56 筆錯誤資料: 1605218257085634
# 第 56 筆算術錯誤: 32769
# 第 57 筆錯誤資料: 1605218257020098
# 第 57 筆算術錯誤: -32767
# 第 58 筆錯誤資料: 1605218257085632
# 第 58 筆算術錯誤: 32767
# 第 59 筆錯誤資料: 1605218257020096
# 第 59 筆算術錯誤: -32769
# 第 60 筆錯誤資料: 1605218257118402
# 第 60 筆算術錯誤: 65537
# 第 61 筆錯誤資料: 1605218256987330
# 第 61 筆算術錯誤: -65535
# 第 62 筆錯誤資料: 1605218257118400
# 第 62 筆算術錯誤: 65535
# 第 63 筆錯誤資料: 1605218256987328
# 第 63 筆算術錯誤: -65537
# 第 64 筆錯誤資料: 1605218257183938
# 第 64 筆算術錯誤: 131073
# 第 65 筆錯誤資料: 1605218256921794
# 第 65 筆算術錯誤: -131071
# 第 66 筆錯誤資料: 1605218257183936
# 第 66 筆算術錯誤: 131071
# 第 67 筆錯誤資料: 1605218256921792
# 第 67 筆算術錯誤: -131073
# 第 68 筆錯誤資料: 1605218257315010
# 第 68 筆算術錯誤: 262145
# 第 69 筆錯誤資料: 1605218256790722
# 第 69 筆算術錯誤: -262143
# 第 70 筆錯誤資料: 1605218257315008
# 第 70 筆算術錯誤: 262143
# 第 71 筆錯誤資料: 1605218256790720
# 第 71 筆算術錯誤: -262145
# 第 72 筆錯誤資料: 1605218257577154
# 第 72 筆算術錯誤: 524289
# 第 73 筆錯誤資料: 1605218256528578
# 第 73 筆算術錯誤: -524287
# 第 74 筆錯誤資料: 1605218257577152
# 第 74 筆算術錯誤: 524287
# 第 75 筆錯誤資料: 1605218256528576
# 第 75 筆算術錯誤: -524289
# 第 76 筆錯誤資料: 1605218258101442
# 第 76 筆算術錯誤: 1048577
# 第 77 筆錯誤資料: 1605218256004290
# 第 77 筆算術錯誤: -1048575
# 第 78 筆錯誤資料: 1605218258101440
# 第 78 筆算術錯誤: 1048575
# 第 79 筆錯誤資料: 1605218256004288
# 第 79 筆算術錯誤: -1048577
# 第 80 筆錯誤資料: 1605218259150018
# 第 80 筆算術錯誤: 2097153
# 第 81 筆錯誤資料: 1605218254955714
# 第 81 筆算術錯誤: -2097151
# 第 82 筆錯誤資料: 1605218259150016
# 第 82 筆算術錯誤: 2097151
# 第 83 筆錯誤資料: 1605218254955712
# 第 83 筆算術錯誤: -2097153
# 第 84 筆錯誤資料: 1605218261247170
# 第 84 筆算術錯誤: 4194305
# 第 85 筆錯誤資料: 1605218252858562
# 第 85 筆算術錯誤: -4194303
# 第 86 筆錯誤資料: 1605218261247168
# 第 86 筆算術錯誤: 4194303
# 第 87 筆錯誤資料: 1605218252858560
# 第 87 筆算術錯誤: -4194305
# 第 88 筆錯誤資料: 1605218265441474
# 第 88 筆算術錯誤: 8388609
# 第 89 筆錯誤資料: 1605218248664258
# 第 89 筆算術錯誤: -8388607
# 第 90 筆錯誤資料: 1605218265441472
# 第 90 筆算術錯誤: 8388607
# 第 91 筆錯誤資料: 1605218248664256
# 第 91 筆算術錯誤: -8388609
# 第 92 筆錯誤資料: 1605218273830082
# 第 92 筆算術錯誤: 16777217
# 第 93 筆錯誤資料: 1605218240275650
# 第 93 筆算術錯誤: -16777215
# 第 94 筆錯誤資料: 1605218273830080
# 第 94 筆算術錯誤: 16777215
# 第 95 筆錯誤資料: 1605218240275648
# 第 95 筆算術錯誤: -16777217
# 第 96 筆錯誤資料: 1605218290607298
# 第 96 筆算術錯誤: 33554433
# 第 97 筆錯誤資料: 1605218223498434
# 第 97 筆算術錯誤: -33554431
# 第 98 筆錯誤資料: 1605218290607296
# 第 98 筆算術錯誤: 33554431
# 第 99 筆錯誤資料: 1605218223498432
# 第 99 筆算術錯誤: -33554433
# 第 100 筆錯誤資料: 1605218324161730
# 第 100 筆算術錯誤: 67108865
# 第 101 筆錯誤資料: 1605218189944002
# 第 101 筆算術錯誤: -67108863
# 第 102 筆錯誤資料: 1605218324161728
# 第 102 筆算術錯誤: 67108863
# 第 103 筆錯誤資料: 1605218189944000
# 第 103 筆算術錯誤: -67108865
# 第 104 筆錯誤資料: 1605218391270594
# 第 104 筆算術錯誤: 134217729
# 第 105 筆錯誤資料: 1605218122835138
# 第 105 筆算術錯誤: -134217727
# 第 106 筆錯誤資料: 1605218391270592
# 第 106 筆算術錯誤: 134217727
# 第 107 筆錯誤資料: 1605218122835136
# 第 107 筆算術錯誤: -134217729
# 第 108 筆錯誤資料: 1605218525488322
# 第 108 筆算術錯誤: 268435457
# 第 109 筆錯誤資料: 1605217988617410
# 第 109 筆算術錯誤: -268435455
# 第 110 筆錯誤資料: 1605218525488320
# 第 110 筆算術錯誤: 268435455
# 第 111 筆錯誤資料: 1605217988617408
# 第 111 筆算術錯誤: -268435457
# 第 112 筆錯誤資料: 1605218793923778
# 第 112 筆算術錯誤: 536870913
# 第 113 筆錯誤資料: 1605217720181954
# 第 113 筆算術錯誤: -536870911
# 第 114 筆錯誤資料: 1605218793923776
# 第 114 筆算術錯誤: 536870911
# 第 115 筆錯誤資料: 1605217720181952
# 第 115 筆算術錯誤: -536870913
# 第 116 筆錯誤資料: 1605219330794690
# 第 116 筆算術錯誤: 1073741825
# 第 117 筆錯誤資料: 1605217183311042
# 第 117 筆算術錯誤: -1073741823
# 第 118 筆錯誤資料: 1605219330794688
# 第 118 筆算術錯誤: 1073741823
# 第 119 筆錯誤資料: 1605217183311040
# 第 119 筆算術錯誤: -1073741825
# 第 120 筆錯誤資料: 1605220404536514
# 第 120 筆算術錯誤: 2147483649
# 第 121 筆錯誤資料: 1605216109569218
# 第 121 筆算術錯誤: -2147483647
# 第 122 筆錯誤資料: 1605220404536512
# 第 122 筆算術錯誤: 2147483647
# 第 123 筆錯誤資料: 1605216109569216
# 第 123 筆算術錯誤: -2147483649
# 第 124 筆錯誤資料: 1605222552020162
# 第 124 筆算術錯誤: 4294967297
# 第 125 筆錯誤資料: 1605213962085570
# 第 125 筆算術錯誤: -4294967295
# 第 126 筆錯誤資料: 1605222552020160
# 第 126 筆算術錯誤: 4294967295
# 第 127 筆錯誤資料: 1605213962085568
# 第 127 筆算術錯誤: -4294967297
# 第 128 筆錯誤資料: 1605226846987458
# 第 128 筆算術錯誤: 8589934593
# 第 129 筆錯誤資料: 1605209667118274
# 第 129 筆算術錯誤: -8589934591
# 第 130 筆錯誤資料: 1605226846987456
# 第 130 筆算術錯誤: 8589934591
# 第 131 筆錯誤資料: 1605209667118272
# 第 131 筆算術錯誤: -8589934593
# 第 132 筆錯誤資料: 1605235436922050
# 第 132 筆算術錯誤: 17179869185
# 第 133 筆錯誤資料: 1605201077183682
# 第 133 筆算術錯誤: -17179869183
# 第 134 筆錯誤資料: 1605235436922048
# 第 134 筆算術錯誤: 17179869183
# 第 135 筆錯誤資料: 1605201077183680
# 第 135 筆算術錯誤: -17179869185
# 第 136 筆錯誤資料: 1605252616791234
# 第 136 筆算術錯誤: 34359738369
# 第 137 筆錯誤資料: 1605183897314498
# 第 137 筆算術錯誤: -34359738367
# 第 138 筆錯誤資料: 1605252616791232
# 第 138 筆算術錯誤: 34359738367
# 第 139 筆錯誤資料: 1605183897314496
# 第 139 筆算術錯誤: -34359738369
# 第 140 筆錯誤資料: 1605286976529602
# 第 140 筆算術錯誤: 68719476737
# 第 141 筆錯誤資料: 1605149537576130
# 第 141 筆算術錯誤: -68719476735
# 第 142 筆錯誤資料: 1605286976529600
# 第 142 筆算術錯誤: 68719476735
# 第 143 筆錯誤資料: 1605149537576128
# 第 143 筆算術錯誤: -68719476737
# 第 144 筆錯誤資料: 1605355696006338
# 第 144 筆算術錯誤: 137438953473
# 第 145 筆錯誤資料: 1605080818099394
# 第 145 筆算術錯誤: -137438953471
# 第 146 筆錯誤資料: 1605355696006336
# 第 146 筆算術錯誤: 137438953471
# 第 147 筆錯誤資料: 1605080818099392
# 第 147 筆算術錯誤: -137438953473
# 第 148 筆錯誤資料: 1605493134959810
# 第 148 筆算術錯誤: 274877906945
# 第 149 筆錯誤資料: 1604943379145922
# 第 149 筆算術錯誤: -274877906943
# 第 150 筆錯誤資料: 1605493134959808
# 第 150 筆算術錯誤: 274877906943
# 第 151 筆錯誤資料: 1604943379145920
# 第 151 筆算術錯誤: -274877906945
# 第 152 筆錯誤資料: 1605768012866754
# 第 152 筆算術錯誤: 549755813889
# 第 153 筆錯誤資料: 1604668501238978
# 第 153 筆算術錯誤: -549755813887
# 第 154 筆錯誤資料: 1605768012866752
# 第 154 筆算術錯誤: 549755813887
# 第 155 筆錯誤資料: 1604668501238976
# 第 155 筆算術錯誤: -549755813889
# 第 156 筆錯誤資料: 1606317768680642
# 第 156 筆算術錯誤: 1099511627777
# 第 157 筆錯誤資料: 1604118745425090
# 第 157 筆算術錯誤: -1099511627775
# 第 158 筆錯誤資料: 1606317768680640
# 第 158 筆算術錯誤: 1099511627775
# 第 159 筆錯誤資料: 1604118745425088
# 第 159 筆算術錯誤: -1099511627777
# 第 160 筆錯誤資料: 1607417280308418
# 第 160 筆算術錯誤: 2199023255553
# 第 161 筆錯誤資料: 1603019233797314
# 第 161 筆算術錯誤: -2199023255551
# 第 162 筆錯誤資料: 1607417280308416
# 第 162 筆算術錯誤: 2199023255551
# 第 163 筆錯誤資料: 1603019233797312
# 第 163 筆算術錯誤: -2199023255553
# 第 164 筆錯誤資料: 1609616303563970
# 第 164 筆算術錯誤: 4398046511105
# 第 165 筆錯誤資料: 1600820210541762
# 第 165 筆算術錯誤: -4398046511103
# 第 166 筆錯誤資料: 1609616303563968
# 第 166 筆算術錯誤: 4398046511103
# 第 167 筆錯誤資料: 1600820210541760
# 第 167 筆算術錯誤: -4398046511105
# 第 168 筆錯誤資料: 1614014350075074
# 第 168 筆算術錯誤: 8796093022209
# 第 169 筆錯誤資料: 1596422164030658
# 第 169 筆算術錯誤: -8796093022207
# 第 170 筆錯誤資料: 1614014350075072
# 第 170 筆算術錯誤: 8796093022207
# 第 171 筆錯誤資料: 1596422164030656
# 第 171 筆算術錯誤: -8796093022209
# 第 172 筆錯誤資料: 1622810443097282
# 第 172 筆算術錯誤: 17592186044417
# 第 173 筆錯誤資料: 1587626071008450
# 第 173 筆算術錯誤: -17592186044415
# 第 174 筆錯誤資料: 1622810443097280
# 第 174 筆算術錯誤: 17592186044415
# 第 175 筆錯誤資料: 1587626071008448
# 第 175 筆算術錯誤: -17592186044417
# 第 176 筆錯誤資料: 1640402629141698
# 第 176 筆算術錯誤: 35184372088833
# 第 177 筆錯誤資料: 1570033884964034
# 第 177 筆算術錯誤: -35184372088831
# 第 178 筆錯誤資料: 1640402629141696
# 第 178 筆算術錯誤: 35184372088831
# 第 179 筆錯誤資料: 1570033884964032
# 第 179 筆算術錯誤: -35184372088833
# 第 180 筆錯誤資料: 1675587001230530
# 第 180 筆算術錯誤: 70368744177665
# 第 181 筆錯誤資料: 1534849512875202
# 第 181 筆算術錯誤: -70368744177663
# 第 182 筆錯誤資料: 1675587001230528
# 第 182 筆算術錯誤: 70368744177663
# 第 183 筆錯誤資料: 1534849512875200
# 第 183 筆算術錯誤: -70368744177665
# 第 184 筆錯誤資料: 1745955745408194
# 第 184 筆算術錯誤: 140737488355329
# 第 185 筆錯誤資料: 1464480768697538
# 第 185 筆算術錯誤: -140737488355327
# 第 186 筆錯誤資料: 1745955745408192
# 第 186 筆算術錯誤: 140737488355327
# 第 187 筆錯誤資料: 1464480768697536
# 第 187 筆算術錯誤: -140737488355329
# 第 188 筆錯誤資料: 1886693233763522
# 第 188 筆算術錯誤: 281474976710657
# 第 189 筆錯誤資料: 1323743280342210
# 第 189 筆算術錯誤: -281474976710655
# 第 190 筆錯誤資料: 1886693233763520
# 第 190 筆算術錯誤: 281474976710655
# 第 191 筆錯誤資料: 1323743280342208
# 第 191 筆算術錯誤: -281474976710657
# 第 192 筆錯誤資料: 2168168210474178
# 第 192 筆算術錯誤: 562949953421313
# 第 193 筆錯誤資料: 1042268303631554
# 第 193 筆算術錯誤: -562949953421311
# 第 194 筆錯誤資料: 2168168210474176
# 第 194 筆算術錯誤: 562949953421311
# 第 195 筆錯誤資料: 1042268303631552
# 第 195 筆算術錯誤: -562949953421313
# 第 196 筆錯誤資料: 2731118163895490
# 第 196 筆算術錯誤: 1125899906842625
# 第 197 筆錯誤資料: 479318350210242
# 第 197 筆算術錯誤: -1125899906842623
# 第 198 筆錯誤資料: 2731118163895488
# 第 198 筆算術錯誤: 1125899906842623
# 第 199 筆錯誤資料: 479318350210240
# 第 199 筆算術錯誤: -1125899906842625
# 第 200 筆錯誤資料: 1605218257052871
# 第 200 筆算術錯誤: 6
# 第 201 筆錯誤資料: 1605218257052863
# 第 201 筆算術錯誤: -2
# 第 202 筆錯誤資料: 1605218257052867
# 第 202 筆算術錯誤: 2
# 第 203 筆錯誤資料: 1605218257052859
# 第 203 筆算術錯誤: -6
# 第 204 筆錯誤資料: 1605218257052875
# 第 204 筆算術錯誤: 10
# 第 205 筆錯誤資料: 1605218257052859
# 第 205 筆算術錯誤: -6
# 第 206 筆錯誤資料: 1605218257052871
# 第 206 筆算術錯誤: 6
# 第 207 筆錯誤資料: 1605218257052855
# 第 207 筆算術錯誤: -10
# 第 208 筆錯誤資料: 1605218257052883
# 第 208 筆算術錯誤: 18
# 第 209 筆錯誤資料: 1605218257052851
# 第 209 筆算術錯誤: -14
# 第 210 筆錯誤資料: 1605218257052879
# 第 210 筆算術錯誤: 14
# 第 211 筆錯誤資料: 1605218257052847
# 第 211 筆算術錯誤: -18
# 第 212 筆錯誤資料: 1605218257052899
# 第 212 筆算術錯誤: 34
# 第 213 筆錯誤資料: 1605218257052835
# 第 213 筆算術錯誤: -30
# 第 214 筆錯誤資料: 1605218257052895
# 第 214 筆算術錯誤: 30
# 第 215 筆錯誤資料: 1605218257052831
# 第 215 筆算術錯誤: -34
# 第 216 筆錯誤資料: 1605218257052931
# 第 216 筆算術錯誤: 66
# 第 217 筆錯誤資料: 1605218257052803
# 第 217 筆算術錯誤: -62
# 第 218 筆錯誤資料: 1605218257052927
# 第 218 筆算術錯誤: 62
# 第 219 筆錯誤資料: 1605218257052799
# 第 219 筆算術錯誤: -66
# 第 220 筆錯誤資料: 1605218257052995
# 第 220 筆算術錯誤: 130
# 第 221 筆錯誤資料: 1605218257052739
# 第 221 筆算術錯誤: -126
# 第 222 筆錯誤資料: 1605218257052991
# 第 222 筆算術錯誤: 126
# 第 223 筆錯誤資料: 1605218257052735
# 第 223 筆算術錯誤: -130
# 第 224 筆錯誤資料: 1605218257053123
# 第 224 筆算術錯誤: 258
# 第 225 筆錯誤資料: 1605218257052611
# 第 225 筆算術錯誤: -254
# 第 226 筆錯誤資料: 1605218257053119
# 第 226 筆算術錯誤: 254
# 第 227 筆錯誤資料: 1605218257052607
# 第 227 筆算術錯誤: -258
# 第 228 筆錯誤資料: 1605218257053379
# 第 228 筆算術錯誤: 514
# 第 229 筆錯誤資料: 1605218257052355
# 第 229 筆算術錯誤: -510
# 第 230 筆錯誤資料: 1605218257053375
# 第 230 筆算術錯誤: 510
# 第 231 筆錯誤資料: 1605218257052351
# 第 231 筆算術錯誤: -514
# 第 232 筆錯誤資料: 1605218257053891
# 第 232 筆算術錯誤: 1026
# 第 233 筆錯誤資料: 1605218257051843
# 第 233 筆算術錯誤: -1022
# 第 234 筆錯誤資料: 1605218257053887
# 第 234 筆算術錯誤: 1022
# 第 235 筆錯誤資料: 1605218257051839
# 第 235 筆算術錯誤: -1026
# 第 236 筆錯誤資料: 1605218257054915
# 第 236 筆算術錯誤: 2050
# 第 237 筆錯誤資料: 1605218257050819
# 第 237 筆算術錯誤: -2046
# 第 238 筆錯誤資料: 1605218257054911
# 第 238 筆算術錯誤: 2046
# 第 239 筆錯誤資料: 1605218257050815
# 第 239 筆算術錯誤: -2050
# 第 240 筆錯誤資料: 1605218257056963
# 第 240 筆算術錯誤: 4098
# 第 241 筆錯誤資料: 1605218257048771
# 第 241 筆算術錯誤: -4094
# 第 242 筆錯誤資料: 1605218257056959
# 第 242 筆算術錯誤: 4094
# 第 243 筆錯誤資料: 1605218257048767
# 第 243 筆算術錯誤: -4098
# 第 244 筆錯誤資料: 1605218257061059
# 第 244 筆算術錯誤: 8194
# 第 245 筆錯誤資料: 1605218257044675
# 第 245 筆算術錯誤: -8190
# 第 246 筆錯誤資料: 1605218257061055
# 第 246 筆算術錯誤: 8190
# 第 247 筆錯誤資料: 1605218257044671
# 第 247 筆算術錯誤: -8194
# 第 248 筆錯誤資料: 1605218257069251
# 第 248 筆算術錯誤: 16386
# 第 249 筆錯誤資料: 1605218257036483
# 第 249 筆算術錯誤: -16382
# 第 250 筆錯誤資料: 1605218257069247
# 第 250 筆算術錯誤: 16382
# 第 251 筆錯誤資料: 1605218257036479
# 第 251 筆算術錯誤: -16386
# 第 252 筆錯誤資料: 1605218257085635
# 第 252 筆算術錯誤: 32770
# 第 253 筆錯誤資料: 1605218257020099
# 第 253 筆算術錯誤: -32766
# 第 254 筆錯誤資料: 1605218257085631
# 第 254 筆算術錯誤: 32766
# 第 255 筆錯誤資料: 1605218257020095
# 第 255 筆算術錯誤: -32770
# 第 256 筆錯誤資料: 1605218257118403
# 第 256 筆算術錯誤: 65538
# 第 257 筆錯誤資料: 1605218256987331
# 第 257 筆算術錯誤: -65534
# 第 258 筆錯誤資料: 1605218257118399
# 第 258 筆算術錯誤: 65534
# 第 259 筆錯誤資料: 1605218256987327
# 第 259 筆算術錯誤: -65538
# 第 260 筆錯誤資料: 1605218257183939
# 第 260 筆算術錯誤: 131074
# 第 261 筆錯誤資料: 1605218256921795
# 第 261 筆算術錯誤: -131070
# 第 262 筆錯誤資料: 1605218257183935
# 第 262 筆算術錯誤: 131070
# 第 263 筆錯誤資料: 1605218256921791
# 第 263 筆算術錯誤: -131074
# 第 264 筆錯誤資料: 1605218257315011
# 第 264 筆算術錯誤: 262146
# 第 265 筆錯誤資料: 1605218256790723
# 第 265 筆算術錯誤: -262142
# 第 266 筆錯誤資料: 1605218257315007
# 第 266 筆算術錯誤: 262142
# 第 267 筆錯誤資料: 1605218256790719
# 第 267 筆算術錯誤: -262146
# 第 268 筆錯誤資料: 1605218257577155
# 第 268 筆算術錯誤: 524290
# 第 269 筆錯誤資料: 1605218256528579
# 第 269 筆算術錯誤: -524286
# 第 270 筆錯誤資料: 1605218257577151
# 第 270 筆算術錯誤: 524286
# 第 271 筆錯誤資料: 1605218256528575
# 第 271 筆算術錯誤: -524290
# 第 272 筆錯誤資料: 1605218258101443
# 第 272 筆算術錯誤: 1048578
# 第 273 筆錯誤資料: 1605218256004291
# 第 273 筆算術錯誤: -1048574
# 第 274 筆錯誤資料: 1605218258101439
# 第 274 筆算術錯誤: 1048574
# 第 275 筆錯誤資料: 1605218256004287
# 第 275 筆算術錯誤: -1048578
# 第 276 筆錯誤資料: 1605218259150019
# 第 276 筆算術錯誤: 2097154
# 第 277 筆錯誤資料: 1605218254955715
# 第 277 筆算術錯誤: -2097150
# 第 278 筆錯誤資料: 1605218259150015
# 第 278 筆算術錯誤: 2097150
# 第 279 筆錯誤資料: 1605218254955711
# 第 279 筆算術錯誤: -2097154
# 第 280 筆錯誤資料: 1605218261247171
# 第 280 筆算術錯誤: 4194306
# 第 281 筆錯誤資料: 1605218252858563
# 第 281 筆算術錯誤: -4194302
# 第 282 筆錯誤資料: 1605218261247167
# 第 282 筆算術錯誤: 4194302
# 第 283 筆錯誤資料: 1605218252858559
# 第 283 筆算術錯誤: -4194306
# 第 284 筆錯誤資料: 1605218265441475
# 第 284 筆算術錯誤: 8388610
# 第 285 筆錯誤資料: 1605218248664259
# 第 285 筆算術錯誤: -8388606
# 第 286 筆錯誤資料: 1605218265441471
# 第 286 筆算術錯誤: 8388606
# 第 287 筆錯誤資料: 1605218248664255
# 第 287 筆算術錯誤: -8388610
# 第 288 筆錯誤資料: 1605218273830083
# 第 288 筆算術錯誤: 16777218
# 第 289 筆錯誤資料: 1605218240275651
# 第 289 筆算術錯誤: -16777214
# 第 290 筆錯誤資料: 1605218273830079
# 第 290 筆算術錯誤: 16777214
# 第 291 筆錯誤資料: 1605218240275647
# 第 291 筆算術錯誤: -16777218
# 第 292 筆錯誤資料: 1605218290607299
# 第 292 筆算術錯誤: 33554434
# 第 293 筆錯誤資料: 1605218223498435
# 第 293 筆算術錯誤: -33554430
# 第 294 筆錯誤資料: 1605218290607295
# 第 294 筆算術錯誤: 33554430
# 第 295 筆錯誤資料: 1605218223498431
# 第 295 筆算術錯誤: -33554434
# 第 296 筆錯誤資料: 1605218324161731
# 第 296 筆算術錯誤: 67108866
# 第 297 筆錯誤資料: 1605218189944003
# 第 297 筆算術錯誤: -67108862
# 第 298 筆錯誤資料: 1605218324161727
# 第 298 筆算術錯誤: 67108862
# 第 299 筆錯誤資料: 1605218189943999
# 第 299 筆算術錯誤: -67108866
# 第 300 筆錯誤資料: 1605218391270595
# 第 300 筆算術錯誤: 134217730
# 第 301 筆錯誤資料: 1605218122835139
# 第 301 筆算術錯誤: -134217726
# 第 302 筆錯誤資料: 1605218391270591
# 第 302 筆算術錯誤: 134217726
# 第 303 筆錯誤資料: 1605218122835135
# 第 303 筆算術錯誤: -134217730
# 第 304 筆錯誤資料: 1605218525488323
# 第 304 筆算術錯誤: 268435458
# 第 305 筆錯誤資料: 1605217988617411
# 第 305 筆算術錯誤: -268435454
# 第 306 筆錯誤資料: 1605218525488319
# 第 306 筆算術錯誤: 268435454
# 第 307 筆錯誤資料: 1605217988617407
# 第 307 筆算術錯誤: -268435458
# 第 308 筆錯誤資料: 1605218793923779
# 第 308 筆算術錯誤: 536870914
# 第 309 筆錯誤資料: 1605217720181955
# 第 309 筆算術錯誤: -536870910
# 第 310 筆錯誤資料: 1605218793923775
# 第 310 筆算術錯誤: 536870910
# 第 311 筆錯誤資料: 1605217720181951
# 第 311 筆算術錯誤: -536870914
# 第 312 筆錯誤資料: 1605219330794691
# 第 312 筆算術錯誤: 1073741826
# 第 313 筆錯誤資料: 1605217183311043
# 第 313 筆算術錯誤: -1073741822
# 第 314 筆錯誤資料: 1605219330794687
# 第 314 筆算術錯誤: 1073741822
# 第 315 筆錯誤資料: 1605217183311039
# 第 315 筆算術錯誤: -1073741826
# 第 316 筆錯誤資料: 1605220404536515
# 第 316 筆算術錯誤: 2147483650
# 第 317 筆錯誤資料: 1605216109569219
# 第 317 筆算術錯誤: -2147483646
# 第 318 筆錯誤資料: 1605220404536511
# 第 318 筆算術錯誤: 2147483646
# 第 319 筆錯誤資料: 1605216109569215
# 第 319 筆算術錯誤: -2147483650
# 第 320 筆錯誤資料: 1605222552020163
# 第 320 筆算術錯誤: 4294967298
# 第 321 筆錯誤資料: 1605213962085571
# 第 321 筆算術錯誤: -4294967294
# 第 322 筆錯誤資料: 1605222552020159
# 第 322 筆算術錯誤: 4294967294
# 第 323 筆錯誤資料: 1605213962085567
# 第 323 筆算術錯誤: -4294967298
# 第 324 筆錯誤資料: 1605226846987459
# 第 324 筆算術錯誤: 8589934594
# 第 325 筆錯誤資料: 1605209667118275
# 第 325 筆算術錯誤: -8589934590
# 第 326 筆錯誤資料: 1605226846987455
# 第 326 筆算術錯誤: 8589934590
# 第 327 筆錯誤資料: 1605209667118271
# 第 327 筆算術錯誤: -8589934594
# 第 328 筆錯誤資料: 1605235436922051
# 第 328 筆算術錯誤: 17179869186
# 第 329 筆錯誤資料: 1605201077183683
# 第 329 筆算術錯誤: -17179869182
# 第 330 筆錯誤資料: 1605235436922047
# 第 330 筆算術錯誤: 17179869182
# 第 331 筆錯誤資料: 1605201077183679
# 第 331 筆算術錯誤: -17179869186
# 第 332 筆錯誤資料: 1605252616791235
# 第 332 筆算術錯誤: 34359738370
# 第 333 筆錯誤資料: 1605183897314499
# 第 333 筆算術錯誤: -34359738366
# 第 334 筆錯誤資料: 1605252616791231
# 第 334 筆算術錯誤: 34359738366
# 第 335 筆錯誤資料: 1605183897314495
# 第 335 筆算術錯誤: -34359738370
# 第 336 筆錯誤資料: 1605286976529603
# 第 336 筆算術錯誤: 68719476738
# 第 337 筆錯誤資料: 1605149537576131
# 第 337 筆算術錯誤: -68719476734
# 第 338 筆錯誤資料: 1605286976529599
# 第 338 筆算術錯誤: 68719476734
# 第 339 筆錯誤資料: 1605149537576127
# 第 339 筆算術錯誤: -68719476738
# 第 340 筆錯誤資料: 1605355696006339
# 第 340 筆算術錯誤: 137438953474
# 第 341 筆錯誤資料: 1605080818099395
# 第 341 筆算術錯誤: -137438953470
# 第 342 筆錯誤資料: 1605355696006335
# 第 342 筆算術錯誤: 137438953470
# 第 343 筆錯誤資料: 1605080818099391
# 第 343 筆算術錯誤: -137438953474
# 第 344 筆錯誤資料: 1605493134959811
# 第 344 筆算術錯誤: 274877906946
# 第 345 筆錯誤資料: 1604943379145923
# 第 345 筆算術錯誤: -274877906942
# 第 346 筆錯誤資料: 1605493134959807
# 第 346 筆算術錯誤: 274877906942
# 第 347 筆錯誤資料: 1604943379145919
# 第 347 筆算術錯誤: -274877906946
# 第 348 筆錯誤資料: 1605768012866755
# 第 348 筆算術錯誤: 549755813890
# 第 349 筆錯誤資料: 1604668501238979
# 第 349 筆算術錯誤: -549755813886
# 第 350 筆錯誤資料: 1605768012866751
# 第 350 筆算術錯誤: 549755813886
# 第 351 筆錯誤資料: 1604668501238975
# 第 351 筆算術錯誤: -549755813890
# 第 352 筆錯誤資料: 1606317768680643
# 第 352 筆算術錯誤: 1099511627778
# 第 353 筆錯誤資料: 1604118745425091
# 第 353 筆算術錯誤: -1099511627774
# 第 354 筆錯誤資料: 1606317768680639
# 第 354 筆算術錯誤: 1099511627774
# 第 355 筆錯誤資料: 1604118745425087
# 第 355 筆算術錯誤: -1099511627778
# 第 356 筆錯誤資料: 1607417280308419
# 第 356 筆算術錯誤: 2199023255554
# 第 357 筆錯誤資料: 1603019233797315
# 第 357 筆算術錯誤: -2199023255550
# 第 358 筆錯誤資料: 1607417280308415
# 第 358 筆算術錯誤: 2199023255550
# 第 359 筆錯誤資料: 1603019233797311
# 第 359 筆算術錯誤: -2199023255554
# 第 360 筆錯誤資料: 1609616303563971
# 第 360 筆算術錯誤: 4398046511106
# 第 361 筆錯誤資料: 1600820210541763
# 第 361 筆算術錯誤: -4398046511102
# 第 362 筆錯誤資料: 1609616303563967
# 第 362 筆算術錯誤: 4398046511102
# 第 363 筆錯誤資料: 1600820210541759
# 第 363 筆算術錯誤: -4398046511106
# 第 364 筆錯誤資料: 1614014350075075
# 第 364 筆算術錯誤: 8796093022210
# 第 365 筆錯誤資料: 1596422164030659
# 第 365 筆算術錯誤: -8796093022206
# 第 366 筆錯誤資料: 1614014350075071
# 第 366 筆算術錯誤: 8796093022206
# 第 367 筆錯誤資料: 1596422164030655
# 第 367 筆算術錯誤: -8796093022210
# 第 368 筆錯誤資料: 1622810443097283
# 第 368 筆算術錯誤: 17592186044418
# 第 369 筆錯誤資料: 1587626071008451
# 第 369 筆算術錯誤: -17592186044414
# 第 370 筆錯誤資料: 1622810443097279
# 第 370 筆算術錯誤: 17592186044414
# 第 371 筆錯誤資料: 1587626071008447
# 第 371 筆算術錯誤: -17592186044418
# 第 372 筆錯誤資料: 1640402629141699
# 第 372 筆算術錯誤: 35184372088834
# 第 373 筆錯誤資料: 1570033884964035
# 第 373 筆算術錯誤: -35184372088830
# 第 374 筆錯誤資料: 1640402629141695
# 第 374 筆算術錯誤: 35184372088830
# 第 375 筆錯誤資料: 1570033884964031
# 第 375 筆算術錯誤: -35184372088834
# 第 376 筆錯誤資料: 1675587001230531
# 第 376 筆算術錯誤: 70368744177666
# 第 377 筆錯誤資料: 1534849512875203
# 第 377 筆算術錯誤: -70368744177662
# 第 378 筆錯誤資料: 1675587001230527
# 第 378 筆算術錯誤: 70368744177662
# 第 379 筆錯誤資料: 1534849512875199
# 第 379 筆算術錯誤: -70368744177666
# 第 380 筆錯誤資料: 1745955745408195
# 第 380 筆算術錯誤: 140737488355330
# 第 381 筆錯誤資料: 1464480768697539
# 第 381 筆算術錯誤: -140737488355326
# 第 382 筆錯誤資料: 1745955745408191
# 第 382 筆算術錯誤: 140737488355326
# 第 383 筆錯誤資料: 1464480768697535
# 第 383 筆算術錯誤: -140737488355330
# 第 384 筆錯誤資料: 1886693233763523
# 第 384 筆算術錯誤: 281474976710658
# 第 385 筆錯誤資料: 1323743280342211
# 第 385 筆算術錯誤: -281474976710654
# 第 386 筆錯誤資料: 1886693233763519
# 第 386 筆算術錯誤: 281474976710654
# 第 387 筆錯誤資料: 1323743280342207
# 第 387 筆算術錯誤: -281474976710658
# 第 388 筆錯誤資料: 2168168210474179
# 第 388 筆算術錯誤: 562949953421314
# 第 389 筆錯誤資料: 1042268303631555
# 第 389 筆算術錯誤: -562949953421310
# 第 390 筆錯誤資料: 2168168210474175
# 第 390 筆算術錯誤: 562949953421310
# 第 391 筆錯誤資料: 1042268303631551
# 第 391 筆算術錯誤: -562949953421314
# 第 392 筆錯誤資料: 2731118163895491
# 第 392 筆算術錯誤: 1125899906842626
# 第 393 筆錯誤資料: 479318350210243
# 第 393 筆算術錯誤: -1125899906842622
# 第 394 筆錯誤資料: 2731118163895487
# 第 394 筆算術錯誤: 1125899906842622
# 第 395 筆錯誤資料: 479318350210239
# 第 395 筆算術錯誤: -1125899906842626
# 第 396 筆錯誤資料: 1605218257052877
# 第 396 筆算術錯誤: 12
# 第 397 筆錯誤資料: 1605218257052861
# 第 397 筆算術錯誤: -4
# 第 398 筆錯誤資料: 1605218257052869
# 第 398 筆算術錯誤: 4
# 第 399 筆錯誤資料: 1605218257052853
# 第 399 筆算術錯誤: -12
# 第 400 筆錯誤資料: 1605218257052885
# 第 400 筆算術錯誤: 20
# 第 401 筆錯誤資料: 1605218257052853
# 第 401 筆算術錯誤: -12
# 第 402 筆錯誤資料: 1605218257052877
# 第 402 筆算術錯誤: 12
# 第 403 筆錯誤資料: 1605218257052845
# 第 403 筆算術錯誤: -20
# 第 404 筆錯誤資料: 1605218257052901
# 第 404 筆算術錯誤: 36
# 第 405 筆錯誤資料: 1605218257052837
# 第 405 筆算術錯誤: -28
# 第 406 筆錯誤資料: 1605218257052893
# 第 406 筆算術錯誤: 28
# 第 407 筆錯誤資料: 1605218257052829
# 第 407 筆算術錯誤: -36
# 第 408 筆錯誤資料: 1605218257052933
# 第 408 筆算術錯誤: 68
# 第 409 筆錯誤資料: 1605218257052805
# 第 409 筆算術錯誤: -60
# 第 410 筆錯誤資料: 1605218257052925
# 第 410 筆算術錯誤: 60
# 第 411 筆錯誤資料: 1605218257052797
# 第 411 筆算術錯誤: -68
# 第 412 筆錯誤資料: 1605218257052997
# 第 412 筆算術錯誤: 132
# 第 413 筆錯誤資料: 1605218257052741
# 第 413 筆算術錯誤: -124
# 第 414 筆錯誤資料: 1605218257052989
# 第 414 筆算術錯誤: 124
# 第 415 筆錯誤資料: 1605218257052733
# 第 415 筆算術錯誤: -132
# 第 416 筆錯誤資料: 1605218257053125
# 第 416 筆算術錯誤: 260
# 第 417 筆錯誤資料: 1605218257052613
# 第 417 筆算術錯誤: -252
# 第 418 筆錯誤資料: 1605218257053117
# 第 418 筆算術錯誤: 252
# 第 419 筆錯誤資料: 1605218257052605
# 第 419 筆算術錯誤: -260
# 第 420 筆錯誤資料: 1605218257053381
# 第 420 筆算術錯誤: 516
# 第 421 筆錯誤資料: 1605218257052357
# 第 421 筆算術錯誤: -508
# 第 422 筆錯誤資料: 1605218257053373
# 第 422 筆算術錯誤: 508
# 第 423 筆錯誤資料: 1605218257052349
# 第 423 筆算術錯誤: -516
# 第 424 筆錯誤資料: 1605218257053893
# 第 424 筆算術錯誤: 1028
# 第 425 筆錯誤資料: 1605218257051845
# 第 425 筆算術錯誤: -1020
# 第 426 筆錯誤資料: 1605218257053885
# 第 426 筆算術錯誤: 1020
# 第 427 筆錯誤資料: 1605218257051837
# 第 427 筆算術錯誤: -1028
# 第 428 筆錯誤資料: 1605218257054917
# 第 428 筆算術錯誤: 2052
# 第 429 筆錯誤資料: 1605218257050821
# 第 429 筆算術錯誤: -2044
# 第 430 筆錯誤資料: 1605218257054909
# 第 430 筆算術錯誤: 2044
# 第 431 筆錯誤資料: 1605218257050813
# 第 431 筆算術錯誤: -2052
# 第 432 筆錯誤資料: 1605218257056965
# 第 432 筆算術錯誤: 4100
# 第 433 筆錯誤資料: 1605218257048773
# 第 433 筆算術錯誤: -4092
# 第 434 筆錯誤資料: 1605218257056957
# 第 434 筆算術錯誤: 4092
# 第 435 筆錯誤資料: 1605218257048765
# 第 435 筆算術錯誤: -4100
# 第 436 筆錯誤資料: 1605218257061061
# 第 436 筆算術錯誤: 8196
# 第 437 筆錯誤資料: 1605218257044677
# 第 437 筆算術錯誤: -8188
# 第 438 筆錯誤資料: 1605218257061053
# 第 438 筆算術錯誤: 8188
# 第 439 筆錯誤資料: 1605218257044669
# 第 439 筆算術錯誤: -8196
# 第 440 筆錯誤資料: 1605218257069253
# 第 440 筆算術錯誤: 16388
# 第 441 筆錯誤資料: 1605218257036485
# 第 441 筆算術錯誤: -16380
# 第 442 筆錯誤資料: 1605218257069245
# 第 442 筆算術錯誤: 16380
# 第 443 筆錯誤資料: 1605218257036477
# 第 443 筆算術錯誤: -16388
# 第 444 筆錯誤資料: 1605218257085637
# 第 444 筆算術錯誤: 32772
# 第 445 筆錯誤資料: 1605218257020101
# 第 445 筆算術錯誤: -32764
# 第 446 筆錯誤資料: 1605218257085629
# 第 446 筆算術錯誤: 32764
# 第 447 筆錯誤資料: 1605218257020093
# 第 447 筆算術錯誤: -32772
# 第 448 筆錯誤資料: 1605218257118405
# 第 448 筆算術錯誤: 65540
# 第 449 筆錯誤資料: 1605218256987333
# 第 449 筆算術錯誤: -65532
# 第 450 筆錯誤資料: 1605218257118397
# 第 450 筆算術錯誤: 65532
# 第 451 筆錯誤資料: 1605218256987325
# 第 451 筆算術錯誤: -65540
# 第 452 筆錯誤資料: 1605218257183941
# 第 452 筆算術錯誤: 131076
# 第 453 筆錯誤資料: 1605218256921797
# 第 453 筆算術錯誤: -131068
# 第 454 筆錯誤資料: 1605218257183933
# 第 454 筆算術錯誤: 131068
# 第 455 筆錯誤資料: 1605218256921789
# 第 455 筆算術錯誤: -131076
# 第 456 筆錯誤資料: 1605218257315013
# 第 456 筆算術錯誤: 262148
# 第 457 筆錯誤資料: 1605218256790725
# 第 457 筆算術錯誤: -262140
# 第 458 筆錯誤資料: 1605218257315005
# 第 458 筆算術錯誤: 262140
# 第 459 筆錯誤資料: 1605218256790717
# 第 459 筆算術錯誤: -262148
# 第 460 筆錯誤資料: 1605218257577157
# 第 460 筆算術錯誤: 524292
# 第 461 筆錯誤資料: 1605218256528581
# 第 461 筆算術錯誤: -524284
# 第 462 筆錯誤資料: 1605218257577149
# 第 462 筆算術錯誤: 524284
# 第 463 筆錯誤資料: 1605218256528573
# 第 463 筆算術錯誤: -524292
# 第 464 筆錯誤資料: 1605218258101445
# 第 464 筆算術錯誤: 1048580
# 第 465 筆錯誤資料: 1605218256004293
# 第 465 筆算術錯誤: -1048572
# 第 466 筆錯誤資料: 1605218258101437
# 第 466 筆算術錯誤: 1048572
# 第 467 筆錯誤資料: 1605218256004285
# 第 467 筆算術錯誤: -1048580
# 第 468 筆錯誤資料: 1605218259150021
# 第 468 筆算術錯誤: 2097156
# 第 469 筆錯誤資料: 1605218254955717
# 第 469 筆算術錯誤: -2097148
# 第 470 筆錯誤資料: 1605218259150013
# 第 470 筆算術錯誤: 2097148
# 第 471 筆錯誤資料: 1605218254955709
# 第 471 筆算術錯誤: -2097156
# 第 472 筆錯誤資料: 1605218261247173
# 第 472 筆算術錯誤: 4194308
# 第 473 筆錯誤資料: 1605218252858565
# 第 473 筆算術錯誤: -4194300
# 第 474 筆錯誤資料: 1605218261247165
# 第 474 筆算術錯誤: 4194300
# 第 475 筆錯誤資料: 1605218252858557
# 第 475 筆算術錯誤: -4194308
# 第 476 筆錯誤資料: 1605218265441477
# 第 476 筆算術錯誤: 8388612
# 第 477 筆錯誤資料: 1605218248664261
# 第 477 筆算術錯誤: -8388604
# 第 478 筆錯誤資料: 1605218265441469
# 第 478 筆算術錯誤: 8388604
# 第 479 筆錯誤資料: 1605218248664253
# 第 479 筆算術錯誤: -8388612
# 第 480 筆錯誤資料: 1605218273830085
# 第 480 筆算術錯誤: 16777220
# 第 481 筆錯誤資料: 1605218240275653
# 第 481 筆算術錯誤: -16777212
# 第 482 筆錯誤資料: 1605218273830077
# 第 482 筆算術錯誤: 16777212
# 第 483 筆錯誤資料: 1605218240275645
# 第 483 筆算術錯誤: -16777220
# 第 484 筆錯誤資料: 1605218290607301
# 第 484 筆算術錯誤: 33554436
# 第 485 筆錯誤資料: 1605218223498437
# 第 485 筆算術錯誤: -33554428
# 第 486 筆錯誤資料: 1605218290607293
# 第 486 筆算術錯誤: 33554428
# 第 487 筆錯誤資料: 1605218223498429
# 第 487 筆算術錯誤: -33554436
# 第 488 筆錯誤資料: 1605218324161733
# 第 488 筆算術錯誤: 67108868
# 第 489 筆錯誤資料: 1605218189944005
# 第 489 筆算術錯誤: -67108860
# 第 490 筆錯誤資料: 1605218324161725
# 第 490 筆算術錯誤: 67108860
# 第 491 筆錯誤資料: 1605218189943997
# 第 491 筆算術錯誤: -67108868
# 第 492 筆錯誤資料: 1605218391270597
# 第 492 筆算術錯誤: 134217732
# 第 493 筆錯誤資料: 1605218122835141
# 第 493 筆算術錯誤: -134217724
# 第 494 筆錯誤資料: 1605218391270589
# 第 494 筆算術錯誤: 134217724
# 第 495 筆錯誤資料: 1605218122835133
# 第 495 筆算術錯誤: -134217732
# 第 496 筆錯誤資料: 1605218525488325
# 第 496 筆算術錯誤: 268435460
# 第 497 筆錯誤資料: 1605217988617413
# 第 497 筆算術錯誤: -268435452
# 第 498 筆錯誤資料: 1605218525488317
# 第 498 筆算術錯誤: 268435452
# 第 499 筆錯誤資料: 1605217988617405
# 第 499 筆算術錯誤: -268435460
# 第 500 筆錯誤資料: 1605218793923781
# 第 500 筆算術錯誤: 536870916
# 第 501 筆錯誤資料: 1605217720181957
# 第 501 筆算術錯誤: -536870908
# 第 502 筆錯誤資料: 1605218793923773
# 第 502 筆算術錯誤: 536870908
# 第 503 筆錯誤資料: 1605217720181949
# 第 503 筆算術錯誤: -536870916
# 第 504 筆錯誤資料: 1605219330794693
# 第 504 筆算術錯誤: 1073741828
# 第 505 筆錯誤資料: 1605217183311045
# 第 505 筆算術錯誤: -1073741820
# 第 506 筆錯誤資料: 1605219330794685
# 第 506 筆算術錯誤: 1073741820
# 第 507 筆錯誤資料: 1605217183311037
# 第 507 筆算術錯誤: -1073741828
# 第 508 筆錯誤資料: 1605220404536517
# 第 508 筆算術錯誤: 2147483652
# 第 509 筆錯誤資料: 1605216109569221
# 第 509 筆算術錯誤: -2147483644
# 第 510 筆錯誤資料: 1605220404536509
# 第 510 筆算術錯誤: 2147483644
# 第 511 筆錯誤資料: 1605216109569213
# 第 511 筆算術錯誤: -2147483652
# 第 512 筆錯誤資料: 1605222552020165
# 第 512 筆算術錯誤: 4294967300
# 第 513 筆錯誤資料: 1605213962085573
# 第 513 筆算術錯誤: -4294967292
# 第 514 筆錯誤資料: 1605222552020157
# 第 514 筆算術錯誤: 4294967292
# 第 515 筆錯誤資料: 1605213962085565
# 第 515 筆算術錯誤: -4294967300
# 第 516 筆錯誤資料: 1605226846987461
# 第 516 筆算術錯誤: 8589934596
# 第 517 筆錯誤資料: 1605209667118277
# 第 517 筆算術錯誤: -8589934588
# 第 518 筆錯誤資料: 1605226846987453
# 第 518 筆算術錯誤: 8589934588
# 第 519 筆錯誤資料: 1605209667118269
# 第 519 筆算術錯誤: -8589934596
# 第 520 筆錯誤資料: 1605235436922053
# 第 520 筆算術錯誤: 17179869188
# 第 521 筆錯誤資料: 1605201077183685
# 第 521 筆算術錯誤: -17179869180
# 第 522 筆錯誤資料: 1605235436922045
# 第 522 筆算術錯誤: 17179869180
# 第 523 筆錯誤資料: 1605201077183677
# 第 523 筆算術錯誤: -17179869188
# 第 524 筆錯誤資料: 1605252616791237
# 第 524 筆算術錯誤: 34359738372
# 第 525 筆錯誤資料: 1605183897314501
# 第 525 筆算術錯誤: -34359738364
# 第 526 筆錯誤資料: 1605252616791229
# 第 526 筆算術錯誤: 34359738364
# 第 527 筆錯誤資料: 1605183897314493
# 第 527 筆算術錯誤: -34359738372
# 第 528 筆錯誤資料: 1605286976529605
# 第 528 筆算術錯誤: 68719476740
# 第 529 筆錯誤資料: 1605149537576133
# 第 529 筆算術錯誤: -68719476732
# 第 530 筆錯誤資料: 1605286976529597
# 第 530 筆算術錯誤: 68719476732
# 第 531 筆錯誤資料: 1605149537576125
# 第 531 筆算術錯誤: -68719476740
# 第 532 筆錯誤資料: 1605355696006341
# 第 532 筆算術錯誤: 137438953476
# 第 533 筆錯誤資料: 1605080818099397
# 第 533 筆算術錯誤: -137438953468
# 第 534 筆錯誤資料: 1605355696006333
# 第 534 筆算術錯誤: 137438953468
# 第 535 筆錯誤資料: 1605080818099389
# 第 535 筆算術錯誤: -137438953476
# 第 536 筆錯誤資料: 1605493134959813
# 第 536 筆算術錯誤: 274877906948
# 第 537 筆錯誤資料: 1604943379145925
# 第 537 筆算術錯誤: -274877906940
# 第 538 筆錯誤資料: 1605493134959805
# 第 538 筆算術錯誤: 274877906940
# 第 539 筆錯誤資料: 1604943379145917
# 第 539 筆算術錯誤: -274877906948
# 第 540 筆錯誤資料: 1605768012866757
# 第 540 筆算術錯誤: 549755813892
# 第 541 筆錯誤資料: 1604668501238981
# 第 541 筆算術錯誤: -549755813884
# 第 542 筆錯誤資料: 1605768012866749
# 第 542 筆算術錯誤: 549755813884
# 第 543 筆錯誤資料: 1604668501238973
# 第 543 筆算術錯誤: -549755813892
# 第 544 筆錯誤資料: 1606317768680645
# 第 544 筆算術錯誤: 1099511627780
# 第 545 筆錯誤資料: 1604118745425093
# 第 545 筆算術錯誤: -1099511627772
# 第 546 筆錯誤資料: 1606317768680637
# 第 546 筆算術錯誤: 1099511627772
# 第 547 筆錯誤資料: 1604118745425085
# 第 547 筆算術錯誤: -1099511627780
# 第 548 筆錯誤資料: 1607417280308421
# 第 548 筆算術錯誤: 2199023255556
# 第 549 筆錯誤資料: 1603019233797317
# 第 549 筆算術錯誤: -2199023255548
# 第 550 筆錯誤資料: 1607417280308413
# 第 550 筆算術錯誤: 2199023255548
# 第 551 筆錯誤資料: 1603019233797309
# 第 551 筆算術錯誤: -2199023255556
# 第 552 筆錯誤資料: 1609616303563973
# 第 552 筆算術錯誤: 4398046511108
# 第 553 筆錯誤資料: 1600820210541765
# 第 553 筆算術錯誤: -4398046511100
# 第 554 筆錯誤資料: 1609616303563965
# 第 554 筆算術錯誤: 4398046511100
# 第 555 筆錯誤資料: 1600820210541757
# 第 555 筆算術錯誤: -4398046511108
# 第 556 筆錯誤資料: 1614014350075077
# 第 556 筆算術錯誤: 8796093022212
# 第 557 筆錯誤資料: 1596422164030661
# 第 557 筆算術錯誤: -8796093022204
# 第 558 筆錯誤資料: 1614014350075069
# 第 558 筆算術錯誤: 8796093022204
# 第 559 筆錯誤資料: 1596422164030653
# 第 559 筆算術錯誤: -8796093022212
# 第 560 筆錯誤資料: 1622810443097285
# 第 560 筆算術錯誤: 17592186044420
# 第 561 筆錯誤資料: 1587626071008453
# 第 561 筆算術錯誤: -17592186044412
# 第 562 筆錯誤資料: 1622810443097277
# 第 562 筆算術錯誤: 17592186044412
# 第 563 筆錯誤資料: 1587626071008445
# 第 563 筆算術錯誤: -17592186044420
# 第 564 筆錯誤資料: 1640402629141701
# 第 564 筆算術錯誤: 35184372088836
# 第 565 筆錯誤資料: 1570033884964037
# 第 565 筆算術錯誤: -35184372088828
# 第 566 筆錯誤資料: 1640402629141693
# 第 566 筆算術錯誤: 35184372088828
# 第 567 筆錯誤資料: 1570033884964029
# 第 567 筆算術錯誤: -35184372088836
# 第 568 筆錯誤資料: 1675587001230533
# 第 568 筆算術錯誤: 70368744177668
# 第 569 筆錯誤資料: 1534849512875205
# 第 569 筆算術錯誤: -70368744177660
# 第 570 筆錯誤資料: 1675587001230525
# 第 570 筆算術錯誤: 70368744177660
# 第 571 筆錯誤資料: 1534849512875197
# 第 571 筆算術錯誤: -70368744177668
# 第 572 筆錯誤資料: 1745955745408197
# 第 572 筆算術錯誤: 140737488355332
# 第 573 筆錯誤資料: 1464480768697541
# 第 573 筆算術錯誤: -140737488355324
# 第 574 筆錯誤資料: 1745955745408189
# 第 574 筆算術錯誤: 140737488355324
# 第 575 筆錯誤資料: 1464480768697533
# 第 575 筆算術錯誤: -140737488355332
# 第 576 筆錯誤資料: 1886693233763525
# 第 576 筆算術錯誤: 281474976710660
# 第 577 筆錯誤資料: 1323743280342213
# 第 577 筆算術錯誤: -281474976710652
# 第 578 筆錯誤資料: 1886693233763517
# 第 578 筆算術錯誤: 281474976710652
# 第 579 筆錯誤資料: 1323743280342205
# 第 579 筆算術錯誤: -281474976710660
# 第 580 筆錯誤資料: 2168168210474181
# 第 580 筆算術錯誤: 562949953421316
# 第 581 筆錯誤資料: 1042268303631557
# 第 581 筆算術錯誤: -562949953421308
# 第 582 筆錯誤資料: 2168168210474173
# 第 582 筆算術錯誤: 562949953421308
# 第 583 筆錯誤資料: 1042268303631549
# 第 583 筆算術錯誤: -562949953421316
# 第 584 筆錯誤資料: 2731118163895493
# 第 584 筆算術錯誤: 1125899906842628
# 第 585 筆錯誤資料: 479318350210245
# 第 585 筆算術錯誤: -1125899906842620
# 第 586 筆錯誤資料: 2731118163895485
# 第 586 筆算術錯誤: 1125899906842620
# 第 587 筆錯誤資料: 479318350210237
# 第 587 筆算術錯誤: -1125899906842628
# 第 588 筆錯誤資料: 1605218257052889
# 第 588 筆算術錯誤: 24
# 第 589 筆錯誤資料: 1605218257052857
# 第 589 筆算術錯誤: -8
# 第 590 筆錯誤資料: 1605218257052873
# 第 590 筆算術錯誤: 8
# 第 591 筆錯誤資料: 1605218257052841
# 第 591 筆算術錯誤: -24
# 第 592 筆錯誤資料: 1605218257052905
# 第 592 筆算術錯誤: 40
# 第 593 筆錯誤資料: 1605218257052841
# 第 593 筆算術錯誤: -24
# 第 594 筆錯誤資料: 1605218257052889
# 第 594 筆算術錯誤: 24
# 第 595 筆錯誤資料: 1605218257052825
# 第 595 筆算術錯誤: -40
# 第 596 筆錯誤資料: 1605218257052937
# 第 596 筆算術錯誤: 72
# 第 597 筆錯誤資料: 1605218257052809
# 第 597 筆算術錯誤: -56
# 第 598 筆錯誤資料: 1605218257052921
# 第 598 筆算術錯誤: 56
# 第 599 筆錯誤資料: 1605218257052793
# 第 599 筆算術錯誤: -72
# 第 600 筆錯誤資料: 1605218257053001
# 第 600 筆算術錯誤: 136
# 第 601 筆錯誤資料: 1605218257052745
# 第 601 筆算術錯誤: -120
# 第 602 筆錯誤資料: 1605218257052985
# 第 602 筆算術錯誤: 120
# 第 603 筆錯誤資料: 1605218257052729
# 第 603 筆算術錯誤: -136
# 第 604 筆錯誤資料: 1605218257053129
# 第 604 筆算術錯誤: 264
# 第 605 筆錯誤資料: 1605218257052617
# 第 605 筆算術錯誤: -248
# 第 606 筆錯誤資料: 1605218257053113
# 第 606 筆算術錯誤: 248
# 第 607 筆錯誤資料: 1605218257052601
# 第 607 筆算術錯誤: -264
# 第 608 筆錯誤資料: 1605218257053385
# 第 608 筆算術錯誤: 520
# 第 609 筆錯誤資料: 1605218257052361
# 第 609 筆算術錯誤: -504
# 第 610 筆錯誤資料: 1605218257053369
# 第 610 筆算術錯誤: 504
# 第 611 筆錯誤資料: 1605218257052345
# 第 611 筆算術錯誤: -520
# 第 612 筆錯誤資料: 1605218257053897
# 第 612 筆算術錯誤: 1032
# 第 613 筆錯誤資料: 1605218257051849
# 第 613 筆算術錯誤: -1016
# 第 614 筆錯誤資料: 1605218257053881
# 第 614 筆算術錯誤: 1016
# 第 615 筆錯誤資料: 1605218257051833
# 第 615 筆算術錯誤: -1032
# 第 616 筆錯誤資料: 1605218257054921
# 第 616 筆算術錯誤: 2056
# 第 617 筆錯誤資料: 1605218257050825
# 第 617 筆算術錯誤: -2040
# 第 618 筆錯誤資料: 1605218257054905
# 第 618 筆算術錯誤: 2040
# 第 619 筆錯誤資料: 1605218257050809
# 第 619 筆算術錯誤: -2056
# 第 620 筆錯誤資料: 1605218257056969
# 第 620 筆算術錯誤: 4104
# 第 621 筆錯誤資料: 1605218257048777
# 第 621 筆算術錯誤: -4088
# 第 622 筆錯誤資料: 1605218257056953
# 第 622 筆算術錯誤: 4088
# 第 623 筆錯誤資料: 1605218257048761
# 第 623 筆算術錯誤: -4104
# 第 624 筆錯誤資料: 1605218257061065
# 第 624 筆算術錯誤: 8200
# 第 625 筆錯誤資料: 1605218257044681
# 第 625 筆算術錯誤: -8184
# 第 626 筆錯誤資料: 1605218257061049
# 第 626 筆算術錯誤: 8184
# 第 627 筆錯誤資料: 1605218257044665
# 第 627 筆算術錯誤: -8200
# 第 628 筆錯誤資料: 1605218257069257
# 第 628 筆算術錯誤: 16392
# 第 629 筆錯誤資料: 1605218257036489
# 第 629 筆算術錯誤: -16376
# 第 630 筆錯誤資料: 1605218257069241
# 第 630 筆算術錯誤: 16376
# 第 631 筆錯誤資料: 1605218257036473
# 第 631 筆算術錯誤: -16392
# 第 632 筆錯誤資料: 1605218257085641
# 第 632 筆算術錯誤: 32776
# 第 633 筆錯誤資料: 1605218257020105
# 第 633 筆算術錯誤: -32760
# 第 634 筆錯誤資料: 1605218257085625
# 第 634 筆算術錯誤: 32760
# 第 635 筆錯誤資料: 1605218257020089
# 第 635 筆算術錯誤: -32776
# 第 636 筆錯誤資料: 1605218257118409
# 第 636 筆算術錯誤: 65544
# 第 637 筆錯誤資料: 1605218256987337
# 第 637 筆算術錯誤: -65528
# 第 638 筆錯誤資料: 1605218257118393
# 第 638 筆算術錯誤: 65528
# 第 639 筆錯誤資料: 1605218256987321
# 第 639 筆算術錯誤: -65544
# 第 640 筆錯誤資料: 1605218257183945
# 第 640 筆算術錯誤: 131080
# 第 641 筆錯誤資料: 1605218256921801
# 第 641 筆算術錯誤: -131064
# 第 642 筆錯誤資料: 1605218257183929
# 第 642 筆算術錯誤: 131064
# 第 643 筆錯誤資料: 1605218256921785
# 第 643 筆算術錯誤: -131080
# 第 644 筆錯誤資料: 1605218257315017
# 第 644 筆算術錯誤: 262152
# 第 645 筆錯誤資料: 1605218256790729
# 第 645 筆算術錯誤: -262136
# 第 646 筆錯誤資料: 1605218257315001
# 第 646 筆算術錯誤: 262136
# 第 647 筆錯誤資料: 1605218256790713
# 第 647 筆算術錯誤: -262152
# 第 648 筆錯誤資料: 1605218257577161
# 第 648 筆算術錯誤: 524296
# 第 649 筆錯誤資料: 1605218256528585
# 第 649 筆算術錯誤: -524280
# 第 650 筆錯誤資料: 1605218257577145
# 第 650 筆算術錯誤: 524280
# 第 651 筆錯誤資料: 1605218256528569
# 第 651 筆算術錯誤: -524296
# 第 652 筆錯誤資料: 1605218258101449
# 第 652 筆算術錯誤: 1048584
# 第 653 筆錯誤資料: 1605218256004297
# 第 653 筆算術錯誤: -1048568
# 第 654 筆錯誤資料: 1605218258101433
# 第 654 筆算術錯誤: 1048568
# 第 655 筆錯誤資料: 1605218256004281
# 第 655 筆算術錯誤: -1048584
# 第 656 筆錯誤資料: 1605218259150025
# 第 656 筆算術錯誤: 2097160
# 第 657 筆錯誤資料: 1605218254955721
# 第 657 筆算術錯誤: -2097144
# 第 658 筆錯誤資料: 1605218259150009
# 第 658 筆算術錯誤: 2097144
# 第 659 筆錯誤資料: 1605218254955705
# 第 659 筆算術錯誤: -2097160
# 第 660 筆錯誤資料: 1605218261247177
# 第 660 筆算術錯誤: 4194312
# 第 661 筆錯誤資料: 1605218252858569
# 第 661 筆算術錯誤: -4194296
# 第 662 筆錯誤資料: 1605218261247161
# 第 662 筆算術錯誤: 4194296
# 第 663 筆錯誤資料: 1605218252858553
# 第 663 筆算術錯誤: -4194312
# 第 664 筆錯誤資料: 1605218265441481
# 第 664 筆算術錯誤: 8388616
# 第 665 筆錯誤資料: 1605218248664265
# 第 665 筆算術錯誤: -8388600
# 第 666 筆錯誤資料: 1605218265441465
# 第 666 筆算術錯誤: 8388600
# 第 667 筆錯誤資料: 1605218248664249
# 第 667 筆算術錯誤: -8388616
# 第 668 筆錯誤資料: 1605218273830089
# 第 668 筆算術錯誤: 16777224
# 第 669 筆錯誤資料: 1605218240275657
# 第 669 筆算術錯誤: -16777208
# 第 670 筆錯誤資料: 1605218273830073
# 第 670 筆算術錯誤: 16777208
# 第 671 筆錯誤資料: 1605218240275641
# 第 671 筆算術錯誤: -16777224
# 第 672 筆錯誤資料: 1605218290607305
# 第 672 筆算術錯誤: 33554440
# 第 673 筆錯誤資料: 1605218223498441
# 第 673 筆算術錯誤: -33554424
# 第 674 筆錯誤資料: 1605218290607289
# 第 674 筆算術錯誤: 33554424
# 第 675 筆錯誤資料: 1605218223498425
# 第 675 筆算術錯誤: -33554440
# 第 676 筆錯誤資料: 1605218324161737
# 第 676 筆算術錯誤: 67108872
# 第 677 筆錯誤資料: 1605218189944009
# 第 677 筆算術錯誤: -67108856
# 第 678 筆錯誤資料: 1605218324161721
# 第 678 筆算術錯誤: 67108856
# 第 679 筆錯誤資料: 1605218189943993
# 第 679 筆算術錯誤: -67108872
# 第 680 筆錯誤資料: 1605218391270601
# 第 680 筆算術錯誤: 134217736
# 第 681 筆錯誤資料: 1605218122835145
# 第 681 筆算術錯誤: -134217720
# 第 682 筆錯誤資料: 1605218391270585
# 第 682 筆算術錯誤: 134217720
# 第 683 筆錯誤資料: 1605218122835129
# 第 683 筆算術錯誤: -134217736
# 第 684 筆錯誤資料: 1605218525488329
# 第 684 筆算術錯誤: 268435464
# 第 685 筆錯誤資料: 1605217988617417
# 第 685 筆算術錯誤: -268435448
# 第 686 筆錯誤資料: 1605218525488313
# 第 686 筆算術錯誤: 268435448
# 第 687 筆錯誤資料: 1605217988617401
# 第 687 筆算術錯誤: -268435464
# 第 688 筆錯誤資料: 1605218793923785
# 第 688 筆算術錯誤: 536870920
# 第 689 筆錯誤資料: 1605217720181961
# 第 689 筆算術錯誤: -536870904
# 第 690 筆錯誤資料: 1605218793923769
# 第 690 筆算術錯誤: 536870904
# 第 691 筆錯誤資料: 1605217720181945
# 第 691 筆算術錯誤: -536870920
# 第 692 筆錯誤資料: 1605219330794697
# 第 692 筆算術錯誤: 1073741832
# 第 693 筆錯誤資料: 1605217183311049
# 第 693 筆算術錯誤: -1073741816
# 第 694 筆錯誤資料: 1605219330794681
# 第 694 筆算術錯誤: 1073741816
# 第 695 筆錯誤資料: 1605217183311033
# 第 695 筆算術錯誤: -1073741832
# 第 696 筆錯誤資料: 1605220404536521
# 第 696 筆算術錯誤: 2147483656
# 第 697 筆錯誤資料: 1605216109569225
# 第 697 筆算術錯誤: -2147483640
# 第 698 筆錯誤資料: 1605220404536505
# 第 698 筆算術錯誤: 2147483640
# 第 699 筆錯誤資料: 1605216109569209
# 第 699 筆算術錯誤: -2147483656
# 第 700 筆錯誤資料: 1605222552020169
# 第 700 筆算術錯誤: 4294967304
# 第 701 筆錯誤資料: 1605213962085577
# 第 701 筆算術錯誤: -4294967288
# 第 702 筆錯誤資料: 1605222552020153
# 第 702 筆算術錯誤: 4294967288
# 第 703 筆錯誤資料: 1605213962085561
# 第 703 筆算術錯誤: -4294967304
# 第 704 筆錯誤資料: 1605226846987465
# 第 704 筆算術錯誤: 8589934600
# 第 705 筆錯誤資料: 1605209667118281
# 第 705 筆算術錯誤: -8589934584
# 第 706 筆錯誤資料: 1605226846987449
# 第 706 筆算術錯誤: 8589934584
# 第 707 筆錯誤資料: 1605209667118265
# 第 707 筆算術錯誤: -8589934600
# 第 708 筆錯誤資料: 1605235436922057
# 第 708 筆算術錯誤: 17179869192
# 第 709 筆錯誤資料: 1605201077183689
# 第 709 筆算術錯誤: -17179869176
# 第 710 筆錯誤資料: 1605235436922041
# 第 710 筆算術錯誤: 17179869176
# 第 711 筆錯誤資料: 1605201077183673
# 第 711 筆算術錯誤: -17179869192
# 第 712 筆錯誤資料: 1605252616791241
# 第 712 筆算術錯誤: 34359738376
# 第 713 筆錯誤資料: 1605183897314505
# 第 713 筆算術錯誤: -34359738360
# 第 714 筆錯誤資料: 1605252616791225
# 第 714 筆算術錯誤: 34359738360
# 第 715 筆錯誤資料: 1605183897314489
# 第 715 筆算術錯誤: -34359738376
# 第 716 筆錯誤資料: 1605286976529609
# 第 716 筆算術錯誤: 68719476744
# 第 717 筆錯誤資料: 1605149537576137
# 第 717 筆算術錯誤: -68719476728
# 第 718 筆錯誤資料: 1605286976529593
# 第 718 筆算術錯誤: 68719476728
# 第 719 筆錯誤資料: 1605149537576121
# 第 719 筆算術錯誤: -68719476744
# 第 720 筆錯誤資料: 1605355696006345
# 第 720 筆算術錯誤: 137438953480
# 第 721 筆錯誤資料: 1605080818099401
# 第 721 筆算術錯誤: -137438953464
# 第 722 筆錯誤資料: 1605355696006329
# 第 722 筆算術錯誤: 137438953464
# 第 723 筆錯誤資料: 1605080818099385
# 第 723 筆算術錯誤: -137438953480
# 第 724 筆錯誤資料: 1605493134959817
# 第 724 筆算術錯誤: 274877906952
# 第 725 筆錯誤資料: 1604943379145929
# 第 725 筆算術錯誤: -274877906936
# 第 726 筆錯誤資料: 1605493134959801
# 第 726 筆算術錯誤: 274877906936
# 第 727 筆錯誤資料: 1604943379145913
# 第 727 筆算術錯誤: -274877906952
# 第 728 筆錯誤資料: 1605768012866761
# 第 728 筆算術錯誤: 549755813896
# 第 729 筆錯誤資料: 1604668501238985
# 第 729 筆算術錯誤: -549755813880
# 第 730 筆錯誤資料: 1605768012866745
# 第 730 筆算術錯誤: 549755813880
# 第 731 筆錯誤資料: 1604668501238969
# 第 731 筆算術錯誤: -549755813896
# 第 732 筆錯誤資料: 1606317768680649
# 第 732 筆算術錯誤: 1099511627784
# 第 733 筆錯誤資料: 1604118745425097
# 第 733 筆算術錯誤: -1099511627768
# 第 734 筆錯誤資料: 1606317768680633
# 第 734 筆算術錯誤: 1099511627768
# 第 735 筆錯誤資料: 1604118745425081
# 第 735 筆算術錯誤: -1099511627784
# 第 736 筆錯誤資料: 1607417280308425
# 第 736 筆算術錯誤: 2199023255560
# 第 737 筆錯誤資料: 1603019233797321
# 第 737 筆算術錯誤: -2199023255544
# 第 738 筆錯誤資料: 1607417280308409
# 第 738 筆算術錯誤: 2199023255544
# 第 739 筆錯誤資料: 1603019233797305
# 第 739 筆算術錯誤: -2199023255560
# 第 740 筆錯誤資料: 1609616303563977
# 第 740 筆算術錯誤: 4398046511112
# 第 741 筆錯誤資料: 1600820210541769
# 第 741 筆算術錯誤: -4398046511096
# 第 742 筆錯誤資料: 1609616303563961
# 第 742 筆算術錯誤: 4398046511096
# 第 743 筆錯誤資料: 1600820210541753
# 第 743 筆算術錯誤: -4398046511112
# 第 744 筆錯誤資料: 1614014350075081
# 第 744 筆算術錯誤: 8796093022216
# 第 745 筆錯誤資料: 1596422164030665
# 第 745 筆算術錯誤: -8796093022200
# 第 746 筆錯誤資料: 1614014350075065
# 第 746 筆算術錯誤: 8796093022200
# 第 747 筆錯誤資料: 1596422164030649
# 第 747 筆算術錯誤: -8796093022216
# 第 748 筆錯誤資料: 1622810443097289
# 第 748 筆算術錯誤: 17592186044424
# 第 749 筆錯誤資料: 1587626071008457
# 第 749 筆算術錯誤: -17592186044408
# 第 750 筆錯誤資料: 1622810443097273
# 第 750 筆算術錯誤: 17592186044408
# 第 751 筆錯誤資料: 1587626071008441
# 第 751 筆算術錯誤: -17592186044424
# 第 752 筆錯誤資料: 1640402629141705
# 第 752 筆算術錯誤: 35184372088840
# 第 753 筆錯誤資料: 1570033884964041
# 第 753 筆算術錯誤: -35184372088824
# 第 754 筆錯誤資料: 1640402629141689
# 第 754 筆算術錯誤: 35184372088824
# 第 755 筆錯誤資料: 1570033884964025
# 第 755 筆算術錯誤: -35184372088840
# 第 756 筆錯誤資料: 1675587001230537
# 第 756 筆算術錯誤: 70368744177672
# 第 757 筆錯誤資料: 1534849512875209
# 第 757 筆算術錯誤: -70368744177656
# 第 758 筆錯誤資料: 1675587001230521
# 第 758 筆算術錯誤: 70368744177656
# 第 759 筆錯誤資料: 1534849512875193
# 第 759 筆算術錯誤: -70368744177672
# 第 760 筆錯誤資料: 1745955745408201
# 第 760 筆算術錯誤: 140737488355336
# 第 761 筆錯誤資料: 1464480768697545
# 第 761 筆算術錯誤: -140737488355320
# 第 762 筆錯誤資料: 1745955745408185
# 第 762 筆算術錯誤: 140737488355320
# 第 763 筆錯誤資料: 1464480768697529
# 第 763 筆算術錯誤: -140737488355336
# 第 764 筆錯誤資料: 1886693233763529
# 第 764 筆算術錯誤: 281474976710664
# 第 765 筆錯誤資料: 1323743280342217
# 第 765 筆算術錯誤: -281474976710648
# 第 766 筆錯誤資料: 1886693233763513
# 第 766 筆算術錯誤: 281474976710648
# 第 767 筆錯誤資料: 1323743280342201
# 第 767 筆算術錯誤: -281474976710664
# 第 768 筆錯誤資料: 2168168210474185
# 第 768 筆算術錯誤: 562949953421320
# 第 769 筆錯誤資料: 1042268303631561
# 第 769 筆算術錯誤: -562949953421304
# 第 770 筆錯誤資料: 2168168210474169
# 第 770 筆算術錯誤: 562949953421304
# 第 771 筆錯誤資料: 1042268303631545
# 第 771 筆算術錯誤: -562949953421320
# 第 772 筆錯誤資料: 2731118163895497
# 第 772 筆算術錯誤: 1125899906842632
# 第 773 筆錯誤資料: 479318350210249
# 第 773 筆算術錯誤: -1125899906842616
# 第 774 筆錯誤資料: 2731118163895481
# 第 774 筆算術錯誤: 1125899906842616
# 第 775 筆錯誤資料: 479318350210233
# 第 775 筆算術錯誤: -1125899906842632
# 第 776 筆錯誤資料: 1605218257052913
# 第 776 筆算術錯誤: 48
# 第 777 筆錯誤資料: 1605218257052849
# 第 777 筆算術錯誤: -16
# 第 778 筆錯誤資料: 1605218257052881
# 第 778 筆算術錯誤: 16
# 第 779 筆錯誤資料: 1605218257052817
# 第 779 筆算術錯誤: -48
# 第 780 筆錯誤資料: 1605218257052945
# 第 780 筆算術錯誤: 80
# 第 781 筆錯誤資料: 1605218257052817
# 第 781 筆算術錯誤: -48
# 第 782 筆錯誤資料: 1605218257052913
# 第 782 筆算術錯誤: 48
# 第 783 筆錯誤資料: 1605218257052785
# 第 783 筆算術錯誤: -80
# 第 784 筆錯誤資料: 1605218257053009
# 第 784 筆算術錯誤: 144
# 第 785 筆錯誤資料: 1605218257052753
# 第 785 筆算術錯誤: -112
# 第 786 筆錯誤資料: 1605218257052977
# 第 786 筆算術錯誤: 112
# 第 787 筆錯誤資料: 1605218257052721
# 第 787 筆算術錯誤: -144
# 第 788 筆錯誤資料: 1605218257053137
# 第 788 筆算術錯誤: 272
# 第 789 筆錯誤資料: 1605218257052625
# 第 789 筆算術錯誤: -240
# 第 790 筆錯誤資料: 1605218257053105
# 第 790 筆算術錯誤: 240
# 第 791 筆錯誤資料: 1605218257052593
# 第 791 筆算術錯誤: -272
# 第 792 筆錯誤資料: 1605218257053393
# 第 792 筆算術錯誤: 528
# 第 793 筆錯誤資料: 1605218257052369
# 第 793 筆算術錯誤: -496
# 第 794 筆錯誤資料: 1605218257053361
# 第 794 筆算術錯誤: 496
# 第 795 筆錯誤資料: 1605218257052337
# 第 795 筆算術錯誤: -528
# 第 796 筆錯誤資料: 1605218257053905
# 第 796 筆算術錯誤: 1040
# 第 797 筆錯誤資料: 1605218257051857
# 第 797 筆算術錯誤: -1008
# 第 798 筆錯誤資料: 1605218257053873
# 第 798 筆算術錯誤: 1008
# 第 799 筆錯誤資料: 1605218257051825
# 第 799 筆算術錯誤: -1040
# 第 800 筆錯誤資料: 1605218257054929
# 第 800 筆算術錯誤: 2064
# 第 801 筆錯誤資料: 1605218257050833
# 第 801 筆算術錯誤: -2032
# 第 802 筆錯誤資料: 1605218257054897
# 第 802 筆算術錯誤: 2032
# 第 803 筆錯誤資料: 1605218257050801
# 第 803 筆算術錯誤: -2064
# 第 804 筆錯誤資料: 1605218257056977
# 第 804 筆算術錯誤: 4112
# 第 805 筆錯誤資料: 1605218257048785
# 第 805 筆算術錯誤: -4080
# 第 806 筆錯誤資料: 1605218257056945
# 第 806 筆算術錯誤: 4080
# 第 807 筆錯誤資料: 1605218257048753
# 第 807 筆算術錯誤: -4112
# 第 808 筆錯誤資料: 1605218257061073
# 第 808 筆算術錯誤: 8208
# 第 809 筆錯誤資料: 1605218257044689
# 第 809 筆算術錯誤: -8176
# 第 810 筆錯誤資料: 1605218257061041
# 第 810 筆算術錯誤: 8176
# 第 811 筆錯誤資料: 1605218257044657
# 第 811 筆算術錯誤: -8208
# 第 812 筆錯誤資料: 1605218257069265
# 第 812 筆算術錯誤: 16400
# 第 813 筆錯誤資料: 1605218257036497
# 第 813 筆算術錯誤: -16368
# 第 814 筆錯誤資料: 1605218257069233
# 第 814 筆算術錯誤: 16368
# 第 815 筆錯誤資料: 1605218257036465
# 第 815 筆算術錯誤: -16400
# 第 816 筆錯誤資料: 1605218257085649
# 第 816 筆算術錯誤: 32784
# 第 817 筆錯誤資料: 1605218257020113
# 第 817 筆算術錯誤: -32752
# 第 818 筆錯誤資料: 1605218257085617
# 第 818 筆算術錯誤: 32752
# 第 819 筆錯誤資料: 1605218257020081
# 第 819 筆算術錯誤: -32784
# 第 820 筆錯誤資料: 1605218257118417
# 第 820 筆算術錯誤: 65552
# 第 821 筆錯誤資料: 1605218256987345
# 第 821 筆算術錯誤: -65520
# 第 822 筆錯誤資料: 1605218257118385
# 第 822 筆算術錯誤: 65520
# 第 823 筆錯誤資料: 1605218256987313
# 第 823 筆算術錯誤: -65552
# 第 824 筆錯誤資料: 1605218257183953
# 第 824 筆算術錯誤: 131088
# 第 825 筆錯誤資料: 1605218256921809
# 第 825 筆算術錯誤: -131056
# 第 826 筆錯誤資料: 1605218257183921
# 第 826 筆算術錯誤: 131056
# 第 827 筆錯誤資料: 1605218256921777
# 第 827 筆算術錯誤: -131088
# 第 828 筆錯誤資料: 1605218257315025
# 第 828 筆算術錯誤: 262160
# 第 829 筆錯誤資料: 1605218256790737
# 第 829 筆算術錯誤: -262128
# 第 830 筆錯誤資料: 1605218257314993
# 第 830 筆算術錯誤: 262128
# 第 831 筆錯誤資料: 1605218256790705
# 第 831 筆算術錯誤: -262160
# 第 832 筆錯誤資料: 1605218257577169
# 第 832 筆算術錯誤: 524304
# 第 833 筆錯誤資料: 1605218256528593
# 第 833 筆算術錯誤: -524272
# 第 834 筆錯誤資料: 1605218257577137
# 第 834 筆算術錯誤: 524272
# 第 835 筆錯誤資料: 1605218256528561
# 第 835 筆算術錯誤: -524304
# 第 836 筆錯誤資料: 1605218258101457
# 第 836 筆算術錯誤: 1048592
# 第 837 筆錯誤資料: 1605218256004305
# 第 837 筆算術錯誤: -1048560
# 第 838 筆錯誤資料: 1605218258101425
# 第 838 筆算術錯誤: 1048560
# 第 839 筆錯誤資料: 1605218256004273
# 第 839 筆算術錯誤: -1048592
# 第 840 筆錯誤資料: 1605218259150033
# 第 840 筆算術錯誤: 2097168
# 第 841 筆錯誤資料: 1605218254955729
# 第 841 筆算術錯誤: -2097136
# 第 842 筆錯誤資料: 1605218259150001
# 第 842 筆算術錯誤: 2097136
# 第 843 筆錯誤資料: 1605218254955697
# 第 843 筆算術錯誤: -2097168
# 第 844 筆錯誤資料: 1605218261247185
# 第 844 筆算術錯誤: 4194320
# 第 845 筆錯誤資料: 1605218252858577
# 第 845 筆算術錯誤: -4194288
# 第 846 筆錯誤資料: 1605218261247153
# 第 846 筆算術錯誤: 4194288
# 第 847 筆錯誤資料: 1605218252858545
# 第 847 筆算術錯誤: -4194320
# 第 848 筆錯誤資料: 1605218265441489
# 第 848 筆算術錯誤: 8388624
# 第 849 筆錯誤資料: 1605218248664273
# 第 849 筆算術錯誤: -8388592
# 第 850 筆錯誤資料: 1605218265441457
# 第 850 筆算術錯誤: 8388592
# 第 851 筆錯誤資料: 1605218248664241
# 第 851 筆算術錯誤: -8388624
# 第 852 筆錯誤資料: 1605218273830097
# 第 852 筆算術錯誤: 16777232
# 第 853 筆錯誤資料: 1605218240275665
# 第 853 筆算術錯誤: -16777200
# 第 854 筆錯誤資料: 1605218273830065
# 第 854 筆算術錯誤: 16777200
# 第 855 筆錯誤資料: 1605218240275633
# 第 855 筆算術錯誤: -16777232
# 第 856 筆錯誤資料: 1605218290607313
# 第 856 筆算術錯誤: 33554448
# 第 857 筆錯誤資料: 1605218223498449
# 第 857 筆算術錯誤: -33554416
# 第 858 筆錯誤資料: 1605218290607281
# 第 858 筆算術錯誤: 33554416
# 第 859 筆錯誤資料: 1605218223498417
# 第 859 筆算術錯誤: -33554448
# 第 860 筆錯誤資料: 1605218324161745
# 第 860 筆算術錯誤: 67108880
# 第 861 筆錯誤資料: 1605218189944017
# 第 861 筆算術錯誤: -67108848
# 第 862 筆錯誤資料: 1605218324161713
# 第 862 筆算術錯誤: 67108848
# 第 863 筆錯誤資料: 1605218189943985
# 第 863 筆算術錯誤: -67108880
# 第 864 筆錯誤資料: 1605218391270609
# 第 864 筆算術錯誤: 134217744
# 第 865 筆錯誤資料: 1605218122835153
# 第 865 筆算術錯誤: -134217712
# 第 866 筆錯誤資料: 1605218391270577
# 第 866 筆算術錯誤: 134217712
# 第 867 筆錯誤資料: 1605218122835121
# 第 867 筆算術錯誤: -134217744
# 第 868 筆錯誤資料: 1605218525488337
# 第 868 筆算術錯誤: 268435472
# 第 869 筆錯誤資料: 1605217988617425
# 第 869 筆算術錯誤: -268435440
# 第 870 筆錯誤資料: 1605218525488305
# 第 870 筆算術錯誤: 268435440
# 第 871 筆錯誤資料: 1605217988617393
# 第 871 筆算術錯誤: -268435472
# 第 872 筆錯誤資料: 1605218793923793
# 第 872 筆算術錯誤: 536870928
# 第 873 筆錯誤資料: 1605217720181969
# 第 873 筆算術錯誤: -536870896
# 第 874 筆錯誤資料: 1605218793923761
# 第 874 筆算術錯誤: 536870896
# 第 875 筆錯誤資料: 1605217720181937
# 第 875 筆算術錯誤: -536870928
# 第 876 筆錯誤資料: 1605219330794705
# 第 876 筆算術錯誤: 1073741840
# 第 877 筆錯誤資料: 1605217183311057
# 第 877 筆算術錯誤: -1073741808
# 第 878 筆錯誤資料: 1605219330794673
# 第 878 筆算術錯誤: 1073741808
# 第 879 筆錯誤資料: 1605217183311025
# 第 879 筆算術錯誤: -1073741840
# 第 880 筆錯誤資料: 1605220404536529
# 第 880 筆算術錯誤: 2147483664
# 第 881 筆錯誤資料: 1605216109569233
# 第 881 筆算術錯誤: -2147483632
# 第 882 筆錯誤資料: 1605220404536497
# 第 882 筆算術錯誤: 2147483632
# 第 883 筆錯誤資料: 1605216109569201
# 第 883 筆算術錯誤: -2147483664
# 第 884 筆錯誤資料: 1605222552020177
# 第 884 筆算術錯誤: 4294967312
# 第 885 筆錯誤資料: 1605213962085585
# 第 885 筆算術錯誤: -4294967280
# 第 886 筆錯誤資料: 1605222552020145
# 第 886 筆算術錯誤: 4294967280
# 第 887 筆錯誤資料: 1605213962085553
# 第 887 筆算術錯誤: -4294967312
# 第 888 筆錯誤資料: 1605226846987473
# 第 888 筆算術錯誤: 8589934608
# 第 889 筆錯誤資料: 1605209667118289
# 第 889 筆算術錯誤: -8589934576
# 第 890 筆錯誤資料: 1605226846987441
# 第 890 筆算術錯誤: 8589934576
# 第 891 筆錯誤資料: 1605209667118257
# 第 891 筆算術錯誤: -8589934608
# 第 892 筆錯誤資料: 1605235436922065
# 第 892 筆算術錯誤: 17179869200
# 第 893 筆錯誤資料: 1605201077183697
# 第 893 筆算術錯誤: -17179869168
# 第 894 筆錯誤資料: 1605235436922033
# 第 894 筆算術錯誤: 17179869168
# 第 895 筆錯誤資料: 1605201077183665
# 第 895 筆算術錯誤: -17179869200
# 第 896 筆錯誤資料: 1605252616791249
# 第 896 筆算術錯誤: 34359738384
# 第 897 筆錯誤資料: 1605183897314513
# 第 897 筆算術錯誤: -34359738352
# 第 898 筆錯誤資料: 1605252616791217
# 第 898 筆算術錯誤: 34359738352
# 第 899 筆錯誤資料: 1605183897314481
# 第 899 筆算術錯誤: -34359738384
# 第 900 筆錯誤資料: 1605286976529617
# 第 900 筆算術錯誤: 68719476752
# 第 901 筆錯誤資料: 1605149537576145
# 第 901 筆算術錯誤: -68719476720
# 第 902 筆錯誤資料: 1605286976529585
# 第 902 筆算術錯誤: 68719476720
# 第 903 筆錯誤資料: 1605149537576113
# 第 903 筆算術錯誤: -68719476752
# 第 904 筆錯誤資料: 1605355696006353
# 第 904 筆算術錯誤: 137438953488
# 第 905 筆錯誤資料: 1605080818099409
# 第 905 筆算術錯誤: -137438953456
# 第 906 筆錯誤資料: 1605355696006321
# 第 906 筆算術錯誤: 137438953456
# 第 907 筆錯誤資料: 1605080818099377
# 第 907 筆算術錯誤: -137438953488
# 第 908 筆錯誤資料: 1605493134959825
# 第 908 筆算術錯誤: 274877906960
# 第 909 筆錯誤資料: 1604943379145937
# 第 909 筆算術錯誤: -274877906928
# 第 910 筆錯誤資料: 1605493134959793
# 第 910 筆算術錯誤: 274877906928
# 第 911 筆錯誤資料: 1604943379145905
# 第 911 筆算術錯誤: -274877906960
# 第 912 筆錯誤資料: 1605768012866769
# 第 912 筆算術錯誤: 549755813904
# 第 913 筆錯誤資料: 1604668501238993
# 第 913 筆算術錯誤: -549755813872
# 第 914 筆錯誤資料: 1605768012866737
# ...
# 第 5039 筆算術錯誤: -1143492092887040
# 第 5040 筆錯誤資料: 1710771373319361
# 第 5040 筆算術錯誤: 105553116266496
# 第 5041 筆錯誤資料: 1570033884964033
# 第 5041 筆算術錯誤: -35184372088832
# 第 5042 筆錯誤資料: 1640402629141697
# 第 5042 筆算術錯誤: 35184372088832
# 第 5043 筆錯誤資料: 1499665140786369
# 第 5043 筆算術錯誤: -105553116266496
# 第 5044 筆錯誤資料: 1781140117497025
# 第 5044 筆算術錯誤: 175921860444160
# 第 5045 筆錯誤資料: 1499665140786369
# 第 5045 筆算術錯誤: -105553116266496
# 第 5046 筆錯誤資料: 1710771373319361
# 第 5046 筆算術錯誤: 105553116266496
# 第 5047 筆錯誤資料: 1429296396608705
# 第 5047 筆算術錯誤: -175921860444160
# 第 5048 筆錯誤資料: 1921877605852353
# 第 5048 筆算術錯誤: 316659348799488
# 第 5049 筆錯誤資料: 1358927652431041
# 第 5049 筆算術錯誤: -246290604621824
# 第 5050 筆錯誤資料: 1851508861674689
# 第 5050 筆算術錯誤: 246290604621824
# 第 5051 筆錯誤資料: 1288558908253377
# 第 5051 筆算術錯誤: -316659348799488
# 第 5052 筆錯誤資料: 2203352582563009
# 第 5052 筆算術錯誤: 598134325510144
# 第 5053 筆錯誤資料: 1077452675720385
# 第 5053 筆算術錯誤: -527765581332480
# 第 5054 筆錯誤資料: 2132983838385345
# 第 5054 筆算術錯誤: 527765581332480
# 第 5055 筆錯誤資料: 1007083931542721
# 第 5055 筆算術錯誤: -598134325510144
# 第 5056 筆錯誤資料: 2766302535984321
# 第 5056 筆算術錯誤: 1161084278931456
# 第 5057 筆錯誤資料: 514502722299073
# 第 5057 筆算術錯誤: -1090715534753792
# 第 5058 筆錯誤資料: 2695933791806657
# 第 5058 筆算術錯誤: 1090715534753792
# 第 5059 筆錯誤資料: 444133978121409
# 第 5059 筆算術錯誤: -1161084278931456
# 第 5060 筆錯誤資料: 1816324489585857
# 第 5060 筆算術錯誤: 211106232532992
# 第 5061 筆錯誤資料: 1534849512875201
# 第 5061 筆算術錯誤: -70368744177664
# 第 5062 筆錯誤資料: 1675587001230529
# 第 5062 筆算術錯誤: 70368744177664
# 第 5063 筆錯誤資料: 1394112024519873
# 第 5063 筆算術錯誤: -211106232532992
# 第 5064 筆錯誤資料: 1957061977941185
# 第 5064 筆算術錯誤: 351843720888320
# 第 5065 筆錯誤資料: 1394112024519873
# 第 5065 筆算術錯誤: -211106232532992
# 第 5066 筆錯誤資料: 1816324489585857
# 第 5066 筆算術錯誤: 211106232532992
# 第 5067 筆錯誤資料: 1253374536164545
# 第 5067 筆算術錯誤: -351843720888320
# 第 5068 筆錯誤資料: 2238536954651841
# 第 5068 筆算術錯誤: 633318697598976
# 第 5069 筆錯誤資料: 1112637047809217
# 第 5069 筆算術錯誤: -492581209243648
# 第 5070 筆錯誤資料: 2097799466296513
# 第 5070 筆算術錯誤: 492581209243648
# 第 5071 筆錯誤資料: 971899559453889
# 第 5071 筆算術錯誤: -633318697598976
# 第 5072 筆錯誤資料: 2801486908073153
# 第 5072 筆算術錯誤: 1196268651020288
# 第 5073 筆錯誤資料: 549687094387905
# 第 5073 筆算術錯誤: -1055531162664960
# 第 5074 筆錯誤資料: 2660749419717825
# 第 5074 筆算術錯誤: 1055531162664960
# 第 5075 筆錯誤資料: 408949606032577
# 第 5075 筆算術錯誤: -1196268651020288
# 第 5076 筆錯誤資料: 2027430722118849
# 第 5076 筆算術錯誤: 422212465065984
# 第 5077 筆錯誤資料: 1464480768697537
# 第 5077 筆算術錯誤: -140737488355328
# 第 5078 筆錯誤資料: 1745955745408193
# 第 5078 筆算術錯誤: 140737488355328
# 第 5079 筆錯誤資料: 1183005791986881
# 第 5079 筆算術錯誤: -422212465065984
# 第 5080 筆錯誤資料: 2308905698829505
# 第 5080 筆算術錯誤: 703687441776640
# 第 5081 筆錯誤資料: 1183005791986881
# 第 5081 筆算術錯誤: -422212465065984
# 第 5082 筆錯誤資料: 2027430722118849
# 第 5082 筆算術錯誤: 422212465065984
# 第 5083 筆錯誤資料: 901530815276225
# 第 5083 筆算術錯誤: -703687441776640
# 第 5084 筆錯誤資料: 2871855652250817
# 第 5084 筆算術錯誤: 1266637395197952
# 第 5085 筆錯誤資料: 620055838565569
# 第 5085 筆算術錯誤: -985162418487296
# 第 5086 筆錯誤資料: 2590380675540161
# 第 5086 筆算術錯誤: 985162418487296
# 第 5087 筆錯誤資料: 338580861854913
# 第 5087 筆算術錯誤: -1266637395197952
# 第 5088 筆錯誤資料: 2449643187184833
# 第 5088 筆算術錯誤: 844424930131968
# 第 5089 筆錯誤資料: 1323743280342209
# 第 5089 筆算術錯誤: -281474976710656
# 第 5090 筆錯誤資料: 1886693233763521
# 第 5090 筆算術錯誤: 281474976710656
# 第 5091 筆錯誤資料: 760793326920897
# 第 5091 筆算術錯誤: -844424930131968
# 第 5092 筆錯誤資料: 3012593140606145
# 第 5092 筆算術錯誤: 1407374883553280
# 第 5093 筆錯誤資料: 760793326920897
# 第 5093 筆算術錯誤: -844424930131968
# 第 5094 筆錯誤資料: 2449643187184833
# 第 5094 筆算術錯誤: 844424930131968
# 第 5095 筆錯誤資料: 197843373499585
# 第 5095 筆算術錯誤: -1407374883553280
# 第 5096 筆錯誤資料: 3294068117316801
# 第 5096 筆算術錯誤: 1688849860263936
# 第 5097 筆錯誤資料: 1042268303631553
# 第 5097 筆算術錯誤: -562949953421312
# 第 5098 筆錯誤資料: 2168168210474177
# 第 5098 筆算術錯誤: 562949953421312
# 第 5099 筆錯誤資料: -83631603211071
# 第 5099 筆算術錯誤: -1688849860263936
# 錯誤資料對AN取完模數:
#  [9423, 19532, 12907, 21274, 13778, 10030, 8156, 7219, 18430, 12356, 9319, 19480, 12881, 21261, 2092, 4187, 16914, 11598, 8940, 7611, 18626, 12454, 9368, 7825, 18733, 828, 3555, 16598, 11440, 8861, 19251, 1087, 15364, 10823, 20232, 13257, 21449, 2186, 4234, 5258, 5770, 6026, 6154, 6218, 6250, 6266, 6274, 6278, 6280, 6281, 6282, 6283, 6284, 6286, 6290, 6298, 6314, 6346, 6410, 6538, 6794, 7306, 8330, 10378, 14474, 22666, 15691, 1741, 20559, 11477, 16672, 3703, 1124, 19325, 9009, 11736, 17190, 4739, 3196, 110, 17297, 4953, 3624, 966, 19009, 8377, 10472, 14662, 23042, 16443, 3245, 208, 17493, 5345, 4408, 2534, 22145, 14649, 23016, 16391, 9766, 18133, 10637, 6889, 5015, 4078, 15289, 9215, 6178, 16339, 9740, 18120, 22310, 1046, 13773, 8457, 5799, 4470, 15485, 9313, 6227, 4684, 15592, 21046, 414, 13457, 8299, 5720, 16110, 21305, 12223, 7682, 17091, 10116, 18308, 22404, 1093, 2117, 2629, 2885, 3013, 3077, 3109, 3125, 3133, 3137, 3139, 3140, 3141, 3142, 3143, 3145, 3149, 3157, 3173, 3205, 3269, 3397, 3653, 4165, 5189, 7237, 11333, 19525, 12550, 21959, 17418, 8336, 13531, 562, 21342, 16184, 5868, 8595, 14049, 1598, 55, 20328, 14156, 1812, 483, 21184, 15868, 5236, 7331, 11521, 19901, 13302, 104, 20426, 14352, 2204, 1267, 22752, 19004, 11508, 19875, 4883, 20746, 16998, 15124, 14187, 2039, 19324, 16287, 3089, 19849, 4870, 9060, 11155, 523, 18566, 15908, 14579, 2235, 19422, 16336, 14793, 2342, 7796, 10523, 207, 18408, 15829, 2860, 8055, 22332, 17791, 3841, 20225, 5058, 9154, 11202, 12226, 12738, 12994, 13122, 13186, 13218, 13234, 13242, 13246, 13248, 13249, 13250, 13251, 13252, 13254, 13258, 13266, 13282, 13314, 13378, 13506, 13762, 14274, 15298, 17346, 21442, 6275, 22659, 8709, 4168, 18445, 281, 10671, 8092, 2934, 15977, 18704, 799, 11707, 10164, 7078, 906, 11921, 10592, 7934, 2618, 15345, 17440, 21630, 6651, 52, 10213, 7176, 1102, 12313, 11376, 9502, 5754, 21617, 14121, 10373, 8499, 7562, 18773, 12699, 9662, 19823, 13224, 21604, 2435, 4530, 17257, 11941, 9283, 7954, 18969, 12797, 9711, 8168, 19076, 1171, 3898, 16941, 11783, 9204, 19594, 1430, 15707, 11166, 20575, 13600, 21792, 2529, 4577, 5601, 6113, 6369, 6497, 6561, 6593, 6609, 6617, 6621, 6623, 6624, 6625, 6626, 6627, 6629, 6633, 6641, 6657, 6689, 6753, 6881, 7137, 7649, 8673, 10721, 14817, 23009, 16034, 2084, 20902, 11820, 17015, 4046, 1467, 19668, 9352, 12079, 17533, 5082, 3539, 453, 17640, 5296, 3967, 1309, 19352, 8720, 10815, 15005, 26, 16786, 3588, 551, 17836, 5688, 4751, 2877, 22488, 18740, 16866, 15929, 3781, 21066, 18029, 4831, 21591, 6612, 10802, 12897, 2265, 20308, 17650, 16321, 3977, 21164, 18078, 16535, 4084, 9538, 12265, 1949, 20150, 17571, 4602, 9797, 715, 19533, 5583, 21967, 6800, 10896, 12944, 13968, 14480, 14736, 14864, 14928, 14960, 14976, 14984, 14988, 14990, 14991, 14992, 14993, 14994, 14996, 15000, 15008, 15024, 15056, 15120, 15248, 15504, 16016, 17040, 19088, 23184, 8017, 1042, 10451, 5910, 20187, 2023, 12413, 9834, 4676, 17719, 20446, 2541, 13449, 11906, 8820, 2648, 13663, 12334, 9676, 4360, 17087, 19182, 13, 8393, 1794, 11955, 8918, 2844, 14055, 13118, 11244, 9370, 8433, 19644, 13570, 10533, 20694, 14095, 22475, 3306, 5401, 18128, 12812, 10154, 8825, 19840, 13668, 10582, 9039, 19947, 2042, 4769, 17812, 12654, 10075, 20465, 2301, 16578, 12037, 21446, 14471, 22663, 3400, 5448, 6472, 6984, 7240, 7368, 7432, 7464, 7480, 7488, 7492, 7494, 7495, 7496, 7497, 7498, 7500, 7504, 7512, 7528, 7560, 7624, 7752, 8008, 8520, 9544, 11592, 15688, 521, 16905, 2955, 21773, 12691, 17886, 4917, 2338, 20539, 10223, 12950, 18404, 5953, 4410, 1324, 18511, 6167, 4838, 2180, 20223, 9591, 11686, 15876, 897, 17657, 4459, 1422, 18707, 6559, 5622, 4685, 15896, 9822, 6785, 16946, 10347, 18727, 22917, 1653, 14380, 9064, 6406, 5077, 16092, 9920, 6834, 5291, 16199, 21653, 1021, 14064, 8906, 6327, 16717, 21912, 12830, 8289, 17698, 10723, 18915, 23011, 1700, 2724, 3236, 3492, 3620, 3684, 3716, 3732, 3740, 3744, 3746, 3747, 3748, 3749, 3750, 3752, 3756, 3764, 3780, 3812, 3876, 4004, 4260, 4772, 579 ...
# Barret reduction對錯誤資料取完模數:
#  [9423, 19532, 12907, 21274, 13778, 10030, 8156, 7219, 18430, 12356, 9319, 19480, 12881, 21261, 2092, 4187, 16914, 11598, 8940, 7611, 18626, 12454, 9368, 7825, 18733, 828, 3555, 16598, 11440, 8861, 19251, 1087, 15364, 10823, 20232, 13257, 21449, 2186, 4234, 5258, 5770, 6026, 6154, 6218, 6250, 6266, 6274, 6278, 6280, 6281, 6282, 6283, 6284, 6286, 6290, 6298, 6314, 6346, 6410, 6538, 6794, 7306, 8330, 10378, 14474, 22666, 15691, 1741, 20559, 11477, 16672, 3703, 1124, 19325, 9009, 11736, 17190, 4739, 3196, 110, 17297, 4953, 3624, 966, 19009, 8377, 10472, 14662, 23042, 16443, 3245, 208, 17493, 5345, 4408, 2534, 22145, 14649, 23016, 16391, 9766, 18133, 10637, 6889, 5015, 4078, 15289, 9215, 6178, 16339, 9740, 18120, 22310, 1046, 13773, 8457, 5799, 4470, 15485, 9313, 6227, 4684, 15592, 21046, 414, 13457, 8299, 5720, 16110, 21305, 12223, 7682, 17091, 10116, 18308, 22404, 1093, 2117, 2629, 2885, 3013, 3077, 3109, 3125, 3133, 3137, 3139, 3140, 3141, 3142, 3143, 3145, 3149, 3157, 3173, 3205, 3269, 3397, 3653, 4165, 5189, 7237, 11333, 19525, 12550, 21959, 17418, 8336, 13531, 562, 21342, 16184, 5868, 8595, 14049, 1598, 55, 20328, 14156, 1812, 483, 21184, 15868, 5236, 7331, 11521, 19901, 13302, 104, 20426, 14352, 2204, 1267, 22752, 19004, 11508, 19875, 4883, 20746, 16998, 15124, 14187, 2039, 19324, 16287, 3089, 19849, 4870, 9060, 11155, 523, 18566, 15908, 14579, 2235, 19422, 16336, 14793, 2342, 7796, 10523, 207, 18408, 15829, 2860, 8055, 22332, 17791, 3841, 20225, 5058, 9154, 11202, 12226, 12738, 12994, 13122, 13186, 13218, 13234, 13242, 13246, 13248, 13249, 13250, 13251, 13252, 13254, 13258, 13266, 13282, 13314, 13378, 13506, 13762, 14274, 15298, 17346, 21442, 6275, 22659, 8709, 4168, 18445, 281, 10671, 8092, 2934, 15977, 18704, 799, 11707, 10164, 7078, 906, 11921, 10592, 7934, 2618, 15345, 17440, 21630, 6651, 52, 10213, 7176, 1102, 12313, 11376, 9502, 5754, 21617, 14121, 10373, 8499, 7562, 18773, 12699, 9662, 19823, 13224, 21604, 2435, 4530, 17257, 11941, 9283, 7954, 18969, 12797, 9711, 8168, 19076, 1171, 3898, 16941, 11783, 9204, 19594, 1430, 15707, 11166, 20575, 13600, 21792, 2529, 4577, 5601, 6113, 6369, 6497, 6561, 6593, 6609, 6617, 6621, 6623, 6624, 6625, 6626, 6627, 6629, 6633, 6641, 6657, 6689, 6753, 6881, 7137, 7649, 8673, 10721, 14817, 23009, 16034, 2084, 20902, 11820, 17015, 4046, 1467, 19668, 9352, 12079, 17533, 5082, 3539, 453, 17640, 5296, 3967, 1309, 19352, 8720, 10815, 15005, 26, 16786, 3588, 551, 17836, 5688, 4751, 2877, 22488, 18740, 16866, 15929, 3781, 21066, 18029, 4831, 21591, 6612, 10802, 12897, 2265, 20308, 17650, 16321, 3977, 21164, 18078, 16535, 4084, 9538, 12265, 1949, 20150, 17571, 4602, 9797, 715, 19533, 5583, 21967, 6800, 10896, 12944, 13968, 14480, 14736, 14864, 14928, 14960, 14976, 14984, 14988, 14990, 14991, 14992, 14993, 14994, 14996, 15000, 15008, 15024, 15056, 15120, 15248, 15504, 16016, 17040, 19088, 23184, 8017, 1042, 10451, 5910, 20187, 2023, 12413, 9834, 4676, 17719, 20446, 2541, 13449, 11906, 8820, 2648, 13663, 12334, 9676, 4360, 17087, 19182, 13, 8393, 1794, 11955, 8918, 2844, 14055, 13118, 11244, 9370, 8433, 19644, 13570, 10533, 20694, 14095, 22475, 3306, 5401, 18128, 12812, 10154, 8825, 19840, 13668, 10582, 9039, 19947, 2042, 4769, 17812, 12654, 10075, 20465, 2301, 16578, 12037, 21446, 14471, 22663, 3400, 5448, 6472, 6984, 7240, 7368, 7432, 7464, 7480, 7488, 7492, 7494, 7495, 7496, 7497, 7498, 7500, 7504, 7512, 7528, 7560, 7624, 7752, 8008, 8520, 9544, 11592, 15688, 521, 16905, 2955, 21773, 12691, 17886, 4917, 2338, 20539, 10223, 12950, 18404, 5953, 4410, 1324, 18511, 6167, 4838, 2180, 20223, 9591, 11686, 15876, 897, 17657, 4459, 1422, 18707, 6559, 5622, 4685, 15896, 9822, 6785, 16946, 10347, 18727, 22917, 1653, 14380, 9064, 6406, 5077, 16092, 9920, 6834, 5291, 16199, 21653, 1021, 14064, 8906, 6327, 16717, 21912, 12830, 8289, 17698, 10723, 18915, 23011, 1700, 2724, 3236, 3492, 3620, 3684, 3716, 3732, 3740, 3744, 3746, 3747, 3748, 3749, 3750, 3752, 3756, 3764, 3780, 3812, 3876, 4004, 4260, 4772, 579 ...
# Barret reduction是否可以使用: True
# 所有餘數(一般mod函數)是否完全相異: True
# 所有餘數(Barret reduction)是否完全相異: True
# 所有的AWE:
#  [-1688849860263936, -1407374883553280, -1266637395197952, -1196268651020288, -1161084278931456, -1143492092887040, -1134695999864832, -1130297953353728, -1128098930098176, -1126999418470400, -1126449662656512, -1126174784749568, -1126037345796096, -1125968626319360, -1125934266580992, -1125917086711808, -1125908496777216, -1125904201809920, -1125902054326272, -1125900980584448, -1125900443713536, -1125900175278080, -1125900041060352, -1125899973951488, -1125899940397056, -1125899923619840, -1125899915231232, -1125899911036928, -1125899908939776, -1125899907891200, -1125899907366912, -1125899907104768, -1125899906973696, -1125899906908160, -1125899906875392, -1125899906859008, -1125899906850816, -1125899906846720, -1125899906844672, -1125899906843648, -1125899906843136, -1125899906842880, -1125899906842752, -1125899906842688, -1125899906842656, -1125899906842640, -1125899906842632, -1125899906842628, -1125899906842626, -1125899906842625, -1125899906842624, -1125899906842623, -1125899906842622, -1125899906842620, -1125899906842616, -1125899906842608, -1125899906842592, -1125899906842560, -1125899906842496, -1125899906842368, -1125899906842112, -1125899906841600, -1125899906840576, -1125899906838528, -1125899906834432, -1125899906826240, -1125899906809856, -1125899906777088, -1125899906711552, -1125899906580480, -1125899906318336, -1125899905794048, -1125899904745472, -1125899902648320, -1125899898454016, -1125899890065408, -1125899873288192, -1125899839733760, -1125899772624896, -1125899638407168, -1125899369971712, -1125898833100800, -1125897759358976, -1125895611875328, -1125891316908032, -1125882726973440, -1125865547104256, -1125831187365888, -1125762467889152, -1125625028935680, -1125350151028736, -1124800395214848, -1123700883587072, -1121501860331520, -1117103813820416, -1108307720798208, -1090715534753792, -1055531162664960, -985162418487296, -844424930131968, -703687441776640, -633318697598976, -598134325510144, -580542139465728, -571746046443520, -567347999932416, -565148976676864, -564049465049088, -563499709235200, -563224831328256, -563087392374784, -563018672898048, -562984313159680, -562967133290496, -562958543355904, -562954248388608, -562952100904960, -562951027163136, -562950490292224, -562950221856768, -562950087639040, -562950020530176, -562949986975744, -562949970198528, -562949961809920, -562949957615616, -562949955518464, -562949954469888, -562949953945600, -562949953683456, -562949953552384, -562949953486848, -562949953454080, -562949953437696, -562949953429504, -562949953425408, -562949953423360, -562949953422336, -562949953421824, -562949953421568, -562949953421440, -562949953421376, -562949953421344, -562949953421328, -562949953421320, -562949953421316, -562949953421314, -562949953421313, -562949953421312, -562949953421311, -562949953421310, -562949953421308, -562949953421304, -562949953421296, -562949953421280, -562949953421248, -562949953421184, -562949953421056, -562949953420800, -562949953420288, -562949953419264, -562949953417216, -562949953413120, -562949953404928, -562949953388544, -562949953355776, -562949953290240, -562949953159168, -562949952897024, -562949952372736, -562949951324160, -562949949227008, -562949945032704, -562949936644096, -562949919866880, -562949886312448, -562949819203584, -562949684985856, -562949416550400, -562948879679488, -562947805937664, -562945658454016, -562941363486720, -562932773552128, -562915593682944, -562881233944576, -562812514467840, -562675075514368, -562400197607424, -561850441793536, -560750930165760, -558551906910208, -554153860399104, -545357767376896, -527765581332480, -492581209243648, -422212465065984, -351843720888320, -316659348799488, -299067162755072, -290271069732864, -285873023221760, -283673999966208, -282574488338432, -282024732524544, -281749854617600, -281612415664128, -281543696187392, -281509336449024, -281492156579840, -281483566645248, -281479271677952, -281477124194304, -281476050452480, -281475513581568, -281475245146112, -28147511092 ...
# 5004
# 輸入餘數 9423, 對應算術錯誤: -1688849860263936
# 輸入餘數 19532, 對應算術錯誤: -1407374883553280
# 1605218257052865
# 1605218257052865
# 更正是否正確: True

# %% [markdown]
# #### DEC_ANcode (LUT):

# %%
DEC_A = 23359
Range_Max_number = 262143
DEC_Range_Max_number = 262143 * DEC_A
DEC_A_bits = math.floor(math.log2(DEC_Range_Max_number)) + 1
bits = math.floor(math.log2(Range_Max_number)) + 1      
print(bits)
print(DEC_A_bits)
# Out:
# 18
# 33

# %%
def simulate_adder_noise(A, B, width, sigma, threshold=0.22):
    carry_in = 0
    result_bits = []

    for i in range(width):
        a_bit = (A >> i) & 1
        b_bit = (B >> i) & 1

        # XOR(a, b)
        XOR_AB = a_bit ^ b_bit
        if abs(np.random.normal(0, sigma)) > threshold:
            XOR_AB ^= 1

        # sum = XOR_AB ^ carry_in
        sum_out = XOR_AB ^ carry_in
        if abs(np.random.normal(0, sigma)) > threshold:
            sum_out ^= 1

        # AND(a, b)
        AND_AB = a_bit & b_bit
        if abs(np.random.normal(0, sigma)) > threshold:
            AND_AB ^= 1

        # AND(XOR_AB, carry_in)
        AND_Cin = XOR_AB & carry_in
        if abs(np.random.normal(0, sigma)) > threshold:
            AND_Cin ^= 1

        # OR(AND_AB, AND_Cin)
        carry_out = AND_AB | AND_Cin
        if abs(np.random.normal(0, sigma)) > threshold:
            carry_out ^= 1

        result_bits.append(sum_out)
        carry_in = carry_out

    result_bits.append(carry_in)

    final_result = 0
    for i, bit in enumerate(result_bits):
        final_result |= (bit << i)

    return final_result

def simulate_array_multiplier_noise(A, B, sigma, threshold=0.22):
    """
    模擬具雜訊的 Array Multiplier（Shift-Add 實作 + 加上 AND 雜訊）
    - A, B: 18-bit 整數
    - sigma: 高斯白雜訊標準差
    - threshold: 閘門輸出被翻轉的雜訊門檻
    回傳值: 加上雜訊後的乘積
    """
    product = 0
    
    for i in range(bits):               # 對 B 的每一個位元 i
        partial = 0                     # 初始化此層的 partial product
        b_bit = (B >> i) & 1            # 搬到外層，B[i] 固定，只算一次
        
        for j in range(DEC_A_bits):           # 對 A 的每個位元 j
            a_bit = (A >> j) & 1
            
            # AND gate 模擬部分積：pp[i][j] = A[j] & B[i]
            AND_result = a_bit & b_bit
            
            # 加入雜訊 (noise)
            noise_AND = np.random.normal(0, sigma)
            if abs(noise_AND) > threshold:
                AND_result ^= 1  # 翻轉此位元
            
            # 將 AND_result 放到對應的位移上（i + j）
            partial |= (AND_result << (i + j))
        
        # 將此層 partial product 累加進總乘積
        product = simulate_adder_noise(product, partial, width=(bits + DEC_A_bits), sigma=sigma, threshold=threshold)
    
    return product

def noise_simulation(trials=1000, sigma=0.22, threshold=0.22):                   
        
    DEC_error_count = 0
    for _ in range(trials):
        A = random.randint(0, Range_Max_number)
        B = random.randint(0, Range_Max_number)
        correct_result = A * B
        DEC_AN_A = A * DEC_A
        DEC_AN_B = B
        result_withA = simulate_array_multiplier_noise(DEC_AN_A, DEC_AN_B, sigma, threshold)
        result_dividebyA = result_withA // DEC_A
        if result_dividebyA != correct_result:
            ### r = result_withA % DEC_A
            ### q = result_withA // DEC_A
            r,q = Barret_q_23359(result_withA)
            RAW_DATA = int(result_withA) - int(remainder_to_AWE[r])
            corrected_r,corrected_value = Barret_q_23359(RAW_DATA)
            ### corrected_value =  RAW_DATA % DEC_A
            if corrected_value != correct_result:
                DEC_error_count += 1
                
    return DEC_error_count / trials

if __name__ == "__main__":
    trials = 50000                              
    EbNodB_range = range(17, 24)
    threshold = 0.22
    DEC_AN_list = []

    for EbNodB in EbNodB_range:
        EbNo = 10.0**(EbNodB / 10.0)
        noise_std = 1 / sqrt(2 * EbNo)
        DEC_err_rate = noise_simulation(trials=trials, sigma=noise_std, threshold=threshold)
        DEC_AN_list.append(DEC_err_rate)
        print(f"SNR={EbNodB} dB, Noise Std={noise_std:.5f}, Error Rate={DEC_err_rate:.5f}")
# Out:
# SNR=17 dB, Noise Std=0.09988, Error Rate=1.00000
# SNR=18 dB, Noise Std=0.08902, Error Rate=1.00000
# SNR=19 dB, Noise Std=0.07934, Error Rate=1.00000
# SNR=20 dB, Noise Std=0.07071, Error Rate=0.99124
# SNR=21 dB, Noise Std=0.06302, Error Rate=0.40282
# SNR=22 dB, Noise Std=0.05617, Error Rate=0.00998
# SNR=23 dB, Noise Std=0.05006, Error Rate=0.00006

# %%
import matplotlib.pyplot as plt

SEC_BLER = plt.plot( EbNodB_range, SEC_AN_list,marker='o',linestyle='-.',color='#DC143C',markersize=4,label="SEC_BLER(A=101)")
DEC_BLER = plt.plot( EbNodB_range, DEC_AN_list,marker='D', linestyle='--',color='#0000FF',markersize=4,label="DEC_BLER(A=23359)")
Uncode_BLER=plt.plot( EbNodB_range, uncode_list,color='#008000',marker='v', linestyle='-',markersize=6,label="Uncode BLER")


plt.legend()
plt.axis([17, 24, 1e-5, 1])
plt.xscale('linear')
plt.yscale('log')
plt.xlabel('EbNo(dB)')
plt.ylabel('BLER')
plt.grid(True)
plt.title('Multiplier in 18-bits: SEC v.s. DEC v.s Uncode')
plt.savefig("Multiplier in 18bits SEC vs DEC vs Uncode(23dB)")
plt.show()
