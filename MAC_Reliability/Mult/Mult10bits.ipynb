# %% [markdown]
# ## 分析加法,乘法運算時底層硬體電路受到白雜訊 (SNR) 干擾發生的錯誤

# %% [markdown]
# * AER (Arithmetic Error Rate): 1bit 發生加錯或減錯的機率 (like BER)
# * CER (Carry Error Rate): Carry(進位) 受到影響而發生錯誤的機率
# * RER (Register Error Rate): 整個資料的發生錯誤的機率 (like BLER)

# %% [markdown]
# #### 乘法: 以 --> Array Multipiler 模擬

# %%
import numpy as np
from numpy.random import rand, randn, randint
import random
import scipy
from scipy.stats import truncnorm
import math
from numpy import sqrt

a, b = 0, 1  # 範圍限制在 0 ~ 1
mean = 0.5   # 平均值
std = 0.1    # 標准差
data = truncnorm.rvs((a - mean) / std, (b - mean) / std, loc=mean, scale=std, size=1).item()
print(data) 
print(np.random.normal(0, 0.2))
# Out:
# 0.4214181491732578
# 0.06299854127854114

# %%
Range_Max_number = (1 << 10) - 1                        # n-bit最大值
bits = math.floor(math.log2(Range_Max_number)) + 1      # bits = 

def simulate_adder_noise(A, B, width, sigma, threshold=0.22):
    carry_in = 0
    result_bits = []

    for i in range(width):
        a_bit = (A >> i) & 1
        b_bit = (B >> i) & 1

        # XOR(a, b)
        XOR_AB = a_bit ^ b_bit
        if abs(np.random.normal(0, sigma)) > threshold:
            XOR_AB ^= 1

        # sum = XOR_AB ^ carry_in
        sum_out = XOR_AB ^ carry_in
        if abs(np.random.normal(0, sigma)) > threshold:
            sum_out ^= 1

        # AND(a, b)
        AND_AB = a_bit & b_bit
        if abs(np.random.normal(0, sigma)) > threshold:
            AND_AB ^= 1

        # AND(XOR_AB, carry_in)
        AND_Cin = XOR_AB & carry_in
        if abs(np.random.normal(0, sigma)) > threshold:
            AND_Cin ^= 1

        # OR(AND_AB, AND_Cin)
        carry_out = AND_AB | AND_Cin
        if abs(np.random.normal(0, sigma)) > threshold:
            carry_out ^= 1

        result_bits.append(sum_out)
        carry_in = carry_out

    result_bits.append(carry_in)

    final_result = 0
    for i, bit in enumerate(result_bits):
        final_result |= (bit << i)

    return final_result

def simulate_array_multiplier_noise(A, B, sigma, threshold=0.22):
    """
    模擬具雜訊的 Array Multiplier（Shift-Add 實作 + 加上 AND 雜訊）
    - A, B: 18-bit 整數
    - sigma: 高斯白雜訊標準差
    - threshold: 閘門輸出被翻轉的雜訊門檻
    回傳值: 加上雜訊後的乘積
    """
    product = 0
    
    for i in range(bits):               # 對 B 的每一個位元 i
        partial = 0                     # 初始化此層的 partial product
        b_bit = (B >> i) & 1            # 搬到外層，B[i] 固定，只算一次
        
        for j in range(bits):  # 對 A 的每個位元 j
            a_bit = (A >> j) & 1
            
            # AND gate 模擬部分積：pp[i][j] = A[j] & B[i]
            AND_result = a_bit & b_bit
            
            # 加入雜訊 (noise)
            noise_AND = np.random.normal(0, sigma)
            if abs(noise_AND) > threshold:
                AND_result ^= 1  # 翻轉此位元
            
            # 將 and_result 放到對應的位移上（i + j）
            partial |= (AND_result << (i + j))
        
        # 將此層 partial product 累加進總乘積
        product = simulate_adder_noise(product, partial, width=2*bits, sigma=sigma, threshold=threshold)
    
    return product

def noise_simulation(trials=1000, sigma=0.22, threshold=0.22):
    error_count = 0
    for _ in range(trials):
        A = random.randint(0, Range_Max_number)
        B = random.randint(0, Range_Max_number)
        correct_result = A * B
        result = simulate_array_multiplier_noise(A, B, sigma, threshold)
        if result != correct_result:
            error_count += 1
    return error_count / trials

if __name__ == "__main__":
    trials = 100000                              
    EbNodB_range = range(16, 24)
    threshold = 0.22
    uncode_list = []

    for EbNodB in EbNodB_range:
        EbNo = 10.0**(EbNodB / 10.0)
        noise_std = 1 / sqrt(2 * EbNo)
        err_rate = noise_simulation(trials=trials, sigma=noise_std, threshold=threshold)
        uncode_list.append(err_rate)
        print(f"SNR={EbNodB} dB, Noise Std={noise_std:.5f}, Error Rate={err_rate:.5f}")
# Out:
# SNR=16 dB, Noise Std=0.11207, Error Rate=1.00000
# SNR=17 dB, Noise Std=0.09988, Error Rate=1.00000
# SNR=18 dB, Noise Std=0.08902, Error Rate=0.99999
# SNR=19 dB, Noise Std=0.07934, Error Rate=0.99609
# SNR=20 dB, Noise Std=0.07071, Error Rate=0.85338
# SNR=21 dB, Noise Std=0.06302, Error Rate=0.39798
# SNR=22 dB, Noise Std=0.05617, Error Rate=0.09116
# SNR=23 dB, Noise Std=0.05006, Error Rate=0.01169

# %%
print(uncode_list)
# Out:
# [1.0, 1.0, 0.99999, 0.99609, 0.85338, 0.39798, 0.09116, 0.01169]

# %% [markdown]
# #### Single AWE ANcode Decoder(A=59)

# %%
def A59_AN_decoder(residue,quotient):
    s_re=str(residue)
    msg={
        "1": lambda quotient: quotient,
        "2": lambda quotient: quotient,
        "4": lambda quotient: quotient,
        "8": lambda quotient: quotient,
        "16": lambda quotient: quotient,
        "32": lambda quotient: quotient,
        "5": lambda quotient: quotient-1,
        "10": lambda quotient: quotient-2,
        "20": lambda quotient: quotient-4,
        "40": lambda quotient: quotient-8,
        "21": lambda quotient: quotient-17,
        "42": lambda quotient: quotient-34,
        "25": lambda quotient: quotient-69,
        "50": lambda quotient: quotient-138,
        "41": lambda quotient: quotient-277,
        "23": lambda quotient: quotient-555,
        "46": lambda quotient: quotient-1110,
        "33": lambda quotient: quotient-2221,
        "7": lambda quotient: quotient-4443,
        "14": lambda quotient: quotient-8886,
        "28": lambda quotient: quotient-17772,
        "56": lambda quotient: quotient-35544,
        "53": lambda quotient: quotient-71089,
        "47": lambda quotient: quotient-142179,
        "35": lambda quotient: quotient-284359,
        "11": lambda quotient: quotient-568719,
        "22": lambda quotient: quotient-1137438,
        "44": lambda quotient: quotient-2274876,
        "29": lambda quotient: quotient-4549753,
        "58": lambda quotient: quotient+1,
        "57": lambda quotient: quotient+1,
        "55": lambda quotient: quotient+1,
        "51": lambda quotient: quotient+1,
        "43": lambda quotient: quotient+1,
        "27": lambda quotient: quotient+1,
        "54": lambda quotient: quotient+2,
        "49": lambda quotient: quotient+3,
        "39": lambda quotient: quotient+5,
        "19": lambda quotient: quotient+9,
        "38": lambda quotient: quotient+18,
        "17": lambda quotient: quotient+35,
        "34": lambda quotient: quotient+70,
        "9": lambda quotient: quotient+139,
        "18": lambda quotient: quotient+278,
        "36": lambda quotient: quotient+556,
        "13": lambda quotient: quotient+1111,
        "26": lambda quotient: quotient+2222,
        "52": lambda quotient: quotient+4444,
        "45": lambda quotient: quotient+8887,
        "31": lambda quotient: quotient+17773,
        "3": lambda quotient: quotient+35545,
        "6": lambda quotient: quotient+71090,
        "12": lambda quotient: quotient+142180,
        "24": lambda quotient: quotient+284360,
        "48": lambda quotient: quotient+568720,
        "37": lambda quotient: quotient+1137439,
        "15": lambda quotient: quotient+2274877,
        "30": lambda quotient: quotient+4549754,
        "0" :lambda quotient: quotient,
    }[s_re](quotient)
    msg
    return int(msg)



def Barret_q_59(x):
    q = (int(x) * 1137438) >> 26      ## (2^26)//59後, 右移26次         
    r = x - q * 59
    if r < 59:
        return (r,q)
    else:
        return (r - 59, q + 1)

# %% [markdown]
# #### Conventional SEC_ANcode:

# %%
print((1 << 10) - 1)
# Out:
# 1023

# %%
SEC_A = 59
Range_Max_number = 1023
SEC_Range_Max_number = 1023 * SEC_A
SEC_A_bits = math.floor(math.log2(SEC_Range_Max_number)) + 1
bits = math.floor(math.log2(Range_Max_number)) + 1      
print(bits)
print(SEC_A_bits)
# Out:
# 10
# 16

# %%
def simulate_adder_noise(A, B, width, sigma, threshold=0.22):
    carry_in = 0
    result_bits = []

    for i in range(width):
        a_bit = (A >> i) & 1
        b_bit = (B >> i) & 1

        # XOR(a, b)
        XOR_AB = a_bit ^ b_bit
        if abs(np.random.normal(0, sigma)) > threshold:
            XOR_AB ^= 1

        # sum = XOR_AB ^ carry_in
        sum_out = XOR_AB ^ carry_in
        if abs(np.random.normal(0, sigma)) > threshold:
            sum_out ^= 1

        # AND(a, b)
        AND_AB = a_bit & b_bit
        if abs(np.random.normal(0, sigma)) > threshold:
            AND_AB ^= 1

        # AND(XOR_AB, carry_in)
        AND_Cin = XOR_AB & carry_in
        if abs(np.random.normal(0, sigma)) > threshold:
            AND_Cin ^= 1

        # OR(AND_AB, AND_Cin)
        carry_out = AND_AB | AND_Cin
        if abs(np.random.normal(0, sigma)) > threshold:
            carry_out ^= 1

        result_bits.append(sum_out)
        carry_in = carry_out

    result_bits.append(carry_in)

    final_result = 0
    for i, bit in enumerate(result_bits):
        final_result |= (bit << i)

    return final_result

def simulate_array_multiplier_noise(A, B, sigma, threshold=0.22):
    """
    模擬具雜訊的 Array Multiplier（Shift-Add 實作 + 加上 AND 雜訊）
    - A, B: 18-bit 整數
    - sigma: 高斯白雜訊標準差
    - threshold: 閘門輸出被翻轉的雜訊門檻
    回傳值: 加上雜訊後的乘積
    """
    product = 0
    
    for i in range(bits):               # 對 B 的每一個位元 i
        partial = 0                     # 初始化此層的 partial product
        b_bit = (B >> i) & 1            # 搬到外層，B[i] 固定，只算一次
        
        for j in range(SEC_A_bits):           # 對 A 的每個位元 j
            a_bit = (A >> j) & 1
            
            # AND gate 模擬部分積：pp[i][j] = A[j] & B[i]
            AND_result = a_bit & b_bit
            
            # 加入雜訊 (noise)
            noise_AND = np.random.normal(0, sigma)
            if abs(noise_AND) > threshold:
                AND_result ^= 1  # 翻轉此位元
            
            # 將 AND_result 放到對應的位移上（i + j）
            partial |= (AND_result << (i + j))
        
        # 將此層 partial product 累加進總乘積
        product = simulate_adder_noise(product, partial, width=(bits + SEC_A_bits), sigma=sigma, threshold=threshold)
    
    return product

def noise_simulation(trials=1000, sigma=0.22, threshold=0.22):                   
        
    SEC_error_count = 0
    for _ in range(trials):
        A = random.randint(0, Range_Max_number)
        B = random.randint(0, Range_Max_number)
        correct_result = A * B
        SEC_AN_A = A * SEC_A
        SEC_AN_B = B
        result_withA = simulate_array_multiplier_noise(SEC_AN_A, SEC_AN_B, sigma, threshold)
        result_dividebyA = result_withA // SEC_A
        if result_dividebyA != correct_result:
            r,q = Barret_q_59(result_withA)
            corrected_value = A59_AN_decoder(r,q)
            if corrected_value != correct_result:
                SEC_error_count += 1
                
    return SEC_error_count / trials

if __name__ == "__main__":
    trials = 100000                              
    EbNodB_range = range(16, 24)
    threshold = 0.22
    SEC_AN_list = []

    for EbNodB in EbNodB_range:
        EbNo = 10.0**(EbNodB / 10.0)
        noise_std = 1 / sqrt(2 * EbNo)
        SEC_err_rate = noise_simulation(trials=trials, sigma=noise_std, threshold=threshold)
        SEC_AN_list.append(SEC_err_rate)
        print(f"SNR={EbNodB} dB, Noise Std={noise_std:.5f}, Error Rate={SEC_err_rate:.5f}")
# Out:
# SNR=16 dB, Noise Std=0.11207, Error Rate=1.00000
# SNR=17 dB, Noise Std=0.09988, Error Rate=1.00000
# SNR=18 dB, Noise Std=0.08902, Error Rate=0.99999
# SNR=19 dB, Noise Std=0.07934, Error Rate=0.99176
# SNR=20 dB, Noise Std=0.07071, Error Rate=0.69745
# SNR=21 dB, Noise Std=0.06302, Error Rate=0.13692
# SNR=22 dB, Noise Std=0.05617, Error Rate=0.00648
# SNR=23 dB, Noise Std=0.05006, Error Rate=0.00013

# %% [markdown]
# ### 使用查找表更正: DEC_ANcode, A = 6311
# * 10-bits*10bits = 20-bits
# * Function Definition

# %%
import math
import numpy as np

def decimal_to_binary(decimal_number):
    if decimal_number == 0:
        return "0"
    # 處理正數：直接轉換
    if decimal_number > 0:
        return bin(decimal_number)[2:]  # 移除 "0b" 前綴
       # 處理負數：自動計算所需位元數（2's complement）
    abs_value = abs(decimal_number)
    bits = abs_value.bit_length() + 1  # 負數多一個符號位元
    two_complement_value = (1 << bits) + decimal_number
    
    return bin(two_complement_value)[2:]  # 移除 "0b" 前綴

def bits_needed(number):
    if number < 0:
        raise ValueError("2's complement is not available")  # 如果輸入負數，拋出錯誤
    if number == 0:
        return 1  # 0 需要 1 個位元
    
    # 計算位元數
    bits = math.floor(math.log2(number)) + 1
    return bits

def bits_range(bits, signed=False):     ## 可選擇設定 有號數 或 無號數
    if bits <= 0:
        return "位元數必須為正整數！"
    
    if signed:
        # 二補數範圍: -2^(bits-1) 到 2^(bits-1)-1
        min_value = -(2**(bits - 1))
        max_value = 2**(bits - 1) - 1
    else:
        # 無符號範圍: 0 到 2^bits - 1
        min_value = 0
        max_value = 2**bits - 1

    return min_value, max_value

## 把重複的 AWE 去除
def remove_duplicates(input_list):
    unique_list = []
    for number in input_list:
        if number not in unique_list:
            unique_list.append(number)
    return sorted(unique_list)

def custom_mod(a, b):
    if b == 0:
        return "錯誤：除數不能為零！"
    # 計算商和餘數，修正餘數計算邏輯
    quotient = a // b
    remainder = a - b * quotient
    # 修正負餘數的情況
    if remainder > 0 and a < 0:
        remainder -= abs(b)
        quotient += 1
    return remainder

def remainder_unique(input_list):
    # 使用集合判斷元素是否有重複
    return len(input_list) == len(set(input_list))


def create_mapping(source_list, address_map):
    """
    建立值到位址和位址到值的雙向映射。
    若 address_map 中某位址沒有對應值，則該位址的值為 0。
    
    參數:
    source_list (list): 原始資料列表。
    address_map (list): 位址映射列表。
    
    回傳:
    tuple: (值到位址的映射, 位址到值的映射)
    """
    # 初始化值到位址的映射
    value_to_address = {value: addr for value, addr in zip(source_list, address_map)}
    
    # 初始化位址到值的映射，未指定的位址預設為 0
    max_address = max(address_map)  # 確保涵蓋所有位址
    address_to_value = {addr: 0 for addr in range(max_address + 1)}  # 預設為 0
    for value, addr in zip(source_list, address_map):
        address_to_value[addr] = value  # 更新有指定值的位址

    return value_to_address, address_to_value
def decimal_to_binary(decimal_number):
    if decimal_number == 0:
        return "0"
    # 處理正數：直接轉換
    if decimal_number > 0:
        return bin(decimal_number)[2:]  # 移除 "0b" 前綴
       # 處理負數：自動計算所需位元數（2's complement）
    abs_value = abs(decimal_number)
    bits = abs_value.bit_length() + 1  # 負數多一個符號位元
    two_complement_value = (1 << bits) + decimal_number
    
    return bin(two_complement_value)[2:]  # 移除 "0b" 前綴

def bits_needed(number):
    if number < 0:
        raise ValueError("2's complement is not available")  # 如果輸入負數，拋出錯誤
    if number == 0:
        return 1  # 0 需要 1 個位元
    
    # 計算位元數
    bits = math.floor(math.log2(number)) + 1
    return bits

def bits_range(bits, signed=False):     ## 可選擇設定 有號數 或 無號數
    if bits <= 0:
        return "位元數必須為正整數！"
    
    if signed:
        # 二補數範圍: -2^(bits-1) 到 2^(bits-1)-1
        min_value = -(2**(bits - 1))
        max_value = 2**(bits - 1) - 1
    else:
        # 無符號範圍: 0 到 2^bits - 1
        min_value = 0
        max_value = 2**bits - 1

    return min_value, max_value

## 把重複的 AWE 去除
def remove_duplicates(input_list):
    unique_list = []
    for number in input_list:
        if number not in unique_list:
            unique_list.append(number)
    return sorted(unique_list)

def custom_mod(a, b):
    if b == 0:
        return "錯誤：除數不能為零！"
    # 計算商和餘數，修正餘數計算邏輯
    quotient = a // b
    remainder = a - b * quotient
    # 修正負餘數的情況
    if remainder > 0 and a < 0:
        remainder -= abs(b)
        quotient += 1
    return remainder

def remainder_unique(input_list):
    # 使用集合判斷元素是否有重複
    return len(input_list) == len(set(input_list))

# %%
data = (1 << 20) - 1
print(data)
# Out:
# 1048575

# %%
### 輸入數值為data, ANcode的A為AN
### 乘完A後的數值為 input
data = (1 << 20) - 1
AN = 6311           ## AN:6311, 只適用輸入為0 ~ 1048575
input = data*AN
bits = bits_needed(input)

### 1-bit AWE:
AWE_1=[]
e1=0     ## 錯誤數量
e1_data=[]
for i in range(0, bits):
    AWE_1.insert(e1 , input + 2**i)
    e1_data.insert(e1, 2**i)
    e1 = e1 + 1
    AWE_1.insert(e1 , input - 2**i)
    e1_data.insert(e1, -2**i)
    e1 = e1 + 1
    
### 2-bit AWE:
AWE_2=[]
e2=0     ## 錯誤數量
p=0      ## 錯誤位置
e2_data=[]
for i in range(0, bits):
    for j in range(i+1, bits):
        AWE_2.insert(e2 , (input + 2**i + 2**j))
        e2_data.insert(e2 , (2**i + 2**j))        
        print(f"第 {e2} 筆錯誤資料: {AWE_2[e2]}")
        print(f"第 {e2} 筆算術錯誤: {e2_data[e2]}")
        e2 = e2 + 1
        AWE_2.insert(e2 , (input + 2**i - 2**j))
        e2_data.insert(e2 , (2**i - 2**j))        
        print(f"第 {e2} 筆錯誤資料: {AWE_2[e2]}")
        print(f"第 {e2} 筆算術錯誤: {e2_data[e2]}")
        e2 = e2 + 1
        AWE_2.insert(e2 , (input - 2**i + 2**j))
        e2_data.insert(e2 , (-2**i + 2**j))                
        print(f"第 {e2} 筆錯誤資料: {AWE_2[e2]}")
        print(f"第 {e2} 筆算術錯誤: {e2_data[e2]}")
        e2 = e2 + 1
        AWE_2.insert(e2 , (input - 2**i -2**j))
        e2_data.insert(e2 , (-2**i - 2**j))
        print(f"第 {e2} 筆錯誤資料: {AWE_2[e2]}")
        print(f"第 {e2} 筆算術錯誤: {e2_data[e2]}")
        e2 = e2 + 1
        p = p + 1
        
## 把list:AWE_1 和 list:AWE_2合併
AWE = AWE_1 + AWE_2
e_total = e1_data + e2_data
## 把重複的 AWE 去除
new_AWE = remove_duplicates(AWE)
new_e_total = remove_duplicates(e_total)
AWE_count = np.size(new_AWE)
e_count = np.size(new_e_total)

### 模AN, 使用一般mod函數和 Barret reduction 比較
remainder = []
for m in range(0,AWE_count):
    mod = new_AWE[m] % AN
    remainder.append(mod)

print("錯誤資料對AN取完模數:\n",remainder)

##############################################################
### Barret reduction ###
def Barret_q_6311(x):      
    q = (int(x) * 1361105) >> 33       ## (2^33)//6311, 右移33次 
    r = x - q * 6311
    if r < 6311:
        return (r,q)
    else:
        return (r - 6311, q + 1)
    
Barret_remainder = []
for m in range(0,AWE_count):
    Barret_r,Barret_q = Barret_q_6311(new_AWE[m])
    Barret_remainder.append(Barret_r)
    
print("Barret reduction對錯誤資料取完模數:\n",Barret_remainder)
print("Barret reduction是否可以使用:", Barret_remainder == remainder)
#################################################################
print("所有餘數(一般mod函數)是否完全相異:", remainder_unique(remainder))
print("所有餘數(Barret reduction)是否完全相異:", remainder_unique(Barret_remainder))
print("所有的AWE:\n", new_e_total)
print(np.size(remainder))

### 建立錯誤映射表(LUT)
## Decoder
AWE_to_remainder, remainder_to_AWE = create_mapping(new_e_total, Barret_remainder)

## example
example_r1 = Barret_remainder[0]
example_r2 = Barret_remainder[1]
print(f"輸入餘數 {example_r1}, 對應算術錯誤: {remainder_to_AWE[example_r1]}")
print(f"輸入餘數 {example_r2}, 對應算術錯誤: {remainder_to_AWE[example_r2]}")

Raw_data1 = new_AWE[0]-remainder_to_AWE[example_r1]
Raw_data2 = new_AWE[1]-remainder_to_AWE[example_r2]
print(Raw_data1)
print(Raw_data2)
print("更正是否正確:", input == Raw_data1)
# Out:
# 第 0 筆錯誤資料: 6617556828
# 第 0 筆算術錯誤: 3
# 第 1 筆錯誤資料: 6617556824
# 第 1 筆算術錯誤: -1
# 第 2 筆錯誤資料: 6617556826
# 第 2 筆算術錯誤: 1
# 第 3 筆錯誤資料: 6617556822
# 第 3 筆算術錯誤: -3
# 第 4 筆錯誤資料: 6617556830
# 第 4 筆算術錯誤: 5
# 第 5 筆錯誤資料: 6617556822
# 第 5 筆算術錯誤: -3
# 第 6 筆錯誤資料: 6617556828
# 第 6 筆算術錯誤: 3
# 第 7 筆錯誤資料: 6617556820
# 第 7 筆算術錯誤: -5
# 第 8 筆錯誤資料: 6617556834
# 第 8 筆算術錯誤: 9
# 第 9 筆錯誤資料: 6617556818
# 第 9 筆算術錯誤: -7
# 第 10 筆錯誤資料: 6617556832
# 第 10 筆算術錯誤: 7
# 第 11 筆錯誤資料: 6617556816
# 第 11 筆算術錯誤: -9
# 第 12 筆錯誤資料: 6617556842
# 第 12 筆算術錯誤: 17
# 第 13 筆錯誤資料: 6617556810
# 第 13 筆算術錯誤: -15
# 第 14 筆錯誤資料: 6617556840
# 第 14 筆算術錯誤: 15
# 第 15 筆錯誤資料: 6617556808
# 第 15 筆算術錯誤: -17
# 第 16 筆錯誤資料: 6617556858
# 第 16 筆算術錯誤: 33
# 第 17 筆錯誤資料: 6617556794
# 第 17 筆算術錯誤: -31
# 第 18 筆錯誤資料: 6617556856
# 第 18 筆算術錯誤: 31
# 第 19 筆錯誤資料: 6617556792
# 第 19 筆算術錯誤: -33
# 第 20 筆錯誤資料: 6617556890
# 第 20 筆算術錯誤: 65
# 第 21 筆錯誤資料: 6617556762
# 第 21 筆算術錯誤: -63
# 第 22 筆錯誤資料: 6617556888
# 第 22 筆算術錯誤: 63
# 第 23 筆錯誤資料: 6617556760
# 第 23 筆算術錯誤: -65
# 第 24 筆錯誤資料: 6617556954
# 第 24 筆算術錯誤: 129
# 第 25 筆錯誤資料: 6617556698
# 第 25 筆算術錯誤: -127
# 第 26 筆錯誤資料: 6617556952
# 第 26 筆算術錯誤: 127
# 第 27 筆錯誤資料: 6617556696
# 第 27 筆算術錯誤: -129
# 第 28 筆錯誤資料: 6617557082
# 第 28 筆算術錯誤: 257
# 第 29 筆錯誤資料: 6617556570
# 第 29 筆算術錯誤: -255
# 第 30 筆錯誤資料: 6617557080
# 第 30 筆算術錯誤: 255
# 第 31 筆錯誤資料: 6617556568
# 第 31 筆算術錯誤: -257
# 第 32 筆錯誤資料: 6617557338
# 第 32 筆算術錯誤: 513
# 第 33 筆錯誤資料: 6617556314
# 第 33 筆算術錯誤: -511
# 第 34 筆錯誤資料: 6617557336
# 第 34 筆算術錯誤: 511
# 第 35 筆錯誤資料: 6617556312
# 第 35 筆算術錯誤: -513
# 第 36 筆錯誤資料: 6617557850
# 第 36 筆算術錯誤: 1025
# 第 37 筆錯誤資料: 6617555802
# 第 37 筆算術錯誤: -1023
# 第 38 筆錯誤資料: 6617557848
# 第 38 筆算術錯誤: 1023
# 第 39 筆錯誤資料: 6617555800
# 第 39 筆算術錯誤: -1025
# 第 40 筆錯誤資料: 6617558874
# 第 40 筆算術錯誤: 2049
# 第 41 筆錯誤資料: 6617554778
# 第 41 筆算術錯誤: -2047
# 第 42 筆錯誤資料: 6617558872
# 第 42 筆算術錯誤: 2047
# 第 43 筆錯誤資料: 6617554776
# 第 43 筆算術錯誤: -2049
# 第 44 筆錯誤資料: 6617560922
# 第 44 筆算術錯誤: 4097
# 第 45 筆錯誤資料: 6617552730
# 第 45 筆算術錯誤: -4095
# 第 46 筆錯誤資料: 6617560920
# 第 46 筆算術錯誤: 4095
# 第 47 筆錯誤資料: 6617552728
# 第 47 筆算術錯誤: -4097
# 第 48 筆錯誤資料: 6617565018
# 第 48 筆算術錯誤: 8193
# 第 49 筆錯誤資料: 6617548634
# 第 49 筆算術錯誤: -8191
# 第 50 筆錯誤資料: 6617565016
# 第 50 筆算術錯誤: 8191
# 第 51 筆錯誤資料: 6617548632
# 第 51 筆算術錯誤: -8193
# 第 52 筆錯誤資料: 6617573210
# 第 52 筆算術錯誤: 16385
# 第 53 筆錯誤資料: 6617540442
# 第 53 筆算術錯誤: -16383
# 第 54 筆錯誤資料: 6617573208
# 第 54 筆算術錯誤: 16383
# 第 55 筆錯誤資料: 6617540440
# 第 55 筆算術錯誤: -16385
# 第 56 筆錯誤資料: 6617589594
# 第 56 筆算術錯誤: 32769
# 第 57 筆錯誤資料: 6617524058
# 第 57 筆算術錯誤: -32767
# 第 58 筆錯誤資料: 6617589592
# 第 58 筆算術錯誤: 32767
# 第 59 筆錯誤資料: 6617524056
# 第 59 筆算術錯誤: -32769
# 第 60 筆錯誤資料: 6617622362
# 第 60 筆算術錯誤: 65537
# 第 61 筆錯誤資料: 6617491290
# 第 61 筆算術錯誤: -65535
# 第 62 筆錯誤資料: 6617622360
# 第 62 筆算術錯誤: 65535
# 第 63 筆錯誤資料: 6617491288
# 第 63 筆算術錯誤: -65537
# 第 64 筆錯誤資料: 6617687898
# 第 64 筆算術錯誤: 131073
# 第 65 筆錯誤資料: 6617425754
# 第 65 筆算術錯誤: -131071
# 第 66 筆錯誤資料: 6617687896
# 第 66 筆算術錯誤: 131071
# 第 67 筆錯誤資料: 6617425752
# 第 67 筆算術錯誤: -131073
# 第 68 筆錯誤資料: 6617818970
# 第 68 筆算術錯誤: 262145
# 第 69 筆錯誤資料: 6617294682
# 第 69 筆算術錯誤: -262143
# 第 70 筆錯誤資料: 6617818968
# 第 70 筆算術錯誤: 262143
# 第 71 筆錯誤資料: 6617294680
# 第 71 筆算術錯誤: -262145
# 第 72 筆錯誤資料: 6618081114
# 第 72 筆算術錯誤: 524289
# 第 73 筆錯誤資料: 6617032538
# 第 73 筆算術錯誤: -524287
# 第 74 筆錯誤資料: 6618081112
# 第 74 筆算術錯誤: 524287
# 第 75 筆錯誤資料: 6617032536
# 第 75 筆算術錯誤: -524289
# 第 76 筆錯誤資料: 6618605402
# 第 76 筆算術錯誤: 1048577
# 第 77 筆錯誤資料: 6616508250
# 第 77 筆算術錯誤: -1048575
# 第 78 筆錯誤資料: 6618605400
# 第 78 筆算術錯誤: 1048575
# 第 79 筆錯誤資料: 6616508248
# 第 79 筆算術錯誤: -1048577
# 第 80 筆錯誤資料: 6619653978
# 第 80 筆算術錯誤: 2097153
# 第 81 筆錯誤資料: 6615459674
# 第 81 筆算術錯誤: -2097151
# 第 82 筆錯誤資料: 6619653976
# 第 82 筆算術錯誤: 2097151
# 第 83 筆錯誤資料: 6615459672
# 第 83 筆算術錯誤: -2097153
# 第 84 筆錯誤資料: 6621751130
# 第 84 筆算術錯誤: 4194305
# 第 85 筆錯誤資料: 6613362522
# 第 85 筆算術錯誤: -4194303
# 第 86 筆錯誤資料: 6621751128
# 第 86 筆算術錯誤: 4194303
# 第 87 筆錯誤資料: 6613362520
# 第 87 筆算術錯誤: -4194305
# 第 88 筆錯誤資料: 6625945434
# 第 88 筆算術錯誤: 8388609
# 第 89 筆錯誤資料: 6609168218
# 第 89 筆算術錯誤: -8388607
# 第 90 筆錯誤資料: 6625945432
# 第 90 筆算術錯誤: 8388607
# 第 91 筆錯誤資料: 6609168216
# 第 91 筆算術錯誤: -8388609
# 第 92 筆錯誤資料: 6634334042
# 第 92 筆算術錯誤: 16777217
# 第 93 筆錯誤資料: 6600779610
# 第 93 筆算術錯誤: -16777215
# 第 94 筆錯誤資料: 6634334040
# 第 94 筆算術錯誤: 16777215
# 第 95 筆錯誤資料: 6600779608
# 第 95 筆算術錯誤: -16777217
# 第 96 筆錯誤資料: 6651111258
# 第 96 筆算術錯誤: 33554433
# 第 97 筆錯誤資料: 6584002394
# 第 97 筆算術錯誤: -33554431
# 第 98 筆錯誤資料: 6651111256
# 第 98 筆算術錯誤: 33554431
# 第 99 筆錯誤資料: 6584002392
# 第 99 筆算術錯誤: -33554433
# 第 100 筆錯誤資料: 6684665690
# 第 100 筆算術錯誤: 67108865
# 第 101 筆錯誤資料: 6550447962
# 第 101 筆算術錯誤: -67108863
# 第 102 筆錯誤資料: 6684665688
# 第 102 筆算術錯誤: 67108863
# 第 103 筆錯誤資料: 6550447960
# 第 103 筆算術錯誤: -67108865
# 第 104 筆錯誤資料: 6751774554
# 第 104 筆算術錯誤: 134217729
# 第 105 筆錯誤資料: 6483339098
# 第 105 筆算術錯誤: -134217727
# 第 106 筆錯誤資料: 6751774552
# 第 106 筆算術錯誤: 134217727
# 第 107 筆錯誤資料: 6483339096
# 第 107 筆算術錯誤: -134217729
# 第 108 筆錯誤資料: 6885992282
# 第 108 筆算術錯誤: 268435457
# 第 109 筆錯誤資料: 6349121370
# 第 109 筆算術錯誤: -268435455
# 第 110 筆錯誤資料: 6885992280
# 第 110 筆算術錯誤: 268435455
# 第 111 筆錯誤資料: 6349121368
# 第 111 筆算術錯誤: -268435457
# 第 112 筆錯誤資料: 7154427738
# 第 112 筆算術錯誤: 536870913
# 第 113 筆錯誤資料: 6080685914
# 第 113 筆算術錯誤: -536870911
# 第 114 筆錯誤資料: 7154427736
# 第 114 筆算術錯誤: 536870911
# 第 115 筆錯誤資料: 6080685912
# 第 115 筆算術錯誤: -536870913
# 第 116 筆錯誤資料: 7691298650
# 第 116 筆算術錯誤: 1073741825
# 第 117 筆錯誤資料: 5543815002
# 第 117 筆算術錯誤: -1073741823
# 第 118 筆錯誤資料: 7691298648
# 第 118 筆算術錯誤: 1073741823
# 第 119 筆錯誤資料: 5543815000
# 第 119 筆算術錯誤: -1073741825
# 第 120 筆錯誤資料: 8765040474
# 第 120 筆算術錯誤: 2147483649
# 第 121 筆錯誤資料: 4470073178
# 第 121 筆算術錯誤: -2147483647
# 第 122 筆錯誤資料: 8765040472
# 第 122 筆算術錯誤: 2147483647
# 第 123 筆錯誤資料: 4470073176
# 第 123 筆算術錯誤: -2147483649
# 第 124 筆錯誤資料: 10912524122
# 第 124 筆算術錯誤: 4294967297
# 第 125 筆錯誤資料: 2322589530
# 第 125 筆算術錯誤: -4294967295
# 第 126 筆錯誤資料: 10912524120
# 第 126 筆算術錯誤: 4294967295
# 第 127 筆錯誤資料: 2322589528
# 第 127 筆算術錯誤: -4294967297
# 第 128 筆錯誤資料: 6617556831
# 第 128 筆算術錯誤: 6
# 第 129 筆錯誤資料: 6617556823
# 第 129 筆算術錯誤: -2
# 第 130 筆錯誤資料: 6617556827
# 第 130 筆算術錯誤: 2
# 第 131 筆錯誤資料: 6617556819
# 第 131 筆算術錯誤: -6
# 第 132 筆錯誤資料: 6617556835
# 第 132 筆算術錯誤: 10
# 第 133 筆錯誤資料: 6617556819
# 第 133 筆算術錯誤: -6
# 第 134 筆錯誤資料: 6617556831
# 第 134 筆算術錯誤: 6
# 第 135 筆錯誤資料: 6617556815
# 第 135 筆算術錯誤: -10
# 第 136 筆錯誤資料: 6617556843
# 第 136 筆算術錯誤: 18
# 第 137 筆錯誤資料: 6617556811
# 第 137 筆算術錯誤: -14
# 第 138 筆錯誤資料: 6617556839
# 第 138 筆算術錯誤: 14
# 第 139 筆錯誤資料: 6617556807
# 第 139 筆算術錯誤: -18
# 第 140 筆錯誤資料: 6617556859
# 第 140 筆算術錯誤: 34
# 第 141 筆錯誤資料: 6617556795
# 第 141 筆算術錯誤: -30
# 第 142 筆錯誤資料: 6617556855
# 第 142 筆算術錯誤: 30
# 第 143 筆錯誤資料: 6617556791
# 第 143 筆算術錯誤: -34
# 第 144 筆錯誤資料: 6617556891
# 第 144 筆算術錯誤: 66
# 第 145 筆錯誤資料: 6617556763
# 第 145 筆算術錯誤: -62
# 第 146 筆錯誤資料: 6617556887
# 第 146 筆算術錯誤: 62
# 第 147 筆錯誤資料: 6617556759
# 第 147 筆算術錯誤: -66
# 第 148 筆錯誤資料: 6617556955
# 第 148 筆算術錯誤: 130
# 第 149 筆錯誤資料: 6617556699
# 第 149 筆算術錯誤: -126
# 第 150 筆錯誤資料: 6617556951
# 第 150 筆算術錯誤: 126
# 第 151 筆錯誤資料: 6617556695
# 第 151 筆算術錯誤: -130
# 第 152 筆錯誤資料: 6617557083
# 第 152 筆算術錯誤: 258
# 第 153 筆錯誤資料: 6617556571
# 第 153 筆算術錯誤: -254
# 第 154 筆錯誤資料: 6617557079
# 第 154 筆算術錯誤: 254
# 第 155 筆錯誤資料: 6617556567
# 第 155 筆算術錯誤: -258
# 第 156 筆錯誤資料: 6617557339
# 第 156 筆算術錯誤: 514
# 第 157 筆錯誤資料: 6617556315
# 第 157 筆算術錯誤: -510
# 第 158 筆錯誤資料: 6617557335
# 第 158 筆算術錯誤: 510
# 第 159 筆錯誤資料: 6617556311
# 第 159 筆算術錯誤: -514
# 第 160 筆錯誤資料: 6617557851
# 第 160 筆算術錯誤: 1026
# 第 161 筆錯誤資料: 6617555803
# 第 161 筆算術錯誤: -1022
# 第 162 筆錯誤資料: 6617557847
# 第 162 筆算術錯誤: 1022
# 第 163 筆錯誤資料: 6617555799
# 第 163 筆算術錯誤: -1026
# 第 164 筆錯誤資料: 6617558875
# 第 164 筆算術錯誤: 2050
# 第 165 筆錯誤資料: 6617554779
# 第 165 筆算術錯誤: -2046
# 第 166 筆錯誤資料: 6617558871
# 第 166 筆算術錯誤: 2046
# 第 167 筆錯誤資料: 6617554775
# 第 167 筆算術錯誤: -2050
# 第 168 筆錯誤資料: 6617560923
# 第 168 筆算術錯誤: 4098
# 第 169 筆錯誤資料: 6617552731
# 第 169 筆算術錯誤: -4094
# 第 170 筆錯誤資料: 6617560919
# 第 170 筆算術錯誤: 4094
# 第 171 筆錯誤資料: 6617552727
# 第 171 筆算術錯誤: -4098
# 第 172 筆錯誤資料: 6617565019
# 第 172 筆算術錯誤: 8194
# 第 173 筆錯誤資料: 6617548635
# 第 173 筆算術錯誤: -8190
# 第 174 筆錯誤資料: 6617565015
# 第 174 筆算術錯誤: 8190
# 第 175 筆錯誤資料: 6617548631
# 第 175 筆算術錯誤: -8194
# 第 176 筆錯誤資料: 6617573211
# 第 176 筆算術錯誤: 16386
# 第 177 筆錯誤資料: 6617540443
# 第 177 筆算術錯誤: -16382
# 第 178 筆錯誤資料: 6617573207
# 第 178 筆算術錯誤: 16382
# 第 179 筆錯誤資料: 6617540439
# 第 179 筆算術錯誤: -16386
# 第 180 筆錯誤資料: 6617589595
# 第 180 筆算術錯誤: 32770
# 第 181 筆錯誤資料: 6617524059
# 第 181 筆算術錯誤: -32766
# 第 182 筆錯誤資料: 6617589591
# 第 182 筆算術錯誤: 32766
# 第 183 筆錯誤資料: 6617524055
# 第 183 筆算術錯誤: -32770
# 第 184 筆錯誤資料: 6617622363
# 第 184 筆算術錯誤: 65538
# 第 185 筆錯誤資料: 6617491291
# 第 185 筆算術錯誤: -65534
# 第 186 筆錯誤資料: 6617622359
# 第 186 筆算術錯誤: 65534
# 第 187 筆錯誤資料: 6617491287
# 第 187 筆算術錯誤: -65538
# 第 188 筆錯誤資料: 6617687899
# 第 188 筆算術錯誤: 131074
# 第 189 筆錯誤資料: 6617425755
# 第 189 筆算術錯誤: -131070
# 第 190 筆錯誤資料: 6617687895
# 第 190 筆算術錯誤: 131070
# 第 191 筆錯誤資料: 6617425751
# 第 191 筆算術錯誤: -131074
# 第 192 筆錯誤資料: 6617818971
# 第 192 筆算術錯誤: 262146
# 第 193 筆錯誤資料: 6617294683
# 第 193 筆算術錯誤: -262142
# 第 194 筆錯誤資料: 6617818967
# 第 194 筆算術錯誤: 262142
# 第 195 筆錯誤資料: 6617294679
# 第 195 筆算術錯誤: -262146
# 第 196 筆錯誤資料: 6618081115
# 第 196 筆算術錯誤: 524290
# 第 197 筆錯誤資料: 6617032539
# 第 197 筆算術錯誤: -524286
# 第 198 筆錯誤資料: 6618081111
# 第 198 筆算術錯誤: 524286
# 第 199 筆錯誤資料: 6617032535
# 第 199 筆算術錯誤: -524290
# 第 200 筆錯誤資料: 6618605403
# 第 200 筆算術錯誤: 1048578
# 第 201 筆錯誤資料: 6616508251
# 第 201 筆算術錯誤: -1048574
# 第 202 筆錯誤資料: 6618605399
# 第 202 筆算術錯誤: 1048574
# 第 203 筆錯誤資料: 6616508247
# 第 203 筆算術錯誤: -1048578
# 第 204 筆錯誤資料: 6619653979
# 第 204 筆算術錯誤: 2097154
# 第 205 筆錯誤資料: 6615459675
# 第 205 筆算術錯誤: -2097150
# 第 206 筆錯誤資料: 6619653975
# 第 206 筆算術錯誤: 2097150
# 第 207 筆錯誤資料: 6615459671
# 第 207 筆算術錯誤: -2097154
# 第 208 筆錯誤資料: 6621751131
# 第 208 筆算術錯誤: 4194306
# 第 209 筆錯誤資料: 6613362523
# 第 209 筆算術錯誤: -4194302
# 第 210 筆錯誤資料: 6621751127
# 第 210 筆算術錯誤: 4194302
# 第 211 筆錯誤資料: 6613362519
# 第 211 筆算術錯誤: -4194306
# 第 212 筆錯誤資料: 6625945435
# 第 212 筆算術錯誤: 8388610
# 第 213 筆錯誤資料: 6609168219
# 第 213 筆算術錯誤: -8388606
# 第 214 筆錯誤資料: 6625945431
# 第 214 筆算術錯誤: 8388606
# 第 215 筆錯誤資料: 6609168215
# 第 215 筆算術錯誤: -8388610
# 第 216 筆錯誤資料: 6634334043
# 第 216 筆算術錯誤: 16777218
# 第 217 筆錯誤資料: 6600779611
# 第 217 筆算術錯誤: -16777214
# 第 218 筆錯誤資料: 6634334039
# 第 218 筆算術錯誤: 16777214
# 第 219 筆錯誤資料: 6600779607
# 第 219 筆算術錯誤: -16777218
# 第 220 筆錯誤資料: 6651111259
# 第 220 筆算術錯誤: 33554434
# 第 221 筆錯誤資料: 6584002395
# 第 221 筆算術錯誤: -33554430
# 第 222 筆錯誤資料: 6651111255
# 第 222 筆算術錯誤: 33554430
# 第 223 筆錯誤資料: 6584002391
# 第 223 筆算術錯誤: -33554434
# 第 224 筆錯誤資料: 6684665691
# 第 224 筆算術錯誤: 67108866
# 第 225 筆錯誤資料: 6550447963
# 第 225 筆算術錯誤: -67108862
# 第 226 筆錯誤資料: 6684665687
# 第 226 筆算術錯誤: 67108862
# 第 227 筆錯誤資料: 6550447959
# 第 227 筆算術錯誤: -67108866
# 第 228 筆錯誤資料: 6751774555
# 第 228 筆算術錯誤: 134217730
# 第 229 筆錯誤資料: 6483339099
# 第 229 筆算術錯誤: -134217726
# 第 230 筆錯誤資料: 6751774551
# 第 230 筆算術錯誤: 134217726
# 第 231 筆錯誤資料: 6483339095
# 第 231 筆算術錯誤: -134217730
# 第 232 筆錯誤資料: 6885992283
# 第 232 筆算術錯誤: 268435458
# 第 233 筆錯誤資料: 6349121371
# 第 233 筆算術錯誤: -268435454
# 第 234 筆錯誤資料: 6885992279
# 第 234 筆算術錯誤: 268435454
# 第 235 筆錯誤資料: 6349121367
# 第 235 筆算術錯誤: -268435458
# 第 236 筆錯誤資料: 7154427739
# 第 236 筆算術錯誤: 536870914
# 第 237 筆錯誤資料: 6080685915
# 第 237 筆算術錯誤: -536870910
# 第 238 筆錯誤資料: 7154427735
# 第 238 筆算術錯誤: 536870910
# 第 239 筆錯誤資料: 6080685911
# 第 239 筆算術錯誤: -536870914
# 第 240 筆錯誤資料: 7691298651
# 第 240 筆算術錯誤: 1073741826
# 第 241 筆錯誤資料: 5543815003
# 第 241 筆算術錯誤: -1073741822
# 第 242 筆錯誤資料: 7691298647
# 第 242 筆算術錯誤: 1073741822
# 第 243 筆錯誤資料: 5543814999
# 第 243 筆算術錯誤: -1073741826
# 第 244 筆錯誤資料: 8765040475
# 第 244 筆算術錯誤: 2147483650
# 第 245 筆錯誤資料: 4470073179
# 第 245 筆算術錯誤: -2147483646
# 第 246 筆錯誤資料: 8765040471
# 第 246 筆算術錯誤: 2147483646
# 第 247 筆錯誤資料: 4470073175
# 第 247 筆算術錯誤: -2147483650
# 第 248 筆錯誤資料: 10912524123
# 第 248 筆算術錯誤: 4294967298
# 第 249 筆錯誤資料: 2322589531
# 第 249 筆算術錯誤: -4294967294
# 第 250 筆錯誤資料: 10912524119
# 第 250 筆算術錯誤: 4294967294
# 第 251 筆錯誤資料: 2322589527
# 第 251 筆算術錯誤: -4294967298
# 第 252 筆錯誤資料: 6617556837
# 第 252 筆算術錯誤: 12
# 第 253 筆錯誤資料: 6617556821
# 第 253 筆算術錯誤: -4
# 第 254 筆錯誤資料: 6617556829
# 第 254 筆算術錯誤: 4
# 第 255 筆錯誤資料: 6617556813
# 第 255 筆算術錯誤: -12
# 第 256 筆錯誤資料: 6617556845
# 第 256 筆算術錯誤: 20
# 第 257 筆錯誤資料: 6617556813
# 第 257 筆算術錯誤: -12
# 第 258 筆錯誤資料: 6617556837
# 第 258 筆算術錯誤: 12
# 第 259 筆錯誤資料: 6617556805
# 第 259 筆算術錯誤: -20
# 第 260 筆錯誤資料: 6617556861
# 第 260 筆算術錯誤: 36
# 第 261 筆錯誤資料: 6617556797
# 第 261 筆算術錯誤: -28
# 第 262 筆錯誤資料: 6617556853
# 第 262 筆算術錯誤: 28
# 第 263 筆錯誤資料: 6617556789
# 第 263 筆算術錯誤: -36
# 第 264 筆錯誤資料: 6617556893
# 第 264 筆算術錯誤: 68
# 第 265 筆錯誤資料: 6617556765
# 第 265 筆算術錯誤: -60
# 第 266 筆錯誤資料: 6617556885
# 第 266 筆算術錯誤: 60
# 第 267 筆錯誤資料: 6617556757
# 第 267 筆算術錯誤: -68
# 第 268 筆錯誤資料: 6617556957
# 第 268 筆算術錯誤: 132
# 第 269 筆錯誤資料: 6617556701
# 第 269 筆算術錯誤: -124
# 第 270 筆錯誤資料: 6617556949
# 第 270 筆算術錯誤: 124
# 第 271 筆錯誤資料: 6617556693
# 第 271 筆算術錯誤: -132
# 第 272 筆錯誤資料: 6617557085
# 第 272 筆算術錯誤: 260
# 第 273 筆錯誤資料: 6617556573
# 第 273 筆算術錯誤: -252
# 第 274 筆錯誤資料: 6617557077
# 第 274 筆算術錯誤: 252
# 第 275 筆錯誤資料: 6617556565
# 第 275 筆算術錯誤: -260
# 第 276 筆錯誤資料: 6617557341
# 第 276 筆算術錯誤: 516
# 第 277 筆錯誤資料: 6617556317
# 第 277 筆算術錯誤: -508
# 第 278 筆錯誤資料: 6617557333
# 第 278 筆算術錯誤: 508
# 第 279 筆錯誤資料: 6617556309
# 第 279 筆算術錯誤: -516
# 第 280 筆錯誤資料: 6617557853
# 第 280 筆算術錯誤: 1028
# 第 281 筆錯誤資料: 6617555805
# 第 281 筆算術錯誤: -1020
# 第 282 筆錯誤資料: 6617557845
# 第 282 筆算術錯誤: 1020
# 第 283 筆錯誤資料: 6617555797
# 第 283 筆算術錯誤: -1028
# 第 284 筆錯誤資料: 6617558877
# 第 284 筆算術錯誤: 2052
# 第 285 筆錯誤資料: 6617554781
# 第 285 筆算術錯誤: -2044
# 第 286 筆錯誤資料: 6617558869
# 第 286 筆算術錯誤: 2044
# 第 287 筆錯誤資料: 6617554773
# 第 287 筆算術錯誤: -2052
# 第 288 筆錯誤資料: 6617560925
# 第 288 筆算術錯誤: 4100
# 第 289 筆錯誤資料: 6617552733
# 第 289 筆算術錯誤: -4092
# 第 290 筆錯誤資料: 6617560917
# 第 290 筆算術錯誤: 4092
# 第 291 筆錯誤資料: 6617552725
# 第 291 筆算術錯誤: -4100
# 第 292 筆錯誤資料: 6617565021
# 第 292 筆算術錯誤: 8196
# 第 293 筆錯誤資料: 6617548637
# 第 293 筆算術錯誤: -8188
# 第 294 筆錯誤資料: 6617565013
# 第 294 筆算術錯誤: 8188
# 第 295 筆錯誤資料: 6617548629
# 第 295 筆算術錯誤: -8196
# 第 296 筆錯誤資料: 6617573213
# 第 296 筆算術錯誤: 16388
# 第 297 筆錯誤資料: 6617540445
# 第 297 筆算術錯誤: -16380
# 第 298 筆錯誤資料: 6617573205
# 第 298 筆算術錯誤: 16380
# 第 299 筆錯誤資料: 6617540437
# 第 299 筆算術錯誤: -16388
# 第 300 筆錯誤資料: 6617589597
# 第 300 筆算術錯誤: 32772
# 第 301 筆錯誤資料: 6617524061
# 第 301 筆算術錯誤: -32764
# 第 302 筆錯誤資料: 6617589589
# 第 302 筆算術錯誤: 32764
# 第 303 筆錯誤資料: 6617524053
# 第 303 筆算術錯誤: -32772
# 第 304 筆錯誤資料: 6617622365
# 第 304 筆算術錯誤: 65540
# 第 305 筆錯誤資料: 6617491293
# 第 305 筆算術錯誤: -65532
# 第 306 筆錯誤資料: 6617622357
# 第 306 筆算術錯誤: 65532
# 第 307 筆錯誤資料: 6617491285
# 第 307 筆算術錯誤: -65540
# 第 308 筆錯誤資料: 6617687901
# 第 308 筆算術錯誤: 131076
# 第 309 筆錯誤資料: 6617425757
# 第 309 筆算術錯誤: -131068
# 第 310 筆錯誤資料: 6617687893
# 第 310 筆算術錯誤: 131068
# 第 311 筆錯誤資料: 6617425749
# 第 311 筆算術錯誤: -131076
# 第 312 筆錯誤資料: 6617818973
# 第 312 筆算術錯誤: 262148
# 第 313 筆錯誤資料: 6617294685
# 第 313 筆算術錯誤: -262140
# 第 314 筆錯誤資料: 6617818965
# 第 314 筆算術錯誤: 262140
# 第 315 筆錯誤資料: 6617294677
# 第 315 筆算術錯誤: -262148
# 第 316 筆錯誤資料: 6618081117
# 第 316 筆算術錯誤: 524292
# 第 317 筆錯誤資料: 6617032541
# 第 317 筆算術錯誤: -524284
# 第 318 筆錯誤資料: 6618081109
# 第 318 筆算術錯誤: 524284
# 第 319 筆錯誤資料: 6617032533
# 第 319 筆算術錯誤: -524292
# 第 320 筆錯誤資料: 6618605405
# 第 320 筆算術錯誤: 1048580
# 第 321 筆錯誤資料: 6616508253
# 第 321 筆算術錯誤: -1048572
# 第 322 筆錯誤資料: 6618605397
# 第 322 筆算術錯誤: 1048572
# 第 323 筆錯誤資料: 6616508245
# 第 323 筆算術錯誤: -1048580
# 第 324 筆錯誤資料: 6619653981
# 第 324 筆算術錯誤: 2097156
# 第 325 筆錯誤資料: 6615459677
# 第 325 筆算術錯誤: -2097148
# 第 326 筆錯誤資料: 6619653973
# 第 326 筆算術錯誤: 2097148
# 第 327 筆錯誤資料: 6615459669
# 第 327 筆算術錯誤: -2097156
# 第 328 筆錯誤資料: 6621751133
# 第 328 筆算術錯誤: 4194308
# 第 329 筆錯誤資料: 6613362525
# 第 329 筆算術錯誤: -4194300
# 第 330 筆錯誤資料: 6621751125
# 第 330 筆算術錯誤: 4194300
# 第 331 筆錯誤資料: 6613362517
# 第 331 筆算術錯誤: -4194308
# 第 332 筆錯誤資料: 6625945437
# 第 332 筆算術錯誤: 8388612
# 第 333 筆錯誤資料: 6609168221
# 第 333 筆算術錯誤: -8388604
# 第 334 筆錯誤資料: 6625945429
# 第 334 筆算術錯誤: 8388604
# 第 335 筆錯誤資料: 6609168213
# 第 335 筆算術錯誤: -8388612
# 第 336 筆錯誤資料: 6634334045
# 第 336 筆算術錯誤: 16777220
# 第 337 筆錯誤資料: 6600779613
# 第 337 筆算術錯誤: -16777212
# 第 338 筆錯誤資料: 6634334037
# 第 338 筆算術錯誤: 16777212
# 第 339 筆錯誤資料: 6600779605
# 第 339 筆算術錯誤: -16777220
# 第 340 筆錯誤資料: 6651111261
# 第 340 筆算術錯誤: 33554436
# 第 341 筆錯誤資料: 6584002397
# 第 341 筆算術錯誤: -33554428
# 第 342 筆錯誤資料: 6651111253
# 第 342 筆算術錯誤: 33554428
# 第 343 筆錯誤資料: 6584002389
# 第 343 筆算術錯誤: -33554436
# 第 344 筆錯誤資料: 6684665693
# 第 344 筆算術錯誤: 67108868
# 第 345 筆錯誤資料: 6550447965
# 第 345 筆算術錯誤: -67108860
# 第 346 筆錯誤資料: 6684665685
# 第 346 筆算術錯誤: 67108860
# 第 347 筆錯誤資料: 6550447957
# 第 347 筆算術錯誤: -67108868
# 第 348 筆錯誤資料: 6751774557
# 第 348 筆算術錯誤: 134217732
# 第 349 筆錯誤資料: 6483339101
# 第 349 筆算術錯誤: -134217724
# 第 350 筆錯誤資料: 6751774549
# 第 350 筆算術錯誤: 134217724
# 第 351 筆錯誤資料: 6483339093
# 第 351 筆算術錯誤: -134217732
# 第 352 筆錯誤資料: 6885992285
# 第 352 筆算術錯誤: 268435460
# 第 353 筆錯誤資料: 6349121373
# 第 353 筆算術錯誤: -268435452
# 第 354 筆錯誤資料: 6885992277
# 第 354 筆算術錯誤: 268435452
# 第 355 筆錯誤資料: 6349121365
# 第 355 筆算術錯誤: -268435460
# 第 356 筆錯誤資料: 7154427741
# 第 356 筆算術錯誤: 536870916
# 第 357 筆錯誤資料: 6080685917
# 第 357 筆算術錯誤: -536870908
# 第 358 筆錯誤資料: 7154427733
# 第 358 筆算術錯誤: 536870908
# 第 359 筆錯誤資料: 6080685909
# 第 359 筆算術錯誤: -536870916
# 第 360 筆錯誤資料: 7691298653
# 第 360 筆算術錯誤: 1073741828
# 第 361 筆錯誤資料: 5543815005
# 第 361 筆算術錯誤: -1073741820
# 第 362 筆錯誤資料: 7691298645
# 第 362 筆算術錯誤: 1073741820
# 第 363 筆錯誤資料: 5543814997
# 第 363 筆算術錯誤: -1073741828
# 第 364 筆錯誤資料: 8765040477
# 第 364 筆算術錯誤: 2147483652
# 第 365 筆錯誤資料: 4470073181
# 第 365 筆算術錯誤: -2147483644
# 第 366 筆錯誤資料: 8765040469
# 第 366 筆算術錯誤: 2147483644
# 第 367 筆錯誤資料: 4470073173
# 第 367 筆算術錯誤: -2147483652
# 第 368 筆錯誤資料: 10912524125
# 第 368 筆算術錯誤: 4294967300
# 第 369 筆錯誤資料: 2322589533
# 第 369 筆算術錯誤: -4294967292
# 第 370 筆錯誤資料: 10912524117
# 第 370 筆算術錯誤: 4294967292
# 第 371 筆錯誤資料: 2322589525
# 第 371 筆算術錯誤: -4294967300
# 第 372 筆錯誤資料: 6617556849
# 第 372 筆算術錯誤: 24
# 第 373 筆錯誤資料: 6617556817
# 第 373 筆算術錯誤: -8
# 第 374 筆錯誤資料: 6617556833
# 第 374 筆算術錯誤: 8
# 第 375 筆錯誤資料: 6617556801
# 第 375 筆算術錯誤: -24
# 第 376 筆錯誤資料: 6617556865
# 第 376 筆算術錯誤: 40
# 第 377 筆錯誤資料: 6617556801
# 第 377 筆算術錯誤: -24
# 第 378 筆錯誤資料: 6617556849
# 第 378 筆算術錯誤: 24
# 第 379 筆錯誤資料: 6617556785
# 第 379 筆算術錯誤: -40
# 第 380 筆錯誤資料: 6617556897
# 第 380 筆算術錯誤: 72
# 第 381 筆錯誤資料: 6617556769
# 第 381 筆算術錯誤: -56
# 第 382 筆錯誤資料: 6617556881
# 第 382 筆算術錯誤: 56
# 第 383 筆錯誤資料: 6617556753
# 第 383 筆算術錯誤: -72
# 第 384 筆錯誤資料: 6617556961
# 第 384 筆算術錯誤: 136
# 第 385 筆錯誤資料: 6617556705
# 第 385 筆算術錯誤: -120
# 第 386 筆錯誤資料: 6617556945
# 第 386 筆算術錯誤: 120
# 第 387 筆錯誤資料: 6617556689
# 第 387 筆算術錯誤: -136
# 第 388 筆錯誤資料: 6617557089
# 第 388 筆算術錯誤: 264
# 第 389 筆錯誤資料: 6617556577
# 第 389 筆算術錯誤: -248
# 第 390 筆錯誤資料: 6617557073
# 第 390 筆算術錯誤: 248
# 第 391 筆錯誤資料: 6617556561
# 第 391 筆算術錯誤: -264
# 第 392 筆錯誤資料: 6617557345
# 第 392 筆算術錯誤: 520
# 第 393 筆錯誤資料: 6617556321
# 第 393 筆算術錯誤: -504
# 第 394 筆錯誤資料: 6617557329
# 第 394 筆算術錯誤: 504
# 第 395 筆錯誤資料: 6617556305
# 第 395 筆算術錯誤: -520
# 第 396 筆錯誤資料: 6617557857
# 第 396 筆算術錯誤: 1032
# 第 397 筆錯誤資料: 6617555809
# 第 397 筆算術錯誤: -1016
# 第 398 筆錯誤資料: 6617557841
# 第 398 筆算術錯誤: 1016
# 第 399 筆錯誤資料: 6617555793
# 第 399 筆算術錯誤: -1032
# 第 400 筆錯誤資料: 6617558881
# 第 400 筆算術錯誤: 2056
# 第 401 筆錯誤資料: 6617554785
# 第 401 筆算術錯誤: -2040
# 第 402 筆錯誤資料: 6617558865
# 第 402 筆算術錯誤: 2040
# 第 403 筆錯誤資料: 6617554769
# 第 403 筆算術錯誤: -2056
# 第 404 筆錯誤資料: 6617560929
# 第 404 筆算術錯誤: 4104
# 第 405 筆錯誤資料: 6617552737
# 第 405 筆算術錯誤: -4088
# 第 406 筆錯誤資料: 6617560913
# 第 406 筆算術錯誤: 4088
# 第 407 筆錯誤資料: 6617552721
# 第 407 筆算術錯誤: -4104
# 第 408 筆錯誤資料: 6617565025
# 第 408 筆算術錯誤: 8200
# 第 409 筆錯誤資料: 6617548641
# 第 409 筆算術錯誤: -8184
# 第 410 筆錯誤資料: 6617565009
# 第 410 筆算術錯誤: 8184
# 第 411 筆錯誤資料: 6617548625
# 第 411 筆算術錯誤: -8200
# 第 412 筆錯誤資料: 6617573217
# 第 412 筆算術錯誤: 16392
# 第 413 筆錯誤資料: 6617540449
# 第 413 筆算術錯誤: -16376
# 第 414 筆錯誤資料: 6617573201
# 第 414 筆算術錯誤: 16376
# 第 415 筆錯誤資料: 6617540433
# 第 415 筆算術錯誤: -16392
# 第 416 筆錯誤資料: 6617589601
# 第 416 筆算術錯誤: 32776
# 第 417 筆錯誤資料: 6617524065
# 第 417 筆算術錯誤: -32760
# 第 418 筆錯誤資料: 6617589585
# 第 418 筆算術錯誤: 32760
# 第 419 筆錯誤資料: 6617524049
# 第 419 筆算術錯誤: -32776
# 第 420 筆錯誤資料: 6617622369
# 第 420 筆算術錯誤: 65544
# 第 421 筆錯誤資料: 6617491297
# 第 421 筆算術錯誤: -65528
# 第 422 筆錯誤資料: 6617622353
# 第 422 筆算術錯誤: 65528
# 第 423 筆錯誤資料: 6617491281
# 第 423 筆算術錯誤: -65544
# 第 424 筆錯誤資料: 6617687905
# 第 424 筆算術錯誤: 131080
# 第 425 筆錯誤資料: 6617425761
# 第 425 筆算術錯誤: -131064
# 第 426 筆錯誤資料: 6617687889
# 第 426 筆算術錯誤: 131064
# 第 427 筆錯誤資料: 6617425745
# 第 427 筆算術錯誤: -131080
# 第 428 筆錯誤資料: 6617818977
# 第 428 筆算術錯誤: 262152
# 第 429 筆錯誤資料: 6617294689
# 第 429 筆算術錯誤: -262136
# 第 430 筆錯誤資料: 6617818961
# 第 430 筆算術錯誤: 262136
# 第 431 筆錯誤資料: 6617294673
# 第 431 筆算術錯誤: -262152
# 第 432 筆錯誤資料: 6618081121
# 第 432 筆算術錯誤: 524296
# 第 433 筆錯誤資料: 6617032545
# 第 433 筆算術錯誤: -524280
# 第 434 筆錯誤資料: 6618081105
# 第 434 筆算術錯誤: 524280
# 第 435 筆錯誤資料: 6617032529
# 第 435 筆算術錯誤: -524296
# 第 436 筆錯誤資料: 6618605409
# 第 436 筆算術錯誤: 1048584
# 第 437 筆錯誤資料: 6616508257
# 第 437 筆算術錯誤: -1048568
# 第 438 筆錯誤資料: 6618605393
# 第 438 筆算術錯誤: 1048568
# 第 439 筆錯誤資料: 6616508241
# 第 439 筆算術錯誤: -1048584
# 第 440 筆錯誤資料: 6619653985
# 第 440 筆算術錯誤: 2097160
# 第 441 筆錯誤資料: 6615459681
# 第 441 筆算術錯誤: -2097144
# 第 442 筆錯誤資料: 6619653969
# 第 442 筆算術錯誤: 2097144
# 第 443 筆錯誤資料: 6615459665
# 第 443 筆算術錯誤: -2097160
# 第 444 筆錯誤資料: 6621751137
# 第 444 筆算術錯誤: 4194312
# 第 445 筆錯誤資料: 6613362529
# 第 445 筆算術錯誤: -4194296
# 第 446 筆錯誤資料: 6621751121
# 第 446 筆算術錯誤: 4194296
# 第 447 筆錯誤資料: 6613362513
# 第 447 筆算術錯誤: -4194312
# 第 448 筆錯誤資料: 6625945441
# 第 448 筆算術錯誤: 8388616
# 第 449 筆錯誤資料: 6609168225
# 第 449 筆算術錯誤: -8388600
# 第 450 筆錯誤資料: 6625945425
# 第 450 筆算術錯誤: 8388600
# 第 451 筆錯誤資料: 6609168209
# 第 451 筆算術錯誤: -8388616
# 第 452 筆錯誤資料: 6634334049
# 第 452 筆算術錯誤: 16777224
# 第 453 筆錯誤資料: 6600779617
# 第 453 筆算術錯誤: -16777208
# 第 454 筆錯誤資料: 6634334033
# 第 454 筆算術錯誤: 16777208
# 第 455 筆錯誤資料: 6600779601
# 第 455 筆算術錯誤: -16777224
# 第 456 筆錯誤資料: 6651111265
# 第 456 筆算術錯誤: 33554440
# 第 457 筆錯誤資料: 6584002401
# 第 457 筆算術錯誤: -33554424
# 第 458 筆錯誤資料: 6651111249
# 第 458 筆算術錯誤: 33554424
# 第 459 筆錯誤資料: 6584002385
# 第 459 筆算術錯誤: -33554440
# 第 460 筆錯誤資料: 6684665697
# 第 460 筆算術錯誤: 67108872
# 第 461 筆錯誤資料: 6550447969
# 第 461 筆算術錯誤: -67108856
# 第 462 筆錯誤資料: 6684665681
# 第 462 筆算術錯誤: 67108856
# 第 463 筆錯誤資料: 6550447953
# 第 463 筆算術錯誤: -67108872
# 第 464 筆錯誤資料: 6751774561
# 第 464 筆算術錯誤: 134217736
# 第 465 筆錯誤資料: 6483339105
# 第 465 筆算術錯誤: -134217720
# 第 466 筆錯誤資料: 6751774545
# 第 466 筆算術錯誤: 134217720
# 第 467 筆錯誤資料: 6483339089
# 第 467 筆算術錯誤: -134217736
# 第 468 筆錯誤資料: 6885992289
# 第 468 筆算術錯誤: 268435464
# 第 469 筆錯誤資料: 6349121377
# 第 469 筆算術錯誤: -268435448
# 第 470 筆錯誤資料: 6885992273
# 第 470 筆算術錯誤: 268435448
# 第 471 筆錯誤資料: 6349121361
# 第 471 筆算術錯誤: -268435464
# 第 472 筆錯誤資料: 7154427745
# 第 472 筆算術錯誤: 536870920
# 第 473 筆錯誤資料: 6080685921
# 第 473 筆算術錯誤: -536870904
# 第 474 筆錯誤資料: 7154427729
# 第 474 筆算術錯誤: 536870904
# 第 475 筆錯誤資料: 6080685905
# 第 475 筆算術錯誤: -536870920
# 第 476 筆錯誤資料: 7691298657
# 第 476 筆算術錯誤: 1073741832
# 第 477 筆錯誤資料: 5543815009
# 第 477 筆算術錯誤: -1073741816
# 第 478 筆錯誤資料: 7691298641
# 第 478 筆算術錯誤: 1073741816
# 第 479 筆錯誤資料: 5543814993
# 第 479 筆算術錯誤: -1073741832
# 第 480 筆錯誤資料: 8765040481
# 第 480 筆算術錯誤: 2147483656
# 第 481 筆錯誤資料: 4470073185
# 第 481 筆算術錯誤: -2147483640
# 第 482 筆錯誤資料: 8765040465
# 第 482 筆算術錯誤: 2147483640
# 第 483 筆錯誤資料: 4470073169
# 第 483 筆算術錯誤: -2147483656
# 第 484 筆錯誤資料: 10912524129
# 第 484 筆算術錯誤: 4294967304
# 第 485 筆錯誤資料: 2322589537
# 第 485 筆算術錯誤: -4294967288
# 第 486 筆錯誤資料: 10912524113
# 第 486 筆算術錯誤: 4294967288
# 第 487 筆錯誤資料: 2322589521
# 第 487 筆算術錯誤: -4294967304
# 第 488 筆錯誤資料: 6617556873
# 第 488 筆算術錯誤: 48
# 第 489 筆錯誤資料: 6617556809
# 第 489 筆算術錯誤: -16
# 第 490 筆錯誤資料: 6617556841
# 第 490 筆算術錯誤: 16
# 第 491 筆錯誤資料: 6617556777
# 第 491 筆算術錯誤: -48
# 第 492 筆錯誤資料: 6617556905
# 第 492 筆算術錯誤: 80
# 第 493 筆錯誤資料: 6617556777
# 第 493 筆算術錯誤: -48
# 第 494 筆錯誤資料: 6617556873
# 第 494 筆算術錯誤: 48
# 第 495 筆錯誤資料: 6617556745
# 第 495 筆算術錯誤: -80
# 第 496 筆錯誤資料: 6617556969
# 第 496 筆算術錯誤: 144
# 第 497 筆錯誤資料: 6617556713
# 第 497 筆算術錯誤: -112
# 第 498 筆錯誤資料: 6617556937
# 第 498 筆算術錯誤: 112
# 第 499 筆錯誤資料: 6617556681
# 第 499 筆算術錯誤: -144
# 第 500 筆錯誤資料: 6617557097
# 第 500 筆算術錯誤: 272
# 第 501 筆錯誤資料: 6617556585
# 第 501 筆算術錯誤: -240
# 第 502 筆錯誤資料: 6617557065
# 第 502 筆算術錯誤: 240
# 第 503 筆錯誤資料: 6617556553
# 第 503 筆算術錯誤: -272
# 第 504 筆錯誤資料: 6617557353
# 第 504 筆算術錯誤: 528
# 第 505 筆錯誤資料: 6617556329
# 第 505 筆算術錯誤: -496
# 第 506 筆錯誤資料: 6617557321
# 第 506 筆算術錯誤: 496
# 第 507 筆錯誤資料: 6617556297
# 第 507 筆算術錯誤: -528
# 第 508 筆錯誤資料: 6617557865
# 第 508 筆算術錯誤: 1040
# 第 509 筆錯誤資料: 6617555817
# 第 509 筆算術錯誤: -1008
# 第 510 筆錯誤資料: 6617557833
# 第 510 筆算術錯誤: 1008
# 第 511 筆錯誤資料: 6617555785
# 第 511 筆算術錯誤: -1040
# 第 512 筆錯誤資料: 6617558889
# 第 512 筆算術錯誤: 2064
# 第 513 筆錯誤資料: 6617554793
# 第 513 筆算術錯誤: -2032
# 第 514 筆錯誤資料: 6617558857
# 第 514 筆算術錯誤: 2032
# 第 515 筆錯誤資料: 6617554761
# 第 515 筆算術錯誤: -2064
# 第 516 筆錯誤資料: 6617560937
# 第 516 筆算術錯誤: 4112
# 第 517 筆錯誤資料: 6617552745
# 第 517 筆算術錯誤: -4080
# 第 518 筆錯誤資料: 6617560905
# 第 518 筆算術錯誤: 4080
# 第 519 筆錯誤資料: 6617552713
# 第 519 筆算術錯誤: -4112
# 第 520 筆錯誤資料: 6617565033
# 第 520 筆算術錯誤: 8208
# 第 521 筆錯誤資料: 6617548649
# 第 521 筆算術錯誤: -8176
# 第 522 筆錯誤資料: 6617565001
# 第 522 筆算術錯誤: 8176
# 第 523 筆錯誤資料: 6617548617
# 第 523 筆算術錯誤: -8208
# 第 524 筆錯誤資料: 6617573225
# 第 524 筆算術錯誤: 16400
# 第 525 筆錯誤資料: 6617540457
# 第 525 筆算術錯誤: -16368
# 第 526 筆錯誤資料: 6617573193
# 第 526 筆算術錯誤: 16368
# 第 527 筆錯誤資料: 6617540425
# 第 527 筆算術錯誤: -16400
# 第 528 筆錯誤資料: 6617589609
# 第 528 筆算術錯誤: 32784
# 第 529 筆錯誤資料: 6617524073
# 第 529 筆算術錯誤: -32752
# 第 530 筆錯誤資料: 6617589577
# 第 530 筆算術錯誤: 32752
# 第 531 筆錯誤資料: 6617524041
# 第 531 筆算術錯誤: -32784
# 第 532 筆錯誤資料: 6617622377
# 第 532 筆算術錯誤: 65552
# 第 533 筆錯誤資料: 6617491305
# 第 533 筆算術錯誤: -65520
# 第 534 筆錯誤資料: 6617622345
# 第 534 筆算術錯誤: 65520
# 第 535 筆錯誤資料: 6617491273
# 第 535 筆算術錯誤: -65552
# 第 536 筆錯誤資料: 6617687913
# 第 536 筆算術錯誤: 131088
# 第 537 筆錯誤資料: 6617425769
# 第 537 筆算術錯誤: -131056
# 第 538 筆錯誤資料: 6617687881
# 第 538 筆算術錯誤: 131056
# 第 539 筆錯誤資料: 6617425737
# 第 539 筆算術錯誤: -131088
# 第 540 筆錯誤資料: 6617818985
# 第 540 筆算術錯誤: 262160
# 第 541 筆錯誤資料: 6617294697
# 第 541 筆算術錯誤: -262128
# 第 542 筆錯誤資料: 6617818953
# 第 542 筆算術錯誤: 262128
# 第 543 筆錯誤資料: 6617294665
# 第 543 筆算術錯誤: -262160
# 第 544 筆錯誤資料: 6618081129
# 第 544 筆算術錯誤: 524304
# 第 545 筆錯誤資料: 6617032553
# 第 545 筆算術錯誤: -524272
# 第 546 筆錯誤資料: 6618081097
# 第 546 筆算術錯誤: 524272
# 第 547 筆錯誤資料: 6617032521
# 第 547 筆算術錯誤: -524304
# 第 548 筆錯誤資料: 6618605417
# 第 548 筆算術錯誤: 1048592
# 第 549 筆錯誤資料: 6616508265
# 第 549 筆算術錯誤: -1048560
# 第 550 筆錯誤資料: 6618605385
# 第 550 筆算術錯誤: 1048560
# 第 551 筆錯誤資料: 6616508233
# 第 551 筆算術錯誤: -1048592
# 第 552 筆錯誤資料: 6619653993
# 第 552 筆算術錯誤: 2097168
# 第 553 筆錯誤資料: 6615459689
# 第 553 筆算術錯誤: -2097136
# 第 554 筆錯誤資料: 6619653961
# 第 554 筆算術錯誤: 2097136
# 第 555 筆錯誤資料: 6615459657
# 第 555 筆算術錯誤: -2097168
# 第 556 筆錯誤資料: 6621751145
# 第 556 筆算術錯誤: 4194320
# 第 557 筆錯誤資料: 6613362537
# 第 557 筆算術錯誤: -4194288
# 第 558 筆錯誤資料: 6621751113
# 第 558 筆算術錯誤: 4194288
# 第 559 筆錯誤資料: 6613362505
# 第 559 筆算術錯誤: -4194320
# 第 560 筆錯誤資料: 6625945449
# 第 560 筆算術錯誤: 8388624
# 第 561 筆錯誤資料: 6609168233
# 第 561 筆算術錯誤: -8388592
# 第 562 筆錯誤資料: 6625945417
# 第 562 筆算術錯誤: 8388592
# 第 563 筆錯誤資料: 6609168201
# 第 563 筆算術錯誤: -8388624
# 第 564 筆錯誤資料: 6634334057
# 第 564 筆算術錯誤: 16777232
# 第 565 筆錯誤資料: 6600779625
# 第 565 筆算術錯誤: -16777200
# 第 566 筆錯誤資料: 6634334025
# 第 566 筆算術錯誤: 16777200
# 第 567 筆錯誤資料: 6600779593
# 第 567 筆算術錯誤: -16777232
# 第 568 筆錯誤資料: 6651111273
# 第 568 筆算術錯誤: 33554448
# 第 569 筆錯誤資料: 6584002409
# 第 569 筆算術錯誤: -33554416
# 第 570 筆錯誤資料: 6651111241
# 第 570 筆算術錯誤: 33554416
# 第 571 筆錯誤資料: 6584002377
# 第 571 筆算術錯誤: -33554448
# 第 572 筆錯誤資料: 6684665705
# 第 572 筆算術錯誤: 67108880
# 第 573 筆錯誤資料: 6550447977
# 第 573 筆算術錯誤: -67108848
# 第 574 筆錯誤資料: 6684665673
# 第 574 筆算術錯誤: 67108848
# 第 575 筆錯誤資料: 6550447945
# 第 575 筆算術錯誤: -67108880
# 第 576 筆錯誤資料: 6751774569
# 第 576 筆算術錯誤: 134217744
# 第 577 筆錯誤資料: 6483339113
# 第 577 筆算術錯誤: -134217712
# 第 578 筆錯誤資料: 6751774537
# 第 578 筆算術錯誤: 134217712
# 第 579 筆錯誤資料: 6483339081
# 第 579 筆算術錯誤: -134217744
# 第 580 筆錯誤資料: 6885992297
# 第 580 筆算術錯誤: 268435472
# 第 581 筆錯誤資料: 6349121385
# 第 581 筆算術錯誤: -268435440
# 第 582 筆錯誤資料: 6885992265
# 第 582 筆算術錯誤: 268435440
# 第 583 筆錯誤資料: 6349121353
# 第 583 筆算術錯誤: -268435472
# 第 584 筆錯誤資料: 7154427753
# 第 584 筆算術錯誤: 536870928
# 第 585 筆錯誤資料: 6080685929
# 第 585 筆算術錯誤: -536870896
# 第 586 筆錯誤資料: 7154427721
# 第 586 筆算術錯誤: 536870896
# 第 587 筆錯誤資料: 6080685897
# 第 587 筆算術錯誤: -536870928
# 第 588 筆錯誤資料: 7691298665
# 第 588 筆算術錯誤: 1073741840
# 第 589 筆錯誤資料: 5543815017
# 第 589 筆算術錯誤: -1073741808
# 第 590 筆錯誤資料: 7691298633
# 第 590 筆算術錯誤: 1073741808
# 第 591 筆錯誤資料: 5543814985
# 第 591 筆算術錯誤: -1073741840
# 第 592 筆錯誤資料: 8765040489
# 第 592 筆算術錯誤: 2147483664
# 第 593 筆錯誤資料: 4470073193
# 第 593 筆算術錯誤: -2147483632
# 第 594 筆錯誤資料: 8765040457
# 第 594 筆算術錯誤: 2147483632
# 第 595 筆錯誤資料: 4470073161
# 第 595 筆算術錯誤: -2147483664
# 第 596 筆錯誤資料: 10912524137
# 第 596 筆算術錯誤: 4294967312
# 第 597 筆錯誤資料: 2322589545
# 第 597 筆算術錯誤: -4294967280
# 第 598 筆錯誤資料: 10912524105
# 第 598 筆算術錯誤: 4294967280
# 第 599 筆錯誤資料: 2322589513
# 第 599 筆算術錯誤: -4294967312
# 第 600 筆錯誤資料: 6617556921
# 第 600 筆算術錯誤: 96
# 第 601 筆錯誤資料: 6617556793
# 第 601 筆算術錯誤: -32
# 第 602 筆錯誤資料: 6617556857
# 第 602 筆算術錯誤: 32
# 第 603 筆錯誤資料: 6617556729
# 第 603 筆算術錯誤: -96
# 第 604 筆錯誤資料: 6617556985
# 第 604 筆算術錯誤: 160
# 第 605 筆錯誤資料: 6617556729
# 第 605 筆算術錯誤: -96
# 第 606 筆錯誤資料: 6617556921
# 第 606 筆算術錯誤: 96
# 第 607 筆錯誤資料: 6617556665
# 第 607 筆算術錯誤: -160
# 第 608 筆錯誤資料: 6617557113
# 第 608 筆算術錯誤: 288
# 第 609 筆錯誤資料: 6617556601
# 第 609 筆算術錯誤: -224
# 第 610 筆錯誤資料: 6617557049
# 第 610 筆算術錯誤: 224
# 第 611 筆錯誤資料: 6617556537
# 第 611 筆算術錯誤: -288
# 第 612 筆錯誤資料: 6617557369
# 第 612 筆算術錯誤: 544
# 第 613 筆錯誤資料: 6617556345
# 第 613 筆算術錯誤: -480
# 第 614 筆錯誤資料: 6617557305
# 第 614 筆算術錯誤: 480
# 第 615 筆錯誤資料: 6617556281
# 第 615 筆算術錯誤: -544
# 第 616 筆錯誤資料: 6617557881
# 第 616 筆算術錯誤: 1056
# 第 617 筆錯誤資料: 6617555833
# 第 617 筆算術錯誤: -992
# 第 618 筆錯誤資料: 6617557817
# 第 618 筆算術錯誤: 992
# 第 619 筆錯誤資料: 6617555769
# 第 619 筆算術錯誤: -1056
# 第 620 筆錯誤資料: 6617558905
# 第 620 筆算術錯誤: 2080
# 第 621 筆錯誤資料: 6617554809
# 第 621 筆算術錯誤: -2016
# 第 622 筆錯誤資料: 6617558841
# 第 622 筆算術錯誤: 2016
# 第 623 筆錯誤資料: 6617554745
# 第 623 筆算術錯誤: -2080
# 第 624 筆錯誤資料: 6617560953
# 第 624 筆算術錯誤: 4128
# 第 625 筆錯誤資料: 6617552761
# 第 625 筆算術錯誤: -4064
# 第 626 筆錯誤資料: 6617560889
# 第 626 筆算術錯誤: 4064
# 第 627 筆錯誤資料: 6617552697
# 第 627 筆算術錯誤: -4128
# 第 628 筆錯誤資料: 6617565049
# 第 628 筆算術錯誤: 8224
# 第 629 筆錯誤資料: 6617548665
# 第 629 筆算術錯誤: -8160
# 第 630 筆錯誤資料: 6617564985
# 第 630 筆算術錯誤: 8160
# 第 631 筆錯誤資料: 6617548601
# 第 631 筆算術錯誤: -8224
# 第 632 筆錯誤資料: 6617573241
# 第 632 筆算術錯誤: 16416
# 第 633 筆錯誤資料: 6617540473
# 第 633 筆算術錯誤: -16352
# 第 634 筆錯誤資料: 6617573177
# 第 634 筆算術錯誤: 16352
# 第 635 筆錯誤資料: 6617540409
# 第 635 筆算術錯誤: -16416
# 第 636 筆錯誤資料: 6617589625
# 第 636 筆算術錯誤: 32800
# 第 637 筆錯誤資料: 6617524089
# 第 637 筆算術錯誤: -32736
# 第 638 筆錯誤資料: 6617589561
# 第 638 筆算術錯誤: 32736
# 第 639 筆錯誤資料: 6617524025
# 第 639 筆算術錯誤: -32800
# 第 640 筆錯誤資料: 6617622393
# 第 640 筆算術錯誤: 65568
# 第 641 筆錯誤資料: 6617491321
# 第 641 筆算術錯誤: -65504
# 第 642 筆錯誤資料: 6617622329
# 第 642 筆算術錯誤: 65504
# 第 643 筆錯誤資料: 6617491257
# 第 643 筆算術錯誤: -65568
# 第 644 筆錯誤資料: 6617687929
# 第 644 筆算術錯誤: 131104
# 第 645 筆錯誤資料: 6617425785
# 第 645 筆算術錯誤: -131040
# 第 646 筆錯誤資料: 6617687865
# 第 646 筆算術錯誤: 131040
# 第 647 筆錯誤資料: 6617425721
# 第 647 筆算術錯誤: -131104
# 第 648 筆錯誤資料: 6617819001
# 第 648 筆算術錯誤: 262176
# 第 649 筆錯誤資料: 6617294713
# 第 649 筆算術錯誤: -262112
# 第 650 筆錯誤資料: 6617818937
# 第 650 筆算術錯誤: 262112
# 第 651 筆錯誤資料: 6617294649
# 第 651 筆算術錯誤: -262176
# 第 652 筆錯誤資料: 6618081145
# 第 652 筆算術錯誤: 524320
# 第 653 筆錯誤資料: 6617032569
# 第 653 筆算術錯誤: -524256
# 第 654 筆錯誤資料: 6618081081
# 第 654 筆算術錯誤: 524256
# 第 655 筆錯誤資料: 6617032505
# 第 655 筆算術錯誤: -524320
# 第 656 筆錯誤資料: 6618605433
# 第 656 筆算術錯誤: 1048608
# 第 657 筆錯誤資料: 6616508281
# 第 657 筆算術錯誤: -1048544
# 第 658 筆錯誤資料: 6618605369
# 第 658 筆算術錯誤: 1048544
# 第 659 筆錯誤資料: 6616508217
# 第 659 筆算術錯誤: -1048608
# 第 660 筆錯誤資料: 6619654009
# 第 660 筆算術錯誤: 2097184
# 第 661 筆錯誤資料: 6615459705
# 第 661 筆算術錯誤: -2097120
# 第 662 筆錯誤資料: 6619653945
# 第 662 筆算術錯誤: 2097120
# 第 663 筆錯誤資料: 6615459641
# 第 663 筆算術錯誤: -2097184
# 第 664 筆錯誤資料: 6621751161
# 第 664 筆算術錯誤: 4194336
# 第 665 筆錯誤資料: 6613362553
# 第 665 筆算術錯誤: -4194272
# 第 666 筆錯誤資料: 6621751097
# 第 666 筆算術錯誤: 4194272
# 第 667 筆錯誤資料: 6613362489
# 第 667 筆算術錯誤: -4194336
# 第 668 筆錯誤資料: 6625945465
# 第 668 筆算術錯誤: 8388640
# 第 669 筆錯誤資料: 6609168249
# 第 669 筆算術錯誤: -8388576
# 第 670 筆錯誤資料: 6625945401
# 第 670 筆算術錯誤: 8388576
# 第 671 筆錯誤資料: 6609168185
# 第 671 筆算術錯誤: -8388640
# 第 672 筆錯誤資料: 6634334073
# 第 672 筆算術錯誤: 16777248
# 第 673 筆錯誤資料: 6600779641
# 第 673 筆算術錯誤: -16777184
# 第 674 筆錯誤資料: 6634334009
# 第 674 筆算術錯誤: 16777184
# 第 675 筆錯誤資料: 6600779577
# 第 675 筆算術錯誤: -16777248
# 第 676 筆錯誤資料: 6651111289
# 第 676 筆算術錯誤: 33554464
# 第 677 筆錯誤資料: 6584002425
# 第 677 筆算術錯誤: -33554400
# 第 678 筆錯誤資料: 6651111225
# 第 678 筆算術錯誤: 33554400
# 第 679 筆錯誤資料: 6584002361
# 第 679 筆算術錯誤: -33554464
# 第 680 筆錯誤資料: 6684665721
# 第 680 筆算術錯誤: 67108896
# 第 681 筆錯誤資料: 6550447993
# 第 681 筆算術錯誤: -67108832
# 第 682 筆錯誤資料: 6684665657
# 第 682 筆算術錯誤: 67108832
# 第 683 筆錯誤資料: 6550447929
# 第 683 筆算術錯誤: -67108896
# 第 684 筆錯誤資料: 6751774585
# 第 684 筆算術錯誤: 134217760
# 第 685 筆錯誤資料: 6483339129
# 第 685 筆算術錯誤: -134217696
# 第 686 筆錯誤資料: 6751774521
# 第 686 筆算術錯誤: 134217696
# 第 687 筆錯誤資料: 6483339065
# 第 687 筆算術錯誤: -134217760
# 第 688 筆錯誤資料: 6885992313
# 第 688 筆算術錯誤: 268435488
# 第 689 筆錯誤資料: 6349121401
# 第 689 筆算術錯誤: -268435424
# 第 690 筆錯誤資料: 6885992249
# 第 690 筆算術錯誤: 268435424
# 第 691 筆錯誤資料: 6349121337
# 第 691 筆算術錯誤: -268435488
# 第 692 筆錯誤資料: 7154427769
# 第 692 筆算術錯誤: 536870944
# 第 693 筆錯誤資料: 6080685945
# 第 693 筆算術錯誤: -536870880
# 第 694 筆錯誤資料: 7154427705
# 第 694 筆算術錯誤: 536870880
# 第 695 筆錯誤資料: 6080685881
# 第 695 筆算術錯誤: -536870944
# 第 696 筆錯誤資料: 7691298681
# 第 696 筆算術錯誤: 1073741856
# 第 697 筆錯誤資料: 5543815033
# 第 697 筆算術錯誤: -1073741792
# 第 698 筆錯誤資料: 7691298617
# 第 698 筆算術錯誤: 1073741792
# 第 699 筆錯誤資料: 5543814969
# 第 699 筆算術錯誤: -1073741856
# 第 700 筆錯誤資料: 8765040505
# 第 700 筆算術錯誤: 2147483680
# 第 701 筆錯誤資料: 4470073209
# 第 701 筆算術錯誤: -2147483616
# 第 702 筆錯誤資料: 8765040441
# 第 702 筆算術錯誤: 2147483616
# 第 703 筆錯誤資料: 4470073145
# 第 703 筆算術錯誤: -2147483680
# 第 704 筆錯誤資料: 10912524153
# 第 704 筆算術錯誤: 4294967328
# 第 705 筆錯誤資料: 2322589561
# 第 705 筆算術錯誤: -4294967264
# 第 706 筆錯誤資料: 10912524089
# 第 706 筆算術錯誤: 4294967264
# 第 707 筆錯誤資料: 2322589497
# 第 707 筆算術錯誤: -4294967328
# 第 708 筆錯誤資料: 6617557017
# 第 708 筆算術錯誤: 192
# 第 709 筆錯誤資料: 6617556761
# 第 709 筆算術錯誤: -64
# 第 710 筆錯誤資料: 6617556889
# 第 710 筆算術錯誤: 64
# 第 711 筆錯誤資料: 6617556633
# 第 711 筆算術錯誤: -192
# 第 712 筆錯誤資料: 6617557145
# 第 712 筆算術錯誤: 320
# 第 713 筆錯誤資料: 6617556633
# 第 713 筆算術錯誤: -192
# 第 714 筆錯誤資料: 6617557017
# 第 714 筆算術錯誤: 192
# 第 715 筆錯誤資料: 6617556505
# 第 715 筆算術錯誤: -320
# 第 716 筆錯誤資料: 6617557401
# 第 716 筆算術錯誤: 576
# 第 717 筆錯誤資料: 6617556377
# 第 717 筆算術錯誤: -448
# 第 718 筆錯誤資料: 6617557273
# 第 718 筆算術錯誤: 448
# 第 719 筆錯誤資料: 6617556249
# 第 719 筆算術錯誤: -576
# 第 720 筆錯誤資料: 6617557913
# 第 720 筆算術錯誤: 1088
# 第 721 筆錯誤資料: 6617555865
# 第 721 筆算術錯誤: -960
# 第 722 筆錯誤資料: 6617557785
# 第 722 筆算術錯誤: 960
# 第 723 筆錯誤資料: 6617555737
# 第 723 筆算術錯誤: -1088
# 第 724 筆錯誤資料: 6617558937
# 第 724 筆算術錯誤: 2112
# 第 725 筆錯誤資料: 6617554841
# 第 725 筆算術錯誤: -1984
# 第 726 筆錯誤資料: 6617558809
# 第 726 筆算術錯誤: 1984
# 第 727 筆錯誤資料: 6617554713
# 第 727 筆算術錯誤: -2112
# 第 728 筆錯誤資料: 6617560985
# 第 728 筆算術錯誤: 4160
# 第 729 筆錯誤資料: 6617552793
# 第 729 筆算術錯誤: -4032
# 第 730 筆錯誤資料: 6617560857
# 第 730 筆算術錯誤: 4032
# 第 731 筆錯誤資料: 6617552665
# 第 731 筆算術錯誤: -4160
# 第 732 筆錯誤資料: 6617565081
# 第 732 筆算術錯誤: 8256
# 第 733 筆錯誤資料: 6617548697
# 第 733 筆算術錯誤: -8128
# 第 734 筆錯誤資料: 6617564953
# 第 734 筆算術錯誤: 8128
# 第 735 筆錯誤資料: 6617548569
# 第 735 筆算術錯誤: -8256
# 第 736 筆錯誤資料: 6617573273
# 第 736 筆算術錯誤: 16448
# 第 737 筆錯誤資料: 6617540505
# 第 737 筆算術錯誤: -16320
# 第 738 筆錯誤資料: 6617573145
# 第 738 筆算術錯誤: 16320
# 第 739 筆錯誤資料: 6617540377
# 第 739 筆算術錯誤: -16448
# 第 740 筆錯誤資料: 6617589657
# 第 740 筆算術錯誤: 32832
# 第 741 筆錯誤資料: 6617524121
# 第 741 筆算術錯誤: -32704
# 第 742 筆錯誤資料: 6617589529
# 第 742 筆算術錯誤: 32704
# 第 743 筆錯誤資料: 6617523993
# 第 743 筆算術錯誤: -32832
# 第 744 筆錯誤資料: 6617622425
# 第 744 筆算術錯誤: 65600
# 第 745 筆錯誤資料: 6617491353
# 第 745 筆算術錯誤: -65472
# 第 746 筆錯誤資料: 6617622297
# 第 746 筆算術錯誤: 65472
# 第 747 筆錯誤資料: 6617491225
# 第 747 筆算術錯誤: -65600
# 第 748 筆錯誤資料: 6617687961
# 第 748 筆算術錯誤: 131136
# 第 749 筆錯誤資料: 6617425817
# 第 749 筆算術錯誤: -131008
# 第 750 筆錯誤資料: 6617687833
# 第 750 筆算術錯誤: 131008
# 第 751 筆錯誤資料: 6617425689
# 第 751 筆算術錯誤: -131136
# 第 752 筆錯誤資料: 6617819033
# 第 752 筆算術錯誤: 262208
# 第 753 筆錯誤資料: 6617294745
# 第 753 筆算術錯誤: -262080
# 第 754 筆錯誤資料: 6617818905
# 第 754 筆算術錯誤: 262080
# 第 755 筆錯誤資料: 6617294617
# 第 755 筆算術錯誤: -262208
# 第 756 筆錯誤資料: 6618081177
# 第 756 筆算術錯誤: 524352
# 第 757 筆錯誤資料: 6617032601
# 第 757 筆算術錯誤: -524224
# 第 758 筆錯誤資料: 6618081049
# 第 758 筆算術錯誤: 524224
# 第 759 筆錯誤資料: 6617032473
# 第 759 筆算術錯誤: -524352
# 第 760 筆錯誤資料: 6618605465
# 第 760 筆算術錯誤: 1048640
# 第 761 筆錯誤資料: 6616508313
# 第 761 筆算術錯誤: -1048512
# 第 762 筆錯誤資料: 6618605337
# 第 762 筆算術錯誤: 1048512
# 第 763 筆錯誤資料: 6616508185
# 第 763 筆算術錯誤: -1048640
# 第 764 筆錯誤資料: 6619654041
# 第 764 筆算術錯誤: 2097216
# 第 765 筆錯誤資料: 6615459737
# 第 765 筆算術錯誤: -2097088
# 第 766 筆錯誤資料: 6619653913
# 第 766 筆算術錯誤: 2097088
# 第 767 筆錯誤資料: 6615459609
# 第 767 筆算術錯誤: -2097216
# 第 768 筆錯誤資料: 6621751193
# 第 768 筆算術錯誤: 4194368
# 第 769 筆錯誤資料: 6613362585
# 第 769 筆算術錯誤: -4194240
# 第 770 筆錯誤資料: 6621751065
# 第 770 筆算術錯誤: 4194240
# 第 771 筆錯誤資料: 6613362457
# 第 771 筆算術錯誤: -4194368
# 第 772 筆錯誤資料: 6625945497
# 第 772 筆算術錯誤: 8388672
# 第 773 筆錯誤資料: 6609168281
# 第 773 筆算術錯誤: -8388544
# 第 774 筆錯誤資料: 6625945369
# 第 774 筆算術錯誤: 8388544
# 第 775 筆錯誤資料: 6609168153
# 第 775 筆算術錯誤: -8388672
# 第 776 筆錯誤資料: 6634334105
# 第 776 筆算術錯誤: 16777280
# 第 777 筆錯誤資料: 6600779673
# 第 777 筆算術錯誤: -16777152
# 第 778 筆錯誤資料: 6634333977
# 第 778 筆算術錯誤: 16777152
# 第 779 筆錯誤資料: 6600779545
# 第 779 筆算術錯誤: -16777280
# 第 780 筆錯誤資料: 6651111321
# 第 780 筆算術錯誤: 33554496
# 第 781 筆錯誤資料: 6584002457
# 第 781 筆算術錯誤: -33554368
# 第 782 筆錯誤資料: 6651111193
# 第 782 筆算術錯誤: 33554368
# 第 783 筆錯誤資料: 6584002329
# 第 783 筆算術錯誤: -33554496
# 第 784 筆錯誤資料: 6684665753
# 第 784 筆算術錯誤: 67108928
# 第 785 筆錯誤資料: 6550448025
# 第 785 筆算術錯誤: -67108800
# 第 786 筆錯誤資料: 6684665625
# 第 786 筆算術錯誤: 67108800
# 第 787 筆錯誤資料: 6550447897
# 第 787 筆算術錯誤: -67108928
# 第 788 筆錯誤資料: 6751774617
# 第 788 筆算術錯誤: 134217792
# 第 789 筆錯誤資料: 6483339161
# 第 789 筆算術錯誤: -134217664
# 第 790 筆錯誤資料: 6751774489
# 第 790 筆算術錯誤: 134217664
# 第 791 筆錯誤資料: 6483339033
# 第 791 筆算術錯誤: -134217792
# 第 792 筆錯誤資料: 6885992345
# 第 792 筆算術錯誤: 268435520
# 第 793 筆錯誤資料: 6349121433
# 第 793 筆算術錯誤: -268435392
# 第 794 筆錯誤資料: 6885992217
# 第 794 筆算術錯誤: 268435392
# 第 795 筆錯誤資料: 6349121305
# 第 795 筆算術錯誤: -268435520
# 第 796 筆錯誤資料: 7154427801
# 第 796 筆算術錯誤: 536870976
# 第 797 筆錯誤資料: 6080685977
# 第 797 筆算術錯誤: -536870848
# 第 798 筆錯誤資料: 7154427673
# 第 798 筆算術錯誤: 536870848
# 第 799 筆錯誤資料: 6080685849
# 第 799 筆算術錯誤: -536870976
# 第 800 筆錯誤資料: 7691298713
# 第 800 筆算術錯誤: 1073741888
# 第 801 筆錯誤資料: 5543815065
# 第 801 筆算術錯誤: -1073741760
# 第 802 筆錯誤資料: 7691298585
# 第 802 筆算術錯誤: 1073741760
# 第 803 筆錯誤資料: 5543814937
# 第 803 筆算術錯誤: -1073741888
# 第 804 筆錯誤資料: 8765040537
# 第 804 筆算術錯誤: 2147483712
# 第 805 筆錯誤資料: 4470073241
# 第 805 筆算術錯誤: -2147483584
# 第 806 筆錯誤資料: 8765040409
# 第 806 筆算術錯誤: 2147483584
# 第 807 筆錯誤資料: 4470073113
# 第 807 筆算術錯誤: -2147483712
# 第 808 筆錯誤資料: 10912524185
# 第 808 筆算術錯誤: 4294967360
# 第 809 筆錯誤資料: 2322589593
# 第 809 筆算術錯誤: -4294967232
# 第 810 筆錯誤資料: 10912524057
# 第 810 筆算術錯誤: 4294967232
# 第 811 筆錯誤資料: 2322589465
# 第 811 筆算術錯誤: -4294967360
# 第 812 筆錯誤資料: 6617557209
# 第 812 筆算術錯誤: 384
# 第 813 筆錯誤資料: 6617556697
# 第 813 筆算術錯誤: -128
# 第 814 筆錯誤資料: 6617556953
# 第 814 筆算術錯誤: 128
# 第 815 筆錯誤資料: 6617556441
# 第 815 筆算術錯誤: -384
# 第 816 筆錯誤資料: 6617557465
# 第 816 筆算術錯誤: 640
# 第 817 筆錯誤資料: 6617556441
# 第 817 筆算術錯誤: -384
# 第 818 筆錯誤資料: 6617557209
# 第 818 筆算術錯誤: 384
# 第 819 筆錯誤資料: 6617556185
# 第 819 筆算術錯誤: -640
# 第 820 筆錯誤資料: 6617557977
# 第 820 筆算術錯誤: 1152
# 第 821 筆錯誤資料: 6617555929
# 第 821 筆算術錯誤: -896
# 第 822 筆錯誤資料: 6617557721
# 第 822 筆算術錯誤: 896
# 第 823 筆錯誤資料: 6617555673
# 第 823 筆算術錯誤: -1152
# 第 824 筆錯誤資料: 6617559001
# 第 824 筆算術錯誤: 2176
# 第 825 筆錯誤資料: 6617554905
# 第 825 筆算術錯誤: -1920
# 第 826 筆錯誤資料: 6617558745
# 第 826 筆算術錯誤: 1920
# 第 827 筆錯誤資料: 6617554649
# 第 827 筆算術錯誤: -2176
# 第 828 筆錯誤資料: 6617561049
# 第 828 筆算術錯誤: 4224
# 第 829 筆錯誤資料: 6617552857
# 第 829 筆算術錯誤: -3968
# 第 830 筆錯誤資料: 6617560793
# 第 830 筆算術錯誤: 3968
# 第 831 筆錯誤資料: 6617552601
# 第 831 筆算術錯誤: -4224
# 第 832 筆錯誤資料: 6617565145
# 第 832 筆算術錯誤: 8320
# 第 833 筆錯誤資料: 6617548761
# 第 833 筆算術錯誤: -8064
# 第 834 筆錯誤資料: 6617564889
# 第 834 筆算術錯誤: 8064
# 第 835 筆錯誤資料: 6617548505
# 第 835 筆算術錯誤: -8320
# 第 836 筆錯誤資料: 6617573337
# 第 836 筆算術錯誤: 16512
# 第 837 筆錯誤資料: 6617540569
# 第 837 筆算術錯誤: -16256
# 第 838 筆錯誤資料: 6617573081
# 第 838 筆算術錯誤: 16256
# 第 839 筆錯誤資料: 6617540313
# 第 839 筆算術錯誤: -16512
# 第 840 筆錯誤資料: 6617589721
# 第 840 筆算術錯誤: 32896
# 第 841 筆錯誤資料: 6617524185
# 第 841 筆算術錯誤: -32640
# 第 842 筆錯誤資料: 6617589465
# 第 842 筆算術錯誤: 32640
# 第 843 筆錯誤資料: 6617523929
# 第 843 筆算術錯誤: -32896
# 第 844 筆錯誤資料: 6617622489
# 第 844 筆算術錯誤: 65664
# 第 845 筆錯誤資料: 6617491417
# 第 845 筆算術錯誤: -65408
# 第 846 筆錯誤資料: 6617622233
# 第 846 筆算術錯誤: 65408
# 第 847 筆錯誤資料: 6617491161
# 第 847 筆算術錯誤: -65664
# 第 848 筆錯誤資料: 6617688025
# 第 848 筆算術錯誤: 131200
# 第 849 筆錯誤資料: 6617425881
# 第 849 筆算術錯誤: -130944
# 第 850 筆錯誤資料: 6617687769
# 第 850 筆算術錯誤: 130944
# 第 851 筆錯誤資料: 6617425625
# 第 851 筆算術錯誤: -131200
# 第 852 筆錯誤資料: 6617819097
# 第 852 筆算術錯誤: 262272
# 第 853 筆錯誤資料: 6617294809
# 第 853 筆算術錯誤: -262016
# 第 854 筆錯誤資料: 6617818841
# 第 854 筆算術錯誤: 262016
# 第 855 筆錯誤資料: 6617294553
# 第 855 筆算術錯誤: -262272
# 第 856 筆錯誤資料: 6618081241
# 第 856 筆算術錯誤: 524416
# 第 857 筆錯誤資料: 6617032665
# 第 857 筆算術錯誤: -524160
# 第 858 筆錯誤資料: 6618080985
# 第 858 筆算術錯誤: 524160
# 第 859 筆錯誤資料: 6617032409
# 第 859 筆算術錯誤: -524416
# 第 860 筆錯誤資料: 6618605529
# 第 860 筆算術錯誤: 1048704
# 第 861 筆錯誤資料: 6616508377
# 第 861 筆算術錯誤: -1048448
# 第 862 筆錯誤資料: 6618605273
# 第 862 筆算術錯誤: 1048448
# 第 863 筆錯誤資料: 6616508121
# 第 863 筆算術錯誤: -1048704
# 第 864 筆錯誤資料: 6619654105
# 第 864 筆算術錯誤: 2097280
# 第 865 筆錯誤資料: 6615459801
# 第 865 筆算術錯誤: -2097024
# 第 866 筆錯誤資料: 6619653849
# 第 866 筆算術錯誤: 2097024
# 第 867 筆錯誤資料: 6615459545
# 第 867 筆算術錯誤: -2097280
# 第 868 筆錯誤資料: 6621751257
# 第 868 筆算術錯誤: 4194432
# 第 869 筆錯誤資料: 6613362649
# 第 869 筆算術錯誤: -4194176
# 第 870 筆錯誤資料: 6621751001
# 第 870 筆算術錯誤: 4194176
# 第 871 筆錯誤資料: 6613362393
# 第 871 筆算術錯誤: -4194432
# 第 872 筆錯誤資料: 6625945561
# 第 872 筆算術錯誤: 8388736
# 第 873 筆錯誤資料: 6609168345
# 第 873 筆算術錯誤: -8388480
# 第 874 筆錯誤資料: 6625945305
# 第 874 筆算術錯誤: 8388480
# 第 875 筆錯誤資料: 6609168089
# 第 875 筆算術錯誤: -8388736
# 第 876 筆錯誤資料: 6634334169
# 第 876 筆算術錯誤: 16777344
# 第 877 筆錯誤資料: 6600779737
# 第 877 筆算術錯誤: -16777088
# 第 878 筆錯誤資料: 6634333913
# 第 878 筆算術錯誤: 16777088
# 第 879 筆錯誤資料: 6600779481
# 第 879 筆算術錯誤: -16777344
# 第 880 筆錯誤資料: 6651111385
# 第 880 筆算術錯誤: 33554560
# 第 881 筆錯誤資料: 6584002521
# 第 881 筆算術錯誤: -33554304
# 第 882 筆錯誤資料: 6651111129
# 第 882 筆算術錯誤: 33554304
# 第 883 筆錯誤資料: 6584002265
# 第 883 筆算術錯誤: -33554560
# 第 884 筆錯誤資料: 6684665817
# 第 884 筆算術錯誤: 67108992
# 第 885 筆錯誤資料: 6550448089
# 第 885 筆算術錯誤: -67108736
# 第 886 筆錯誤資料: 6684665561
# 第 886 筆算術錯誤: 67108736
# 第 887 筆錯誤資料: 6550447833
# 第 887 筆算術錯誤: -67108992
# 第 888 筆錯誤資料: 6751774681
# 第 888 筆算術錯誤: 134217856
# 第 889 筆錯誤資料: 6483339225
# 第 889 筆算術錯誤: -134217600
# 第 890 筆錯誤資料: 6751774425
# 第 890 筆算術錯誤: 134217600
# 第 891 筆錯誤資料: 6483338969
# 第 891 筆算術錯誤: -134217856
# 第 892 筆錯誤資料: 6885992409
# 第 892 筆算術錯誤: 268435584
# 第 893 筆錯誤資料: 6349121497
# 第 893 筆算術錯誤: -268435328
# 第 894 筆錯誤資料: 6885992153
# 第 894 筆算術錯誤: 268435328
# 第 895 筆錯誤資料: 6349121241
# 第 895 筆算術錯誤: -268435584
# 第 896 筆錯誤資料: 7154427865
# 第 896 筆算術錯誤: 536871040
# 第 897 筆錯誤資料: 6080686041
# 第 897 筆算術錯誤: -536870784
# 第 898 筆錯誤資料: 7154427609
# 第 898 筆算術錯誤: 536870784
# 第 899 筆錯誤資料: 6080685785
# 第 899 筆算術錯誤: -536871040
# 第 900 筆錯誤資料: 7691298777
# 第 900 筆算術錯誤: 1073741952
# 第 901 筆錯誤資料: 5543815129
# 第 901 筆算術錯誤: -1073741696
# 第 902 筆錯誤資料: 7691298521
# 第 902 筆算術錯誤: 1073741696
# 第 903 筆錯誤資料: 5543814873
# 第 903 筆算術錯誤: -1073741952
# 第 904 筆錯誤資料: 8765040601
# 第 904 筆算術錯誤: 2147483776
# 第 905 筆錯誤資料: 4470073305
# 第 905 筆算術錯誤: -2147483520
# 第 906 筆錯誤資料: 8765040345
# 第 906 筆算術錯誤: 2147483520
# 第 907 筆錯誤資料: 4470073049
# 第 907 筆算術錯誤: -2147483776
# 第 908 筆錯誤資料: 10912524249
# 第 908 筆算術錯誤: 4294967424
# 第 909 筆錯誤資料: 2322589657
# 第 909 筆算術錯誤: -4294967168
# 第 910 筆錯誤資料: 10912523993
# 第 910 筆算術錯誤: 4294967168
# 第 911 筆錯誤資料: 2322589401
# 第 911 筆算術錯誤: -4294967424
# 第 912 筆錯誤資料: 6617557593
# 第 912 筆算術錯誤: 768
# 第 913 筆錯誤資料: 6617556569
# 第 913 筆算術錯誤: -256
# 第 914 筆錯誤資料: 6617557081
# 第 914 筆算術錯誤: 256
# 第 915 筆錯誤資料: 6617556057
# 第 915 筆算術錯誤: -768
# 第 916 筆錯誤資料: 6617558105
# 第 916 筆算術錯誤: 1280
# 第 917 筆錯誤資料: 6617556057
# 第 917 筆算術錯誤: -768
# 第 918 筆錯誤資料: 6617557593
# 第 918 筆算術錯誤: 768
# 第 919 筆錯誤資料: 6617555545
# 第 919 筆算術錯誤: -1280
# 第 920 筆錯誤資料: 6617559129
# 第 920 筆算術錯誤: 2304
# 第 921 筆錯誤資料: 6617555033
# 第 921 筆算術錯誤: -1792
# 第 922 筆錯誤資料: 6617558617
# 第 922 筆算術錯誤: 1792
# 第 923 筆錯誤資料: 6617554521
# 第 923 筆算術錯誤: -2304
# 第 924 筆錯誤資料: 6617561177
# 第 924 筆算術錯誤: 4352
# 第 925 筆錯誤資料: 6617552985
# 第 925 筆算術錯誤: -3840
# 第 926 筆錯誤資料: 6617560665
# 第 926 筆算術錯誤: 3840
# 第 927 筆錯誤資料: 6617552473
# 第 927 筆算術錯誤: -4352
# 第 928 筆錯誤資料: 6617565273
# 第 928 筆算術錯誤: 8448
# 第 929 筆錯誤資料: 6617548889
# 第 929 筆算術錯誤: -7936
# 第 930 筆錯誤資料: 6617564761
# 第 930 筆算術錯誤: 7936
# 第 931 筆錯誤資料: 6617548377
# 第 931 筆算術錯誤: -8448
# 第 932 筆錯誤資料: 6617573465
# 第 932 筆算術錯誤: 16640
# 第 933 筆錯誤資料: 6617540697
# 第 933 筆算術錯誤: -16128
# 第 934 筆錯誤資料: 6617572953
# 第 934 筆算術錯誤: 16128
# 第 935 筆錯誤資料: 6617540185
# 第 935 筆算術錯誤: -16640
# 第 936 筆錯誤資料: 6617589849
# 第 936 筆算術錯誤: 33024
# 第 937 筆錯誤資料: 6617524313
# 第 937 筆算術錯誤: -32512
# 第 938 筆錯誤資料: 6617589337
# 第 938 筆算術錯誤: 32512
# 第 939 筆錯誤資料: 6617523801
# 第 939 筆算術錯誤: -33024
# 第 940 筆錯誤資料: 6617622617
# 第 940 筆算術錯誤: 65792
# 第 941 筆錯誤資料: 6617491545
# 第 941 筆算術錯誤: -65280
# 第 942 筆錯誤資料: 6617622105
# 第 942 筆算術錯誤: 65280
# 第 943 筆錯誤資料: 6617491033
# 第 943 筆算術錯誤: -65792
# 第 944 筆錯誤資料: 6617688153
# 第 944 筆算術錯誤: 131328
# 第 945 筆錯誤資料: 6617426009
# 第 945 筆算術錯誤: -130816
# 第 946 筆錯誤資料: 6617687641
# 第 946 筆算術錯誤: 130816
# 第 947 筆錯誤資料: 6617425497
# 第 947 筆算術錯誤: -131328
# 第 948 筆錯誤資料: 6617819225
# 第 948 筆算術錯誤: 262400
# 第 949 筆錯誤資料: 6617294937
# 第 949 筆算術錯誤: -261888
# 第 950 筆錯誤資料: 6617818713
# 第 950 筆算術錯誤: 261888
# 第 951 筆錯誤資料: 6617294425
# 第 951 筆算術錯誤: -262400
# 第 952 筆錯誤資料: 6618081369
# 第 952 筆算術錯誤: 524544
# 第 953 筆錯誤資料: 6617032793
# 第 953 筆算術錯誤: -524032
# 第 954 筆錯誤資料: 6618080857
# 第 954 筆算術錯誤: 524032
# 第 955 筆錯誤資料: 6617032281
# 第 955 筆算術錯誤: -524544
# 第 956 筆錯誤資料: 6618605657
# 第 956 筆算術錯誤: 1048832
# 第 957 筆錯誤資料: 6616508505
# 第 957 筆算術錯誤: -1048320
# 第 958 筆錯誤資料: 6618605145
# 第 958 筆算術錯誤: 1048320
# 第 959 筆錯誤資料: 6616507993
# 第 959 筆算術錯誤: -1048832
# 第 960 筆錯誤資料: 6619654233
# 第 960 筆算術錯誤: 2097408
# 第 961 筆錯誤資料: 6615459929
# 第 961 筆算術錯誤: -2096896
# 第 962 筆錯誤資料: 6619653721
# 第 962 筆算術錯誤: 2096896
# 第 963 筆錯誤資料: 6615459417
# 第 963 筆算術錯誤: -2097408
# 第 964 筆錯誤資料: 6621751385
# 第 964 筆算術錯誤: 4194560
# 第 965 筆錯誤資料: 6613362777
# 第 965 筆算術錯誤: -4194048
# 第 966 筆錯誤資料: 6621750873
# 第 966 筆算術錯誤: 4194048
# 第 967 筆錯誤資料: 6613362265
# 第 967 筆算術錯誤: -4194560
# 第 968 筆錯誤資料: 6625945689
# 第 968 筆算術錯誤: 8388864
# 第 969 筆錯誤資料: 6609168473
# 第 969 筆算術錯誤: -8388352
# 第 970 筆錯誤資料: 6625945177
# 第 970 筆算術錯誤: 8388352
# 第 971 筆錯誤資料: 6609167961
# 第 971 筆算術錯誤: -8388864
# 第 972 筆錯誤資料: 6634334297
# 第 972 筆算術錯誤: 16777472
# 第 973 筆錯誤資料: 6600779865
# 第 973 筆算術錯誤: -16776960
# 第 974 筆錯誤資料: 6634333785
# 第 974 筆算術錯誤: 16776960
# 第 975 筆錯誤資料: 6600779353
# 第 975 筆算術錯誤: -16777472
# 第 976 筆錯誤資料: 6651111513
# 第 976 筆算術錯誤: 33554688
# 第 977 筆錯誤資料: 6584002649
# 第 977 筆算術錯誤: -33554176
# 第 978 筆錯誤資料: 6651111001
# 第 978 筆算術錯誤: 33554176
# 第 979 筆錯誤資料: 6584002137
# 第 979 筆算術錯誤: -33554688
# 第 980 筆錯誤資料: 6684665945
# 第 980 筆算術錯誤: 67109120
# 第 981 筆錯誤資料: 6550448217
# 第 981 筆算術錯誤: -67108608
# 第 982 筆錯誤資料: 6684665433
# 第 982 筆算術錯誤: 67108608
# 第 983 筆錯誤資料: 6550447705
# 第 983 筆算術錯誤: -67109120
# 第 984 筆錯誤資料: 6751774809
# 第 984 筆算術錯誤: 134217984
# 第 985 筆錯誤資料: 6483339353
# 第 985 筆算術錯誤: -134217472
# 第 986 筆錯誤資料: 6751774297
# 第 986 筆算術錯誤: 134217472
# 第 987 筆錯誤資料: 6483338841
# 第 987 筆算術錯誤: -134217984
# 第 988 筆錯誤資料: 6885992537
# 第 988 筆算術錯誤: 268435712
# 第 989 筆錯誤資料: 6349121625
# 第 989 筆算術錯誤: -268435200
# 第 990 筆錯誤資料: 6885992025
# 第 990 筆算術錯誤: 268435200
# 第 991 筆錯誤資料: 6349121113
# 第 991 筆算術錯誤: -268435712
# 第 992 筆錯誤資料: 7154427993
# 第 992 筆算術錯誤: 536871168
# 第 993 筆錯誤資料: 6080686169
# 第 993 筆算術錯誤: -536870656
# 第 994 筆錯誤資料: 7154427481
# 第 994 筆算術錯誤: 536870656
# 第 995 筆錯誤資料: 6080685657
# 第 995 筆算術錯誤: -536871168
# 第 996 筆錯誤資料: 7691298905
# 第 996 筆算術錯誤: 1073742080
# 第 997 筆錯誤資料: 5543815257
# 第 997 筆算術錯誤: -1073741568
# 第 998 筆錯誤資料: 7691298393
# 第 998 筆算術錯誤: 1073741568
# 第 999 筆錯誤資料: 5543814745
# 第 999 筆算術錯誤: -1073742080
# 第 1000 筆錯誤資料: 8765040729
# 第 1000 筆算術錯誤: 2147483904
# 第 1001 筆錯誤資料: 4470073433
# 第 1001 筆算術錯誤: -2147483392
# 第 1002 筆錯誤資料: 8765040217
# 第 1002 筆算術錯誤: 2147483392
# 第 1003 筆錯誤資料: 4470072921
# 第 1003 筆算術錯誤: -2147483904
# 第 1004 筆錯誤資料: 10912524377
# 第 1004 筆算術錯誤: 4294967552
# 第 1005 筆錯誤資料: 2322589785
# 第 1005 筆算術錯誤: -4294967040
# 第 1006 筆錯誤資料: 10912523865
# 第 1006 筆算術錯誤: 4294967040
# 第 1007 筆錯誤資料: 2322589273
# 第 1007 筆算術錯誤: -4294967552
# 第 1008 筆錯誤資料: 6617558361
# 第 1008 筆算術錯誤: 1536
# 第 1009 筆錯誤資料: 6617556313
# 第 1009 筆算術錯誤: -512
# 第 1010 筆錯誤資料: 6617557337
# 第 1010 筆算術錯誤: 512
# 第 1011 筆錯誤資料: 6617555289
# 第 1011 筆算術錯誤: -1536
# 第 1012 筆錯誤資料: 6617559385
# 第 1012 筆算術錯誤: 2560
# 第 1013 筆錯誤資料: 6617555289
# 第 1013 筆算術錯誤: -1536
# 第 1014 筆錯誤資料: 6617558361
# 第 1014 筆算術錯誤: 1536
# 第 1015 筆錯誤資料: 6617554265
# 第 1015 筆算術錯誤: -2560
# 第 1016 筆錯誤資料: 6617561433
# 第 1016 筆算術錯誤: 4608
# 第 1017 筆錯誤資料: 6617553241
# 第 1017 筆算術錯誤: -3584
# 第 1018 筆錯誤資料: 6617560409
# 第 1018 筆算術錯誤: 3584
# 第 1019 筆錯誤資料: 6617552217
# 第 1019 筆算術錯誤: -4608
# 第 1020 筆錯誤資料: 6617565529
# 第 1020 筆算術錯誤: 8704
# 第 1021 筆錯誤資料: 6617549145
# 第 1021 筆算術錯誤: -7680
# 第 1022 筆錯誤資料: 6617564505
# 第 1022 筆算術錯誤: 7680
# 第 1023 筆錯誤資料: 6617548121
# 第 1023 筆算術錯誤: -8704
# 第 1024 筆錯誤資料: 6617573721
# 第 1024 筆算術錯誤: 16896
# 第 1025 筆錯誤資料: 6617540953
# 第 1025 筆算術錯誤: -15872
# 第 1026 筆錯誤資料: 6617572697
# 第 1026 筆算術錯誤: 15872
# 第 1027 筆錯誤資料: 6617539929
# 第 1027 筆算術錯誤: -16896
# 第 1028 筆錯誤資料: 6617590105
# 第 1028 筆算術錯誤: 33280
# 第 1029 筆錯誤資料: 6617524569
# 第 1029 筆算術錯誤: -32256
# 第 1030 筆錯誤資料: 6617589081
# 第 1030 筆算術錯誤: 32256
# 第 1031 筆錯誤資料: 6617523545
# 第 1031 筆算術錯誤: -33280
# 第 1032 筆錯誤資料: 6617622873
# 第 1032 筆算術錯誤: 66048
# 第 1033 筆錯誤資料: 6617491801
# 第 1033 筆算術錯誤: -65024
# 第 1034 筆錯誤資料: 6617621849
# 第 1034 筆算術錯誤: 65024
# 第 1035 筆錯誤資料: 6617490777
# 第 1035 筆算術錯誤: -66048
# 第 1036 筆錯誤資料: 6617688409
# 第 1036 筆算術錯誤: 131584
# 第 1037 筆錯誤資料: 6617426265
# 第 1037 筆算術錯誤: -130560
# 第 1038 筆錯誤資料: 6617687385
# 第 1038 筆算術錯誤: 130560
# 第 1039 筆錯誤資料: 6617425241
# 第 1039 筆算術錯誤: -131584
# 第 1040 筆錯誤資料: 6617819481
# 第 1040 筆算術錯誤: 262656
# 第 1041 筆錯誤資料: 6617295193
# 第 1041 筆算術錯誤: -261632
# 第 1042 筆錯誤資料: 6617818457
# 第 1042 筆算術錯誤: 261632
# 第 1043 筆錯誤資料: 6617294169
# 第 1043 筆算術錯誤: -262656
# 第 1044 筆錯誤資料: 6618081625
# 第 1044 筆算術錯誤: 524800
# 第 1045 筆錯誤資料: 6617033049
# 第 1045 筆算術錯誤: -523776
# 第 1046 筆錯誤資料: 6618080601
# 第 1046 筆算術錯誤: 523776
# 第 1047 筆錯誤資料: 6617032025
# 第 1047 筆算術錯誤: -524800
# 第 1048 筆錯誤資料: 6618605913
# 第 1048 筆算術錯誤: 1049088
# 第 1049 筆錯誤資料: 6616508761
# 第 1049 筆算術錯誤: -1048064
# 第 1050 筆錯誤資料: 6618604889
# 第 1050 筆算術錯誤: 1048064
# 第 1051 筆錯誤資料: 6616507737
# 第 1051 筆算術錯誤: -1049088
# 第 1052 筆錯誤資料: 6619654489
# 第 1052 筆算術錯誤: 2097664
# 第 1053 筆錯誤資料: 6615460185
# 第 1053 筆算術錯誤: -2096640
# 第 1054 筆錯誤資料: 6619653465
# 第 1054 筆算術錯誤: 2096640
# 第 1055 筆錯誤資料: 6615459161
# 第 1055 筆算術錯誤: -2097664
# 第 1056 筆錯誤資料: 6621751641
# 第 1056 筆算術錯誤: 4194816
# 第 1057 筆錯誤資料: 6613363033
# 第 1057 筆算術錯誤: -4193792
# 第 1058 筆錯誤資料: 6621750617
# 第 1058 筆算術錯誤: 4193792
# 第 1059 筆錯誤資料: 6613362009
# 第 1059 筆算術錯誤: -4194816
# 第 1060 筆錯誤資料: 6625945945
# 第 1060 筆算術錯誤: 8389120
# 第 1061 筆錯誤資料: 6609168729
# 第 1061 筆算術錯誤: -8388096
# 第 1062 筆錯誤資料: 6625944921
# 第 1062 筆算術錯誤: 8388096
# 第 1063 筆錯誤資料: 6609167705
# 第 1063 筆算術錯誤: -8389120
# 第 1064 筆錯誤資料: 6634334553
# 第 1064 筆算術錯誤: 16777728
# 第 1065 筆錯誤資料: 6600780121
# 第 1065 筆算術錯誤: -16776704
# 第 1066 筆錯誤資料: 6634333529
# 第 1066 筆算術錯誤: 16776704
# 第 1067 筆錯誤資料: 6600779097
# 第 1067 筆算術錯誤: -16777728
# 第 1068 筆錯誤資料: 6651111769
# 第 1068 筆算術錯誤: 33554944
# 第 1069 筆錯誤資料: 6584002905
# 第 1069 筆算術錯誤: -33553920
# 第 1070 筆錯誤資料: 6651110745
# 第 1070 筆算術錯誤: 33553920
# 第 1071 筆錯誤資料: 6584001881
# 第 1071 筆算術錯誤: -33554944
# 第 1072 筆錯誤資料: 6684666201
# 第 1072 筆算術錯誤: 67109376
# 第 1073 筆錯誤資料: 6550448473
# 第 1073 筆算術錯誤: -67108352
# 第 1074 筆錯誤資料: 6684665177
# 第 1074 筆算術錯誤: 67108352
# 第 1075 筆錯誤資料: 6550447449
# 第 1075 筆算術錯誤: -67109376
# 第 1076 筆錯誤資料: 6751775065
# 第 1076 筆算術錯誤: 134218240
# 第 1077 筆錯誤資料: 6483339609
# 第 1077 筆算術錯誤: -134217216
# ...
# 第 2038 筆錯誤資料: 7087318873
# 第 2038 筆算術錯誤: 469762048
# 第 2039 筆錯誤資料: 6013577049
# 第 2039 筆算術錯誤: -603979776
# 第 2040 筆錯誤資料: 7758407513
# 第 2040 筆算術錯誤: 1140850688
# 第 2041 筆錯誤資料: 5610923865
# 第 2041 筆算術錯誤: -1006632960
# 第 2042 筆錯誤資料: 7624189785
# 第 2042 筆算術錯誤: 1006632960
# 第 2043 筆錯誤資料: 5476706137
# 第 2043 筆算術錯誤: -1140850688
# 第 2044 筆錯誤資料: 8832149337
# 第 2044 筆算術錯誤: 2214592512
# 第 2045 筆錯誤資料: 4537182041
# 第 2045 筆算術錯誤: -2080374784
# 第 2046 筆錯誤資料: 8697931609
# 第 2046 筆算術錯誤: 2080374784
# 第 2047 筆錯誤資料: 4402964313
# 第 2047 筆算術錯誤: -2214592512
# 第 2048 筆錯誤資料: 10979632985
# 第 2048 筆算術錯誤: 4362076160
# 第 2049 筆錯誤資料: 2389698393
# 第 2049 筆算術錯誤: -4227858432
# 第 2050 筆錯誤資料: 10845415257
# 第 2050 筆算術錯誤: 4227858432
# 第 2051 筆錯誤資料: 2255480665
# 第 2051 筆算術錯誤: -4362076160
# 第 2052 筆錯誤資料: 7020210009
# 第 2052 筆算術錯誤: 402653184
# 第 2053 筆錯誤資料: 6483339097
# 第 2053 筆算術錯誤: -134217728
# 第 2054 筆錯誤資料: 6751774553
# 第 2054 筆算術錯誤: 134217728
# 第 2055 筆錯誤資料: 6214903641
# 第 2055 筆算術錯誤: -402653184
# 第 2056 筆錯誤資料: 7288645465
# 第 2056 筆算術錯誤: 671088640
# 第 2057 筆錯誤資料: 6214903641
# 第 2057 筆算術錯誤: -402653184
# 第 2058 筆錯誤資料: 7020210009
# 第 2058 筆算術錯誤: 402653184
# 第 2059 筆錯誤資料: 5946468185
# 第 2059 筆算術錯誤: -671088640
# 第 2060 筆錯誤資料: 7825516377
# 第 2060 筆算術錯誤: 1207959552
# 第 2061 筆錯誤資料: 5678032729
# 第 2061 筆算術錯誤: -939524096
# 第 2062 筆錯誤資料: 7557080921
# 第 2062 筆算術錯誤: 939524096
# 第 2063 筆錯誤資料: 5409597273
# 第 2063 筆算術錯誤: -1207959552
# 第 2064 筆錯誤資料: 8899258201
# 第 2064 筆算術錯誤: 2281701376
# 第 2065 筆錯誤資料: 4604290905
# 第 2065 筆算術錯誤: -2013265920
# 第 2066 筆錯誤資料: 8630822745
# 第 2066 筆算術錯誤: 2013265920
# 第 2067 筆錯誤資料: 4335855449
# 第 2067 筆算術錯誤: -2281701376
# 第 2068 筆錯誤資料: 11046741849
# 第 2068 筆算術錯誤: 4429185024
# 第 2069 筆錯誤資料: 2456807257
# 第 2069 筆算術錯誤: -4160749568
# 第 2070 筆錯誤資料: 10778306393
# 第 2070 筆算術錯誤: 4160749568
# 第 2071 筆錯誤資料: 2188371801
# 第 2071 筆算術錯誤: -4429185024
# 第 2072 筆錯誤資料: 7422863193
# 第 2072 筆算術錯誤: 805306368
# 第 2073 筆錯誤資料: 6349121369
# 第 2073 筆算術錯誤: -268435456
# 第 2074 筆錯誤資料: 6885992281
# 第 2074 筆算術錯誤: 268435456
# 第 2075 筆錯誤資料: 5812250457
# 第 2075 筆算術錯誤: -805306368
# 第 2076 筆錯誤資料: 7959734105
# 第 2076 筆算術錯誤: 1342177280
# 第 2077 筆錯誤資料: 5812250457
# 第 2077 筆算術錯誤: -805306368
# 第 2078 筆錯誤資料: 7422863193
# 第 2078 筆算術錯誤: 805306368
# 第 2079 筆錯誤資料: 5275379545
# 第 2079 筆算術錯誤: -1342177280
# 第 2080 筆錯誤資料: 9033475929
# 第 2080 筆算術錯誤: 2415919104
# 第 2081 筆錯誤資料: 4738508633
# 第 2081 筆算術錯誤: -1879048192
# 第 2082 筆錯誤資料: 8496605017
# 第 2082 筆算術錯誤: 1879048192
# 第 2083 筆錯誤資料: 4201637721
# 第 2083 筆算術錯誤: -2415919104
# 第 2084 筆錯誤資料: 11180959577
# 第 2084 筆算術錯誤: 4563402752
# 第 2085 筆錯誤資料: 2591024985
# 第 2085 筆算術錯誤: -4026531840
# 第 2086 筆錯誤資料: 10644088665
# 第 2086 筆算術錯誤: 4026531840
# 第 2087 筆錯誤資料: 2054154073
# 第 2087 筆算術錯誤: -4563402752
# 第 2088 筆錯誤資料: 8228169561
# 第 2088 筆算術錯誤: 1610612736
# 第 2089 筆錯誤資料: 6080685913
# 第 2089 筆算術錯誤: -536870912
# 第 2090 筆錯誤資料: 7154427737
# 第 2090 筆算術錯誤: 536870912
# 第 2091 筆錯誤資料: 5006944089
# 第 2091 筆算術錯誤: -1610612736
# 第 2092 筆錯誤資料: 9301911385
# 第 2092 筆算術錯誤: 2684354560
# 第 2093 筆錯誤資料: 5006944089
# 第 2093 筆算術錯誤: -1610612736
# 第 2094 筆錯誤資料: 8228169561
# 第 2094 筆算術錯誤: 1610612736
# 第 2095 筆錯誤資料: 3933202265
# 第 2095 筆算術錯誤: -2684354560
# 第 2096 筆錯誤資料: 11449395033
# 第 2096 筆算術錯誤: 4831838208
# 第 2097 筆錯誤資料: 2859460441
# 第 2097 筆算術錯誤: -3758096384
# 第 2098 筆錯誤資料: 10375653209
# 第 2098 筆算術錯誤: 3758096384
# 第 2099 筆錯誤資料: 1785718617
# 第 2099 筆算術錯誤: -4831838208
# 第 2100 筆錯誤資料: 9838782297
# 第 2100 筆算術錯誤: 3221225472
# 第 2101 筆錯誤資料: 5543815001
# 第 2101 筆算術錯誤: -1073741824
# 第 2102 筆錯誤資料: 7691298649
# 第 2102 筆算術錯誤: 1073741824
# 第 2103 筆錯誤資料: 3396331353
# 第 2103 筆算術錯誤: -3221225472
# 第 2104 筆錯誤資料: 11986265945
# 第 2104 筆算術錯誤: 5368709120
# 第 2105 筆錯誤資料: 3396331353
# 第 2105 筆算術錯誤: -3221225472
# 第 2106 筆錯誤資料: 9838782297
# 第 2106 筆算術錯誤: 3221225472
# 第 2107 筆錯誤資料: 1248847705
# 第 2107 筆算術錯誤: -5368709120
# 第 2108 筆錯誤資料: 13060007769
# 第 2108 筆算術錯誤: 6442450944
# 第 2109 筆錯誤資料: 4470073177
# 第 2109 筆算術錯誤: -2147483648
# 第 2110 筆錯誤資料: 8765040473
# 第 2110 筆算術錯誤: 2147483648
# 第 2111 筆錯誤資料: 175105881
# 第 2111 筆算術錯誤: -6442450944
# 錯誤資料對AN取完模數:
#  [875, 1781, 2234, 5616, 996, 4997, 3842, 109, 1398, 5198, 787, 1737, 2212, 5605, 4146, 261, 1474, 5236, 806, 4902, 639, 1663, 2175, 2431, 2559, 2623, 2655, 2671, 2679, 2683, 2685, 2686, 2687, 2688, 2689, 2691, 2695, 2703, 2719, 2751, 2815, 2943, 3199, 3711, 4735, 472, 4568, 138, 3900, 5113, 1228, 6080, 3162, 3637, 4587, 176, 3976, 5265, 1532, 377, 4378, 6069, 3140, 3593, 4046, 1117, 2808, 498, 5654, 1921, 3210, 699, 2599, 3549, 4024, 1106, 5958, 2073, 3286, 737, 2618, 403, 2451, 3475, 3987, 4243, 4371, 4435, 4467, 4483, 4491, 4495, 4497, 4498, 4499, 4500, 4501, 4503, 4507, 4515, 4531, 4563, 4627, 4755, 5011, 5523, 236, 2284, 69, 1950, 5712, 614, 3040, 1581, 4974, 5449, 88, 1988, 5788, 766, 3344, 2189, 6190, 1570, 4952, 2023, 3714, 1404, 249, 2827, 4116, 1605, 3505, 4455, 4930, 2012, 553, 2979, 4192, 1643, 3524, 1309, 3357, 4381, 4893, 5149, 5277, 5341, 5373, 5389, 5397, 5401, 5403, 5404, 5405, 5406, 5407, 5409, 5413, 5421, 5437, 5469, 5533, 5661, 5917, 118, 1142, 3190, 975, 2856, 307, 1520, 3946, 2487, 5880, 44, 994, 2894, 383, 1672, 4250, 3095, 785, 2476, 4167, 1857, 702, 3280, 4569, 2058, 3958, 4908, 5383, 2465, 1006, 3432, 4645, 2096, 3977, 1762, 3810, 4834, 5346, 5602, 5730, 5794, 5826, 5842, 5850, 5854, 5856, 5857, 5858, 5859, 5860, 5862, 5866, 5874, 5890, 5922, 5986, 6114, 59, 571, 1595, 3643, 1428, 3309, 760, 1973, 4399, 2940, 22, 497, 1447, 3347, 836, 2125, 4703, 3548, 1238, 5239, 4084, 351, 1640, 5440, 1029, 1979, 2454, 5847, 4388, 503, 1716, 5478, 1048, 5144, 881, 1905, 2417, 2673, 2801, 2865, 2897, 2913, 2921, 2925, 2927, 2928, 2929, 2930, 2931, 2933, 2937, 2945, 2961, 2993, 3057, 3185, 3441, 3953, 4977, 714, 4810, 380, 4142, 5355, 1470, 11, 3404, 3879, 4829, 418, 4218, 5507, 1774, 619, 5775, 2042, 3331, 820, 2720, 3670, 4145, 1227, 6079, 2194, 3407, 858, 2739, 524, 2572, 3596, 4108, 4364, 4492, 4556, 4588, 4604, 4612, 4616, 4618, 4619, 4620, 4621, 4622, 4624, 4628, 4636, 4652, 4684, 4748, 4876, 5132, 5644, 357, 2405, 190, 2071, 5833, 735, 3161, 1702, 5095, 5570, 209, 2109, 5909, 887, 3465, 6043, 1021, 4821, 410, 1360, 1835, 5228, 3769, 6195, 1097, 4859, 429, 4525, 262, 1286, 1798, 2054, 2182, 2246, 2278, 2294, 2302, 2306, 2308, 2309, 2310, 2311, 2312, 2314, 2318, 2326, 2342, 2374, 2438, 2566, 2822, 3334, 4358, 95, 4191, 6072, 3523, 4736, 851, 5703, 2785, 3260, 4210, 6110, 3599, 4888, 6177, 3666, 5566, 205, 680, 4073, 2614, 5040, 6253, 3704, 5585, 3370, 5418, 131, 643, 899, 1027, 1091, 1123, 1139, 1147, 1151, 1153, 1154, 1155, 1156, 1157, 1159, 1163, 1171, 1187, 1219, 1283, 1411, 1667, 2179, 3203, 5251, 3036, 4917, 2368, 3581, 6007, 4548, 1630, 2105, 3055, 4955, 2444, 6244, 1833, 2783, 3258, 340, 5192, 1307, 2520, 6282, 1852, 5948, 1685, 2709, 3221, 3477, 3605, 3669, 3701, 3717, 3725, 3729, 3731, 3732, 3733, 3734, 3735, 3737, 3741, 3749, 3765, 3797, 3861, 3989, 4245, 4757, 5781, 1518, 5614, 1184, 4946, 6159, 2274, 815, 4208, 4683, 5633, 1222, 3122, 4072, 4547, 1629, 170, 2596, 3809, 1260, 3141, 926, 2974, 3998, 4510, 4766, 4894, 4958, 4990, 5006, 5014, 5018, 5020, 5021, 5022, 5023, 5024, 5026, 5030, 5038, 5054, 5086, 5150, 5278, 5534, 6046, 759, 2807, 592, 2473, 6235, 1137, 3563, 2104, 5497, 5972, 611, 1561, 2036, 5429, 3970, 85, 1298, 5060, 630, 4726, 463, 1487, 1999, 2255, 2383, 2447, 2479, 2495, 2503, 2507, 2509, 2510, 2511, 2512, 2513, 2515, 2519, 2527, 2543, 2575, 2639, 2767, 3023, 3535, 4559, 296, 4392, 6273, 3724, 4937, 1052, 5904, 2986, 3461, 3936, 1018, 5870, 1985, 3198, 649, 2530, 315, 2363, 3387, 3899, 4155, 4283, 4347, 4379, 4395, 4403, 4407, 4409, 4410, 4411, 4412, 4413, 4415, 4419, 4427, 4443, 4475, 4539, 4667, 4923, 5435, 148, 2196, 6292, 1862, 5624, 526, 2952, 1493, 4886, 1968, 509, 2935, 4148, 1599, 3480, 1265, 3313, 4337, 4849, 5105, 5233, 5297, 5329, 5345, 5353, 5357, 5359, 5360, 5361, 5362, 5363, 5365, 5369, 5377, 5393, 5425, 5489, 5617, 5873, 74, 1098, 3146, 931, 2812, 263, 1476, 3902, 2443, 984, 3410, 4623, 2074, 3955, 1740, 3788, 4812, 5324, 5580, 5708, 5772, 5804, 5820, 5828, 5832, 5834, 583 ...
# Barret reduction對錯誤資料取完模數:
#  [875, 1781, 2234, 5616, 996, 4997, 3842, 109, 1398, 5198, 787, 1737, 2212, 5605, 4146, 261, 1474, 5236, 806, 4902, 639, 1663, 2175, 2431, 2559, 2623, 2655, 2671, 2679, 2683, 2685, 2686, 2687, 2688, 2689, 2691, 2695, 2703, 2719, 2751, 2815, 2943, 3199, 3711, 4735, 472, 4568, 138, 3900, 5113, 1228, 6080, 3162, 3637, 4587, 176, 3976, 5265, 1532, 377, 4378, 6069, 3140, 3593, 4046, 1117, 2808, 498, 5654, 1921, 3210, 699, 2599, 3549, 4024, 1106, 5958, 2073, 3286, 737, 2618, 403, 2451, 3475, 3987, 4243, 4371, 4435, 4467, 4483, 4491, 4495, 4497, 4498, 4499, 4500, 4501, 4503, 4507, 4515, 4531, 4563, 4627, 4755, 5011, 5523, 236, 2284, 69, 1950, 5712, 614, 3040, 1581, 4974, 5449, 88, 1988, 5788, 766, 3344, 2189, 6190, 1570, 4952, 2023, 3714, 1404, 249, 2827, 4116, 1605, 3505, 4455, 4930, 2012, 553, 2979, 4192, 1643, 3524, 1309, 3357, 4381, 4893, 5149, 5277, 5341, 5373, 5389, 5397, 5401, 5403, 5404, 5405, 5406, 5407, 5409, 5413, 5421, 5437, 5469, 5533, 5661, 5917, 118, 1142, 3190, 975, 2856, 307, 1520, 3946, 2487, 5880, 44, 994, 2894, 383, 1672, 4250, 3095, 785, 2476, 4167, 1857, 702, 3280, 4569, 2058, 3958, 4908, 5383, 2465, 1006, 3432, 4645, 2096, 3977, 1762, 3810, 4834, 5346, 5602, 5730, 5794, 5826, 5842, 5850, 5854, 5856, 5857, 5858, 5859, 5860, 5862, 5866, 5874, 5890, 5922, 5986, 6114, 59, 571, 1595, 3643, 1428, 3309, 760, 1973, 4399, 2940, 22, 497, 1447, 3347, 836, 2125, 4703, 3548, 1238, 5239, 4084, 351, 1640, 5440, 1029, 1979, 2454, 5847, 4388, 503, 1716, 5478, 1048, 5144, 881, 1905, 2417, 2673, 2801, 2865, 2897, 2913, 2921, 2925, 2927, 2928, 2929, 2930, 2931, 2933, 2937, 2945, 2961, 2993, 3057, 3185, 3441, 3953, 4977, 714, 4810, 380, 4142, 5355, 1470, 11, 3404, 3879, 4829, 418, 4218, 5507, 1774, 619, 5775, 2042, 3331, 820, 2720, 3670, 4145, 1227, 6079, 2194, 3407, 858, 2739, 524, 2572, 3596, 4108, 4364, 4492, 4556, 4588, 4604, 4612, 4616, 4618, 4619, 4620, 4621, 4622, 4624, 4628, 4636, 4652, 4684, 4748, 4876, 5132, 5644, 357, 2405, 190, 2071, 5833, 735, 3161, 1702, 5095, 5570, 209, 2109, 5909, 887, 3465, 6043, 1021, 4821, 410, 1360, 1835, 5228, 3769, 6195, 1097, 4859, 429, 4525, 262, 1286, 1798, 2054, 2182, 2246, 2278, 2294, 2302, 2306, 2308, 2309, 2310, 2311, 2312, 2314, 2318, 2326, 2342, 2374, 2438, 2566, 2822, 3334, 4358, 95, 4191, 6072, 3523, 4736, 851, 5703, 2785, 3260, 4210, 6110, 3599, 4888, 6177, 3666, 5566, 205, 680, 4073, 2614, 5040, 6253, 3704, 5585, 3370, 5418, 131, 643, 899, 1027, 1091, 1123, 1139, 1147, 1151, 1153, 1154, 1155, 1156, 1157, 1159, 1163, 1171, 1187, 1219, 1283, 1411, 1667, 2179, 3203, 5251, 3036, 4917, 2368, 3581, 6007, 4548, 1630, 2105, 3055, 4955, 2444, 6244, 1833, 2783, 3258, 340, 5192, 1307, 2520, 6282, 1852, 5948, 1685, 2709, 3221, 3477, 3605, 3669, 3701, 3717, 3725, 3729, 3731, 3732, 3733, 3734, 3735, 3737, 3741, 3749, 3765, 3797, 3861, 3989, 4245, 4757, 5781, 1518, 5614, 1184, 4946, 6159, 2274, 815, 4208, 4683, 5633, 1222, 3122, 4072, 4547, 1629, 170, 2596, 3809, 1260, 3141, 926, 2974, 3998, 4510, 4766, 4894, 4958, 4990, 5006, 5014, 5018, 5020, 5021, 5022, 5023, 5024, 5026, 5030, 5038, 5054, 5086, 5150, 5278, 5534, 6046, 759, 2807, 592, 2473, 6235, 1137, 3563, 2104, 5497, 5972, 611, 1561, 2036, 5429, 3970, 85, 1298, 5060, 630, 4726, 463, 1487, 1999, 2255, 2383, 2447, 2479, 2495, 2503, 2507, 2509, 2510, 2511, 2512, 2513, 2515, 2519, 2527, 2543, 2575, 2639, 2767, 3023, 3535, 4559, 296, 4392, 6273, 3724, 4937, 1052, 5904, 2986, 3461, 3936, 1018, 5870, 1985, 3198, 649, 2530, 315, 2363, 3387, 3899, 4155, 4283, 4347, 4379, 4395, 4403, 4407, 4409, 4410, 4411, 4412, 4413, 4415, 4419, 4427, 4443, 4475, 4539, 4667, 4923, 5435, 148, 2196, 6292, 1862, 5624, 526, 2952, 1493, 4886, 1968, 509, 2935, 4148, 1599, 3480, 1265, 3313, 4337, 4849, 5105, 5233, 5297, 5329, 5345, 5353, 5357, 5359, 5360, 5361, 5362, 5363, 5365, 5369, 5377, 5393, 5425, 5489, 5617, 5873, 74, 1098, 3146, 931, 2812, 263, 1476, 3902, 2443, 984, 3410, 4623, 2074, 3955, 1740, 3788, 4812, 5324, 5580, 5708, 5772, 5804, 5820, 5828, 5832, 5834, 583 ...
# Barret reduction是否可以使用: True
# 所有餘數(一般mod函數)是否完全相異: True
# 所有餘數(Barret reduction)是否完全相異: True
# 所有的AWE:
#  [-6442450944, -5368709120, -4831838208, -4563402752, -4429185024, -4362076160, -4328521728, -4311744512, -4303355904, -4299161600, -4297064448, -4296015872, -4295491584, -4295229440, -4295098368, -4295032832, -4295000064, -4294983680, -4294975488, -4294971392, -4294969344, -4294968320, -4294967808, -4294967552, -4294967424, -4294967360, -4294967328, -4294967312, -4294967304, -4294967300, -4294967298, -4294967297, -4294967296, -4294967295, -4294967294, -4294967292, -4294967288, -4294967280, -4294967264, -4294967232, -4294967168, -4294967040, -4294966784, -4294966272, -4294965248, -4294963200, -4294959104, -4294950912, -4294934528, -4294901760, -4294836224, -4294705152, -4294443008, -4293918720, -4292870144, -4290772992, -4286578688, -4278190080, -4261412864, -4227858432, -4160749568, -4026531840, -3758096384, -3221225472, -2684354560, -2415919104, -2281701376, -2214592512, -2181038080, -2164260864, -2155872256, -2151677952, -2149580800, -2148532224, -2148007936, -2147745792, -2147614720, -2147549184, -2147516416, -2147500032, -2147491840, -2147487744, -2147485696, -2147484672, -2147484160, -2147483904, -2147483776, -2147483712, -2147483680, -2147483664, -2147483656, -2147483652, -2147483650, -2147483649, -2147483648, -2147483647, -2147483646, -2147483644, -2147483640, -2147483632, -2147483616, -2147483584, -2147483520, -2147483392, -2147483136, -2147482624, -2147481600, -2147479552, -2147475456, -2147467264, -2147450880, -2147418112, -2147352576, -2147221504, -2146959360, -2146435072, -2145386496, -2143289344, -2139095040, -2130706432, -2113929216, -2080374784, -2013265920, -1879048192, -1610612736, -1342177280, -1207959552, -1140850688, -1107296256, -1090519040, -1082130432, -1077936128, -1075838976, -1074790400, -1074266112, -1074003968, -1073872896, -1073807360, -1073774592, -1073758208, -1073750016, -1073745920, -1073743872, -1073742848, -1073742336, -1073742080, -1073741952, -1073741888, -1073741856, -1073741840, -1073741832, -1073741828, -1073741826, -1073741825, -1073741824, -1073741823, -1073741822, -1073741820, -1073741816, -1073741808, -1073741792, -1073741760, -1073741696, -1073741568, -1073741312, -1073740800, -1073739776, -1073737728, -1073733632, -1073725440, -1073709056, -1073676288, -1073610752, -1073479680, -1073217536, -1072693248, -1071644672, -1069547520, -1065353216, -1056964608, -1040187392, -1006632960, -939524096, -805306368, -671088640, -603979776, -570425344, -553648128, -545259520, -541065216, -538968064, -537919488, -537395200, -537133056, -537001984, -536936448, -536903680, -536887296, -536879104, -536875008, -536872960, -536871936, -536871424, -536871168, -536871040, -536870976, -536870944, -536870928, -536870920, -536870916, -536870914, -536870913, -536870912, -536870911, -536870910, -536870908, -536870904, -536870896, -536870880, -536870848, -536870784, -536870656, -536870400, -536869888, -536868864, -536866816, -536862720, -536854528, -536838144, -536805376, -536739840, -536608768, -536346624, -535822336, -534773760, -532676608, -528482304, -520093696, -503316480, -469762048, -402653184, -335544320, -301989888, -285212672, -276824064, -272629760, -270532608, -269484032, -268959744, -268697600, -268566528, -268500992, -268468224, -268451840, -268443648, -268439552, -268437504, -268436480, -268435968, -268435712, -268435584, -268435520, -268435488, -268435472, -268435464, -268435460, -268435458, -268435457, -268435456, -268435455, -268435454, -268435452, -268435448, -268435440, -268435424, -268435392, -268435328, -268435200, -268434944, -268434432, -268433408, -268431360, -268427264, -268419072, -268402688, -268369920, -268304384, -268173312, -267911168, -267386880, -266338304, -264241152, -260046848, -251658240, -234881024, -201326592, -167772160, -150994944, -142606336, -138412032, -136314880, -135266304, -134742016, -134479872, -134348800, -134283264, -134250496, -134234112, -134225920, -134221824, -134219776, -134218752, -134218240, -134217984, -134217856, -134217792, -134217760, -134217744,  ...
# 2052
# 輸入餘數 875, 對應算術錯誤: -6442450944
# 輸入餘數 1781, 對應算術錯誤: -5368709120
# 6617556825
# 6617556825
# 更正是否正確: True

# %% [markdown]
# #### DEC_ANcode (LUT):

# %%
DEC_A = 6311
Range_Max_number = 1023
DEC_Range_Max_number = 1023 * DEC_A
DEC_A_bits = math.floor(math.log2(DEC_Range_Max_number)) + 1
bits = math.floor(math.log2(Range_Max_number)) + 1      
print(bits)
print(DEC_A_bits)
# Out:
# 10
# 23

# %%
def simulate_adder_noise(A, B, width, sigma, threshold=0.22):
    carry_in = 0
    result_bits = []

    for i in range(width):
        a_bit = (A >> i) & 1
        b_bit = (B >> i) & 1

        # XOR(a, b)
        XOR_AB = a_bit ^ b_bit
        if abs(np.random.normal(0, sigma)) > threshold:
            XOR_AB ^= 1

        # sum = XOR_AB ^ carry_in
        sum_out = XOR_AB ^ carry_in
        if abs(np.random.normal(0, sigma)) > threshold:
            sum_out ^= 1

        # AND(a, b)
        AND_AB = a_bit & b_bit
        if abs(np.random.normal(0, sigma)) > threshold:
            AND_AB ^= 1

        # AND(XOR_AB, carry_in)
        AND_Cin = XOR_AB & carry_in
        if abs(np.random.normal(0, sigma)) > threshold:
            AND_Cin ^= 1

        # OR(AND_AB, AND_Cin)
        carry_out = AND_AB | AND_Cin
        if abs(np.random.normal(0, sigma)) > threshold:
            carry_out ^= 1

        result_bits.append(sum_out)
        carry_in = carry_out

    result_bits.append(carry_in)

    final_result = 0
    for i, bit in enumerate(result_bits):
        final_result |= (bit << i)

    return final_result

def simulate_array_multiplier_noise(A, B, sigma, threshold=0.22):
    """
    模擬具雜訊的 Array Multiplier（Shift-Add 實作 + 加上 AND 雜訊）
    - A, B: 18-bit 整數
    - sigma: 高斯白雜訊標準差
    - threshold: 閘門輸出被翻轉的雜訊門檻
    回傳值: 加上雜訊後的乘積
    """
    product = 0
    
    for i in range(bits):               # 對 B 的每一個位元 i
        partial = 0                     # 初始化此層的 partial product
        b_bit = (B >> i) & 1            # 搬到外層，B[i] 固定，只算一次
        
        for j in range(DEC_A_bits):           # 對 A 的每個位元 j
            a_bit = (A >> j) & 1
            
            # AND gate 模擬部分積：pp[i][j] = A[j] & B[i]
            AND_result = a_bit & b_bit
            
            # 加入雜訊 (noise)
            noise_AND = np.random.normal(0, sigma)
            if abs(noise_AND) > threshold:
                AND_result ^= 1  # 翻轉此位元
            
            # 將 AND_result 放到對應的位移上（i + j）
            partial |= (AND_result << (i + j))
        
        # 將此層 partial product 累加進總乘積
        product = simulate_adder_noise(product, partial, width=(bits + DEC_A_bits), sigma=sigma, threshold=threshold)
    
    return product

def noise_simulation(trials=1000, sigma=0.22, threshold=0.22):                   
        
    DEC_error_count = 0
    for _ in range(trials):
        A = random.randint(0, Range_Max_number)
        B = random.randint(0, Range_Max_number)
        correct_result = A * B
        DEC_AN_A = A * DEC_A
        DEC_AN_B = B
        result_withA = simulate_array_multiplier_noise(DEC_AN_A, DEC_AN_B, sigma, threshold)
        result_dividebyA = result_withA // DEC_A
        if result_dividebyA != correct_result:
            ### r = result_withA % DEC_A
            ### q = result_withA // DEC_A
            r,q = Barret_q_6311(result_withA)
            RAW_DATA = int(result_withA) - int(remainder_to_AWE[r])
            corrected_r,corrected_value = Barret_q_6311(RAW_DATA)
            ### corrected_value =  RAW_DATA % DEC_A
            if corrected_value != correct_result:
                DEC_error_count += 1
                
    return DEC_error_count / trials

if __name__ == "__main__":
    trials = 100000                              
    EbNodB_range = range(16, 24)
    threshold = 0.22
    DEC_AN_list = []

    for EbNodB in EbNodB_range:
        EbNo = 10.0**(EbNodB / 10.0)
        noise_std = 1 / sqrt(2 * EbNo)
        DEC_err_rate = noise_simulation(trials=trials, sigma=noise_std, threshold=threshold)
        DEC_AN_list.append(DEC_err_rate)
        print(f"SNR={EbNodB} dB, Noise Std={noise_std:.5f}, Error Rate={DEC_err_rate:.5f}")
# Out:
# SNR=16 dB, Noise Std=0.11207, Error Rate=1.00000
# SNR=17 dB, Noise Std=0.09988, Error Rate=1.00000
# SNR=18 dB, Noise Std=0.08902, Error Rate=0.99999
# SNR=19 dB, Noise Std=0.07934, Error Rate=0.99107
# SNR=20 dB, Noise Std=0.07071, Error Rate=0.59564
# SNR=21 dB, Noise Std=0.06302, Error Rate=0.05015
# SNR=22 dB, Noise Std=0.05617, Error Rate=0.00088
# SNR=23 dB, Noise Std=0.05006, Error Rate=0.00003

# %%
import matplotlib.pyplot as plt

SEC_BLER = plt.plot( EbNodB_range, SEC_AN_list,marker='o',linestyle='-.',color='#DC143C',markersize=4,label="SEC_BLER(A=59)")
DEC_BLER = plt.plot( EbNodB_range, DEC_AN_list,marker='D', linestyle='--',color='#0000FF',markersize=4,label="DEC_BLER(A=6311)")
Uncode_BLER=plt.plot( EbNodB_range, uncode_list,color='#008000',marker='v', linestyle='-',markersize=6,label="Uncode BLER")


plt.legend()
plt.axis([16, 24 , 1e-5, 1])
plt.xscale('linear')
plt.yscale('log')
plt.xlabel('EbNo(dB)')
plt.ylabel('BLER')
plt.grid(True)
plt.title('Multiplier in 10-bits: SEC v.s. DEC v.s Uncode')
plt.savefig("Multiplier in 10bits SEC vs DEC vs Uncode(23dB)")
plt.show()
